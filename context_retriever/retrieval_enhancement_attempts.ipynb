# %%
import sys
import os
script_dir = os.getcwd()
root_dir = os.path.join(os.path.dirname(os.path.abspath(script_dir)))
sys.path.append(os.path.join(os.path.dirname(os.path.abspath(script_dir))))

import json
import pandas as pd
import numpy as np
from utils.io import load_object, save_object
from utils.evaluation import calc_eval_metrics
import ast
from collections import Counter
import matplotlib.pyplot as plt
import seaborn as sns
import colorcet as cc
from statsmodels.stats.multitest import multipletests
import scispacy
import spacy
from transformers import AutoTokenizer, AutoModelForTokenClassification, AutoModel
import torch

# %%
test_ind = split_ranges(len(_CONTEXT), 10, 20)
for i, e in enumerate(_CONTEXT):
    if i in test_ind:
        print(f"======={i}=======")
        print(e)
        print(extract_entities(e, model, tokenizer))
# Out:
# =======4=======
# If a patient with advanced or metastatic invasive breast carcinoma cancer has pr positive, her2-negative, one recommended therapy is anastrozole + abemaciclib. therapy type: hormone therapy + targeted therapy. therapy strategy: aromatase inhibition + cdk4/6 inhibition. indication: verzenio is a kinase inhibitor indicated in combination with an aromatase inhibitor as initial endocrine-based therapy for the treatment of adult patients with hormone receptor (hr)-positive, human epidermal growth factor receptor 2 (her2)-negative advanced or metastatic breast cancer. approval url: https://www.accessdata.fda.gov/drugsatfda_docs/label/2023/208716s010s011lbl.pdf
# {'cancer_type': ['breast carcinoma cancer', 'breast cancer'], 'biomarker': ['pr', 'her2', 'aromatase', 'cdk4', None, 'aromatase', 'hormone receptor', 'hr', 'human epidermal growth factor receptor 2', 'her2']}
# =======15=======
# If a patient with metastatic castration-resistant prostate adenocarcinoma cancer has bard1 oncogenic variants, one recommended therapy is prednisone + niraparib + abiraterone acetate. therapy type: chemotherapy + targeted therapy + hormone therapy. therapy strategy: corticosteroid + parp inhibition + antiandrogen. indication: akeega is a combination of niraparib, a poly (adp-ribose) polymerase (parp) inhibitor, and abiraterone acetate, a cyp17 inhibitor indicated with prednisone for the treatment of adult patients with deleterious or suspected deleterious brca-mutated (brcam) metastatic castration-resistant prostate cancer (mcrpc). select patients for therapy based on an fda-approved test for akeega. approval url: https://www.accessdata.fda.gov/drugsatfda_docs/label/2023/216793s000lbl.pdf
# {'cancer_type': ['castration'], 'biomarker': ['bard1', 'parp', 'poly (adp-ribose) polymerase', 'parp', 'cyp17', 'brca', 'brcam', 'mcrpc']}
# =======97=======
# If a patient with melanoma cancer has braf p.v600k, one recommended therapy is trametinib + dabrafenib. therapy type: targeted therapy + targeted therapy. therapy strategy: mek inhibition + b-raf inhibition. indication: tafinlar is indicated, in combination with trametinib, for the adjuvant treatment of patients with melanoma with braf v600e or v600k mutations, as detected by an fda-approved test, and involvement of lymph node(s), following complete resection. approval url: https://www.accessdata.fda.gov/drugsatfda_docs/label/2024/202806s030lbl.pdf
# {'cancer_type': ['melanoma cancer', 'melanoma'], 'biomarker': ['braf', 'v600k', 'mek', 'b-raf', 'braf', 'v600e', 'v600k']}
# =======101=======
# If a patient with unresectable or metastatic any solid tumor cancer has braf p.v600e, one recommended therapy is trametinib + dabrafenib. therapy type: targeted therapy + targeted therapy. therapy strategy: mek inhibition + b-raf inhibition. indication: tafinlar is indicated, in combination with trametinib, for the treatment of adult and pediatric patients 1 year of age and older with unresectable or metastatic solid tumors with braf v600e mutation who have progressed following prior treatment and have no satisfactory alternative treatment options. this indication is approved under accelerated approval based on overall response rate (orr) and duration of response (dor). continued approval for this indication may be contingent upon verification and description of clinical benefit in a confirmatory trial(s). approval url: https://www.accessdata.fda.gov/drugsatfda_docs/label/2024/202806s030lbl.pdf
# {'cancer_type': ['solid tumor cancer', 'solid tumors'], 'biomarker': ['braf', 'mek', 'b-raf', 'braf v600e']}
# =======148=======
# If a patient with invasive breast carcinoma cancer has her2-negative, er positive, one recommended therapy is exemestane + everolimus. therapy type: hormone therapy + targeted therapy. therapy strategy: aromatase inhibition + pi3k/akt/mtor inhibition. indication: afinitor is a kinase inhibitor indicated for the treatment of postmenopausal women with advanced hormone receptor-positive, her2 negative breast cancer in combination with exemestane after failure of treatment with letrozole or anastrozole. approval url: https://www.accessdata.fda.gov/drugsatfda_docs/label/2022/203985s023,022334s051lbl.pdf
# {'cancer_type': ['invasive', 'breast carcinoma cancer', 'breast cancer'], 'biomarker': ['her2', 'er', 'aromatase', 'pi3k', 'akt', 'mtor', 'hormone', 'her2']}
# =======159=======
# If a patient with advanced or metastatic invasive breast carcinoma cancer has pr positive, her2-negative, er positive, one recommended therapy is fulvestrant + ribociclib. therapy type: hormone therapy + targeted therapy. therapy strategy: estrogen receptor inhibition + cdk4/6 inhibition. indication: faslodex is an estrogen receptor antagonist indicated for the treatment of hr-positive, her2-negative advanced or metastatic breast cancer in postmenopausal women in combination with ribociclib, as initial endocrine based therapy or following disease progression on endocrine therapy. approval url: https://www.accessdata.fda.gov/drugsatfda_docs/label/2021/021344s044lbl.pdf
# {'cancer_type': ['breast carcinoma cancer', 'breast cancer'], 'biomarker': ['pr', 'her2', 'er', 'estrogen receptor', 'cdk4', None, 'estrogen receptor', 'hr', 'her2']}
# =======207=======
# If a patient with acute myeloid leukemia cancer has idh1 p.r132l, one recommended therapy is ivosidenib + azacitidine. therapy type: targeted therapy + chemotherapy. therapy strategy: idh1 inhibition + hypomethylating agent chemotherapy. indication: tibsovo is an isocitrate dehydrogenase-1 (idh1) inhibitor indicated for patients with a susceptible idh1 mutation as detected by an fda-approved test with in combination with azacitidine or as monotherapy for the treatment of newly diagnosed aml in adults 75 years or older, or who have comorbidities that preclude use of intensive induction chemotherapy. approval url: https://www.accessdata.fda.gov/drugsatfda_docs/label/2023/211192s011lbl.pdf
# {'cancer_type': ['acute myeloid leukemia cancer'], 'biomarker': ['idh1', 'idh1', 'isocitrate dehydrogenase-1', 'idh1', 'idh1']}
# =======209=======
# If a patient with relapsed or refractory acute myeloid leukemia cancer has idh1 p.r132c, one recommended therapy is ivosidenib. therapy type: targeted therapy. therapy strategy: idh1 inhibition. indication: tibsovo is an isocitrate dehydrogenase-1 (idh1) inhibitor indicated for patients with a susceptible idh1 mutation as detected by an fda-approved test with for the treatment of adult patients with relapsed or refractory aml. approval url: https://www.accessdata.fda.gov/drugsatfda_docs/label/2023/211192s011lbl.pdf
# {'cancer_type': ['acute myeloid leukemia cancer'], 'biomarker': ['idh1', 'idh1', 'isocitrate dehydrogenase-1', 'idh1', 'idh1']}
# =======265=======
# If a patient with advanced ovarian epithelial tumor cancer has brca2 pathogenic variants, one recommended therapy is olaparib. therapy type: targeted therapy. therapy strategy: parp inhibition. indication: lynparza is a poly (adp-ribose) polymerase (parp) inhibitor indicated for the maintenance treatment of adult patients with deleterious or suspected deleterious germline or somatic brca-mutated advanced epithelial ovarian, fallopian tube or primary peritoneal cancer who are in complete or partial response to first-line platinum-based chemotherapy. select patients for therapy based on an fda-approved companion diagnostic for lynparza. approval url: https://www.accessdata.fda.gov/drugsatfda_docs/label/2023/208558s028lbl.pdf
# {'cancer_type': ['ovarian epithelial tumor cancer', 'epithelial ovarian', 'primary', 'peritoneal cancer'], 'biomarker': ['brca2', 'parp', 'poly (adp-ribose) polymerase', 'parp', 'brca', 'fda']}
# =======315=======
# If a patient with metastatic castration-resistant prostate adenocarcinoma cancer has bard1 oncogenic variants, one recommended therapy is olaparib. therapy type: targeted therapy. therapy strategy: parp inhibition. indication: lynparza is a poly (adp-ribose) polymerase (parp) inhibitor indicated for the treatment of adult patients with deleterious or suspected deleterious germline or somatic homologous recombination repair (hrr) gene-mutated metastatic castration-resistant prostate cancer (mcrpc) who have progressed following prior treatment with enzalutamide or abiraterone. select patients for therapy based on an fda-approved companion diagnostic for lynparza. approval url: https://www.accessdata.fda.gov/drugsatfda_docs/label/2023/208558s028lbl.pdf
# {'cancer_type': [], 'biomarker': ['bard1', 'parp', 'poly (adp-ribose) polymerase', 'parp', 'hrr', 'mcrpc']}
# =======329=======
# If a patient with metastatic castration-resistant prostate adenocarcinoma cancer has rad51b oncogenic variants, one recommended therapy is talazoparib. therapy type: targeted therapy. therapy strategy: parp inhibition. indication: lynparza is a poly (adp-ribose) polymerase (parp) inhibitor indicated for the treatment of adult patients with deleterious or suspected deleterious germline or somatic homologous recombination repair (hrr) gene-mutated metastatic castration-resistant prostate cancer (mcrpc) who have progressed following prior treatment with enzalutamide or abiraterone. select patients for therapy based on an fda-approved companion diagnostic for lynparza. approval url: https://www.accessdata.fda.gov/drugsatfda_docs/label/2023/208558s028lbl.pdf
# {'cancer_type': [], 'biomarker': ['rad51b', 'parp', 'poly (adp-ribose) polymerase', 'parp', 'hrr', 'mcrpc']}
# =======337=======
# If a patient with metastatic castration-resistant prostate adenocarcinoma cancer has brca1 pathogenic variants, one recommended therapy is prednisolone + olaparib + abiraterone acetate. therapy type: chemotherapy + targeted therapy + hormone therapy. therapy strategy: corticosteroid + parp inhibition + antiandrogen. indication: lynparza is a poly (adp-ribose) polymerase (parp) inhibitor indicated in combination with abiraterone and prednisone or prednisolone for the treatment of adult patients with deleterious or suspected deleterious brca-mutated (brcam) metastatic castration-resistant prostate cancer (mcrpc). select patients for therapy based on an fda-approved companion diagnostic for lynparza. approval url: https://www.accessdata.fda.gov/drugsatfda_docs/label/2023/208558s028lbl.pdf
# {'cancer_type': ['prostate adenocarcinoma cancer'], 'biomarker': ['brca1', 'parp', 'poly (adp-ribose) polymerase', 'parp', 'brca', 'brcam']}
# =======418=======
# If a patient with early invasive breast carcinoma cancer has her2-positive, one recommended therapy is trastuzumab + doxorubicin + fluorouracil + paclitaxel + pertuzumab + cyclophosphamide. therapy type: targeted therapy + chemotherapy + chemotherapy + chemotherapy + targeted therapy + chemotherapy. therapy strategy: her2 inhibition + topoisomerase inhibition + thymidylate synthase inhibition + taxane-based chemotherapy + her2 inhibition + alkylating chemotherapy. indication: phesgo is a combination of pertuzumab and trastuzumab, her2/neu receptor antagonists, and hyaluronidase, an endoglycosidase, indicated for use in combination with chemotherapy as adjuvant treatment of patients with her2-positive early breast cancer at high risk of recurrence. approval url: https://www.accessdata.fda.gov/drugsatfda_docs/label/2020/761170s000lbl.pdf
# {'cancer_type': ['early breast cancer'], 'biomarker': ['her2', 'her2', 'topoisomerase', 'thymidylate synthase', 'her2', 'her2', 'neu receptor', 'hyaluronidase', 'her2']}
# =======420=======
# If a patient with early invasive breast carcinoma cancer has her2-positive, one recommended therapy is trastuzumab + paclitaxel + pertuzumab + epirubicin + cyclophosphamide. therapy type: targeted therapy + chemotherapy + targeted therapy + chemotherapy + chemotherapy. therapy strategy: her2 inhibition + taxane-based chemotherapy + her2 inhibition + topoisomerase inhibition + alkylating chemotherapy. indication: phesgo is a combination of pertuzumab and trastuzumab, her2/neu receptor antagonists, and hyaluronidase, an endoglycosidase, indicated for use in combination with chemotherapy as adjuvant treatment of patients with her2-positive early breast cancer at high risk of recurrence. approval url: https://www.accessdata.fda.gov/drugsatfda_docs/label/2020/761170s000lbl.pdf
# {'cancer_type': ['early breast cancer'], 'biomarker': ['her2', 'her2', 'her2', 'topoisomerase', 'her2', 'neu receptor', 'hyaluronidase', 'her2']}
# =======459=======
# If a patient with high-grade serous fallopian tube cancer cancer has brca1 oncogenic variants, one recommended therapy is rucaparib. therapy type: targeted therapy. therapy strategy: parp inhibition. indication: rubraca is a poly (adp-ribose) polymerase (parp) inhibitor indicated for the maintenance treatment of adult patients with a deleterious brca mutation (germline and/or somatic)- associated recurrent epithelial ovarian, fallopian tube, or primary peritoneal cancer who are in a complete or partial response to platinum-based chemotherapy. approval url: https://www.accessdata.fda.gov/drugsatfda_docs/label/2022/209115s013lbl.pdf
# {'cancer_type': ['high-grade serous fallopian tube cancer cancer', 'epithelial ovarian', 'primary', 'peritoneal cancer'], 'biomarker': ['brca1', 'parp', 'rubraca', 'poly (adp-ribose) polymerase', 'parp', 'brca']}
# =======520=======
# If a patient with metastatic castration-resistant prostate adenocarcinoma cancer has chek2 oncogenic variants, one recommended therapy is enzalutamide + talazoparib. therapy type: hormone therapy + targeted therapy. therapy strategy: antiandrogen + parp inhibition. indication: talzenna is a poly (adp-ribose) polymerase (parp) inhibitor indicated in combination with enzalutamide for the treatment of adult patients with hrr gene-mutated metastatic castration-resistant prostate cancer (mcrpc). approval url: https://www.accessdata.fda.gov/drugsatfda_docs/label/2024/211651s012lbl.pdf
# {'cancer_type': [], 'biomarker': ['chek2', 'parp', 'poly (adp-ribose) polymerase', 'parp', 'hrr', 'mcrpc']}
# =======546=======
# If a patient with high-grade serous fallopian tube cancer cancer has folr1 positive, one recommended therapy is mirvetuximab soravtansine. therapy type: chemotherapy. therapy strategy: folate receptor-alpha inhibition. indication: elahere is a folate receptor alpha (frα)-directed antibody and microtubule inhibitor conjugate indicated for the treatment of adult patients with fr-alpha positive, platinum-resistant epithelial ovarian, fallopian tube, or primary peritoneal cancer, who have received one to three prior systemic treatment regimens. select patients for therapy based on an fda-approved test. approval url: https://www.accessdata.fda.gov/drugsatfda_docs/label/2024/761310Origs005lbl.pdf
# {'cancer_type': ['high-grade serous fallopian tube cancer cancer', 'platinum', 'fallopian tube', 'primary', 'peritoneal cancer'], 'biomarker': ['folr1', 'folate receptor-alpha', 'folate receptor alpha', 'frα', 'microtubule', 'fr-alpha']}
# =======574=======
# If a patient with oligodendroglioma cancer has idh2 p.r172g, one recommended therapy is vorasidenib. therapy type: targeted therapy. therapy strategy: idh1/2 inhibition. indication: voranigo is an isocitrate dehydrogenase-1 (idh1) and isocitrate dehydrogenase-2 (idh2) inhibitor indicated for the treatment of adult and pediatric patients 12 years and older with grade 2 astrocytoma or oligodendroglioma with a susceptible idh1 or idh2 mutation following surgery including biopsy, sub-total resection, or gross total resection. approval url: https://www.accessdata.fda.gov/drugsatfda_docs/label/2024/218784s000lbl.pdf
# {'cancer_type': ['oligodendroglioma cancer', 'grade 2 astrocytoma', 'oligodendroglioma'], 'biomarker': ['idh2', 'idh1', None, 'isocitrate dehydrogenase-1', 'idh1', 'isocitrate dehydrogenase-2', 'idh2', 'idh1', 'idh2']}
# =======600=======
# If a patient with pancreatic adenocarcinoma cancer has v::nrg1, one recommended therapy is zenocutuzumab. therapy type: targeted therapy. therapy strategy: nrg1 inhibition. indication: bizengri is a bispecific her2- and her3-directed antibody indicated for the treatment of adults with advanced, unresectable or metastatic pancreatic adenocarcinoma harboring a neuregulin 1 (nrg1) gene fusion with disease progression on or after prior systemic therapy. this indication is approved under accelerated approval based on overall response rate and duration of response. continued approval for this indication may be contingent upon verification and description of clinical benefit in a confirmatory trial(s). approval url: https://www.accessdata.fda.gov/drugsatfda_docs/label/2024/761352s001lbl.pdf
# {'cancer_type': ['pancreatic adenocarcinoma cancer', 'pancreatic adenocarcinoma'], 'biomarker': ['nrg1', 'nrg1', 'her2', 'her3', 'neuregulin 1', 'nrg1']}
# =======614=======
# If a patient with early invasive breast carcinoma cancer has pr positive, her2-negative, one recommended therapy is abemaciclib + letrozole. therapy type: targeted therapy + hormone therapy. therapy strategy: cdk4/6 inhibition + aromatase inhibition. indication: verzenio is a kinase inhibitor indicated in combination with endocrine therapy (tamoxifen or an aromatase inhibitor) for the adjuvant treatment of adult patients with hormone receptor (hr)-positive, human epidermal growth factor receptor 2 (her2)-negative, node positive, early breast cancer at high risk of recurrence. approval url: https://www.accessdata.fda.gov/drugsatfda_docs/label/2023/208716s010s011lbl.pdf
# {'cancer_type': ['breast carcinoma cancer', 'breast cancer'], 'biomarker': ['pr', 'her2', 'cdk4 / 6', 'aromatase', 'aromatase', 'hormone receptor', 'hr', 'human epidermal growth factor receptor 2', 'her2']}

# %% [markdown]
# ### Load MOAlamanc data and synthetic queries

# %%
old_moalmanac_db=pd.read_csv(os.path.join(root_dir, 'data/moa_fda_queries_answers.csv'), index_col=0)
synthetic_prompt_groundtruth_dict=load_object(os.path.join(root_dir, 'data/synthetic_prompt_groundtruth_dict.pkl'))

# %% [markdown]
# ### Testing NER using scispacy on synthetic queries

# %%
# !pip install https://s3-us-west-2.amazonaws.com/ai2-s2-scispacy/releases/v0.5.4/en_ner_bionlp13cg_md-0.5.4.tar.gz
# !pip install https://s3-us-west-2.amazonaws.com/ai2-s2-scispacy/releases/v0.5.4/en_ner_bc5cdr_md-0.5.4.tar.gz
# !pip install https://s3-us-west-2.amazonaws.com/ai2-s2-scispacy/releases/v0.5.4/en_core_sci_scibert-0.5.4.tar.gz

# %%
bionlp13cg_nlp = spacy.load("en_ner_bionlp13cg_md")
bc5cdr_nlp = spacy.load("en_ner_bc5cdr_md")
# Out:
# /opt/conda/lib/python3.10/site-packages/spacy/language.py:2195: FutureWarning: Possible set union at position 6328
#   deserializers["tokenizer"] = lambda p: self.tokenizer.from_disk(  # type: ignore[union-attr]

# %%
spacy_ner_bionlp13cg_entities=[]
spacy_ner_bc5cdr_entities=[]
# spacy_ner_scibert_entities=[]

for i in range(len(synthetic_prompt_groundtruth_dict.keys())):
    
    text=list(synthetic_prompt_groundtruth_dict.keys())[i]
    
    doc=bionlp13cg_nlp(text)
    spacy_ner_bionlp13cg_entities.append(doc.ents)
    
    doc=bc5cdr_nlp(text)
    spacy_ner_bc5cdr_entities.append(doc.ents)

# %%
ner_entities = pd.DataFrame(
    {"synthetic_queries":synthetic_prompt_groundtruth_dict.keys(), 
     "spacy_ner_bionlp13cg_entities":spacy_ner_bionlp13cg_entities,
     "spacy_ner_bc5cdr_entities":spacy_ner_bc5cdr_entities,
     })

# %% [markdown]
# ### Load BioBERT finetuned for NER

# %% [markdown]
# Pre-trained Models (saved in `/mnt/disks/moa-llm/models`):
# - Ishan0612/biobert-ner-disease-ncbi (https://huggingface.co/Ishan0612/biobert-ner-disease-ncbi): extracts disease
# - judithrosell/BioNLP13CG_bioBERT_NER (https://huggingface.co/judithrosell/BioNLP13CG_bioBERT_NER): fine-tuned version of biobert v1.1
# - judithrosell/BioBERT_BioNLP13CG_NER_new

# %%
# load pre-trained BioBERT model for NER
model = AutoModelForTokenClassification.from_pretrained("judithrosell/BioBERT_BioNLP13CG_NER_new")
tokenizer = AutoTokenizer.from_pretrained("judithrosell/BioBERT_BioNLP13CG_NER_new")
id2label = model.config.id2label

# %% [markdown]
# ### Define BioBERT NER function

# %%
# function to predict entities using BioBERT
def ner_predict_entities(text, model, tokenizer):
    inputs = tokenizer(text, return_tensors="pt", truncation=True, padding=True)
    
    # predictions
    with torch.no_grad():
        outputs = model(**inputs)
        logits = outputs.logits
        predictions = torch.argmax(logits, axis=2)
    
    # convert predictions to labels 
    predicted_labels = [id2label[pred.item()] for pred in predictions[0]]
    
    # align predictions with original tokents
    tokens = tokenizer.convert_ids_to_tokens(inputs["input_ids"][0])
    
    # extract entities
    entities = []
    current_entity = None
    for token, label in zip(tokens, predicted_labels):
        # skip special tokents
        if token in [tokenizer.cls_token, tokenizer.sep_token, tokenizer.pad_token]:
            continue
        
        # handle subwords
        if token.startswith("##"):
            if current_entity:
                current_entity["text"] += token[2:] # remove '##' prefix
            continue
        if label.startswith("B-"):
            if current_entity:
                entities.append(current_entity)
            entity_type = label[2:]  # remove B- prefix
            current_entity = {"type": entity_type, "text": token}
        elif label.startswith("I-") and current_entity and current_entity["type"] == label[2:]:
            current_entity["text"] += " " + token
        elif label == "O":
            if current_entity:
                entities.append(current_entity)
                current_entity = None
                
    # last entity
    if current_entity:
        entities.append(current_entity)
    return entities

# %% [markdown]
# Testing on small samples

# %%
sample_text = list(synthetic_prompt_groundtruth_dict.keys())[0]
entities = ner_predict_entities(sample_text, model, tokenizer)
print(sample_text)
print(entities)
# Out:
# If a chronic myelogenous leukemia patient has a rearrangement in gene BCR and ABL1, and is chronic, accelerated, or blast phase, what would be the suggested lines of treatment?
# [{'type': 'Cancer', 'text': 'chronic myelogenous leukemia'}, {'type': 'Organism', 'text': 'patient'}, {'type': 'Gene_or_gene_product', 'text': 'BCR'}, {'type': 'Gene_or_gene_product', 'text': 'ABL1'}]

# %% [markdown]
# ## Rule-based retrieval based on matching key features

# %% [markdown]
# The goal is to retrieve and prerank relevant context chunks based on matching key features that are critical for treatment decision-making.
#
# The key features we will use are:
# - cancer type
# - biomarker

# %% [markdown]
# Below is the context db generated from the latest release of moalamanc database

# %%
moalmanac_new_draft = pd.read_csv(f"{root_dir}/data/latest_db/moalmanac-draft.dereferenced.unique.context_db.csv")
moalmanac_new_draft.head()
# Out:
#    statement_id      approval_status approval_org  \
# 0             0  Regulatory approval          fda
# 1             1  Regulatory approval          fda
# 2             2  Regulatory approval          fda
# 3             3  Regulatory approval          fda
# 4             4  Regulatory approval          fda
#
#                                          description  \
# 0  The U.S. Food and Drug Administration (FDA) gr...
# 1  The U.S. Food and Drug Administration (FDA) gr...
# 2  The U.S. Food and Drug Administration (FDA) gr...
# 3  The U.S. Food and Drug Administration (FDA) gr...
# 4  The U.S. Food and Drug Administration (FDA) gr...
#
#                                           indication  \
# 0  Verzenio is a kinase inhibitor indicated in co...
# 1  Verzenio is a kinase inhibitor indicated in co...
# 2  Verzenio is a kinase inhibitor indicated in co...
# 3  Verzenio is a kinase inhibitor indicated in co...
# 4  Verzenio is a kinase inhibitor indicated in co...
#
#                  cancer_type  \
# 0  Invasive Breast Carcinoma
# 1  Invasive Breast Carcinoma
# 2  Invasive Breast Carcinoma
# 3  Invasive Breast Carcinoma
# 4  Invasive Breast Carcinoma
#
#                                            biomarker  \
# 0     ER positive [present], HER2-negative [present]
# 1     HER2-negative [present], PR positive [present]
# 2  ER positive [present], HER2-negative [present]...
# 3     ER positive [present], HER2-negative [present]
# 4     HER2-negative [present], PR positive [present]
#
#                      therapy_drug     therapy_approach  \
# 0    ['Abemaciclib', 'Tamoxifen']  Combination therapy
# 1    ['Abemaciclib', 'Tamoxifen']  Combination therapy
# 2    ['Abemaciclib', 'Tamoxifen']  Combination therapy
# 3  ['Anastrozole', 'Abemaciclib']  Combination therapy
# 4  ['Anastrozole', 'Abemaciclib']  Combination therapy
#
#                                     therapy_strategy  \
# 0  ['CDK4/6 inhibition', 'Estrogen receptor inhib...
# 1  ['CDK4/6 inhibition', 'Estrogen receptor inhib...
# 2  ['CDK4/6 inhibition', 'Estrogen receptor inhib...
# 3      ['Aromatase inhibition', 'CDK4/6 inhibition']
# 4      ['Aromatase inhibition', 'CDK4/6 inhibition']
#
#                               therapy_type  \
# 0  ['Targeted therapy', 'Hormone therapy']
# 1  ['Targeted therapy', 'Hormone therapy']
# 2  ['Targeted therapy', 'Hormone therapy']
# 3  ['Hormone therapy', 'Targeted therapy']
# 4  ['Hormone therapy', 'Targeted therapy']
#
#                                         approval_url publication_date  \
# 0  https://www.accessdata.fda.gov/drugsatfda_docs...       2023-03-03
# 1  https://www.accessdata.fda.gov/drugsatfda_docs...       2023-03-03
# 2  https://www.accessdata.fda.gov/drugsatfda_docs...       2023-03-03
# 3  https://www.accessdata.fda.gov/drugsatfda_docs...       2023-03-03
# 4  https://www.accessdata.fda.gov/drugsatfda_docs...       2023-03-03
#
#                                              context
# 0  Approval status: Regulatory approval (fda)\nDe...
# 1  Approval status: Regulatory approval (fda)\nDe...
# 2  Approval status: Regulatory approval (fda)\nDe...
# 3  Approval status: Regulatory approval (fda)\nDe...
# 4  Approval status: Regulatory approval (fda)\nDe...

# %% [markdown]
# #### BioBERT NER extraction and standardization of moalmanac entities

# %% [markdown]
# Here, I'm going to:
# - extract cleaned gene symbols using BioBERT NER extraction
# - if nothing is extracted by BioBERT, fallback to the original biomarker (e.g., broad genomic markers like dMMR and MSI-H are not recognized by BioBERT)

# %%
import re

def clean_biomarker(text):
    txt = re.sub(r"\s*\[.*?\]", "", text).strip()
    txt = txt.strip().replace(' ', '').upper() #["v", "ALK"], ["PD - L1"], ["c-Met"]
    
    #ignore if it's too short (e.g. 1 character long)
    if len(txt) <= 1:
        return None
    return txt


def db_extract_entities(db, cancer_col='cancer_type', biomarker_col='biomarker'):
    entities_dict = {'cancer_type': [], 'biomarker': []}
    
    #append cancer type (pre-standardized)
    entities_dict['cancer_type'].append(db[cancer_col])
    
    #extract gene names using biobert 
    b_list = ner_predict_entities(db[biomarker_col], model, tokenizer)
    
    #if nothing's been extracted, append the original biomarker
    if not b_list:
        entities_dict['biomarker'].append(clean_biomarker(db[biomarker_col]))
    else:
        for b in b_list:
            #clean and standardize the extracted biomarker
            cleaned = clean_biomarker(b['text'])
            if cleaned is not None and cleaned not in entities_dict['biomarker']:
                entities_dict['biomarker'].append(cleaned)
                    
    return entities_dict


def db_standardize_entities(entities_dict): 
    entities_dict['cancer_type'] = [cancer.upper() for cancer in entities_dict['cancer_type']] #so that both cancer types and biomarkers are in upper case
    return entities_dict

# %%
#split ranges for testing on small batches
import random
import math

def split_ranges(max_int, num_ranges, samples=None):
    step = math.ceil(max_int / num_ranges)
    ranges = [(i*step+1, min((i+1)*step, max_int)) for i in range(num_ranges)]
    
    if samples is None:
        return ranges
    
    # split samples evenly across ranges
    n_per_range = samples // num_ranges
    remainder = samples % num_ranges
    
    result = []
    for i, r in enumerate(ranges):
        count = n_per_range + (1 if i < remainder else 0)
        result.extend(random.randint(r[0], r[1]) for _ in range(count))
    
    return result

test_idx_list = split_ranges(moalmanac_new_draft.shape[0], 10, 50)

# %% [markdown]
# Run on all moalmanac entities (old)

# %%
for idx, row in old_moalmanac_db.iterrows():
    entities_dict = db_extract_entities(row)
    old_moalmanac_db.at[idx, 'entities_dict'] = json.dumps(entities_dict)
    standardized_entities_dict = db_standardize_entities(entities_dict)
    old_moalmanac_db.at[idx, 'standardized_entities_dict'] = json.dumps(standardized_entities_dict)
    
    print(idx)
    print(row['cancer_type'])
    print(row['biomarker'])
    print(standardized_entities_dict)

# %% [markdown]
# Run on all moalmanac entities (new)

# %%
for idx, row in moalmanac_new_draft.iterrows():
    entities_dict = db_extract_entities(row)
    moalmanac_new_draft.at[idx, 'entities_dict'] = json.dumps(entities_dict)
    standardized_entities_dict = db_standardize_entities(entities_dict)
    moalmanac_new_draft.at[idx, 'standardized_entities_dict'] = json.dumps(standardized_entities_dict)
    
    print(idx)
    print(row['cancer_type'])
    print(row['biomarker'])
    print(standardized_entities_dict)
# Out:
# 0
# Invasive Breast Carcinoma
# ER positive [present], HER2-negative [present]
# {'cancer_type': ['INVASIVE BREAST CARCINOMA'], 'biomarker': ['ER', 'HER2']}
# 1
# Invasive Breast Carcinoma
# HER2-negative [present], PR positive [present]
# {'cancer_type': ['INVASIVE BREAST CARCINOMA'], 'biomarker': ['HER2', 'PR']}
# 2
# Invasive Breast Carcinoma
# ER positive [present], HER2-negative [present], PR positive [present]
# {'cancer_type': ['INVASIVE BREAST CARCINOMA'], 'biomarker': ['ER', 'HER2', 'PR']}
# 3
# Invasive Breast Carcinoma
# ER positive [present], HER2-negative [present]
# {'cancer_type': ['INVASIVE BREAST CARCINOMA'], 'biomarker': ['ER', 'HER2']}
# 4
# Invasive Breast Carcinoma
# HER2-negative [present], PR positive [present]
# {'cancer_type': ['INVASIVE BREAST CARCINOMA'], 'biomarker': ['HER2', 'PR']}
# 5
# Invasive Breast Carcinoma
# ER positive [present], HER2-negative [present], PR positive [present]
# {'cancer_type': ['INVASIVE BREAST CARCINOMA'], 'biomarker': ['ER', 'HER2', 'PR']}
# 6
# Invasive Breast Carcinoma
# ER positive [present], HER2-negative [present]
# {'cancer_type': ['INVASIVE BREAST CARCINOMA'], 'biomarker': ['ER', 'HER2']}
# 7
# Invasive Breast Carcinoma
# HER2-negative [present], PR positive [present]
# {'cancer_type': ['INVASIVE BREAST CARCINOMA'], 'biomarker': ['HER2', 'PR']}
# 8
# Invasive Breast Carcinoma
# ER positive [present], HER2-negative [present], PR positive [present]
# {'cancer_type': ['INVASIVE BREAST CARCINOMA'], 'biomarker': ['ER', 'HER2', 'PR']}
# 9
# Invasive Breast Carcinoma
# ER positive [present], HER2-negative [present]
# {'cancer_type': ['INVASIVE BREAST CARCINOMA'], 'biomarker': ['ER', 'HER2']}
# 10
# Invasive Breast Carcinoma
# HER2-negative [present], PR positive [present]
# {'cancer_type': ['INVASIVE BREAST CARCINOMA'], 'biomarker': ['HER2', 'PR']}
# 11
# Invasive Breast Carcinoma
# ER positive [present], HER2-negative [present], PR positive [present]
# {'cancer_type': ['INVASIVE BREAST CARCINOMA'], 'biomarker': ['ER', 'HER2', 'PR']}
# 12
# Invasive Breast Carcinoma
# ER positive [present], HER2-negative [present]
# {'cancer_type': ['INVASIVE BREAST CARCINOMA'], 'biomarker': ['ER', 'HER2']}
# 13
# Invasive Breast Carcinoma
# HER2-negative [present], PR positive [present]
# {'cancer_type': ['INVASIVE BREAST CARCINOMA'], 'biomarker': ['HER2', 'PR']}
# 14
# Invasive Breast Carcinoma
# ER positive [present], HER2-negative [present], PR positive [present]
# {'cancer_type': ['INVASIVE BREAST CARCINOMA'], 'biomarker': ['ER', 'HER2', 'PR']}
# 15
# Prostate Adenocarcinoma
# BARD1 oncogenic variants [present]
# {'cancer_type': ['PROSTATE ADENOCARCINOMA'], 'biomarker': ['BARD1']}
# 16
# Prostate Adenocarcinoma
# BRIP1 oncogenic variants [present]
# {'cancer_type': ['PROSTATE ADENOCARCINOMA'], 'biomarker': ['BRIP1']}
# 17
# Prostate Adenocarcinoma
# BRIP1 pathogenic variants [present]
# {'cancer_type': ['PROSTATE ADENOCARCINOMA'], 'biomarker': ['BRIP1']}
# 18
# Prostate Adenocarcinoma
# CDK12 pathogenic variants [present]
# {'cancer_type': ['PROSTATE ADENOCARCINOMA'], 'biomarker': ['CDK12']}
# 19
# Non-Small Cell Lung Cancer
# KRAS p.G12C [present]
# {'cancer_type': ['NON-SMALL CELL LUNG CANCER'], 'biomarker': ['KRAS']}
# 20
# Invasive Breast Carcinoma
# HER2-positive [present]
# {'cancer_type': ['INVASIVE BREAST CARCINOMA'], 'biomarker': ['HER2']}
# 21
# Non-Small Cell Lung Cancer
# EGFR somatic variants [present]
# {'cancer_type': ['NON-SMALL CELL LUNG CANCER'], 'biomarker': ['EGFR']}
# 22
# Non-Small Cell Lung Cancer
# v::ALK [present]
# {'cancer_type': ['NON-SMALL CELL LUNG CANCER'], 'biomarker': ['ALK']}
# 23
# Invasive Breast Carcinoma
# ER positive [present], HER2-negative [present], PIK3CA somatic variants [present]
# {'cancer_type': ['INVASIVE BREAST CARCINOMA'], 'biomarker': ['ER', 'HER2', 'PIK3CA']}
# 24
# Invasive Breast Carcinoma
# HER2-negative [present], PR positive [present], PIK3CA somatic variants [present]
# {'cancer_type': ['INVASIVE BREAST CARCINOMA'], 'biomarker': ['HER2', 'PR', 'PIK3CA']}
# 25
# Invasive Breast Carcinoma
# ER positive [present], HER2-negative [present], PR positive [present], PIK3CA somatic variants [present]
# {'cancer_type': ['INVASIVE BREAST CARCINOMA'], 'biomarker': ['ER', 'HER2', 'PR', 'PIK3CA']}
# 26
# Non-Small Cell Lung Cancer
# EGFR Exon 20 (Insertion) [present]
# {'cancer_type': ['NON-SMALL CELL LUNG CANCER'], 'biomarker': ['EGFR']}
# 27
# Non-Small Cell Lung Cancer
# EGFR Exon 20 (Insertion) [present]
# {'cancer_type': ['NON-SMALL CELL LUNG CANCER'], 'biomarker': ['EGFR']}
# 28
# APL with PML-RARA
# PML::RARA [present]
# {'cancer_type': ['APL WITH PML-RARA'], 'biomarker': ['PML', 'RARA']}
# 29
# Chronic Myelogenous Leukemia
# BCR::ABL1 [present]
# {'cancer_type': ['CHRONIC MYELOGENOUS LEUKEMIA'], 'biomarker': ['BCR', 'ABL1']}
# 30
# Chronic Myelogenous Leukemia
# BCR::ABL1 [present], ABL1 p.T315I [present]
# {'cancer_type': ['CHRONIC MYELOGENOUS LEUKEMIA'], 'biomarker': ['BCR', 'ABL1']}
# 31
# Non-Small Cell Lung Cancer
# PD-L1 >= 1% [present]
# {'cancer_type': ['NON-SMALL CELL LUNG CANCER'], 'biomarker': ['PD-L1']}
# 32
# Non-Small Cell Lung Cancer
# PD-L1 >= 50% [present]
# {'cancer_type': ['NON-SMALL CELL LUNG CANCER'], 'biomarker': ['PD-L1']}
# 33
# Non-Small Cell Lung Cancer
# PD-L1 >= 10% TIIC [present]
# {'cancer_type': ['NON-SMALL CELL LUNG CANCER'], 'biomarker': ['PD-L1', 'TIIC']}
# 34
# Non-Small Cell Lung Cancer
# Wild type ALK [present], Wild type EGFR [present]
# {'cancer_type': ['NON-SMALL CELL LUNG CANCER'], 'biomarker': ['ALK', 'EGFR']}
# 35
# Non-Small Cell Lung Cancer
# Wild type ALK [present], Wild type EGFR [present]
# {'cancer_type': ['NON-SMALL CELL LUNG CANCER'], 'biomarker': ['ALK', 'EGFR']}
# 36
# Non-Small Cell Lung Cancer
# EGFR somatic variants [present]
# {'cancer_type': ['NON-SMALL CELL LUNG CANCER'], 'biomarker': ['EGFR']}
# 37
# Non-Small Cell Lung Cancer
# v::ALK [present]
# {'cancer_type': ['NON-SMALL CELL LUNG CANCER'], 'biomarker': ['ALK']}
# 38
# Melanoma
# BRAF p.V600E [present]
# {'cancer_type': ['MELANOMA'], 'biomarker': ['BRAF']}
# 39
# Melanoma
# BRAF p.V600K [present]
# {'cancer_type': ['MELANOMA'], 'biomarker': ['BRAF']}
# 40
# Gastrointestinal Stromal Tumor
# PDGFRA p.D842V [present]
# {'cancer_type': ['GASTROINTESTINAL STROMAL TUMOR'], 'biomarker': ['PDGFRA']}
# 41
# Melanoma
# BRAF p.V600E [present]
# {'cancer_type': ['MELANOMA'], 'biomarker': ['BRAF']}
# 42
# Melanoma
# BRAF p.V600K [present]
# {'cancer_type': ['MELANOMA'], 'biomarker': ['BRAF']}
# 43
# Non-Small Cell Lung Cancer
# BRAF p.V600E [present]
# {'cancer_type': ['NON-SMALL CELL LUNG CANCER'], 'biomarker': ['BRAF']}
# 44
# Invasive Breast Carcinoma
# ER positive [present], HER2-negative [present], PR positive [present]
# {'cancer_type': ['INVASIVE BREAST CARCINOMA'], 'biomarker': ['ER', 'HER2', 'PR']}
# 45
# Acute Lymphoid Leukemia
# CD19 + [present]
# {'cancer_type': ['ACUTE LYMPHOID LEUKEMIA'], 'biomarker': ['CD19']}
# 46
# Acute Lymphoid Leukemia
# CD19 + [present], BCR::ABL1 [not present]
# {'cancer_type': ['ACUTE LYMPHOID LEUKEMIA'], 'biomarker': ['CD19', 'BCR', 'ABL1']}
# 47
# Chronic Myelogenous Leukemia
# BCR::ABL1 [present]
# {'cancer_type': ['CHRONIC MYELOGENOUS LEUKEMIA'], 'biomarker': ['BCR', 'ABL1']}
# 48
# Anaplastic Large Cell Lymphoma
# CD30 + [present]
# {'cancer_type': ['ANAPLASTIC LARGE CELL LYMPHOMA'], 'biomarker': ['CD30']}
# 49
# Anaplastic Large Cell Lymphoma
# CD30 + [present]
# {'cancer_type': ['ANAPLASTIC LARGE CELL LYMPHOMA'], 'biomarker': ['CD30']}
# 50
# Non-Small Cell Lung Cancer
# v::ALK [present]
# {'cancer_type': ['NON-SMALL CELL LUNG CANCER'], 'biomarker': ['ALK']}
# 51
# Adenocarcinoma of the Gastroesophageal Junction
# HER2-positive [present]
# {'cancer_type': ['ADENOCARCINOMA OF THE GASTROESOPHAGEAL JUNCTION'], 'biomarker': ['HER2']}
# 52
# Invasive Breast Carcinoma
# ER positive [present], HER2-negative [present], PIK3CA somatic variants [present]
# {'cancer_type': ['INVASIVE BREAST CARCINOMA'], 'biomarker': ['ER', 'HER2', 'PIK3CA']}
# 53
# Invasive Breast Carcinoma
# HER2-negative [present], PR positive [present], PIK3CA somatic variants [present]
# {'cancer_type': ['INVASIVE BREAST CARCINOMA'], 'biomarker': ['HER2', 'PR', 'PIK3CA']}
# 54
# Invasive Breast Carcinoma
# ER positive [present], HER2-negative [present], PR positive [present], PIK3CA somatic variants [present]
# {'cancer_type': ['INVASIVE BREAST CARCINOMA'], 'biomarker': ['ER', 'HER2', 'PR', 'PIK3CA']}
# 55
# Invasive Breast Carcinoma
# ER positive [present], HER2-negative [present], AKT1 somatic variants [present]
# {'cancer_type': ['INVASIVE BREAST CARCINOMA'], 'biomarker': ['ER', 'HER2', 'AKT1']}
# 56
# Invasive Breast Carcinoma
# HER2-negative [present], PR positive [present], AKT1 somatic variants [present]
# {'cancer_type': ['INVASIVE BREAST CARCINOMA'], 'biomarker': ['HER2', 'PR', 'AKT1']}
# 57
# Invasive Breast Carcinoma
# ER positive [present], HER2-negative [present], PR positive [present], AKT1 somatic variants [present]
# {'cancer_type': ['INVASIVE BREAST CARCINOMA'], 'biomarker': ['ER', 'HER2', 'PR', 'AKT1']}
# 58
# Invasive Breast Carcinoma
# ER positive [present], HER2-negative [present], AKT1 amplification [present]
# {'cancer_type': ['INVASIVE BREAST CARCINOMA'], 'biomarker': ['ER', 'HER2', 'AKT1']}
# 59
# Invasive Breast Carcinoma
# HER2-negative [present], PR positive [present], AKT1 amplification [present]
# {'cancer_type': ['INVASIVE BREAST CARCINOMA'], 'biomarker': ['HER2', 'PR', 'AKT1']}
# 60
# Invasive Breast Carcinoma
# ER positive [present], HER2-negative [present], PR positive [present], AKT1 amplification [present]
# {'cancer_type': ['INVASIVE BREAST CARCINOMA'], 'biomarker': ['ER', 'HER2', 'PR', 'AKT1']}
# 61
# Invasive Breast Carcinoma
# ER positive [present], HER2-negative [present], PTEN nonsense variants [present]
# {'cancer_type': ['INVASIVE BREAST CARCINOMA'], 'biomarker': ['ER', 'HER2', 'PTEN']}
# 62
# Invasive Breast Carcinoma
# HER2-negative [present], PR positive [present], PTEN nonsense variants [present]
# {'cancer_type': ['INVASIVE BREAST CARCINOMA'], 'biomarker': ['HER2', 'PR', 'PTEN']}
# 63
# Invasive Breast Carcinoma
# ER positive [present], HER2-negative [present], PR positive [present], PTEN nonsense variants [present]
# {'cancer_type': ['INVASIVE BREAST CARCINOMA'], 'biomarker': ['ER', 'HER2', 'PR', 'PTEN']}
# 64
# Invasive Breast Carcinoma
# ER positive [present], HER2-negative [present], PTEN frameshift variants [present]
# {'cancer_type': ['INVASIVE BREAST CARCINOMA'], 'biomarker': ['ER', 'HER2', 'PTEN']}
# 65
# Invasive Breast Carcinoma
# HER2-negative [present], PR positive [present], PTEN frameshift variants [present]
# {'cancer_type': ['INVASIVE BREAST CARCINOMA'], 'biomarker': ['HER2', 'PR', 'PTEN']}
# 66
# Invasive Breast Carcinoma
# ER positive [present], HER2-negative [present], PR positive [present], PTEN frameshift variants [present]
# {'cancer_type': ['INVASIVE BREAST CARCINOMA'], 'biomarker': ['ER', 'HER2', 'PR', 'PTEN']}
# 67
# Invasive Breast Carcinoma
# ER positive [present], HER2-negative [present], PTEN splice site variants [present]
# {'cancer_type': ['INVASIVE BREAST CARCINOMA'], 'biomarker': ['ER', 'HER2', 'PTEN']}
# 68
# Invasive Breast Carcinoma
# HER2-negative [present], PR positive [present], PTEN splice site variants [present]
# {'cancer_type': ['INVASIVE BREAST CARCINOMA'], 'biomarker': ['HER2', 'PR', 'PTEN']}
# 69
# Invasive Breast Carcinoma
# ER positive [present], HER2-negative [present], PR positive [present], PTEN splice site variants [present]
# {'cancer_type': ['INVASIVE BREAST CARCINOMA'], 'biomarker': ['ER', 'HER2', 'PR', 'PTEN']}
# 70
# Invasive Breast Carcinoma
# ER positive [present], HER2-negative [present], PTEN deletion [present]
# {'cancer_type': ['INVASIVE BREAST CARCINOMA'], 'biomarker': ['ER', 'HER2', 'PTEN']}
# 71
# Invasive Breast Carcinoma
# HER2-negative [present], PR positive [present], PTEN deletion [present]
# {'cancer_type': ['INVASIVE BREAST CARCINOMA'], 'biomarker': ['HER2', 'PR', 'PTEN']}
# 72
# Invasive Breast Carcinoma
# ER positive [present], HER2-negative [present], PR positive [present], PTEN deletion [present]
# {'cancer_type': ['INVASIVE BREAST CARCINOMA'], 'biomarker': ['ER', 'HER2', 'PR', 'PTEN']}
# 73
# Non-Small Cell Lung Cancer
# MET Exon 14 (Splice Site) [present]
# {'cancer_type': ['NON-SMALL CELL LUNG CANCER'], 'biomarker': ['MET']}
# 74
# Non-Small Cell Lung Cancer
# MET Exon 14 (Deletion) [present]
# {'cancer_type': ['NON-SMALL CELL LUNG CANCER'], 'biomarker': ['MET']}
# 75
# Non-Small Cell Lung Cancer
# Wild type ALK [present], Wild type EGFR [present], Wild type ROS1 [present]
# {'cancer_type': ['NON-SMALL CELL LUNG CANCER'], 'biomarker': ['ALK', 'EGFR', 'ROS1']}
# 76
# Non-Small Cell Lung Cancer
# Wild type ALK [present], Wild type EGFR [present], dMMR [present], PD-L1 >= 50% [present]
# {'cancer_type': ['NON-SMALL CELL LUNG CANCER'], 'biomarker': ['ALK', 'EGFR', 'DMMR', 'PD-L1']}
# 77
# Non-Small Cell Lung Cancer
# v::ALK [present]
# {'cancer_type': ['NON-SMALL CELL LUNG CANCER'], 'biomarker': ['ALK']}
# 78
# Colorectal Adenocarcinoma
# EGFR positive [present], Wild type KRAS [present]
# {'cancer_type': ['COLORECTAL ADENOCARCINOMA'], 'biomarker': ['EGFR', 'KRAS']}
# 79
# Colorectal Adenocarcinoma
# EGFR positive [present], Wild type KRAS [present]
# {'cancer_type': ['COLORECTAL ADENOCARCINOMA'], 'biomarker': ['EGFR', 'KRAS']}
# 80
# Colorectal Adenocarcinoma
# EGFR positive [present], Wild type KRAS [present]
# {'cancer_type': ['COLORECTAL ADENOCARCINOMA'], 'biomarker': ['EGFR', 'KRAS']}
# 81
# Colorectal Adenocarcinoma
# BRAF p.V600E [present]
# {'cancer_type': ['COLORECTAL ADENOCARCINOMA'], 'biomarker': ['BRAF']}
# 82
# Melanoma
# BRAF p.V600E [present]
# {'cancer_type': ['MELANOMA'], 'biomarker': ['BRAF']}
# 83
# Melanoma
# BRAF p.V600K [present]
# {'cancer_type': ['MELANOMA'], 'biomarker': ['BRAF']}
# 84
# Non-Small Cell Lung Cancer
# v::ALK [present]
# {'cancer_type': ['NON-SMALL CELL LUNG CANCER'], 'biomarker': ['ALK']}
# 85
# Non-Small Cell Lung Cancer
# v::ROS1 [present]
# {'cancer_type': ['NON-SMALL CELL LUNG CANCER'], 'biomarker': ['ROS1']}
# 86
# Anaplastic Large Cell Lymphoma
# v::ALK [present]
# {'cancer_type': ['ANAPLASTIC LARGE CELL LYMPHOMA'], 'biomarker': ['ALK']}
# 87
# Inflammatory Myofibroblastic Tumor
# v::ALK [present]
# {'cancer_type': ['INFLAMMATORY MYOFIBROBLASTIC TUMOR'], 'biomarker': ['ALK']}
# 88
# Melanoma
# BRAF p.V600E [present]
# {'cancer_type': ['MELANOMA'], 'biomarker': ['BRAF']}
# 89
# Melanoma
# BRAF p.V600E [present]
# {'cancer_type': ['MELANOMA'], 'biomarker': ['BRAF']}
# 90
# Melanoma
# BRAF p.V600K [present]
# {'cancer_type': ['MELANOMA'], 'biomarker': ['BRAF']}
# 91
# Melanoma
# BRAF p.V600E [present]
# {'cancer_type': ['MELANOMA'], 'biomarker': ['BRAF']}
# 92
# Melanoma
# BRAF p.V600K [present]
# {'cancer_type': ['MELANOMA'], 'biomarker': ['BRAF']}
# 93
# Invasive Breast Carcinoma
# ER positive [present], HER2-negative [present]
# {'cancer_type': ['INVASIVE BREAST CARCINOMA'], 'biomarker': ['ER', 'HER2']}
# 94
# Non-Small Cell Lung Cancer
# BRAF p.V600E [present]
# {'cancer_type': ['NON-SMALL CELL LUNG CANCER'], 'biomarker': ['BRAF']}
# 95
# Anaplastic Thyroid Cancer
# BRAF p.V600E [present]
# {'cancer_type': ['ANAPLASTIC THYROID CANCER'], 'biomarker': ['BRAF']}
# 96
# Any solid tumor
# BRAF p.V600E [present]
# {'cancer_type': ['ANY SOLID TUMOR'], 'biomarker': ['BRAF']}
# 97
# Low-Grade Glioma, NOS
# BRAF p.V600E [present]
# {'cancer_type': ['LOW-GRADE GLIOMA, NOS'], 'biomarker': ['BRAF']}
# 98
# Non-Small Cell Lung Cancer
# EGFR Exon 19 (Deletion) [present]
# {'cancer_type': ['NON-SMALL CELL LUNG CANCER'], 'biomarker': ['EGFR']}
# 99
# Non-Small Cell Lung Cancer
# EGFR p.L858R [present]
# {'cancer_type': ['NON-SMALL CELL LUNG CANCER'], 'biomarker': ['EGFR']}
# 100
# Chronic Myelogenous Leukemia
# BCR::ABL1 [present]
# {'cancer_type': ['CHRONIC MYELOGENOUS LEUKEMIA'], 'biomarker': ['BCR', 'ABL1']}
# 101
# Chronic Myeloid Leukemia, BCR-ABL1+
# BCR::ABL1 [present]
# {'cancer_type': ['CHRONIC MYELOID LEUKEMIA, BCR-ABL1+'], 'biomarker': ['BCR', 'ABL1']}
# 102
# Acute Lymphoid Leukemia
# BCR::ABL1 [present]
# {'cancer_type': ['ACUTE LYMPHOID LEUKEMIA'], 'biomarker': ['BCR', 'ABL1']}
# 103
# Endometrial Carcinoma
# dMMR [present]
# {'cancer_type': ['ENDOMETRIAL CARCINOMA'], 'biomarker': ['DMMR']}
# 104
# Endometrial Carcinoma
# MSI-H [present]
# {'cancer_type': ['ENDOMETRIAL CARCINOMA'], 'biomarker': ['MSI-H']}
# 105
# Endometrial Carcinoma
# dMMR [present]
# {'cancer_type': ['ENDOMETRIAL CARCINOMA'], 'biomarker': ['DMMR']}
# 106
# Any solid tumor
# dMMR [present]
# {'cancer_type': ['ANY SOLID TUMOR'], 'biomarker': ['DMMR']}
# 107
# Non-Small Cell Lung Cancer
# Wild type ALK [present], Wild type EGFR [present]
# {'cancer_type': ['NON-SMALL CELL LUNG CANCER'], 'biomarker': ['ALK', 'EGFR']}
# 108
# Non-Small Cell Lung Cancer
# Wild type ALK [present], Wild type EGFR [present]
# {'cancer_type': ['NON-SMALL CELL LUNG CANCER'], 'biomarker': ['ALK', 'EGFR']}
# 109
# Non-Small Cell Lung Cancer
# Wild type ALK [present], Wild type EGFR [present]
# {'cancer_type': ['NON-SMALL CELL LUNG CANCER'], 'biomarker': ['ALK', 'EGFR']}
# 110
# Non-Small Cell Lung Cancer
# Wild type ALK [present], Wild type EGFR [present]
# {'cancer_type': ['NON-SMALL CELL LUNG CANCER'], 'biomarker': ['ALK', 'EGFR']}
# 111
# Non-Small Cell Lung Cancer
# Wild type ALK [present], Wild type EGFR [present]
# {'cancer_type': ['NON-SMALL CELL LUNG CANCER'], 'biomarker': ['ALK', 'EGFR']}
# 112
# Endometrial Carcinoma
# dMMR [present]
# {'cancer_type': ['ENDOMETRIAL CARCINOMA'], 'biomarker': ['DMMR']}
# 113
# Invasive Breast Carcinoma
# ER positive [present], HER2-negative [present], ESR1 oncogenic variants [present]
# {'cancer_type': ['INVASIVE BREAST CARCINOMA'], 'biomarker': ['ER', 'HER2', 'ESR1']}
# 114
# Acute Myeloid Leukemia
# IDH2 p.R140Q [present]
# {'cancer_type': ['ACUTE MYELOID LEUKEMIA'], 'biomarker': ['IDH2']}
# 115
# Acute Myeloid Leukemia
# IDH2 p.R140L [present]
# {'cancer_type': ['ACUTE MYELOID LEUKEMIA'], 'biomarker': ['IDH2']}
# 116
# Acute Myeloid Leukemia
# IDH2 p.R140G [present]
# {'cancer_type': ['ACUTE MYELOID LEUKEMIA'], 'biomarker': ['IDH2']}
# 117
# Acute Myeloid Leukemia
# IDH2 p.R140W [present]
# {'cancer_type': ['ACUTE MYELOID LEUKEMIA'], 'biomarker': ['IDH2']}
# 118
# Acute Myeloid Leukemia
# IDH2 p.R172K [present]
# {'cancer_type': ['ACUTE MYELOID LEUKEMIA'], 'biomarker': ['IDH2']}
# 119
# Acute Myeloid Leukemia
# IDH2 p.R172M [present]
# {'cancer_type': ['ACUTE MYELOID LEUKEMIA'], 'biomarker': ['IDH2']}
# 120
# Acute Myeloid Leukemia
# IDH2 p.R172G [present]
# {'cancer_type': ['ACUTE MYELOID LEUKEMIA'], 'biomarker': ['IDH2']}
# 121
# Acute Myeloid Leukemia
# IDH2 p.R172S [present]
# {'cancer_type': ['ACUTE MYELOID LEUKEMIA'], 'biomarker': ['IDH2']}
# 122
# Acute Myeloid Leukemia
# IDH2 p.R172W [present]
# {'cancer_type': ['ACUTE MYELOID LEUKEMIA'], 'biomarker': ['IDH2']}
# 123
# Melanoma
# BRAF p.V600E [present]
# {'cancer_type': ['MELANOMA'], 'biomarker': ['BRAF']}
# 124
# Melanoma
# BRAF p.V600K [present]
# {'cancer_type': ['MELANOMA'], 'biomarker': ['BRAF']}
# 125
# Colorectal Adenocarcinoma
# BRAF p.V600E [present]
# {'cancer_type': ['COLORECTAL ADENOCARCINOMA'], 'biomarker': ['BRAF']}
# 126
# Non-Small Cell Lung Cancer
# BRAF p.V600E [present]
# {'cancer_type': ['NON-SMALL CELL LUNG CANCER'], 'biomarker': ['BRAF']}
# 127
# Non-Small Cell Lung Cancer
# v::ROS1 [present]
# {'cancer_type': ['NON-SMALL CELL LUNG CANCER'], 'biomarker': ['ROS1']}
# 128
# Any solid tumor
# v::NTRK1 [present]
# {'cancer_type': ['ANY SOLID TUMOR'], 'biomarker': ['NTRK1']}
# 129
# Any solid tumor
# v::NTRK2 [present]
# {'cancer_type': ['ANY SOLID TUMOR'], 'biomarker': ['NTRK2']}
# 130
# Any solid tumor
# v::NTRK3 [present]
# {'cancer_type': ['ANY SOLID TUMOR'], 'biomarker': ['NTRK3']}
# 131
# Bladder Urothelial Carcinoma
# FGFR3 p.R248C [present]
# {'cancer_type': ['BLADDER UROTHELIAL CARCINOMA'], 'biomarker': ['FGFR3']}
# 132
# Bladder Urothelial Carcinoma
# FGFR3 p.S249C [present]
# {'cancer_type': ['BLADDER UROTHELIAL CARCINOMA'], 'biomarker': ['FGFR3']}
# 133
# Bladder Urothelial Carcinoma
# FGFR3 p.G370C [present]
# {'cancer_type': ['BLADDER UROTHELIAL CARCINOMA'], 'biomarker': ['FGFR3']}
# 134
# Bladder Urothelial Carcinoma
# FGFR3 p.Y373C [present]
# {'cancer_type': ['BLADDER UROTHELIAL CARCINOMA'], 'biomarker': ['FGFR3']}
# 135
# Bladder Urothelial Carcinoma
# FGFR3::TACC3 [present]
# {'cancer_type': ['BLADDER UROTHELIAL CARCINOMA'], 'biomarker': ['FGFR3', 'TACC3']}
# 136
# Non-Small Cell Lung Cancer
# EGFR Exon 19 (Deletion) [present]
# {'cancer_type': ['NON-SMALL CELL LUNG CANCER'], 'biomarker': ['EGFR']}
# 137
# Non-Small Cell Lung Cancer
# EGFR p.L858R [present]
# {'cancer_type': ['NON-SMALL CELL LUNG CANCER'], 'biomarker': ['EGFR']}
# 138
# Invasive Breast Carcinoma
# ER positive [present], HER2-negative [present]
# {'cancer_type': ['INVASIVE BREAST CARCINOMA'], 'biomarker': ['ER', 'HER2']}
# 139
# Invasive Breast Carcinoma
# HER2-negative [present], PR positive [present]
# {'cancer_type': ['INVASIVE BREAST CARCINOMA'], 'biomarker': ['HER2', 'PR']}
# 140
# Invasive Breast Carcinoma
# ER positive [present], HER2-negative [present], PR positive [present]
# {'cancer_type': ['INVASIVE BREAST CARCINOMA'], 'biomarker': ['ER', 'HER2', 'PR']}
# 141
# Invasive Breast Carcinoma
# ER positive [present], HER2-negative [present]
# {'cancer_type': ['INVASIVE BREAST CARCINOMA'], 'biomarker': ['ER', 'HER2']}
# 142
# Invasive Breast Carcinoma
# HER2-negative [present], PR positive [present]
# {'cancer_type': ['INVASIVE BREAST CARCINOMA'], 'biomarker': ['HER2', 'PR']}
# 143
# Invasive Breast Carcinoma
# ER positive [present], HER2-negative [present], PR positive [present]
# {'cancer_type': ['INVASIVE BREAST CARCINOMA'], 'biomarker': ['ER', 'HER2', 'PR']}
# 144
# Invasive Breast Carcinoma
# ER positive [present]
# {'cancer_type': ['INVASIVE BREAST CARCINOMA'], 'biomarker': ['ER']}
# 145
# Invasive Breast Carcinoma
# PR positive [present]
# {'cancer_type': ['INVASIVE BREAST CARCINOMA'], 'biomarker': ['PR']}
# 146
# Invasive Breast Carcinoma
# ER positive [present], PR positive [present]
# {'cancer_type': ['INVASIVE BREAST CARCINOMA'], 'biomarker': ['ER', 'PR']}
# 147
# Invasive Breast Carcinoma
# ER positive [present], HER2-negative [present]
# {'cancer_type': ['INVASIVE BREAST CARCINOMA'], 'biomarker': ['ER', 'HER2']}
# 148
# Invasive Breast Carcinoma
# HER2-negative [present], PR positive [present]
# {'cancer_type': ['INVASIVE BREAST CARCINOMA'], 'biomarker': ['HER2', 'PR']}
# 149
# Invasive Breast Carcinoma
# ER positive [present], HER2-negative [present], PR positive [present]
# {'cancer_type': ['INVASIVE BREAST CARCINOMA'], 'biomarker': ['ER', 'HER2', 'PR']}
# 150
# Invasive Breast Carcinoma
# ER positive [present], HER2-negative [present]
# {'cancer_type': ['INVASIVE BREAST CARCINOMA'], 'biomarker': ['ER', 'HER2']}
# 151
# Invasive Breast Carcinoma
# HER2-negative [present], PR positive [present]
# {'cancer_type': ['INVASIVE BREAST CARCINOMA'], 'biomarker': ['HER2', 'PR']}
# 152
# Invasive Breast Carcinoma
# ER positive [present], HER2-negative [present], PR positive [present]
# {'cancer_type': ['INVASIVE BREAST CARCINOMA'], 'biomarker': ['ER', 'HER2', 'PR']}
# 153
# Invasive Breast Carcinoma
# ER positive [present], HER2-negative [present]
# {'cancer_type': ['INVASIVE BREAST CARCINOMA'], 'biomarker': ['ER', 'HER2']}
# 154
# Invasive Breast Carcinoma
# HER2-negative [present], PR positive [present]
# {'cancer_type': ['INVASIVE BREAST CARCINOMA'], 'biomarker': ['HER2', 'PR']}
# 155
# Invasive Breast Carcinoma
# ER positive [present], HER2-negative [present], PR positive [present]
# {'cancer_type': ['INVASIVE BREAST CARCINOMA'], 'biomarker': ['ER', 'HER2', 'PR']}
# 156
# Intrahepatic Cholangiocarcinoma
# FGFR2::v [present]
# {'cancer_type': ['INTRAHEPATIC CHOLANGIOCARCINOMA'], 'biomarker': ['FGFR2']}
# 157
# Non-Small Cell Lung Cancer
# EGFR Exon 19 (Deletion) [present]
# {'cancer_type': ['NON-SMALL CELL LUNG CANCER'], 'biomarker': ['EGFR']}
# 158
# Non-Small Cell Lung Cancer
# EGFR p.L858R [present]
# {'cancer_type': ['NON-SMALL CELL LUNG CANCER'], 'biomarker': ['EGFR']}
# 159
# Acute Lymphoid Leukemia
# CD33 + [present]
# {'cancer_type': ['ACUTE LYMPHOID LEUKEMIA'], 'biomarker': ['CD33']}
# 160
# Acute Lymphoid Leukemia
# FLT3-ITD [present]
# {'cancer_type': ['ACUTE LYMPHOID LEUKEMIA'], 'biomarker': ['FLT3']}
# 161
# Acute Lymphoid Leukemia
# FLT3 p.D835Y [present]
# {'cancer_type': ['ACUTE LYMPHOID LEUKEMIA'], 'biomarker': ['FLT3']}
# 162
# Acute Lymphoid Leukemia
# FLT3 p.D835A [present]
# {'cancer_type': ['ACUTE LYMPHOID LEUKEMIA'], 'biomarker': ['FLT3']}
# 163
# Acute Lymphoid Leukemia
# FLT3 p.D835E [present]
# {'cancer_type': ['ACUTE LYMPHOID LEUKEMIA'], 'biomarker': ['FLT3']}
# 164
# Acute Lymphoid Leukemia
# FLT3 p.D835H [present]
# {'cancer_type': ['ACUTE LYMPHOID LEUKEMIA'], 'biomarker': ['FLT3']}
# 165
# Acute Lymphoid Leukemia
# FLT3 p.D835N [present]
# {'cancer_type': ['ACUTE LYMPHOID LEUKEMIA'], 'biomarker': ['FLT3']}
# 166
# Acute Lymphoid Leukemia
# FLT3 p.D835S [present]
# {'cancer_type': ['ACUTE LYMPHOID LEUKEMIA'], 'biomarker': ['FLT3']}
# 167
# Acute Lymphoid Leukemia
# FLT3 p.D835V [present]
# {'cancer_type': ['ACUTE LYMPHOID LEUKEMIA'], 'biomarker': ['FLT3']}
# 168
# Chronic Myelogenous Leukemia
# BCR::ABL1 [present]
# {'cancer_type': ['CHRONIC MYELOGENOUS LEUKEMIA'], 'biomarker': ['BCR', 'ABL1']}
# 169
# Chronic Myeloid Leukemia, BCR-ABL1+
# BCR::ABL1 [present]
# {'cancer_type': ['CHRONIC MYELOID LEUKEMIA, BCR-ABL1+'], 'biomarker': ['BCR', 'ABL1']}
# 170
# Acute Lymphoid Leukemia
# BCR::ABL1 [present]
# {'cancer_type': ['ACUTE LYMPHOID LEUKEMIA'], 'biomarker': ['BCR', 'ABL1']}
# 171
# Myelodysplastic Syndromes
# PDGFRA rearrangements [present]
# {'cancer_type': ['MYELODYSPLASTIC SYNDROMES'], 'biomarker': ['PDGFRA']}
# 172
# Myelodysplastic Syndromes
# PDGFRB rearrangements [present]
# {'cancer_type': ['MYELODYSPLASTIC SYNDROMES'], 'biomarker': ['PDGFRB']}
# 173
# Aggressive Systemic Mastocytosis
# KIT p.D816V [not present]
# {'cancer_type': ['AGGRESSIVE SYSTEMIC MASTOCYTOSIS'], 'biomarker': ['KIT']}
# 174
# Chronic Eosinophilic Leukemia, NOS
# FIP1L1::PDGFRA [present]
# {'cancer_type': ['CHRONIC EOSINOPHILIC LEUKEMIA, NOS'], 'biomarker': ['FIP1L1', 'PDGFRA']}
# 175
# Gastrointestinal Stromal Tumor
# CD117 + [present]
# {'cancer_type': ['GASTROINTESTINAL STROMAL TUMOR'], 'biomarker': ['CD117']}
# 176
# Gastrointestinal Stromal Tumor
# FIP1L1::PDGFRA [present]
# {'cancer_type': ['GASTROINTESTINAL STROMAL TUMOR'], 'biomarker': ['FIP1L1', 'PDGFRA']}
# 177
# Cholangiocarcinoma
# FGFR2::v [present]
# {'cancer_type': ['CHOLANGIOCARCINOMA'], 'biomarker': ['FGFR2']}
# 178
# Acute Lymphoid Leukemia
# CD22 + [present]
# {'cancer_type': ['ACUTE LYMPHOID LEUKEMIA'], 'biomarker': ['CD22']}
# 179
# Colorectal Adenocarcinoma
# MSI-H [present]
# {'cancer_type': ['COLORECTAL ADENOCARCINOMA'], 'biomarker': ['MSI-H']}
# 180
# Colorectal Adenocarcinoma
# dMMR [present]
# {'cancer_type': ['COLORECTAL ADENOCARCINOMA'], 'biomarker': ['DMMR']}
# 181
# Non-Small Cell Lung Cancer
# PD-L1 >= 1% [present], Wild type ALK [present], Wild type EGFR [present]
# {'cancer_type': ['NON-SMALL CELL LUNG CANCER'], 'biomarker': ['PD-L1', 'ALK', 'EGFR']}
# 182
# Non-Small Cell Lung Cancer
# Wild type ALK [present], Wild type EGFR [present]
# {'cancer_type': ['NON-SMALL CELL LUNG CANCER'], 'biomarker': ['ALK', 'EGFR']}
# 183
# Non-Small Cell Lung Cancer
# Wild type ALK [present], Wild type EGFR [present]
# {'cancer_type': ['NON-SMALL CELL LUNG CANCER'], 'biomarker': ['ALK', 'EGFR']}
# 184
# Non-Small Cell Lung Cancer
# Wild type ALK [present], Wild type EGFR [present]
# {'cancer_type': ['NON-SMALL CELL LUNG CANCER'], 'biomarker': ['ALK', 'EGFR']}
# 185
# Acute Myeloid Leukemia
# IDH1 p.R132C [present]
# {'cancer_type': ['ACUTE MYELOID LEUKEMIA'], 'biomarker': ['IDH1']}
# 186
# Acute Myeloid Leukemia
# IDH1 p.R132G [present]
# {'cancer_type': ['ACUTE MYELOID LEUKEMIA'], 'biomarker': ['IDH1']}
# 187
# Acute Myeloid Leukemia
# IDH1 p.R132H [present]
# {'cancer_type': ['ACUTE MYELOID LEUKEMIA'], 'biomarker': ['IDH1']}
# 188
# Acute Myeloid Leukemia
# IDH1 p.R132L [present]
# {'cancer_type': ['ACUTE MYELOID LEUKEMIA'], 'biomarker': ['IDH1']}
# 189
# Acute Myeloid Leukemia
# IDH1 p.R132S [present]
# {'cancer_type': ['ACUTE MYELOID LEUKEMIA'], 'biomarker': ['IDH1']}
# 190
# Acute Myeloid Leukemia
# IDH1 p.R132C [present]
# {'cancer_type': ['ACUTE MYELOID LEUKEMIA'], 'biomarker': ['IDH1']}
# 191
# Acute Myeloid Leukemia
# IDH1 p.R132G [present]
# {'cancer_type': ['ACUTE MYELOID LEUKEMIA'], 'biomarker': ['IDH1']}
# 192
# Acute Myeloid Leukemia
# IDH1 p.R132H [present]
# {'cancer_type': ['ACUTE MYELOID LEUKEMIA'], 'biomarker': ['IDH1']}
# 193
# Acute Myeloid Leukemia
# IDH1 p.R132L [present]
# {'cancer_type': ['ACUTE MYELOID LEUKEMIA'], 'biomarker': ['IDH1']}
# 194
# Acute Myeloid Leukemia
# IDH1 p.R132S [present]
# {'cancer_type': ['ACUTE MYELOID LEUKEMIA'], 'biomarker': ['IDH1']}
# 195
# Myelodysplastic Syndromes
# IDH1 p.R132C [present]
# {'cancer_type': ['MYELODYSPLASTIC SYNDROMES'], 'biomarker': ['IDH1']}
# 196
# Myelodysplastic Syndromes
# IDH1 p.R132G [present]
# {'cancer_type': ['MYELODYSPLASTIC SYNDROMES'], 'biomarker': ['IDH1']}
# 197
# Myelodysplastic Syndromes
# IDH1 p.R132H [present]
# {'cancer_type': ['MYELODYSPLASTIC SYNDROMES'], 'biomarker': ['IDH1']}
# 198
# Myelodysplastic Syndromes
# IDH1 p.R132L [present]
# {'cancer_type': ['MYELODYSPLASTIC SYNDROMES'], 'biomarker': ['IDH1']}
# 199
# Myelodysplastic Syndromes
# IDH1 p.R132S [present]
# {'cancer_type': ['MYELODYSPLASTIC SYNDROMES'], 'biomarker': ['IDH1']}
# 200
# Cholangiocarcinoma
# IDH1 p.R132C [present]
# {'cancer_type': ['CHOLANGIOCARCINOMA'], 'biomarker': ['IDH1']}
# 201
# Cholangiocarcinoma
# IDH1 p.R132G [present]
# {'cancer_type': ['CHOLANGIOCARCINOMA'], 'biomarker': ['IDH1']}
# 202
# Cholangiocarcinoma
# IDH1 p.R132H [present]
# {'cancer_type': ['CHOLANGIOCARCINOMA'], 'biomarker': ['IDH1']}
# 203
# Cholangiocarcinoma
# IDH1 p.R132L [present]
# {'cancer_type': ['CHOLANGIOCARCINOMA'], 'biomarker': ['IDH1']}
# 204
# Cholangiocarcinoma
# IDH1 p.R132S [present]
# {'cancer_type': ['CHOLANGIOCARCINOMA'], 'biomarker': ['IDH1']}
# 205
# Invasive Breast Carcinoma
# HER2-positive [present]
# {'cancer_type': ['INVASIVE BREAST CARCINOMA'], 'biomarker': ['HER2']}
# 206
# Invasive Breast Carcinoma
# ER positive [present], HER2-positive [present]
# {'cancer_type': ['INVASIVE BREAST CARCINOMA'], 'biomarker': ['ER', 'HER2']}
# 207
# Invasive Breast Carcinoma
# PR positive [present], HER2-positive [present]
# {'cancer_type': ['INVASIVE BREAST CARCINOMA'], 'biomarker': ['PR', 'HER2']}
# 208
# Invasive Breast Carcinoma
# ER positive [present], PR positive [present], HER2-positive [present]
# {'cancer_type': ['INVASIVE BREAST CARCINOMA'], 'biomarker': ['ER', 'PR', 'HER2']}
# 209
# Any solid tumor
# v::NTRK1 [present]
# {'cancer_type': ['ANY SOLID TUMOR'], 'biomarker': ['NTRK1']}
# 210
# Any solid tumor
# v::NTRK2 [present]
# {'cancer_type': ['ANY SOLID TUMOR'], 'biomarker': ['NTRK2']}
# 211
# Any solid tumor
# v::NTRK3 [present]
# {'cancer_type': ['ANY SOLID TUMOR'], 'biomarker': ['NTRK3']}
# 212
# Myelodysplastic Syndromes
# 5q deletion [present]
# {'cancer_type': ['MYELODYSPLASTIC SYNDROMES'], 'biomarker': ['5QDELETION']}
# 213
# Non-Small Cell Lung Cancer
# v::ALK [present]
# {'cancer_type': ['NON-SMALL CELL LUNG CANCER'], 'biomarker': ['ALK']}
# 214
# Invasive Breast Carcinoma
# HER2-positive [present]
# {'cancer_type': ['INVASIVE BREAST CARCINOMA'], 'biomarker': ['HER2']}
# 215
# Invasive Breast Carcinoma
# HER2-positive [present]
# {'cancer_type': ['INVASIVE BREAST CARCINOMA'], 'biomarker': ['HER2']}
# 216
# Invasive Breast Carcinoma
# HER2-positive [present]
# {'cancer_type': ['INVASIVE BREAST CARCINOMA'], 'biomarker': ['HER2']}
# 217
# Invasive Breast Carcinoma
# HER2-positive [present]
# {'cancer_type': ['INVASIVE BREAST CARCINOMA'], 'biomarker': ['HER2']}
# 218
# Acute Myeloid Leukemia
# FLT3-ITD [present]
# {'cancer_type': ['ACUTE MYELOID LEUKEMIA'], 'biomarker': ['FLT3']}
# 219
# Acute Myeloid Leukemia
# FLT3 p.D835Y [present]
# {'cancer_type': ['ACUTE MYELOID LEUKEMIA'], 'biomarker': ['FLT3']}
# 220
# Acute Myeloid Leukemia
# FLT3 p.D835A [present]
# {'cancer_type': ['ACUTE MYELOID LEUKEMIA'], 'biomarker': ['FLT3']}
# 221
# Acute Myeloid Leukemia
# FLT3 p.D835E [present]
# {'cancer_type': ['ACUTE MYELOID LEUKEMIA'], 'biomarker': ['FLT3']}
# 222
# Acute Myeloid Leukemia
# FLT3 p.D835H [present]
# {'cancer_type': ['ACUTE MYELOID LEUKEMIA'], 'biomarker': ['FLT3']}
# 223
# Acute Myeloid Leukemia
# FLT3 p.D835N [present]
# {'cancer_type': ['ACUTE MYELOID LEUKEMIA'], 'biomarker': ['FLT3']}
# 224
# Acute Myeloid Leukemia
# FLT3 p.D835S [present]
# {'cancer_type': ['ACUTE MYELOID LEUKEMIA'], 'biomarker': ['FLT3']}
# 225
# Acute Myeloid Leukemia
# FLT3 p.D835V [present]
# {'cancer_type': ['ACUTE MYELOID LEUKEMIA'], 'biomarker': ['FLT3']}
# 226
# Acute Myeloid Leukemia
# FLT3 p.I836del [present]
# {'cancer_type': ['ACUTE MYELOID LEUKEMIA'], 'biomarker': ['FLT3']}
# 227
# Acute Myeloid Leukemia
# CDK12 oncogenic variants [present]
# {'cancer_type': ['ACUTE MYELOID LEUKEMIA'], 'biomarker': ['CDK12']}
# 228
# Non-Small Cell Lung Cancer
# EGFR Exon 20 (Insertion) [present]
# {'cancer_type': ['NON-SMALL CELL LUNG CANCER'], 'biomarker': ['EGFR']}
# 229
# Invasive Breast Carcinoma
# HER2-positive [present]
# {'cancer_type': ['INVASIVE BREAST CARCINOMA'], 'biomarker': ['HER2']}
# 230
# Invasive Breast Carcinoma
# HER2-positive [present]
# {'cancer_type': ['INVASIVE BREAST CARCINOMA'], 'biomarker': ['HER2']}
# 231
# Chronic Myelogenous Leukemia
# BCR::ABL1 [present]
# {'cancer_type': ['CHRONIC MYELOGENOUS LEUKEMIA'], 'biomarker': ['BCR', 'ABL1']}
# 232
# Chronic Myeloid Leukemia, BCR-ABL1+
# BCR::ABL1 [present]
# {'cancer_type': ['CHRONIC MYELOID LEUKEMIA, BCR-ABL1+'], 'biomarker': ['BCR', 'ABL1']}
# 233
# Ovarian Epithelial Tumor
# BRCA1 pathogenic variants [present]
# {'cancer_type': ['OVARIAN EPITHELIAL TUMOR'], 'biomarker': ['BRCA1']}
# 234
# Ovarian Epithelial Tumor
# BRCA2 pathogenic variants [present]
# {'cancer_type': ['OVARIAN EPITHELIAL TUMOR'], 'biomarker': ['BRCA2']}
# 235
# High-Grade Serous Fallopian Tube Cancer
# BRCA1 pathogenic variants [present]
# {'cancer_type': ['HIGH-GRADE SEROUS FALLOPIAN TUBE CANCER'], 'biomarker': ['BRCA1']}
# 236
# High-Grade Serous Fallopian Tube Cancer
# BRCA2 pathogenic variants [present]
# {'cancer_type': ['HIGH-GRADE SEROUS FALLOPIAN TUBE CANCER'], 'biomarker': ['BRCA2']}
# 237
# Peritoneal Serous Carcinoma
# BRCA1 pathogenic variants [present]
# {'cancer_type': ['PERITONEAL SEROUS CARCINOMA'], 'biomarker': ['BRCA1']}
# 238
# Peritoneal Serous Carcinoma
# BRCA2 pathogenic variants [present]
# {'cancer_type': ['PERITONEAL SEROUS CARCINOMA'], 'biomarker': ['BRCA2']}
# 239
# Non-Small Cell Lung Cancer
# Wild type ALK [present], Wild type EGFR [present]
# {'cancer_type': ['NON-SMALL CELL LUNG CANCER'], 'biomarker': ['ALK', 'EGFR']}
# 240
# Non-Small Cell Lung Cancer
# PD-L1 >= 1% [present]
# {'cancer_type': ['NON-SMALL CELL LUNG CANCER'], 'biomarker': ['PD-L1']}
# 241
# Ovarian Epithelial Tumor
# BRCA1 oncogenic variants [present]
# {'cancer_type': ['OVARIAN EPITHELIAL TUMOR'], 'biomarker': ['BRCA1']}
# 242
# Ovarian Epithelial Tumor
# BRCA1 pathogenic variants [present]
# {'cancer_type': ['OVARIAN EPITHELIAL TUMOR'], 'biomarker': ['BRCA1']}
# 243
# Ovarian Epithelial Tumor
# BRCA2 oncogenic variants [present]
# {'cancer_type': ['OVARIAN EPITHELIAL TUMOR'], 'biomarker': ['BRCA2']}
# 244
# Ovarian Epithelial Tumor
# BRCA2 pathogenic variants [present]
# {'cancer_type': ['OVARIAN EPITHELIAL TUMOR'], 'biomarker': ['BRCA2']}
# 245
# High-Grade Serous Fallopian Tube Cancer
# BRCA1 oncogenic variants [present]
# {'cancer_type': ['HIGH-GRADE SEROUS FALLOPIAN TUBE CANCER'], 'biomarker': ['BRCA1']}
# 246
# High-Grade Serous Fallopian Tube Cancer
# BRCA1 pathogenic variants [present]
# {'cancer_type': ['HIGH-GRADE SEROUS FALLOPIAN TUBE CANCER'], 'biomarker': ['BRCA1']}
# 247
# High-Grade Serous Fallopian Tube Cancer
# BRCA2 oncogenic variants [present]
# {'cancer_type': ['HIGH-GRADE SEROUS FALLOPIAN TUBE CANCER'], 'biomarker': ['BRCA2']}
# 248
# High-Grade Serous Fallopian Tube Cancer
# BRCA2 pathogenic variants [present]
# {'cancer_type': ['HIGH-GRADE SEROUS FALLOPIAN TUBE CANCER'], 'biomarker': ['BRCA2']}
# 249
# Peritoneal Serous Carcinoma
# BRCA1 oncogenic variants [present]
# {'cancer_type': ['PERITONEAL SEROUS CARCINOMA'], 'biomarker': ['BRCA1']}
# 250
# Peritoneal Serous Carcinoma
# BRCA1 pathogenic variants [present]
# {'cancer_type': ['PERITONEAL SEROUS CARCINOMA'], 'biomarker': ['BRCA1']}
# 251
# Peritoneal Serous Carcinoma
# BRCA2 oncogenic variants [present]
# {'cancer_type': ['PERITONEAL SEROUS CARCINOMA'], 'biomarker': ['BRCA2']}
# 252
# Peritoneal Serous Carcinoma
# BRCA2 pathogenic variants [present]
# {'cancer_type': ['PERITONEAL SEROUS CARCINOMA'], 'biomarker': ['BRCA2']}
# 253
# Ovarian Epithelial Tumor
# BRCA1 oncogenic variants [present]
# {'cancer_type': ['OVARIAN EPITHELIAL TUMOR'], 'biomarker': ['BRCA1']}
# 254
# Ovarian Epithelial Tumor
# BRCA1 pathogenic variants [present]
# {'cancer_type': ['OVARIAN EPITHELIAL TUMOR'], 'biomarker': ['BRCA1']}
# 255
# Ovarian Epithelial Tumor
# BRCA2 oncogenic variants [present]
# {'cancer_type': ['OVARIAN EPITHELIAL TUMOR'], 'biomarker': ['BRCA2']}
# 256
# Ovarian Epithelial Tumor
# BRCA2 pathogenic variants [present]
# {'cancer_type': ['OVARIAN EPITHELIAL TUMOR'], 'biomarker': ['BRCA2']}
# 257
# Ovarian Epithelial Tumor
# HRD [present]
# {'cancer_type': ['OVARIAN EPITHELIAL TUMOR'], 'biomarker': ['HRD']}
# 258
# High-Grade Serous Fallopian Tube Cancer
# BRCA1 oncogenic variants [present]
# {'cancer_type': ['HIGH-GRADE SEROUS FALLOPIAN TUBE CANCER'], 'biomarker': ['BRCA1']}
# 259
# High-Grade Serous Fallopian Tube Cancer
# BRCA1 pathogenic variants [present]
# {'cancer_type': ['HIGH-GRADE SEROUS FALLOPIAN TUBE CANCER'], 'biomarker': ['BRCA1']}
# 260
# High-Grade Serous Fallopian Tube Cancer
# BRCA2 oncogenic variants [present]
# {'cancer_type': ['HIGH-GRADE SEROUS FALLOPIAN TUBE CANCER'], 'biomarker': ['BRCA2']}
# 261
# High-Grade Serous Fallopian Tube Cancer
# BRCA2 pathogenic variants [present]
# {'cancer_type': ['HIGH-GRADE SEROUS FALLOPIAN TUBE CANCER'], 'biomarker': ['BRCA2']}
# 262
# High-Grade Serous Fallopian Tube Cancer
# HRD [present]
# {'cancer_type': ['HIGH-GRADE SEROUS FALLOPIAN TUBE CANCER'], 'biomarker': ['HRD']}
# 263
# Peritoneal Serous Carcinoma
# BRCA1 oncogenic variants [present]
# {'cancer_type': ['PERITONEAL SEROUS CARCINOMA'], 'biomarker': ['BRCA1']}
# 264
# Peritoneal Serous Carcinoma
# BRCA1 pathogenic variants [present]
# {'cancer_type': ['PERITONEAL SEROUS CARCINOMA'], 'biomarker': ['BRCA1']}
# 265
# Peritoneal Serous Carcinoma
# BRCA2 oncogenic variants [present]
# {'cancer_type': ['PERITONEAL SEROUS CARCINOMA'], 'biomarker': ['BRCA2']}
# 266
# Peritoneal Serous Carcinoma
# BRCA2 pathogenic variants [present]
# {'cancer_type': ['PERITONEAL SEROUS CARCINOMA'], 'biomarker': ['BRCA2']}
# 267
# Peritoneal Serous Carcinoma
# HRD [present]
# {'cancer_type': ['PERITONEAL SEROUS CARCINOMA'], 'biomarker': ['HRD']}
# 268
# Invasive Breast Carcinoma
# BRCA1 pathogenic variants [present], HER2-negative [present]
# {'cancer_type': ['INVASIVE BREAST CARCINOMA'], 'biomarker': ['BRCA1', 'HER2']}
# 269
# Invasive Breast Carcinoma
# BRCA2 pathogenic variants [present], HER2-negative [present]
# {'cancer_type': ['INVASIVE BREAST CARCINOMA'], 'biomarker': ['BRCA2', 'HER2']}
# 270
# Pancreatic Adenocarcinoma
# BRCA1 pathogenic variants [present]
# {'cancer_type': ['PANCREATIC ADENOCARCINOMA'], 'biomarker': ['BRCA1']}
# 271
# Pancreatic Adenocarcinoma
# BRCA2 pathogenic variants [present]
# {'cancer_type': ['PANCREATIC ADENOCARCINOMA'], 'biomarker': ['BRCA2']}
# 272
# Prostate Adenocarcinoma
# BRCA1 oncogenic variants [present]
# {'cancer_type': ['PROSTATE ADENOCARCINOMA'], 'biomarker': ['BRCA1']}
# 273
# Prostate Adenocarcinoma
# BRCA1 oncogenic variants [present]
# {'cancer_type': ['PROSTATE ADENOCARCINOMA'], 'biomarker': ['BRCA1']}
# 274
# Prostate Adenocarcinoma
# BRCA1 pathogenic variants [present]
# {'cancer_type': ['PROSTATE ADENOCARCINOMA'], 'biomarker': ['BRCA1']}
# 275
# Prostate Adenocarcinoma
# BRCA2 oncogenic variants [present]
# {'cancer_type': ['PROSTATE ADENOCARCINOMA'], 'biomarker': ['BRCA2']}
# 276
# Prostate Adenocarcinoma
# BRCA2 pathogenic variants [present]
# {'cancer_type': ['PROSTATE ADENOCARCINOMA'], 'biomarker': ['BRCA2']}
# 277
# Prostate Adenocarcinoma
# ATM pathogenic variants [present]
# {'cancer_type': ['PROSTATE ADENOCARCINOMA'], 'biomarker': ['ATM']}
# 278
# Prostate Adenocarcinoma
# ATM oncogenic variants [present]
# {'cancer_type': ['PROSTATE ADENOCARCINOMA'], 'biomarker': ['ATM']}
# 279
# Prostate Adenocarcinoma
# BARD1 pathogenic variants [present]
# {'cancer_type': ['PROSTATE ADENOCARCINOMA'], 'biomarker': ['BARD1']}
# 280
# Prostate Adenocarcinoma
# BARD1 oncogenic variants [present]
# {'cancer_type': ['PROSTATE ADENOCARCINOMA'], 'biomarker': ['BARD1']}
# 281
# Prostate Adenocarcinoma
# BRIP1 oncogenic variants [present]
# {'cancer_type': ['PROSTATE ADENOCARCINOMA'], 'biomarker': ['BRIP1']}
# 282
# Prostate Adenocarcinoma
# BRIP1 pathogenic variants [present]
# {'cancer_type': ['PROSTATE ADENOCARCINOMA'], 'biomarker': ['BRIP1']}
# 283
# Prostate Adenocarcinoma
# CDK12 pathogenic variants [present]
# {'cancer_type': ['PROSTATE ADENOCARCINOMA'], 'biomarker': ['CDK12']}
# 284
# Prostate Adenocarcinoma
# CDK12 oncogenic variants [present]
# {'cancer_type': ['PROSTATE ADENOCARCINOMA'], 'biomarker': ['CDK12']}
# 285
# Prostate Adenocarcinoma
# CHEK1 pathogenic variants [present]
# {'cancer_type': ['PROSTATE ADENOCARCINOMA'], 'biomarker': ['CHEK1']}
# 286
# Prostate Adenocarcinoma
# CHEK1 oncogenic variants [present]
# {'cancer_type': ['PROSTATE ADENOCARCINOMA'], 'biomarker': ['CHEK1']}
# 287
# Prostate Adenocarcinoma
# CHEK2 pathogenic variants [present]
# {'cancer_type': ['PROSTATE ADENOCARCINOMA'], 'biomarker': ['CHEK2']}
# 288
# Prostate Adenocarcinoma
# CHEK2 oncogenic variants [present]
# {'cancer_type': ['PROSTATE ADENOCARCINOMA'], 'biomarker': ['CHEK2']}
# 289
# Prostate Adenocarcinoma
# FANCL pathogenic variants [present]
# {'cancer_type': ['PROSTATE ADENOCARCINOMA'], 'biomarker': ['FANCL']}
# 290
# Prostate Adenocarcinoma
# FANCL oncogenic variants [present]
# {'cancer_type': ['PROSTATE ADENOCARCINOMA'], 'biomarker': ['FANCL']}
# 291
# Prostate Adenocarcinoma
# PALB2 pathogenic variants [present]
# {'cancer_type': ['PROSTATE ADENOCARCINOMA'], 'biomarker': ['PALB2']}
# 292
# Prostate Adenocarcinoma
# PALB2 oncogenic variants [present]
# {'cancer_type': ['PROSTATE ADENOCARCINOMA'], 'biomarker': ['PALB2']}
# 293
# Prostate Adenocarcinoma
# RAD51B pathogenic variants [present]
# {'cancer_type': ['PROSTATE ADENOCARCINOMA'], 'biomarker': ['RAD51B']}
# 294
# Prostate Adenocarcinoma
# RAD51B oncogenic variants [present]
# {'cancer_type': ['PROSTATE ADENOCARCINOMA'], 'biomarker': ['RAD51B']}
# 295
# Prostate Adenocarcinoma
# RAD51C pathogenic variants [present]
# {'cancer_type': ['PROSTATE ADENOCARCINOMA'], 'biomarker': ['RAD51C']}
# 296
# Prostate Adenocarcinoma
# RAD51C oncogenic variants [present]
# {'cancer_type': ['PROSTATE ADENOCARCINOMA'], 'biomarker': ['RAD51C']}
# 297
# Prostate Adenocarcinoma
# RAD51D pathogenic variants [present]
# {'cancer_type': ['PROSTATE ADENOCARCINOMA'], 'biomarker': ['RAD51D']}
# 298
# Prostate Adenocarcinoma
# RAD51D oncogenic variants [present]
# {'cancer_type': ['PROSTATE ADENOCARCINOMA'], 'biomarker': ['RAD51D']}
# 299
# Prostate Adenocarcinoma
# RAD54L pathogenic variants [present]
# {'cancer_type': ['PROSTATE ADENOCARCINOMA'], 'biomarker': ['RAD54L']}
# 300
# Prostate Adenocarcinoma
# RAD54L oncogenic variants [present]
# {'cancer_type': ['PROSTATE ADENOCARCINOMA'], 'biomarker': ['RAD54L']}
# 301
# Prostate Adenocarcinoma
# BRCA1 oncogenic variants [present]
# {'cancer_type': ['PROSTATE ADENOCARCINOMA'], 'biomarker': ['BRCA1']}
# 302
# Prostate Adenocarcinoma
# BRCA1 pathogenic variants [present]
# {'cancer_type': ['PROSTATE ADENOCARCINOMA'], 'biomarker': ['BRCA1']}
# 303
# Prostate Adenocarcinoma
# BRCA2 oncogenic variants [present]
# {'cancer_type': ['PROSTATE ADENOCARCINOMA'], 'biomarker': ['BRCA2']}
# 304
# Prostate Adenocarcinoma
# BRCA2 pathogenic variants [present]
# {'cancer_type': ['PROSTATE ADENOCARCINOMA'], 'biomarker': ['BRCA2']}
# 305
# Prostate Adenocarcinoma
# BRCA1 oncogenic variants [present]
# {'cancer_type': ['PROSTATE ADENOCARCINOMA'], 'biomarker': ['BRCA1']}
# 306
# Prostate Adenocarcinoma
# BRCA1 pathogenic variants [present]
# {'cancer_type': ['PROSTATE ADENOCARCINOMA'], 'biomarker': ['BRCA1']}
# 307
# Prostate Adenocarcinoma
# BRCA2 oncogenic variants [present]
# {'cancer_type': ['PROSTATE ADENOCARCINOMA'], 'biomarker': ['BRCA2']}
# 308
# Prostate Adenocarcinoma
# BRCA2 pathogenic variants [present]
# {'cancer_type': ['PROSTATE ADENOCARCINOMA'], 'biomarker': ['BRCA2']}
# 309
# Acute Myeloid Leukemia
# IDH1 p.R132C [present]
# {'cancer_type': ['ACUTE MYELOID LEUKEMIA'], 'biomarker': ['IDH1']}
# 310
# Acute Myeloid Leukemia
# IDH1 p.R132G [present]
# {'cancer_type': ['ACUTE MYELOID LEUKEMIA'], 'biomarker': ['IDH1']}
# 311
# Acute Myeloid Leukemia
# IDH1 p.R132H [present]
# {'cancer_type': ['ACUTE MYELOID LEUKEMIA'], 'biomarker': ['IDH1']}
# 312
# Acute Myeloid Leukemia
# IDH1 p.R132L [present]
# {'cancer_type': ['ACUTE MYELOID LEUKEMIA'], 'biomarker': ['IDH1']}
# 313
# Acute Myeloid Leukemia
# IDH1 p.R132S [present]
# {'cancer_type': ['ACUTE MYELOID LEUKEMIA'], 'biomarker': ['IDH1']}
# 314
# Non-Small Cell Lung Cancer
# EGFR Exon 19 (Deletion) [present]
# {'cancer_type': ['NON-SMALL CELL LUNG CANCER'], 'biomarker': ['EGFR']}
# 315
# Non-Small Cell Lung Cancer
# EGFR p.L858R [present]
# {'cancer_type': ['NON-SMALL CELL LUNG CANCER'], 'biomarker': ['EGFR']}
# 316
# Non-Small Cell Lung Cancer
# EGFR p.L858R [present]
# {'cancer_type': ['NON-SMALL CELL LUNG CANCER'], 'biomarker': ['EGFR']}
# 317
# Non-Small Cell Lung Cancer
# EGFR p.L858R [present]
# {'cancer_type': ['NON-SMALL CELL LUNG CANCER'], 'biomarker': ['EGFR']}
# 318
# Non-Small Cell Lung Cancer
# EGFR Exon 19 (Deletion) [present]
# {'cancer_type': ['NON-SMALL CELL LUNG CANCER'], 'biomarker': ['EGFR']}
# 319
# Non-Small Cell Lung Cancer
# EGFR Exon 19 (Deletion) [present]
# {'cancer_type': ['NON-SMALL CELL LUNG CANCER'], 'biomarker': ['EGFR']}
# 320
# Non-Small Cell Lung Cancer
# EGFR p.T790M [present]
# {'cancer_type': ['NON-SMALL CELL LUNG CANCER'], 'biomarker': ['EGFR']}
# 321
# Invasive Breast Carcinoma
# ER positive [present], HER2-negative [present]
# {'cancer_type': ['INVASIVE BREAST CARCINOMA'], 'biomarker': ['ER', 'HER2']}
# 322
# Invasive Breast Carcinoma
# HER2-negative [present], PR positive [present]
# {'cancer_type': ['INVASIVE BREAST CARCINOMA'], 'biomarker': ['HER2', 'PR']}
# 323
# Invasive Breast Carcinoma
# ER positive [present], HER2-negative [present], PR positive [present]
# {'cancer_type': ['INVASIVE BREAST CARCINOMA'], 'biomarker': ['ER', 'HER2', 'PR']}
# 324
# Invasive Breast Carcinoma
# ER positive [present], HER2-negative [present]
# {'cancer_type': ['INVASIVE BREAST CARCINOMA'], 'biomarker': ['ER', 'HER2']}
# 325
# Invasive Breast Carcinoma
# HER2-negative [present], PR positive [present]
# {'cancer_type': ['INVASIVE BREAST CARCINOMA'], 'biomarker': ['HER2', 'PR']}
# 326
# Invasive Breast Carcinoma
# ER positive [present], HER2-negative [present], PR positive [present]
# {'cancer_type': ['INVASIVE BREAST CARCINOMA'], 'biomarker': ['ER', 'HER2', 'PR']}
# 327
# Colorectal Adenocarcinoma
# Wild type KRAS [present], Wild type HRAS [present]
# {'cancer_type': ['COLORECTAL ADENOCARCINOMA'], 'biomarker': ['KRAS', 'HRAS']}
# 328
# Colorectal Adenocarcinoma
# Wild type KRAS [present], Wild type HRAS [present]
# {'cancer_type': ['COLORECTAL ADENOCARCINOMA'], 'biomarker': ['KRAS', 'HRAS']}
# 329
# Non-Small Cell Lung Cancer
# Wild type ALK [present], Wild type EGFR [present]
# {'cancer_type': ['NON-SMALL CELL LUNG CANCER'], 'biomarker': ['ALK', 'EGFR']}
# 330
# Non-Small Cell Lung Cancer
# Wild type ALK [present], Wild type EGFR [present]
# {'cancer_type': ['NON-SMALL CELL LUNG CANCER'], 'biomarker': ['ALK', 'EGFR']}
# 331
# Non-Small Cell Lung Cancer
# PD-L1 >= 1% [present], Wild type ALK [present], Wild type EGFR [present]
# {'cancer_type': ['NON-SMALL CELL LUNG CANCER'], 'biomarker': ['PD-L1', 'ALK', 'EGFR']}
# 332
# Non-Small Cell Lung Cancer
# PD-L1 >= 1% [present]
# {'cancer_type': ['NON-SMALL CELL LUNG CANCER'], 'biomarker': ['PD-L1']}
# 333
# Head and Neck Squamous Cell Carcinoma
# PD-L1 (CPS) >= 1 [present]
# {'cancer_type': ['HEAD AND NECK SQUAMOUS CELL CARCINOMA'], 'biomarker': ['PD-L1', 'CPS']}
# 334
# Any solid tumor
# dMMR [present]
# {'cancer_type': ['ANY SOLID TUMOR'], 'biomarker': ['DMMR']}
# 335
# Any solid tumor
# MSI-H [present]
# {'cancer_type': ['ANY SOLID TUMOR'], 'biomarker': ['MSI-H']}
# 336
# Colorectal Adenocarcinoma
# dMMR [present]
# {'cancer_type': ['COLORECTAL ADENOCARCINOMA'], 'biomarker': ['DMMR']}
# 337
# Colorectal Adenocarcinoma
# MSI-H [present]
# {'cancer_type': ['COLORECTAL ADENOCARCINOMA'], 'biomarker': ['MSI-H']}
# 338
# Adenocarcinoma of the Gastroesophageal Junction
# HER2-positive [present], PD-L1 (CPS) >= 1 [present]
# {'cancer_type': ['ADENOCARCINOMA OF THE GASTROESOPHAGEAL JUNCTION'], 'biomarker': ['HER2', 'PD-L1']}
# 339
# Adenocarcinoma of the Gastroesophageal Junction
# HER2-positive [present], PD-L1 (CPS) >= 1 [present]
# {'cancer_type': ['ADENOCARCINOMA OF THE GASTROESOPHAGEAL JUNCTION'], 'biomarker': ['HER2', 'PD-L1']}
# 340
# Adenocarcinoma of the Gastroesophageal Junction
# HER2-negative [present]
# {'cancer_type': ['ADENOCARCINOMA OF THE GASTROESOPHAGEAL JUNCTION'], 'biomarker': ['HER2']}
# 341
# Adenocarcinoma of the Gastroesophageal Junction
# HER2-negative [present]
# {'cancer_type': ['ADENOCARCINOMA OF THE GASTROESOPHAGEAL JUNCTION'], 'biomarker': ['HER2']}
# 342
# Adenocarcinoma of the Gastroesophageal Junction
# PD-L1 (CPS) >= 10 [present]
# {'cancer_type': ['ADENOCARCINOMA OF THE GASTROESOPHAGEAL JUNCTION'], 'biomarker': ['PD-L1', 'CPS']}
# 343
# Esophageal Adenocarcinoma
# PD-L1 (CPS) >= 10 [present]
# {'cancer_type': ['ESOPHAGEAL ADENOCARCINOMA'], 'biomarker': ['PD-L1', 'CPS']}
# 344
# Cervical Adenocarcinoma
# PD-L1 (CPS) >= 1 [present]
# ...
# {'cancer_type': ['FOLLICULAR LYMPHOMA'], 'biomarker': ['EZH2']}
# 465
# Follicular Lymphoma
# EZH2 p.Y646F [present]
# {'cancer_type': ['FOLLICULAR LYMPHOMA'], 'biomarker': ['EZH2']}
# 466
# Follicular Lymphoma
# EZH2 p.Y646H [present]
# {'cancer_type': ['FOLLICULAR LYMPHOMA'], 'biomarker': ['EZH2']}
# 467
# Follicular Lymphoma
# EZH2 p.Y646S [present]
# {'cancer_type': ['FOLLICULAR LYMPHOMA'], 'biomarker': ['EZH2']}
# 468
# Follicular Lymphoma
# EZH2 p.Y646C [present]
# {'cancer_type': ['FOLLICULAR LYMPHOMA'], 'biomarker': ['EZH2']}
# 469
# Follicular Lymphoma
# EZH2 p.A862G [present]
# {'cancer_type': ['FOLLICULAR LYMPHOMA'], 'biomarker': ['EZH2']}
# 470
# Follicular Lymphoma
# EZH2 p.A692V [present]
# {'cancer_type': ['FOLLICULAR LYMPHOMA'], 'biomarker': ['EZH2']}
# 471
# Prostate Adenocarcinoma
# BRCA1 pathogenic variants [present]
# {'cancer_type': ['PROSTATE ADENOCARCINOMA'], 'biomarker': ['BRCA1']}
# 472
# Prostate Adenocarcinoma
# BRCA2 oncogenic variants [present]
# {'cancer_type': ['PROSTATE ADENOCARCINOMA'], 'biomarker': ['BRCA2']}
# 473
# Prostate Adenocarcinoma
# BRCA2 pathogenic variants [present]
# {'cancer_type': ['PROSTATE ADENOCARCINOMA'], 'biomarker': ['BRCA2']}
# 474
# Prostate Adenocarcinoma
# ATM pathogenic variants [present]
# {'cancer_type': ['PROSTATE ADENOCARCINOMA'], 'biomarker': ['ATM']}
# 475
# Prostate Adenocarcinoma
# ATM oncogenic variants [present]
# {'cancer_type': ['PROSTATE ADENOCARCINOMA'], 'biomarker': ['ATM']}
# 476
# Prostate Adenocarcinoma
# ATR oncogenic variants [present]
# {'cancer_type': ['PROSTATE ADENOCARCINOMA'], 'biomarker': ['ATR']}
# 477
# Prostate Adenocarcinoma
# CDK12 oncogenic variants [present]
# {'cancer_type': ['PROSTATE ADENOCARCINOMA'], 'biomarker': ['CDK12']}
# 478
# Prostate Adenocarcinoma
# ATR pathogenic variants [present]
# {'cancer_type': ['PROSTATE ADENOCARCINOMA'], 'biomarker': ['ATR']}
# 479
# Prostate Adenocarcinoma
# FANCA oncogenic variants [present]
# {'cancer_type': ['PROSTATE ADENOCARCINOMA'], 'biomarker': ['FANCA']}
# 480
# Prostate Adenocarcinoma
# CHEK2 pathogenic variants [present]
# {'cancer_type': ['PROSTATE ADENOCARCINOMA'], 'biomarker': ['CHEK2']}
# 481
# Prostate Adenocarcinoma
# CHEK2 oncogenic variants [present]
# {'cancer_type': ['PROSTATE ADENOCARCINOMA'], 'biomarker': ['CHEK2']}
# 482
# Prostate Adenocarcinoma
# FANCA pathogenic variants [present]
# {'cancer_type': ['PROSTATE ADENOCARCINOMA'], 'biomarker': ['FANCA']}
# 483
# Prostate Adenocarcinoma
# MLH1 oncogenic variants [present]
# {'cancer_type': ['PROSTATE ADENOCARCINOMA'], 'biomarker': ['MLH1']}
# 484
# Prostate Adenocarcinoma
# PALB2 pathogenic variants [present]
# {'cancer_type': ['PROSTATE ADENOCARCINOMA'], 'biomarker': ['PALB2']}
# 485
# Prostate Adenocarcinoma
# PALB2 oncogenic variants [present]
# {'cancer_type': ['PROSTATE ADENOCARCINOMA'], 'biomarker': ['PALB2']}
# 486
# Prostate Adenocarcinoma
# MLH1 pathogenic variants [present]
# {'cancer_type': ['PROSTATE ADENOCARCINOMA'], 'biomarker': ['MLH1']}
# 487
# Prostate Adenocarcinoma
# MRE11 oncogenic variants [present]
# {'cancer_type': ['PROSTATE ADENOCARCINOMA'], 'biomarker': ['MRE11']}
# 488
# Prostate Adenocarcinoma
# RAD51C pathogenic variants [present]
# {'cancer_type': ['PROSTATE ADENOCARCINOMA'], 'biomarker': ['RAD51C']}
# 489
# Prostate Adenocarcinoma
# RAD51C oncogenic variants [present]
# {'cancer_type': ['PROSTATE ADENOCARCINOMA'], 'biomarker': ['RAD51C']}
# 490
# Prostate Adenocarcinoma
# MRE11 pathogenic variants [present]
# {'cancer_type': ['PROSTATE ADENOCARCINOMA'], 'biomarker': ['MRE11']}
# 491
# Prostate Adenocarcinoma
# NBN oncogenic variants [present]
# {'cancer_type': ['PROSTATE ADENOCARCINOMA'], 'biomarker': ['NBN']}
# 492
# Prostate Adenocarcinoma
# NBN pathogenic variants [present]
# {'cancer_type': ['PROSTATE ADENOCARCINOMA'], 'biomarker': ['NBN']}
# 493
# Renal Angiomyolipoma
# TSC1 oncogenic variants [present]
# {'cancer_type': ['RENAL ANGIOMYOLIPOMA'], 'biomarker': ['TSC1']}
# 494
# Renal Angiomyolipoma
# TSC2 oncogenic variants [present]
# {'cancer_type': ['RENAL ANGIOMYOLIPOMA'], 'biomarker': ['TSC2']}
# 495
# Anaplastic Thyroid Cancer
# TSC1 oncogenic variants [present]
# {'cancer_type': ['ANAPLASTIC THYROID CANCER'], 'biomarker': ['TSC1']}
# 496
# Anaplastic Thyroid Cancer
# TSC2 oncogenic variants [present]
# {'cancer_type': ['ANAPLASTIC THYROID CANCER'], 'biomarker': ['TSC2']}
# 497
# Prostate Adenocarcinoma
# CDK12 pathogenic variants [present]
# {'cancer_type': ['PROSTATE ADENOCARCINOMA'], 'biomarker': ['CDK12']}
# 498
# Non-Small Cell Lung Cancer
# EGFR Exon 19 (Deletion) [present]
# {'cancer_type': ['NON-SMALL CELL LUNG CANCER'], 'biomarker': ['EGFR']}
# 499
# Non-Small Cell Lung Cancer
# EGFR p.L858R [present]
# {'cancer_type': ['NON-SMALL CELL LUNG CANCER'], 'biomarker': ['EGFR']}
# 500
# Non-Small Cell Lung Cancer
# EGFR Exon 19 (Deletion) [present]
# {'cancer_type': ['NON-SMALL CELL LUNG CANCER'], 'biomarker': ['EGFR']}
# 501
# Non-Small Cell Lung Cancer
# EGFR p.L858R [present]
# {'cancer_type': ['NON-SMALL CELL LUNG CANCER'], 'biomarker': ['EGFR']}
# 502
# Non-Small Cell Lung Cancer
# EGFR Exon 19 (Deletion) [present]
# {'cancer_type': ['NON-SMALL CELL LUNG CANCER'], 'biomarker': ['EGFR']}
# 503
# Non-Small Cell Lung Cancer
# EGFR p.L858R [present]
# {'cancer_type': ['NON-SMALL CELL LUNG CANCER'], 'biomarker': ['EGFR']}
# 504
# Ovarian Epithelial Tumor
# FOLR1 positive [present]
# {'cancer_type': ['OVARIAN EPITHELIAL TUMOR'], 'biomarker': ['FOLR1']}
# 505
# High-Grade Serous Fallopian Tube Cancer
# FOLR1 positive [present]
# {'cancer_type': ['HIGH-GRADE SEROUS FALLOPIAN TUBE CANCER'], 'biomarker': ['FOLR1']}
# 506
# Peritoneal Serous Carcinoma
# FOLR1 positive [present]
# {'cancer_type': ['PERITONEAL SEROUS CARCINOMA'], 'biomarker': ['FOLR1']}
# 507
# Low-Grade Glioma, NOS
# BRAF rearrangements [present]
# {'cancer_type': ['LOW-GRADE GLIOMA, NOS'], 'biomarker': ['BRAF']}
# 508
# Low-Grade Glioma, NOS
# v::BRAF [present]
# {'cancer_type': ['LOW-GRADE GLIOMA, NOS'], 'biomarker': ['V:', 'BRAF']}
# 509
# Low-Grade Glioma, NOS
# BRAF p.V600E [present]
# {'cancer_type': ['LOW-GRADE GLIOMA, NOS'], 'biomarker': ['BRAF']}
# 510
# Low-Grade Glioma, NOS
# BRAF p.V600K [present]
# {'cancer_type': ['LOW-GRADE GLIOMA, NOS'], 'biomarker': ['BRAF']}
# 511
# Non-Small Cell Lung Cancer
# Wild type ALK [present], Wild type EGFR [present]
# {'cancer_type': ['NON-SMALL CELL LUNG CANCER'], 'biomarker': ['ALK', 'EGFR']}
# 512
# Non-Small Cell Lung Cancer
# Wild type ALK [present], Wild type EGFR [present]
# {'cancer_type': ['NON-SMALL CELL LUNG CANCER'], 'biomarker': ['ALK', 'EGFR']}
# 513
# Non-Small Cell Lung Cancer
# Wild type ALK [present], Wild type EGFR [present]
# {'cancer_type': ['NON-SMALL CELL LUNG CANCER'], 'biomarker': ['ALK', 'EGFR']}
# 514
# Non-Small Cell Lung Cancer
# Wild type ALK [present], Wild type EGFR [present]
# {'cancer_type': ['NON-SMALL CELL LUNG CANCER'], 'biomarker': ['ALK', 'EGFR']}
# 515
# Colorectal Adenocarcinoma
# KRAS p.G12C [present]
# {'cancer_type': ['COLORECTAL ADENOCARCINOMA'], 'biomarker': ['KRAS']}
# 516
# Astrocytoma
# IDH1 p.R132C [present]
# {'cancer_type': ['ASTROCYTOMA'], 'biomarker': ['IDH1']}
# 517
# Astrocytoma
# IDH1 p.R132G [present]
# {'cancer_type': ['ASTROCYTOMA'], 'biomarker': ['IDH1']}
# 518
# Astrocytoma
# IDH1 p.R132H [present]
# {'cancer_type': ['ASTROCYTOMA'], 'biomarker': ['IDH1']}
# 519
# Astrocytoma
# IDH1 p.R132L [present]
# {'cancer_type': ['ASTROCYTOMA'], 'biomarker': ['IDH1']}
# 520
# Astrocytoma
# IDH1 p.R132S [present]
# {'cancer_type': ['ASTROCYTOMA'], 'biomarker': ['IDH1']}
# 521
# Astrocytoma
# IDH2 p.R172K [present]
# {'cancer_type': ['ASTROCYTOMA'], 'biomarker': ['IDH2']}
# 522
# Astrocytoma
# IDH2 p.R172M [present]
# {'cancer_type': ['ASTROCYTOMA'], 'biomarker': ['IDH2']}
# 523
# Astrocytoma
# IDH2 p.R172G [present]
# {'cancer_type': ['ASTROCYTOMA'], 'biomarker': ['IDH2']}
# 524
# Astrocytoma
# IDH2 p.R172S [present]
# {'cancer_type': ['ASTROCYTOMA'], 'biomarker': ['IDH2']}
# 525
# Astrocytoma
# IDH2 p.R172W [present]
# {'cancer_type': ['ASTROCYTOMA'], 'biomarker': ['IDH2']}
# 526
# Oligodendroglioma
# IDH1 p.R132C [present]
# {'cancer_type': ['OLIGODENDROGLIOMA'], 'biomarker': ['IDH1']}
# 527
# Oligodendroglioma
# IDH1 p.R132G [present]
# {'cancer_type': ['OLIGODENDROGLIOMA'], 'biomarker': ['IDH1']}
# 528
# Oligodendroglioma
# IDH1 p.R132H [present]
# {'cancer_type': ['OLIGODENDROGLIOMA'], 'biomarker': ['IDH1']}
# 529
# Oligodendroglioma
# IDH1 p.R132L [present]
# {'cancer_type': ['OLIGODENDROGLIOMA'], 'biomarker': ['IDH1']}
# 530
# Oligodendroglioma
# IDH1 p.R132S [present]
# {'cancer_type': ['OLIGODENDROGLIOMA'], 'biomarker': ['IDH1']}
# 531
# Oligodendroglioma
# IDH2 p.R172K [present]
# {'cancer_type': ['OLIGODENDROGLIOMA'], 'biomarker': ['IDH2']}
# 532
# Oligodendroglioma
# IDH2 p.R172M [present]
# {'cancer_type': ['OLIGODENDROGLIOMA'], 'biomarker': ['IDH2']}
# 533
# Oligodendroglioma
# IDH2 p.R172G [present]
# {'cancer_type': ['OLIGODENDROGLIOMA'], 'biomarker': ['IDH2']}
# 534
# Oligodendroglioma
# IDH2 p.R172S [present]
# {'cancer_type': ['OLIGODENDROGLIOMA'], 'biomarker': ['IDH2']}
# 535
# Oligodendroglioma
# IDH2 p.R172W [present]
# {'cancer_type': ['OLIGODENDROGLIOMA'], 'biomarker': ['IDH2']}
# 536
# Invasive Breast Carcinoma
# ER positive [present], HER2-negative [present]
# {'cancer_type': ['INVASIVE BREAST CARCINOMA'], 'biomarker': ['ER', 'HER2']}
# 537
# Invasive Breast Carcinoma
# HER2-negative [present], PR positive [present]
# {'cancer_type': ['INVASIVE BREAST CARCINOMA'], 'biomarker': ['HER2', 'PR']}
# 538
# Invasive Breast Carcinoma
# ER positive [present], HER2-negative [present], PR positive [present]
# {'cancer_type': ['INVASIVE BREAST CARCINOMA'], 'biomarker': ['ER', 'HER2', 'PR']}
# 539
# Invasive Breast Carcinoma
# ER positive [present], HER2-negative [present]
# {'cancer_type': ['INVASIVE BREAST CARCINOMA'], 'biomarker': ['ER', 'HER2']}
# 540
# Invasive Breast Carcinoma
# HER2-negative [present], PR positive [present]
# {'cancer_type': ['INVASIVE BREAST CARCINOMA'], 'biomarker': ['HER2', 'PR']}
# 541
# Invasive Breast Carcinoma
# ER positive [present], HER2-negative [present], PR positive [present]
# {'cancer_type': ['INVASIVE BREAST CARCINOMA'], 'biomarker': ['ER', 'HER2', 'PR']}
# 542
# Non-Small Cell Lung Cancer
# Wild type ALK [present], Wild type EGFR [present]
# {'cancer_type': ['NON-SMALL CELL LUNG CANCER'], 'biomarker': ['ALK', 'EGFR']}
# 543
# Non-Small Cell Lung Cancer
# Wild type ALK [present], Wild type EGFR [present]
# {'cancer_type': ['NON-SMALL CELL LUNG CANCER'], 'biomarker': ['ALK', 'EGFR']}
# 544
# Non-Small Cell Lung Cancer
# Wild type ALK [present], Wild type EGFR [present]
# {'cancer_type': ['NON-SMALL CELL LUNG CANCER'], 'biomarker': ['ALK', 'EGFR']}
# 545
# Non-Small Cell Lung Cancer
# Wild type ALK [present], Wild type EGFR [present]
# {'cancer_type': ['NON-SMALL CELL LUNG CANCER'], 'biomarker': ['ALK', 'EGFR']}
# 546
# Non-Small Cell Lung Cancer
# Wild type ALK [present], Wild type EGFR [present]
# {'cancer_type': ['NON-SMALL CELL LUNG CANCER'], 'biomarker': ['ALK', 'EGFR']}
# 547
# Colorectal Adenocarcinoma
# dMMR [present]
# {'cancer_type': ['COLORECTAL ADENOCARCINOMA'], 'biomarker': ['DMMR']}
# 548
# Colorectal Adenocarcinoma
# MSI-H [present]
# {'cancer_type': ['COLORECTAL ADENOCARCINOMA'], 'biomarker': ['MSI-H']}
# 549
# Colorectal Adenocarcinoma
# dMMR [present]
# {'cancer_type': ['COLORECTAL ADENOCARCINOMA'], 'biomarker': ['DMMR']}
# 550
# Invasive Breast Carcinoma
# ER positive [present], HER2-negative [present], PIK3CA somatic variants [present]
# {'cancer_type': ['INVASIVE BREAST CARCINOMA'], 'biomarker': ['ER', 'HER2', 'PIK3CA']}
# 551
# Invasive Breast Carcinoma
# HER2-negative [present], PR positive [present], PIK3CA somatic variants [present]
# {'cancer_type': ['INVASIVE BREAST CARCINOMA'], 'biomarker': ['HER2', 'PR', 'PIK3CA']}
# 552
# Invasive Breast Carcinoma
# ER positive [present], HER2-negative [present], PR positive [present], PIK3CA somatic variants [present]
# {'cancer_type': ['INVASIVE BREAST CARCINOMA'], 'biomarker': ['ER', 'HER2', 'PR', 'PIK3CA']}
# 553
# Adenocarcinoma of the Gastroesophageal Junction
# HER2-negative [present], CLDN18.2 >= 75% [present]
# {'cancer_type': ['ADENOCARCINOMA OF THE GASTROESOPHAGEAL JUNCTION'], 'biomarker': ['HER2', 'CLDN18.2']}
# 554
# Adenocarcinoma of the Gastroesophageal Junction
# HER2-negative [present], CLDN18.2 >= 75% [present]
# {'cancer_type': ['ADENOCARCINOMA OF THE GASTROESOPHAGEAL JUNCTION'], 'biomarker': ['HER2', 'CLDN18.2']}
# 555
# Intraductal Papillary Neoplasm of the Bile Duct
# HER2-positive [present]
# {'cancer_type': ['INTRADUCTAL PAPILLARY NEOPLASM OF THE BILE DUCT'], 'biomarker': ['HER2']}
# 556
# Intracholecystic Papillary Neoplasm
# HER2-positive [present]
# {'cancer_type': ['INTRACHOLECYSTIC PAPILLARY NEOPLASM'], 'biomarker': ['HER2']}
# 557
# Cholangiocarcinoma
# HER2-positive [present]
# {'cancer_type': ['CHOLANGIOCARCINOMA'], 'biomarker': ['HER2']}
# 558
# Non-Small Cell Lung Cancer
# v::NRG1 [present]
# {'cancer_type': ['NON-SMALL CELL LUNG CANCER'], 'biomarker': ['NRG1']}
# 559
# Pancreatic Adenocarcinoma
# v::NRG1 [present]
# {'cancer_type': ['PANCREATIC ADENOCARCINOMA'], 'biomarker': ['NRG1']}
# 560
# Non-Small Cell Lung Cancer
# v::ALK [present]
# {'cancer_type': ['NON-SMALL CELL LUNG CANCER'], 'biomarker': ['ALK']}
# 561
# Colorectal Adenocarcinoma
# BRAF p.V600E [present]
# {'cancer_type': ['COLORECTAL ADENOCARCINOMA'], 'biomarker': ['BRAF']}
# 562
# Chronic Myeloid Leukemia, BCR-ABL1+
# BCR::ABL1 [present]
# {'cancer_type': ['CHRONIC MYELOID LEUKEMIA, BCR-ABL1+'], 'biomarker': ['BCR', 'ABL1']}
# 563
# Non-Small Cell Lung Cancer
# Wild type ALK [present], Wild type EGFR [present]
# {'cancer_type': ['NON-SMALL CELL LUNG CANCER'], 'biomarker': ['ALK', 'EGFR']}
# 564
# Non-Small Cell Lung Cancer
# Wild type ALK [present], Wild type EGFR [present]
# {'cancer_type': ['NON-SMALL CELL LUNG CANCER'], 'biomarker': ['ALK', 'EGFR']}
# 565
# Non-Small Cell Lung Cancer
# Wild type ALK [present], Wild type EGFR [present]
# {'cancer_type': ['NON-SMALL CELL LUNG CANCER'], 'biomarker': ['ALK', 'EGFR']}
# 566
# Non-Small Cell Lung Cancer
# Wild type ALK [present], Wild type EGFR [present]
# {'cancer_type': ['NON-SMALL CELL LUNG CANCER'], 'biomarker': ['ALK', 'EGFR']}
# 567
# Non-Small Cell Lung Cancer
# Wild type ALK [present], Wild type EGFR [present]
# {'cancer_type': ['NON-SMALL CELL LUNG CANCER'], 'biomarker': ['ALK', 'EGFR']}
# 568
# Acute Lymphoid Leukemia
# t(KMT2A;v) [present]
# {'cancer_type': ['ACUTE LYMPHOID LEUKEMIA'], 'biomarker': ['KMT2A']}
# 569
# Acute Myeloid Leukemia
# t(KMT2A;v) [present]
# {'cancer_type': ['ACUTE MYELOID LEUKEMIA'], 'biomarker': ['KMT2A']}
# 570
# Burkitt Lymphoma
# t(KMT2A;v) [present]
# {'cancer_type': ['BURKITT LYMPHOMA'], 'biomarker': ['KMT2A']}
# 571
# Acute Leukemias of Ambiguous Lineage
# t(KMT2A;v) [present]
# {'cancer_type': ['ACUTE LEUKEMIAS OF AMBIGUOUS LINEAGE'], 'biomarker': ['KMT2A']}
# 572
# Invasive Breast Carcinoma
# HER2-negative [present], PR positive [present]
# {'cancer_type': ['INVASIVE BREAST CARCINOMA'], 'biomarker': ['HER2', 'PR']}
# 573
# Invasive Breast Carcinoma
# ER positive [present], HER2-negative [present], PR positive [present]
# {'cancer_type': ['INVASIVE BREAST CARCINOMA'], 'biomarker': ['ER', 'HER2', 'PR']}
# 574
# Invasive Breast Carcinoma
# ER positive [present], HER2-negative [present]
# {'cancer_type': ['INVASIVE BREAST CARCINOMA'], 'biomarker': ['ER', 'HER2']}
# 575
# Invasive Breast Carcinoma
# HER2-negative [present], PR positive [present]
# {'cancer_type': ['INVASIVE BREAST CARCINOMA'], 'biomarker': ['HER2', 'PR']}
# 576
# Invasive Breast Carcinoma
# ER positive [present], HER2-negative [present], PR positive [present]
# {'cancer_type': ['INVASIVE BREAST CARCINOMA'], 'biomarker': ['ER', 'HER2', 'PR']}
# 577
# Invasive Breast Carcinoma
# ER positive [present], HER2-negative [present]
# {'cancer_type': ['INVASIVE BREAST CARCINOMA'], 'biomarker': ['ER', 'HER2']}
# 578
# Invasive Breast Carcinoma
# HER2-negative [present], PR positive [present]
# {'cancer_type': ['INVASIVE BREAST CARCINOMA'], 'biomarker': ['HER2', 'PR']}
# 579
# Colorectal Adenocarcinoma
# MSI-H [present]
# {'cancer_type': ['COLORECTAL ADENOCARCINOMA'], 'biomarker': ['MSI-H']}
# 580
# Non-Small Cell Lung Cancer
# v::ROS1 [present]
# {'cancer_type': ['NON-SMALL CELL LUNG CANCER'], 'biomarker': ['ROS1']}
# 581
# Lung Non-Squamous Non-Small Cell Carcinoma
# c-Met >= 50% [present]
# {'cancer_type': ['LUNG NON-SQUAMOUS NON-SMALL CELL CARCINOMA'], 'biomarker': ['C-MET']}
# 582
# Low-Grade Serous Ovarian Cancer
# KRAS p.G12C [present]
# {'cancer_type': ['LOW-GRADE SEROUS OVARIAN CANCER'], 'biomarker': ['KRAS']}
# 583
# Low-Grade Serous Ovarian Cancer
# KRAS p.G12V [present]
# {'cancer_type': ['LOW-GRADE SEROUS OVARIAN CANCER'], 'biomarker': ['KRAS']}

# %%
moalmanac_new_draft
# Out:
#      statement_id      approval_status approval_org  \
# 0               0  Regulatory approval          fda
# 1               1  Regulatory approval          fda
# 2               2  Regulatory approval          fda
# 3               3  Regulatory approval          fda
# 4               4  Regulatory approval          fda
# ..            ...                  ...          ...
# 579           624  Regulatory approval          fda
# 580           625  Regulatory approval          fda
# 581           626  Regulatory approval          fda
# 582           627  Regulatory approval          fda
# 583           628  Regulatory approval          fda
#
#                                            description  \
# 0    The U.S. Food and Drug Administration (FDA) gr...
# 1    The U.S. Food and Drug Administration (FDA) gr...
# 2    The U.S. Food and Drug Administration (FDA) gr...
# 3    The U.S. Food and Drug Administration (FDA) gr...
# 4    The U.S. Food and Drug Administration (FDA) gr...
# ..                                                 ...
# 579  The U.S. Food and Drug Administration (FDA) gr...
# 580  The U.S. Food and Drug Administration (FDA) gr...
# 581  The U.S. Food and Drug Administration (FDA) gr...
# 582  The U.S. Food and Drug Administration (FDA) gr...
# 583  The U.S. Food and Drug Administration (FDA) gr...
#
#                                             indication  \
# 0    Verzenio is a kinase inhibitor indicated in co...
# 1    Verzenio is a kinase inhibitor indicated in co...
# 2    Verzenio is a kinase inhibitor indicated in co...
# 3    Verzenio is a kinase inhibitor indicated in co...
# 4    Verzenio is a kinase inhibitor indicated in co...
# ..                                                 ...
# 579  OPDIVO is a programmed death receptor-1 (PD-1)...
# 580  IBTROZI is a kinase inhibitor indicated for th...
# 581  EMRELIS is a c-Met-directed antibody and micro...
# 582  AVMAPKI FAKZYNJA CO-PACK, a combination of avu...
# 583  AVMAPKI FAKZYNJA CO-PACK, a combination of avu...
#
#                                     cancer_type  \
# 0                     Invasive Breast Carcinoma
# 1                     Invasive Breast Carcinoma
# 2                     Invasive Breast Carcinoma
# 3                     Invasive Breast Carcinoma
# 4                     Invasive Breast Carcinoma
# ..                                          ...
# 579                   Colorectal Adenocarcinoma
# 580                  Non-Small Cell Lung Cancer
# 581  Lung Non-Squamous Non-Small Cell Carcinoma
# 582             Low-Grade Serous Ovarian Cancer
# 583             Low-Grade Serous Ovarian Cancer
#
#                                              biomarker  \
# 0       ER positive [present], HER2-negative [present]
# 1       HER2-negative [present], PR positive [present]
# 2    ER positive [present], HER2-negative [present]...
# 3       ER positive [present], HER2-negative [present]
# 4       HER2-negative [present], PR positive [present]
# ..                                                 ...
# 579                                    MSI-H [present]
# 580                                  v::ROS1 [present]
# 581                             c-Met >= 50% [present]
# 582                              KRAS p.G12C [present]
# 583                              KRAS p.G12V [present]
#
#                        therapy_drug     therapy_approach  \
# 0      ['Abemaciclib', 'Tamoxifen']  Combination therapy
# 1      ['Abemaciclib', 'Tamoxifen']  Combination therapy
# 2      ['Abemaciclib', 'Tamoxifen']  Combination therapy
# 3    ['Anastrozole', 'Abemaciclib']  Combination therapy
# 4    ['Anastrozole', 'Abemaciclib']  Combination therapy
# ..                              ...                  ...
# 579     ['Ipilimumab', 'Nivolumab']  Combination therapy
# 580               ['Taletrectinib']          Monotherapy
# 581       ['Telisotuzumab Vedotin']          Monotherapy
# 582  ['Avutometinib', 'Defactinib']  Combination therapy
# 583  ['Avutometinib', 'Defactinib']  Combination therapy
#
#                                       therapy_strategy  \
# 0    ['CDK4/6 inhibition', 'Estrogen receptor inhib...
# 1    ['CDK4/6 inhibition', 'Estrogen receptor inhib...
# 2    ['CDK4/6 inhibition', 'Estrogen receptor inhib...
# 3        ['Aromatase inhibition', 'CDK4/6 inhibition']
# 4        ['Aromatase inhibition', 'CDK4/6 inhibition']
# ..                                                 ...
# 579     ['CTLA-4 inhibition', 'PD-1/PD-L1 inhibition']
# 580             ['NTRK inhibition', 'ROS1 inhibition']
# 581                                 ['MET inhibition']
# 582  ['MEK inhibition', 'RAF inhibition', 'FAK inhi...
# 583  ['MEK inhibition', 'RAF inhibition', 'FAK inhi...
#
#                                  therapy_type  \
# 0     ['Targeted therapy', 'Hormone therapy']
# 1     ['Targeted therapy', 'Hormone therapy']
# 2     ['Targeted therapy', 'Hormone therapy']
# 3     ['Hormone therapy', 'Targeted therapy']
# 4     ['Hormone therapy', 'Targeted therapy']
# ..                                        ...
# 579        ['Immunotherapy', 'Immunotherapy']
# 580                      ['Targeted therapy']
# 581                      ['Targeted therapy']
# 582  ['Targeted therapy', 'Targeted therapy']
# 583  ['Targeted therapy', 'Targeted therapy']
#
#                                           approval_url publication_date  \
# 0    https://www.accessdata.fda.gov/drugsatfda_docs...       2023-03-03
# 1    https://www.accessdata.fda.gov/drugsatfda_docs...       2023-03-03
# 2    https://www.accessdata.fda.gov/drugsatfda_docs...       2023-03-03
# 3    https://www.accessdata.fda.gov/drugsatfda_docs...       2023-03-03
# 4    https://www.accessdata.fda.gov/drugsatfda_docs...       2023-03-03
# ..                                                 ...              ...
# 579  https://www.accessdata.fda.gov/drugsatfda_docs...       2025-04-11
# 580  https://www.accessdata.fda.gov/drugsatfda_docs...       2025-06-11
# 581  https://www.accessdata.fda.gov/drugsatfda_docs...       2025-05-14
# 582  https://www.accessdata.fda.gov/drugsatfda_docs...       2025-05-08
# 583  https://www.accessdata.fda.gov/drugsatfda_docs...       2025-05-08
#
#                                                context  \
# 0    Approval status: Regulatory approval (fda)\nDe...
# 1    Approval status: Regulatory approval (fda)\nDe...
# 2    Approval status: Regulatory approval (fda)\nDe...
# 3    Approval status: Regulatory approval (fda)\nDe...
# 4    Approval status: Regulatory approval (fda)\nDe...
# ..                                                 ...
# 579  Approval status: Regulatory approval (fda)\nDe...
# 580  Approval status: Regulatory approval (fda)\nDe...
# 581  Approval status: Regulatory approval (fda)\nDe...
# 582  Approval status: Regulatory approval (fda)\nDe...
# 583  Approval status: Regulatory approval (fda)\nDe...
#
#                                          entities_dict  \
# 0    {"cancer_type": ["Invasive Breast Carcinoma"],...
# 1    {"cancer_type": ["Invasive Breast Carcinoma"],...
# 2    {"cancer_type": ["Invasive Breast Carcinoma"],...
# 3    {"cancer_type": ["Invasive Breast Carcinoma"],...
# 4    {"cancer_type": ["Invasive Breast Carcinoma"],...
# ..                                                 ...
# 579  {"cancer_type": ["Colorectal Adenocarcinoma"],...
# 580  {"cancer_type": ["Non-Small Cell Lung Cancer"]...
# 581  {"cancer_type": ["Lung Non-Squamous Non-Small ...
# 582  {"cancer_type": ["Low-Grade Serous Ovarian Can...
# 583  {"cancer_type": ["Low-Grade Serous Ovarian Can...
#
#                             standardized_entities_dict
# 0    {"cancer_type": ["INVASIVE BREAST CARCINOMA"],...
# 1    {"cancer_type": ["INVASIVE BREAST CARCINOMA"],...
# 2    {"cancer_type": ["INVASIVE BREAST CARCINOMA"],...
# 3    {"cancer_type": ["INVASIVE BREAST CARCINOMA"],...
# 4    {"cancer_type": ["INVASIVE BREAST CARCINOMA"],...
# ..                                                 ...
# 579  {"cancer_type": ["COLORECTAL ADENOCARCINOMA"],...
# 580  {"cancer_type": ["NON-SMALL CELL LUNG CANCER"]...
# 581  {"cancer_type": ["LUNG NON-SQUAMOUS NON-SMALL ...
# 582  {"cancer_type": ["LOW-GRADE SEROUS OVARIAN CAN...
# 583  {"cancer_type": ["LOW-GRADE SEROUS OVARIAN CAN...
#
# [584 rows x 16 columns]

# %%
moalmanac_new_draft.to_csv(f"{root_dir}/data/latest_db/moalmanac-draft.dereferenced.unique.context_db.standardized_entities.csv", index=False)

# %% [markdown]
# #### BioBERT NER extraction of entities from synthetic user queries

# %%
synthetic_query=old_moalmanac_db['prompt'].values

# %%
#extract BioBERT NER from synthetic user queries and standardize entities
def query_biobert_ner(query, model, tokenizer):
    entities = ner_predict_entities(query, model, tokenizer)
    entities_dict = {}
    
    for e in entities:
        if e['type'] == 'Cancer':
            entities_dict.setdefault('cancer_type', []).append(e['text'].upper())
        if e['type'] == 'Gene_or_gene_product':
            entities_dict.setdefault('biomarker', []).append(e['text'].upper())
    return entities, entities_dict
    
#run for all synthetic queries    
biobert_entities_list = []
standardized_entities_dict_list = []
for i, query in enumerate(synthetic_query):
    biobert_entities, standardized_entities_dict = query_biobert_ner(query, model, tokenizer)
    biobert_entities_list.append(biobert_entities)
    standardized_entities_dict_list.append(standardized_entities_dict)    
    
    if i % 10 == 0:
        print(i)
        print(biobert_entities)
        print(standardized_entities_dict)
# Out:
# 0
# [{'type': 'Cancer', 'text': 'chronic myelogenous leukemia'}, {'type': 'Organism', 'text': 'patient'}, {'type': 'Gene_or_gene_product', 'text': 'BCR'}, {'type': 'Gene_or_gene_product', 'text': 'ABL1'}]
# {'cancer_type': ['CHRONIC MYELOGENOUS LEUKEMIA'], 'biomarker': ['BCR', 'ABL1']}
# 10
# [{'type': 'Cancer', 'text': 'cholangiocarcinoma'}, {'type': 'Organism', 'text': 'patient'}, {'type': 'Gene_or_gene_product', 'text': 'FGFR2'}]
# {'cancer_type': ['CHOLANGIOCARCINOMA'], 'biomarker': ['FGFR2']}
# 20
# [{'type': 'Cancer', 'text': 'myelodysplastic'}, {'type': 'Organism', 'text': 'patient'}, {'type': 'Gene_or_gene_product', 'text': 'PDGFRA'}]
# {'cancer_type': ['MYELODYSPLASTIC'], 'biomarker': ['PDGFRA']}
# 30
# [{'type': 'Cancer', 'text': 'melanoma'}, {'type': 'Organism', 'text': 'patient'}, {'type': 'Gene_or_gene_product', 'text': 'BRAF'}]
# {'cancer_type': ['MELANOMA'], 'biomarker': ['BRAF']}
# 40
# [{'type': 'Cancer', 'text': 'colorectal cancer'}, {'type': 'Organism', 'text': 'patient'}, {'type': 'Gene_or_gene_product', 'text': 'BRAF'}]
# {'cancer_type': ['COLORECTAL CANCER'], 'biomarker': ['BRAF']}
# 50
# [{'type': 'Cancer', 'text': 'peritoneal cancer'}, {'type': 'Organism', 'text': 'patient'}, {'type': 'Gene_or_gene_product', 'text': 'BRCA1'}]
# {'cancer_type': ['PERITONEAL CANCER'], 'biomarker': ['BRCA1']}
# 60
# [{'type': 'Cancer', 'text': 'peritoneal cancer'}, {'type': 'Organism', 'text': 'patient'}, {'type': 'Gene_or_gene_product', 'text': 'BRCA2'}]
# {'cancer_type': ['PERITONEAL CANCER'], 'biomarker': ['BRCA2']}
# 70
# [{'type': 'Cancer', 'text': 'prostate cancer'}, {'type': 'Organism', 'text': 'patient'}, {'type': 'Gene_or_gene_product', 'text': 'CHEK1'}, {'type': 'Cancer', 'text': 'prostate cancer'}]
# {'cancer_type': ['PROSTATE CANCER', 'PROSTATE CANCER'], 'biomarker': ['CHEK1']}
# 80
# [{'type': 'Cancer', 'text': 'follicular lymphoma'}, {'type': 'Organism', 'text': 'patient'}, {'type': 'Gene_or_gene_product', 'text': 'EZH2'}]
# {'cancer_type': ['FOLLICULAR LYMPHOMA'], 'biomarker': ['EZH2']}
# 90
# [{'type': 'Cancer', 'text': 'acute myeloid leukemia'}, {'type': 'Organism', 'text': 'patient'}, {'type': 'Gene_or_gene_product', 'text': 'IDH1'}]
# {'cancer_type': ['ACUTE MYELOID LEUKEMIA'], 'biomarker': ['IDH1']}
# 100
# [{'type': 'Cancer', 'text': 'gastrointestinal stromal tumor'}, {'type': 'Organism', 'text': 'patient'}, {'type': 'Gene_or_gene_product', 'text': 'KIT'}]
# {'cancer_type': ['GASTROINTESTINAL STROMAL TUMOR'], 'biomarker': ['KIT']}
# 110
# [{'type': 'Cancer', 'text': 'non - small cell lung cancer'}, {'type': 'Organism', 'text': 'patient'}, {'type': 'Gene_or_gene_product', 'text': 'MET'}]
# {'cancer_type': ['NON - SMALL CELL LUNG CANCER'], 'biomarker': ['MET']}
# 120
# [{'type': 'Cancer', 'text': 'medullary thyroid cancer'}, {'type': 'Organism', 'text': 'patient'}, {'type': 'Gene_or_gene_product', 'text': 'RET'}]
# {'cancer_type': ['MEDULLARY THYROID CANCER'], 'biomarker': ['RET']}
# 130
# [{'type': 'Cancer', 'text': 'breast cancer'}, {'type': 'Organism', 'text': 'patient'}, {'type': 'Gene_or_gene_product', 'text': 'BRCA1'}, {'type': 'Gene_or_gene_product', 'text': 'her2'}]
# {'cancer_type': ['BREAST CANCER'], 'biomarker': ['BRCA1', 'HER2']}
# 140
# [{'type': 'Cancer', 'text': 'epithelial ovarian cancer'}, {'type': 'Organism', 'text': 'patient'}, {'type': 'Gene_or_gene_product', 'text': 'BRCA2'}]
# {'cancer_type': ['EPITHELIAL OVARIAN CANCER'], 'biomarker': ['BRCA2']}
# 150
# [{'type': 'Cancer', 'text': 'gastic adenocarcinoma'}, {'type': 'Organism', 'text': 'patient'}, {'type': 'Gene_or_gene_product', 'text': 'ERBB2'}]
# {'cancer_type': ['GASTIC ADENOCARCINOMA'], 'biomarker': ['ERBB2']}
# 160
# [{'type': 'Cancer', 'text': 'solid tumor'}, {'type': 'Organism', 'text': 'patient'}]
# {'cancer_type': ['SOLID TUMOR']}
# 170
# [{'type': 'Cancer', 'text': 'solid tumor'}, {'type': 'Organism', 'text': 'patient'}, {'type': 'Gene_or_gene_product', 'text': 'RET'}]
# {'cancer_type': ['SOLID TUMOR'], 'biomarker': ['RET']}
# 180
# [{'type': 'Cancer', 'text': 'prostate cancer'}, {'type': 'Organism', 'text': 'patient'}, {'type': 'Gene_or_gene_product', 'text': 'BRCA1'}]
# {'cancer_type': ['PROSTATE CANCER'], 'biomarker': ['BRCA1']}
# 190
# [{'type': 'Cancer', 'text': 'prostate cancer'}, {'type': 'Organism', 'text': 'patient'}, {'type': 'Gene_or_gene_product', 'text': 'BRCA1'}]
# {'cancer_type': ['PROSTATE CANCER'], 'biomarker': ['BRCA1']}
# 200
# [{'type': 'Cancer', 'text': 'prostate cancer'}, {'type': 'Organism', 'text': 'patient'}, {'type': 'Gene_or_gene_product', 'text': 'BRCA1'}]
# {'cancer_type': ['PROSTATE CANCER'], 'biomarker': ['BRCA1']}
# 210
# [{'type': 'Cancer', 'text': 'breast cancer'}, {'type': 'Organism', 'text': 'patient'}, {'type': 'Gene_or_gene_product', 'text': 'AKT1'}]
# {'cancer_type': ['BREAST CANCER'], 'biomarker': ['AKT1']}
# 220
# [{'type': 'Cancer', 'text': 'non - small cell lung cancer'}, {'type': 'Organism', 'text': 'patient'}, {'type': 'Gene_or_gene_product', 'text': 'EGFR'}]
# {'cancer_type': ['NON - SMALL CELL LUNG CANCER'], 'biomarker': ['EGFR']}
# 230
# [{'type': 'Cancer', 'text': 'acute lymphoblastic leukemia'}, {'type': 'Organism', 'text': 'patient'}, {'type': 'Gene_or_gene_product', 'text': 'BCR'}, {'type': 'Gene_or_gene_product', 'text': 'ABL1'}]
# {'cancer_type': ['ACUTE LYMPHOBLASTIC LEUKEMIA'], 'biomarker': ['BCR', 'ABL1']}

# %%
# synthetic_query_ner.to_csv(f"{root_dir}/data/synthetic_query_ner_entities.csv", index=False)
with open("entities/synthetic_query_ner_entities.json", "w") as f:
    json.dump(standardized_entities_dict_list, f)

# %%
with open("entities/synthetic_query_ner_entities.json", "r") as f:
    standardized_entities_dict_list = json.load(f)
len(standardized_entities_dict_list)
# Out:
# 234

# %%
#load all ner results
ner_entities=pd.read_csv(os.path.join(root_dir, 'data/synthetic_query_ner_entities_all_methods.csv'))

#merge biobert ner entities
ner_entities['BioNLP13CG_biobert_ner_entities'] = synthetic_query_ner['biobert_entities']
ner_entities['extracted_entities_dict'] = synthetic_query_ner['standardized_entities_dict']
ner_entities
# Out:
#                                      synthetic_queries  \
# 0    If a chronic myelogenous leukemia patient has ...
# 1    If a chronic myelogenous leukemia patient has ...
# 2    If a acute lymphoblastic leukemia patient has ...
# 3    If a acute lymphoblastic leukemia patient has ...
# 4    If a chronic myeloid leukemia patient has a re...
# ..                                                 ...
# 178  If a anaplastic large cell lymphoma (alcl) pat...
# 179  If a non-small cell lung cancer patient has a ...
# 180  If a prostate cancer patient has a somatic var...
# 181  If a acute lymphoblastic leukemia patient has ...
# 182  If a chronic myeloid leukemia patient has a so...
#
#                          spacy_ner_bionlp13cg_entities  \
# 0    (chronic myelogenous leukemia patient, BCR, AB...
# 1    (chronic myelogenous leukemia patient, BCR, AB...
# 2    (acute lymphoblastic leukemia patient, BCR, AB...
# 3    (acute lymphoblastic leukemia patient, BCR, AB...
# 4    (chronic myeloid leukemia patient, BCR, ABL1, ...
# ..                                                 ...
# 178  (anaplastic large cell lymphoma, patient, ALK,...
# 179  (non-small cell lung cancer patient, ROS1, lines)
# 180            (prostate cancer patient, MRE11, lines)
# 181  (acute lymphoblastic leukemia patient, ABL1, l...
# 182    (chronic myeloid leukemia patient, ABL1, lines)
#
#                    spacy_ner_bc5cdr_entities  \
# 0            (chronic myelogenous leukemia,)
# 1            (chronic myelogenous leukemia,)
# 2            (acute lymphoblastic leukemia,)
# 3            (acute lymphoblastic leukemia,)
# 4                (chronic myeloid leukemia,)
# ..                                       ...
# 178  (anaplastic, large cell lymphoma, alcl)
# 179            (non-small cell lung cancer,)
# 180  (prostate cancer, castration-resistant)
# 181          (acute lymphoblastic leukemia,)
# 182              (chronic myeloid leukemia,)
#
#                        BioNLP13CG_biobert_ner_entities  \
# 0    [{"type": "Cancer", "text": "chronic myelogeno...
# 1    [{"type": "Cancer", "text": "chronic myelogeno...
# 2    [{"type": "Cancer", "text": "acute lymphoblast...
# 3    [{"type": "Cancer", "text": "acute lymphoblast...
# 4    [{"type": "Cancer", "text": "chronic myeloid l...
# ..                                                 ...
# 178  [{"type": "Cancer", "text": "anaplastic large ...
# 179  [{"type": "Cancer", "text": "non - small cell ...
# 180  [{"type": "Cancer", "text": "prostate cancer"}...
# 181  [{"type": "Cancer", "text": "acute lymphoblast...
# 182  [{"type": "Cancer", "text": "chronic myeloid l...
#
#                                extracted_entities_dict
# 0    {"cancer_type": ["CHRONIC MYELOGENOUS LEUKEMIA...
# 1    {"cancer_type": ["CHRONIC MYELOGENOUS LEUKEMIA...
# 2    {"cancer_type": ["ACUTE LYMPHOBLASTIC LEUKEMIA...
# 3    {"cancer_type": ["ACUTE LYMPHOBLASTIC LEUKEMIA...
# 4    {"cancer_type": ["CHRONIC MYELOID LEUKEMIA"], ...
# ..                                                 ...
# 178  {"cancer_type": ["ANAPLASTIC LARGE CELL LYMPHO...
# 179  {"cancer_type": ["NON - SMALL CELL LUNG CANCER...
# 180  {"cancer_type": ["PROSTATE CANCER"], "biomarke...
# 181  {"cancer_type": ["ACUTE LYMPHOBLASTIC LEUKEMIA...
# 182  {"cancer_type": ["CHRONIC MYELOID LEUKEMIA"], ...
#
# [183 rows x 5 columns]

# %%
ner_entities.to_csv(f"{root_dir}/data/synthetic_query_ner_entities_all_methods.csv", index=False)

# %% [markdown]
# ### Exact and fuzzy matching

# %% [markdown]
# Load synthetic query entities and db entities

# %%
#load synthetic query entities 
synthetic_query_ner = pd.read_csv(f"{root_dir}/data/synthetic_query_ner_entities.csv")
synthetic_query_ner["standardized_entities_dict"] = synthetic_query_ner["standardized_entities_dict"].apply(ast.literal_eval)

#and moalmanac entities
moalmanac_db = pd.read_csv(f"{root_dir}/data/latest_db/moalmanac-draft.dereferenced.unique.context_db.standardized_entities.csv")
moalmanac_db['standardized_entities_dict'] = moalmanac_db['standardized_entities_dict'].apply(ast.literal_eval)

# %%
from rapidfuzz import fuzz

def check_list(input):
    if isinstance(input, list):
        input = input
    else:
        input = [input]
    return input

def match_entities(user_entities, db, fuzzy_thres=70, id_col='statement_id', entities_col='standardized_entities_dict', context_col='context'):
    """
    Calculate score based on matching cancer types and biomarkers between user's query and the database
    
        Arguments:
        user_entities (dict): A dictionary with 'cancer_type' and 'biomarker' entities extracted using biobert
        db (DataFrame): A context database with 'cancer_type' and 'biomarker' entities extracted using biobert, context, and id

    """
    
    user_cancer = user_entities['cancer_type']
    user_biomarker = user_entities['biomarker']
    user_cancer = check_list(user_cancer)
    user_biomarker = check_list(user_biomarker)
    match_score_all=[]
    
    #iterate over all db entities
    for idx, row in db.iterrows():
        #entities dict
        db_entities = row[entities_col]
        
        #initialize matching score
        score=0
        
        #append matching count
        for db_cancer in db_entities['cancer_type']: 
            db_cancer = check_list(db_cancer)
            if len(set(db_cancer) & set(user_cancer)) > 0:
                score += len(set(db_cancer) & set(user_cancer))
            elif any(fuzz.ratio(dbc, uc) > fuzzy_thres for uc in user_cancer for dbc in db_cancer):
                score += 0.5
        
        for db_biomarker in db_entities['biomarker']:
            db_biomarker = check_list(db_biomarker)
            if len(set(db_biomarker) & set(user_biomarker)) > 0:
                score += len(set(db_biomarker) & set(user_biomarker))
            elif any(fuzz.ratio(dbb, ub) > fuzzy_thres for ub in user_biomarker for dbb in db_biomarker):
                score += 0.5

        if score > 0:
            match_score_all.append((row[id_col], score, row[entities_col], row[context_col]))
        
    #sort by score descending
    match_score_all.sort(key=lambda x: x[1], reverse=True)
    return match_score_all

# %%
# test_idx_list = split_ranges(synthetic_query_ner.shape[0], 10, 50)
test_idx = 0
match_score_all=match_entities(synthetic_query_ner['standardized_entities_dict'][test_idx], moalmanac_db)
print(synthetic_query_ner['standardized_entities_dict'][test_idx])
match_score_all
# Out:
# {'cancer_type': ['CHRONIC MYELOGENOUS LEUKEMIA'], 'biomarker': ['BCR', 'ABL1']}
# [(32,
#   3,
#   {'cancer_type': ['CHRONIC MYELOGENOUS LEUKEMIA'],
#    'biomarker': ['BCR', 'ABL1']},
#   'Approval status: Regulatory approval (fda)\nDescription: The U.S. Food and Drug Administration granted approval to asciminib for the treatment of adult patients with previously treated philadelphia chromosome-positive chronic myeloid leukemia (Ph+ CML) in chronic phase (CP).\nIndication: SCEMBLIX is a kinase inhibitor indicated for the treatment of adult patients with previously treated philadelphia chromosome-positive chronic myeloid leukemia (Ph+ CML) in chronic phase (CP).\nCancer type: Chronic Myelogenous Leukemia\nBiomarkers: BCR::ABL1 [present]\nTherapy: Asciminib\nTherapy approach: Monotherapy\nTherapy strategy: BCR-ABL inhibition\nTherapy type: Targeted therapy\nApproval url: https://www.accessdata.fda.gov/drugsatfda_docs/label/2024/215358Orig1s008lbl.pdf\nPublication date: 2024-10-29'),
#  (33,
#   3,
#   {'cancer_type': ['CHRONIC MYELOGENOUS LEUKEMIA'],
#    'biomarker': ['BCR', 'ABL1']},
#   'Approval status: Regulatory approval (fda)\nDescription: The U.S. Food and Drug Administration granted approval to asciminib for the treatment of adult patients with philadelphia chromosome-positive chronic myeloid leukemia (Ph+ CML) in chronic phase (CP) with the T315I mutation.\nIndication: SCEMBLIX is a kinase inhibitor indicated for the treatment of adult patients with Ph+ CML in CP with the T315I mutation.\nCancer type: Chronic Myelogenous Leukemia\nBiomarkers: BCR::ABL1 [present], ABL1 p.T315I [present]\nTherapy: Asciminib\nTherapy approach: Monotherapy\nTherapy strategy: BCR-ABL inhibition\nTherapy type: Targeted therapy\nApproval url: https://www.accessdata.fda.gov/drugsatfda_docs/label/2024/215358Orig1s008lbl.pdf\nPublication date: 2024-10-29'),
#  (51,
#   3,
#   {'cancer_type': ['CHRONIC MYELOGENOUS LEUKEMIA'],
#    'biomarker': ['BCR', 'ABL1']},
#   'Approval status: Regulatory approval (fda)\nDescription: The U.S. Food and Drug Administration granted approval to bosutinib for the treatment of adult and pediatric patients 1 year of age and older with chronic phase Philadelphia chromosome-positive (Ph+) chronic myelogenous leukemia (CML), newly-diagnosed or resistant or intolerant to prior therapy.\nIndication: BOSULIF is a kinase inhibitor indicated for the treatment of adult and pediatric patients 1 year of age and older with chronic phase Ph+ chronic myelogenous leukemia (CML), newly-diagnosed or resistant or intolerant to prior therapy.\nCancer type: Chronic Myelogenous Leukemia\nBiomarkers: BCR::ABL1 [present]\nTherapy: Bosutinib\nTherapy approach: Monotherapy\nTherapy strategy: BCR-ABL inhibition\nTherapy type: Targeted therapy\nApproval url: https://www.accessdata.fda.gov/drugsatfda_docs/label/2023/203341s025lbl.pdf\nPublication date: 2023-09-26'),
#  (106,
#   3,
#   {'cancer_type': ['CHRONIC MYELOGENOUS LEUKEMIA'],
#    'biomarker': ['BCR', 'ABL1']},
#   'Approval status: Regulatory approval (fda)\nDescription: The U.S. Food and Drug Administration granted approval to dasatinib for the treatment of newly diagnosed adult patients with Philadelphia chromosome-positive (Ph+) chronic myeloid leukemia (CML) in chronic phase.\nIndication: SPRYCEL is a kinase inhibitor indicated for the treatment of newly diagnosed adults with Philadelphia chromosome-positive (Ph+) chronic myeloid leukemia (CML) in chronic phase.\nCancer type: Chronic Myelogenous Leukemia\nBiomarkers: BCR::ABL1 [present]\nTherapy: Dasatinib\nTherapy approach: Monotherapy\nTherapy strategy: BCR-ABL inhibition\nTherapy type: Targeted therapy\nApproval url: https://www.accessdata.fda.gov/drugsatfda_docs/label/2023/021986s027lbl.pdf\nPublication date: 2023-02-08'),
#  (180,
#   3,
#   {'cancer_type': ['CHRONIC MYELOGENOUS LEUKEMIA'],
#    'biomarker': ['BCR', 'ABL1']},
#   'Approval status: Regulatory approval (fda)\nDescription: The U.S. Food and Drug Administration granted approval to imatinib for the treatment of newly diagnosed adult and pediatric patients with Philadelphia chromosome positive chronic myeloid leukemia (Ph+ CML) in chronic phase.\nIndication: Gleevec is a kinase inhibitor indicated for the treatment of newly diagnosed adult and pediatric patients with Philadelphia chromosome positive chronic myeloid leukemia (Ph+ CML) in chronic phase.\nCancer type: Chronic Myelogenous Leukemia\nBiomarkers: BCR::ABL1 [present]\nTherapy: Imatinib\nTherapy approach: Monotherapy\nTherapy strategy: Bcr-Abl inhibition + c-Kit inhibition + PDGF-R inhibition\nTherapy type: Targeted therapy\nApproval url: https://www.accessdata.fda.gov/drugsatfda_docs/label/2022/021588s062lbl.pdf\nPublication date: 2024-03-01'),
#  (251,
#   3,
#   {'cancer_type': ['CHRONIC MYELOGENOUS LEUKEMIA'],
#    'biomarker': ['BCR', 'ABL1']},
#   'Approval status: Regulatory approval (fda)\nDescription: The U.S. Food and Drug Administration granted approval to nilotinib for the treatment of adult and pediatric patients greater than or equal to 1 year of age with newly diagnosed Philadelphia chromosome positive chronic myeloid leukemia (Ph+ CML) in chronic phase.\nIndication: Tasigna is a kinase inhibitor indicated for the treatment of adult and pediatric patients greater than or equal to 1 year of age with newly diagnosed Philadelphia chromosome positive chronic myeloid leukemia (Ph+ CML) in chronic phase.\nCancer type: Chronic Myelogenous Leukemia\nBiomarkers: BCR::ABL1 [present]\nTherapy: Nilotinib\nTherapy approach: Monotherapy\nTherapy strategy: BCR-ABL inhibition\nTherapy type: Targeted therapy\nApproval url: https://www.accessdata.fda.gov/drugsatfda_docs/label/2024/022068s041lbl.pdf\nPublication date: 2024-02-29'),
#  (50,
#   2,
#   {'cancer_type': ['ACUTE LYMPHOID LEUKEMIA'],
#    'biomarker': ['CD19', 'BCR', 'ABL1']},
#   'Approval status: Regulatory approval (fda)\nDescription: The U.S. Food and Drug Administration granted approval to blinatumomab for the treatment of adult and pediatric patients one month and older with CD19-positive Philadelphia chromosome-negative B-cell precursor acute lymphoblastic leukemia (ALL) in the consolidation phase of multiphase chemotherapy.\nIndication: BLINCYTO is a bispecific CD19-directed CD3 T-cell engager indicated for the treatment of adult and pediatric patients one month and older with CD19-positive Philadelphia chromosome-negative B-cell precursor acute lymphoblastic leukemia (ALL) in the consolidation phase of multiphase chemotherapy.\nCancer type: Acute Lymphoid Leukemia\nBiomarkers: CD19 + [present], BCR::ABL1 [not present]\nTherapy: Blinatumomab\nTherapy approach: Monotherapy\nTherapy strategy: CD19 inhibition\nTherapy type: Immunotherapy\nApproval url: https://www.accessdata.fda.gov/drugsatfda_docs/label/2024/125557Orig1s028Correctedlbl.pdf\nPublication date: 2024-06-14'),
#  (107,
#   2,
#   {'cancer_type': ['CHRONIC MYELOID LEUKEMIA, BCR-ABL1+'],
#    'biomarker': ['BCR', 'ABL1']},
#   'Approval status: Regulatory approval (fda)\nDescription: The U.S. Food and Drug Administration granted approval to dasatinib for the treatment of newly diagnosed adult patients with Philadelphia chromosome-positive (Ph+) chronic myeloid leukemia (CML) in chronic phase.\nIndication: SPRYCEL is a kinase inhibitor indicated for the treatment of newly diagnosed adults with Philadelphia chromosome-positive (Ph+) chronic myeloid leukemia (CML) in chronic phase.\nCancer type: Chronic Myeloid Leukemia, BCR-ABL1+\nBiomarkers: BCR::ABL1 [present]\nTherapy: Dasatinib\nTherapy approach: Monotherapy\nTherapy strategy: BCR-ABL inhibition\nTherapy type: Targeted therapy\nApproval url: https://www.accessdata.fda.gov/drugsatfda_docs/label/2023/021986s027lbl.pdf\nPublication date: 2023-02-08'),
#  (110,
#   2,
#   {'cancer_type': ['ACUTE LYMPHOID LEUKEMIA'], 'biomarker': ['BCR', 'ABL1']},
#   'Approval status: Regulatory approval (fda)\nDescription: The U.S. Food and Drug Administration granted approval to dasatinib for the treatment of adults with Philadelphia chromosome-positive acute lymphoblastic leukemia (Ph+ ALL) with resistance or intolerance to prior therapy.\nIndication: SPRYCEL is a kinase inhibitor indicated for the treatment of adults with Philadelphia chromosome-positive acute lymphoblastic leukemia (Ph+ ALL) with resistance or intolerance to prior therapy.\nCancer type: Acute Lymphoid Leukemia\nBiomarkers: BCR::ABL1 [present]\nTherapy: Dasatinib\nTherapy approach: Monotherapy\nTherapy strategy: BCR-ABL inhibition\nTherapy type: Targeted therapy\nApproval url: https://www.accessdata.fda.gov/drugsatfda_docs/label/2023/021986s027lbl.pdf\nPublication date: 2023-02-08'),
#  (181,
#   2,
#   {'cancer_type': ['CHRONIC MYELOID LEUKEMIA, BCR-ABL1+'],
#    'biomarker': ['BCR', 'ABL1']},
#   'Approval status: Regulatory approval (fda)\nDescription: The U.S. Food and Drug Administration granted approval to imatinib for the treatment of newly diagnosed adult and pediatric patients with Philadelphia chromosome positive chronic myeloid leukemia (Ph+ CML) in chronic phase.\nIndication: Gleevec is a kinase inhibitor indicated for the treatment of newly diagnosed adult and pediatric patients with Philadelphia chromosome positive chronic myeloid leukemia (Ph+ CML) in chronic phase.\nCancer type: Chronic Myeloid Leukemia, BCR-ABL1+\nBiomarkers: BCR::ABL1 [present]\nTherapy: Imatinib\nTherapy approach: Monotherapy\nTherapy strategy: Bcr-Abl inhibition + c-Kit inhibition + PDGF-R inhibition\nTherapy type: Targeted therapy\nApproval url: https://www.accessdata.fda.gov/drugsatfda_docs/label/2022/021588s062lbl.pdf\nPublication date: 2024-03-01'),
#  (184,
#   2,
#   {'cancer_type': ['ACUTE LYMPHOID LEUKEMIA'], 'biomarker': ['BCR', 'ABL1']},
#   'Approval status: Regulatory approval (fda)\nDescription: The U.S. Food and Drug Administration granted approval to imatinib for the treatment of adult patients with relapsed or refractory Philadelphia chromosome positive acute lymphoblastic leukemia (Ph+ ALL).\nIndication: Gleevec is a kinase inhibitor indicated for the treatment of adult patients with relapsed or refractory Philadelphia chromosome positive acute lymphoblastic leukemia (Ph+ ALL).\nCancer type: Acute Lymphoid Leukemia\nBiomarkers: BCR::ABL1 [present]\nTherapy: Imatinib\nTherapy approach: Monotherapy\nTherapy strategy: Bcr-Abl inhibition + c-Kit inhibition + PDGF-R inhibition\nTherapy type: Targeted therapy\nApproval url: https://www.accessdata.fda.gov/drugsatfda_docs/label/2022/021588s062lbl.pdf\nPublication date: 2024-03-01'),
#  (252,
#   2,
#   {'cancer_type': ['CHRONIC MYELOID LEUKEMIA, BCR-ABL1+'],
#    'biomarker': ['BCR', 'ABL1']},
#   'Approval status: Regulatory approval (fda)\nDescription: The U.S. Food and Drug Administration granted approval to nilotinib for the treatment of adult and pediatric patients greater than or equal to 1 year of age with newly diagnosed Philadelphia chromosome positive chronic myeloid leukemia (Ph+ CML) in chronic phase.\nIndication: Tasigna is a kinase inhibitor indicated for the treatment of adult and pediatric patients greater than or equal to 1 year of age with newly diagnosed Philadelphia chromosome positive chronic myeloid leukemia (Ph+ CML) in chronic phase.\nCancer type: Chronic Myeloid Leukemia, BCR-ABL1+\nBiomarkers: BCR::ABL1 [present]\nTherapy: Nilotinib\nTherapy approach: Monotherapy\nTherapy strategy: BCR-ABL inhibition\nTherapy type: Targeted therapy\nApproval url: https://www.accessdata.fda.gov/drugsatfda_docs/label/2024/022068s041lbl.pdf\nPublication date: 2024-02-29'),
#  (426,
#   2,
#   {'cancer_type': ['ACUTE LYMPHOID LEUKEMIA'], 'biomarker': ['BCR', 'ABL1']},
#   'Approval status: Regulatory approval (fda)\nDescription: The U.S. Food and Drug Administration granted accelerated approval to ponatinib in combination with chemotherapy for the treatment of adult patients with newly diagnosed philadelphia chromosome-positive acute lymphoblastic leukemia (Ph+ ALL). The product label notes that this indication is approved under accelerated approval based on minimal residual disease (MRD)-negative complete remission (CR) at the end of induction and that continued approval for this indication may be contingent upon verification of clinical benefit in a confirmatory trial(s). This indication is based on PhALLCON (NCT03589326), a randomized, active-controlled, multicenter, open-label trial in which chemotherapy regimens were: vincristine and dexamethasone (induction, cycles 1 to 3); methotrexate and cytarabine (consolidation, cycles 4 to 9, alternating methotrexate and cytarabine); and vincristine and prednisone (maintenance, cycles 10 to 20).\nIndication: ICLUSIG is a kinase inhibitor indicated for the treatment of adult patients with newly diagnosed Ph+ ALL, in combination with chemotherapy. This indication is approved under accelerated approval based on minimal residual disease (MRD)-negative complete remission (CR) at the end of induction. Continued approval for this indication may be contingent upon verification of clinical benefit in a confirmatory trial(s).\nCancer type: Acute Lymphoid Leukemia\nBiomarkers: BCR::ABL1 [present]\nTherapy: Cytarabine + Methotrexate + Ponatinib + Prednisone + Vincristine\nTherapy approach: Combination therapy\nTherapy strategy: DNA Polymerase inhibition + Antifolate + BCR-ABL inhibition + Corticosteroid + Vinca alkaloid chemotherapy\nTherapy type: Chemotherapy + Chemotherapy + Targeted therapy + Chemotherapy + Chemotherapy\nApproval url: https://www.accessdata.fda.gov/drugsatfda_docs/label/2024/203469s037lbl.pdf\nPublication date: 2024-03-19'),
#  (427,
#   2,
#   {'cancer_type': ['ACUTE LYMPHOID LEUKEMIA'], 'biomarker': ['ABL1', 'BCR']},
#   'Approval status: Regulatory approval (fda)\nDescription: The U.S. Food and Drug Administration granted approval to ponatinib for the treatment of adult patients with philadelphia chromosome-positive acute lymphoblastic leukemia (Ph+ ALL) for whom no other kinase inhibitors are indicated or T315I-positive Ph+ ALL.\nIndication: ICLUSIG is a kinase inhibitor indicated for the treatment of adult patients with as monotherapy in Ph+ ALL for whom no other kinase inhibitors are indicated or T315I-positive Ph+ ALL.\nCancer type: Acute Lymphoid Leukemia\nBiomarkers: ABL1 p.T315I [present], BCR::ABL1 [present]\nTherapy: Ponatinib\nTherapy approach: Monotherapy\nTherapy strategy: BCR-ABL inhibition\nTherapy type: Targeted therapy\nApproval url: https://www.accessdata.fda.gov/drugsatfda_docs/label/2024/203469s037lbl.pdf\nPublication date: 2024-03-19'),
#  (428,
#   2,
#   {'cancer_type': ['CHRONIC MYELOGENOUS LEUKEMIA'], 'biomarker': ['ABL1']},
#   'Approval status: Regulatory approval (fda)\nDescription: The U.S. Food and Drug Administration granted approval to ponatinib for the treatment of adult patients with T315I-positive chronic myeloid leukemia (CML) in chronic phase, accelerated phase, or blast phase. The product label states the following limitations of use: ponatinib is not indicated and is not recommended for the treatment of patients with newly diagnosed CP-CML.\nIndication: ICLUSIG is a kinase inhibitor indicated for the treatment of adult patients with T315I-positive CML (chronic phase, accelerated phase, or blast phase). Limitations of Use: ICLUSIG is not indicated and is not recommended for the treatment of patients with newly diagnosed CP-CML.\nCancer type: Chronic Myelogenous Leukemia\nBiomarkers: ABL1 p.T315I [present]\nTherapy: Ponatinib\nTherapy approach: Monotherapy\nTherapy strategy: BCR-ABL inhibition\nTherapy type: Targeted therapy\nApproval url: https://www.accessdata.fda.gov/drugsatfda_docs/label/2024/203469s037lbl.pdf\nPublication date: 2024-03-19'),
#  (607,
#   2,
#   {'cancer_type': ['CHRONIC MYELOID LEUKEMIA, BCR-ABL1+'],
#    'biomarker': ['BCR', 'ABL1']},
#   'Approval status: Regulatory approval (fda)\nDescription: The U.S. Food and Drug Administration granted accelerated approval to asciminib for the treatment of adult patients with newly diagnosed philadelphia chromosome-positive chronic myeloid leukemia (Ph+ CML) in chronic phase (CP). The package insert states that this indication is approved under accelerated approval based on major molecular response rate and that continued approval for this indication may be contingent upon verification of clinical benefit in a confirmatory trial(s).\nIndication: SCEMBLIX is a kinase inhibitor indicated for the treatment of adult patients with newly diagnosed philadelphia chromosome-positive chronic myeloid leukemia (Ph+ CML) in chronic phase (CP). This indication is approved under accelerated approval based on major molecular response rate. Continued approval for this indication may be contingent upon verification of clinical benefit in a confirmatory trial(s).\nCancer type: Chronic Myeloid Leukemia, BCR-ABL1+\nBiomarkers: BCR::ABL1 [present]\nTherapy: Asciminib\nTherapy approach: Monotherapy\nTherapy strategy: BCR-ABL inhibition\nTherapy type: Targeted therapy\nApproval url: https://www.accessdata.fda.gov/drugsatfda_docs/label/2024/215358Orig1s008lbl.pdf\nPublication date: 2024-10-29')]

# %% [markdown]
# ## Rerank based on semantic similarity using BioBERT embeddings

# %% [markdown]
# Next, we can also try enhancing the semantic search by using embedding models pretrained on biomedical text

# %% [markdown]
# BioBERT finetuned for sentence semantic search:
# - pritamdeka/S-PubMedBert-MS-MARCO (https://huggingface.co/pritamdeka/S-PubMedBert-MS-MARCO)
# -

# %%
from sklearn.metrics.pairwise import cosine_similarity

tokenizer = AutoTokenizer.from_pretrained("dmis-lab/biobert-base-cased-v1.1")
model = AutoModel.from_pretrained("dmis-lab/biobert-base-cased-v1.1")

# %%
def embed_text(text):
    inputs = tokenizer(text, return_tensors='pt', truncation=True, max_length=128)
    with torch.no_grad():
        outputs = model(**inputs)
    # using [CLS] token embedding as sentence representation
    return outputs.last_hidden_state[:,0,:].numpy()

def find_semantic_matches(moalmanac_list, user_list, threshold=0.7):
    """
    Return semantic matches using BioBERT embeddings.
    """
    matches = []
    moalmanac_embeddings = [embed_text(b) for b in moalmanac_list]
    user_embeddings = [embed_text(u) for u in user_list]
    
    for i, b in enumerate(moalmanac_list):
        b_vec = moalmanac_embeddings[i]
        matched = []
        for j, u in enumerate(user_list):
            u_vec = user_embeddings[j]
            sim = cosine_similarity(b_vec, u_vec)[0][0]
            if sim >= threshold:
                matched.append(u)
        if matched:
            matches.append((b, matched))
    return matches

# %%
# find_semantic_matches(moalmanac_new_draft['standardized_entities_dict'][0])
# find_semantic_matches(moalmanac_new_draft['context'][0], list(synthetic_prompt_groundtruth_dict.keys())[99])

# %%
# # find_semantic_matches(moalmanac_entities_dict['biomarker'], extracted_entities_dict['biomarker'], threshold=1)
# find_semantic_matches(moalmanac_entities_dict['cancer_type'], extracted_entities_dict['cancer_type'], threshold=.7)
# moalmanac_entities_dict['cancer_type']
# user_entities["extracted_entities_dict"]=user_entities["extracted_entities_dict"].apply(ast.literal_eval)
# Out:
# ['BCR', 'ABL1']
