# %%
import pandas as pd 
import numpy as np
import os, sys
from tqdm import tqdm
import warnings
warnings.filterwarnings('ignore')

# %%
while os.getcwd().split('/')[-1] != 'rag-llm-cancer-paper':
    os.chdir('..')

# %% [markdown]
# ### setup biobert

# %%
biobert_dir = "context_retriever/biobert_ner"
#download model from huggingface
from transformers import AutoTokenizer, AutoModelForTokenClassification
model = AutoModelForTokenClassification.from_pretrained("judithrosell/BioBERT_BioNLP13CG_NER_new")
tokenizer = AutoTokenizer.from_pretrained("judithrosell/BioBERT_BioNLP13CG_NER_new")
id2label = model.config.id2label

#save locally
model.save_pretrained(biobert_dir)
tokenizer.save_pretrained(biobert_dir)
# Out:
# ('context_retriever/biobert_ner/tokenizer_config.json',
#  'context_retriever/biobert_ner/special_tokens_map.json',
#  'context_retriever/biobert_ner/vocab.txt',
#  'context_retriever/biobert_ner/added_tokens.json',
#  'context_retriever/biobert_ner/tokenizer.json')

# %%
#load locally
model = AutoModelForTokenClassification.from_pretrained(biobert_dir)
tokenizer = AutoTokenizer.from_pretrained(biobert_dir)
id2label = model.config.id2label

# %% [markdown]
# ### load other libraries

# %%
# !pip install rank_bm25
import json
import pandas as pd
import random
import math
from transformers import AutoTokenizer, AutoModelForTokenClassification
from utils.entity_prediction import extract_entities, db_extract_entities
#version check is for mol almanac
# from utils.check_db_version import get_local_version
# _VERSION=get_local_version()
# print(_VERSION)

def split_ranges(max_int, num_ranges, samples=None, seed=42):
    random.seed(seed)
    step = math.ceil(max_int / num_ranges)
    ranges = [(i*step+1, min((i+1)*step, max_int)) for i in range(num_ranges)]
    
    if samples is None:
        return ranges
    
    # split samples evenly across ranges
    n_per_range = samples // num_ranges
    remainder = samples % num_ranges
    
    result = []
    for i, r in enumerate(ranges):
        count = n_per_range + (1 if i < remainder else 0)
        result.extend(random.randint(r[0], r[1]) for _ in range(count))
    
    return result

# %% [markdown]
# ### context snippets

# %%
db = pd.read_csv('external-validation/non-moa-database/civic/civic-db/evidence_statements.csv')
db.head(1)
# Out:
#                                   evidence_statement  \
# 0  Daunorubicin treatment resulted in similar ove...
#
#                             evidence_civic_url
# 0  https://civicdb.org/links/evidence_items/11

# %%
_VERSION = 'civic-202509'
_CONTEXT = db.evidence_statement.tolist()
test_ind = split_ranges(len(_CONTEXT), 10, 20)
for i, e in enumerate(_CONTEXT):
    if i in test_ind:
        print(f"======={i}=======")
        print(e)
        print(extract_entities(e, model, tokenizer))
# Out:
# =======13=======
# Ba/F3 cells expressing the RANBP2-ALK fusion containing an F1174L mutation were more resistant to crizotinib treatment than Ba/F3 cells expressing RANBP2-ALK without this mutation.
# {'cancer_type': [], 'biomarker': ['ranbp2', 'alk']}
# =======58=======
# Chemotherapy-refractory patients with metastatic colorectal cancer harboring KRAS mutations (primarily G12/G13; n=230 out of 253 total KRAS mutant patients) had lower response rates (17/253; 6.7% vs KRAS wt 126/352; 35.8%; P < .0001), disease control rates and shorter progression free and overall survival following cetuximab plus chemotherapy than those with wildtype KRAS. Authors note that these patients were treated with cetuximab prior to widespead adoption of regular KRAS mutational status screening. Patients treated with cetuximab or panitumumab monotherapy were not included.
# {'cancer_type': ['colorectal cancer'], 'biomarker': ['kras']}
# =======398=======
# In this phase 2 trial, treatment-naive, ERBB2-positive (by IHC) breast cancer patients with stage IIIA, B, C or inflammatory disease were randomized 1:1:1 to afatinib (n = 10), lapatinib (n = 8), or trastuzumab (n = 11). The primary end point was objective response rate. Objective response was seen in 8 afatinib-, 6 lapatinib-, and 4 trastuzumab-treated patients. Afatinib demonstrated clinical activity that compared favorably to trastuzumab and lapatinib for neoadjuvant treatment of HER2-positive breast cancer.
# {'cancer_type': ['breast cancer'], 'biomarker': ['erbb2', 'her2']}
# =======413=======
# In-vitro studies linked PRL-3 (PP4A3) expression to hyperactivation and dependence on EGFR signaling (through downregulation of PTP1B, an inhibitory phosphatase of EGFR). Retrospective analysis of 68 patients showed improved clinical response to the EGFR inhibitor cetuximab in tumors expressing PRL-3.
# {'cancer_type': ['tumors'], 'biomarker': ['pp4a3', 'ptp1b', 'egfr', 'prl-3']}
# =======616=======
# Colon cancer patient derived xenografts with HER2 mutations are sensitive to HER2 targeted drugs and the greatest tumor reduction was seen with the combination of a tyrosine kinase inhibitor with trastuzumab.
# {'cancer_type': ['colon cancer patient', 'xenografts', 'tumor'], 'biomarker': ['her2']}
# =======659=======
# 10 melanoma patients were evaluated after sunitinib treatment, among which 3 out of the 4 patients with KIT exon 11 mutations showed either complete or partial response.
# {'cancer_type': ['melanoma'], 'biomarker': ['kit']}
# =======861=======
# Preclinical study in melanoma cell lines. NRAS Q61K, in addition to the BRAF V600E mutation was associated with resistance to vemurafenib but sensitivity to AZD6244 (selumetinib) in vitro in the acquired resistant cell line M249-AR4 and in the patient-derived acquired resistant cell line M376.
# {'cancer_type': [], 'biomarker': ['braf', 'nras']}
# =======869=======
# A panel of 26 HNSCC cell lines was tested for efficacy of the p110 alpha, delta and gamma isoform inhibitor taselisib (GDC-0032). Cell lines with PIK3CA mutation or amplification were the most sensitive. Four HNSCC cell lines with activating PIK3CA alterations showed synergistic cell death response to the combination of drug with radiation treatment. This synergism was not apparent in 4 tested HNSCC cell lines with wild-type PIK3CA or PTEN mutation. Nude mouse xenografts were established with Cal-33 PIK3CA H1047R cells. Radiation and taselisib treatments alone showed some growth inhibition in comparison to control, but only the combined treatment led durable tumor regressions.
# {'cancer_type': ['xenografts', 'tumor'], 'biomarker': ['gamma', 'pik3ca', 'p110 alpha', 'pten', 'delta']}
# =======1105=======
# Case report of a 45-year old woman of Japanese descent with recurrent urothelial carcinoma. The patient was identified to harbor mutations in MSH2 (A913fs*2, E226*, E580*) and in MSH6 (R361H) by panel sequencing as well as loss of expression of these genes as confirmed by IHC. Testing also revealed a high mutational load as well as 2+ PD-L1 expression in 80% of the cells. The patient was treated with anti-PD-L1 inhibitor MEDI4736 and MEDI0680 in a phase 1 trial and had a complete remission within 2 months of treatment that was ongoing after 11 months.
# {'cancer_type': ['urothelial carcinoma'], 'biomarker': ['pd-l1', 'msh6', 'msh2']}
# =======1305=======
# EGFR exons 18-24 were analyzed in 7 patients who had shown a partial response to erlotinib in a phase II trial for bronchioloalveolar carcinoma (BAC, or in situ pulmonary adenocarcinoma). One patient (Patient E2) had the E746_A750del mutation. The patient was a male never smoker, and demonstrated response for 8.5 months. Overall survival was 21+ months as the patient was alive at study end.
# {'cancer_type': ['bronchioloalveolar carcinoma', 'in situ pulmonary adenocarcinoma', 'bac'], 'biomarker': ['egfr']}
# =======1376=======
# Primary peripheral blood mononuclear cells were taken from chronic lymphocytic leukemia patients, some of whom had prior therapy. The effect of the F1025L variant on ATM expression was tested by western blot, and the effect on ATM function was tested by treating with doxorubicin to induce double-strand breaks (DSB) and monitoring p21 induction. To confirm wild type p53, parallel cell cultures were treated with fludarabine generating single-strand breaks, in addition to DSB, and monitored for adequate p21 induction. A patient sample had the F1025L variant of ATM, confirmed by sanger sequencing, in trans with a loss of function 11q deletion found in 93% of cells by FISH. Western blot showed stable ATM expression. Treatment with doxorubicin resulted in a p21 expression level of less than 300% that of untreated wild-type controls. This was much lower than the median expression level of treated controls which was 815% that of untreated controls, supporting resistance.
# {'cancer_type': ['chronic lymphocytic leukemia'], 'biomarker': ['p53', 'p21', 'atm']}
# =======1408=======
# This study showed that low MGMT mRNA expression was strongly predictive for prolonged time to progression, treatment response, and length of survival in univariate and multivariate models (p<0.0001). The degree of MGMT mRNA expression was highly correlated with the MGMT promoter methylation status (p<0.0001); however, discordant findings were seen in 12 glioblastoma patients. Patients with methylated tumors with high MGMT mRNA expression (N = 6) did significantly worse than those with low transcriptional activity (p<0.01). Conversely, unmethylated tumors with low MGMT mRNA expression (N = 6) did better than their counterparts.
# {'cancer_type': ['glioblastoma', 'tumors'], 'biomarker': ['mgmt']}
# =======1744=======
# In this retrospective study, imatinib-resistant or -intolerant patients, with chronic phase CML and BCR-ABL fusions, were treated with bosutanib monotherapy. Complete hematologic response (CHR) and major cytogenetic response (MCyR) were comparable for patients with Abl1 mutation versus without. The authors conclude that bosutanib is effective across all BCR-ABL mutations observed except T315I. Of patients with P480A evaluated, 1/1 had a major cytogenetic response.
# {'cancer_type': ['cml'], 'biomarker': ['bcr-abl', 'abl1', 'bcr']}
# =======1752=======
# This retrospective study of a phase 2 clinical trial (NCT01068769) examined regorafenib safety and efficacy in advanced gastrointestinal stromal tumor (GIST) patients refractory to at least imatinib and sunitinib. One patient whose GIST harbored a BRAF exon 15 mutation and wildtype KIT and PDGFRA experienced rapid disease progression despite regorafenib administration.
# {'cancer_type': ['gist', 'gastrointestinal stromal tumor'], 'biomarker': ['kit', 'braf', 'pdgfra']}
# =======1918=======
# The phase 2a MyPathway study assigned patients with HER2, EGFR, BRAF or SHH alterations to treatment with pertuzumab plus trastuzumab, erlotinib, vemurafenib, or vismodegib, respectively. Of 26 patients with BRAF V600E mutations, objective responses were seen in 12 patients (46%; 95% CI, 27% to 67%). Only one of 23 patients (4%; 95% CI, 0% to 22%) with other non-V600 BRAF mutations had a PR (pancreas cancer with a CUX1-BRAF fusion). Nonresponding BRAF mutations included: K601E (n = 6), G464V (n = 2), G469A (n = 2), G496A (n = 2), N581S (n = 2), and one each for G466V, G596R, G606E, L597Q, P731T, intron 9 rearrangement, intron 10 rearrangement, and MACF1- and WASFL-BRAF fusion.
# {'cancer_type': ['pancreas cancer'], 'biomarker': ['wasfl', 'shh', 'k601e', 'braf', 'egfr', 'macf1', 'her2', 'cux1']}
# =======2163=======
# The ABL1-RCSD1 fusion was identified in a 6 yo boy with Ph-like B-ALL and hyperleukocytosis. Following standard induction therapy the patient had an MRD of 16.4% in bone marrow, indicating a poor response. Addition of imatinib decreased MRD to 2% at day 29. In addition, this study reports that expression of the ABL1-RCSD1 fusion protein in murine Ba/F3 cells promotes cytokine-independent proliferation and that viable cells were reduced following exposure to dasatinib.
# {'cancer_type': [], 'biomarker': ['rcsd1', 'abl1']}
# =======2278=======
# In a proliferation assay measuring tritiated thymidine incorporation in the presence of axitinib, Ba/F3 cells carrying the BCR-ABL1 variant showed similar incorporation when harboring fusions with the M244V variant of ABL1 compared to those with wildtype ABL1 (IC50 of 690nM vs. 823 nM), indicating that the M244V variant does not induce resistance.
# {'cancer_type': [], 'biomarker': ['bcr-abl1', 'abl1']}
# =======2391=======
# In this study, patients on imatinib monotherapy were monitored for ABL1 kinase domain variants in BCR-ABL1 fusions amplified from peripheral blood RNA. Of 14 patients who started the study in late chronic phase and had p-loop or non-p-loop mutations, 6/6 with p-loop mutations died compared to no deaths during the course of the study for those with non-p-loop mutations (P=0.0013). 14 patients who started the study in accelerated phase and had p-loop or non-p-loop mutations, 6/7 with p-loop mutations died and 3/6 with non-p-loop mutations died (P=0.14). Overall, this data suggests p-loop mutations that arise during late-chronic phase support resistance to imatinib.
# {'cancer_type': [], 'biomarker': ['abl1', 'bcr']}
# =======2561=======
# Describes a meta-analysis of three separate phase I or II trials: ALKA-372-001, STARTRK-1, and STARTRK-2. All of these evaluate entrectinib in NTRK fusion-positive solid tumours. 31/54 had objective response (57%; 95% CI 43·2–70·8), including 4 CR and 27 PR. 9 had SD. Response by NTRK gene type: 13/22 NTRK1 fusions [59%; 95% CI 36·4–79·3], 18/31 NTRK3 fusions [58%; 39·1–75·5], and 0/1 NTRK2 fusion. Most frequent tumour types were sarcoma, NSCLC, salivary, breast, thyroid, colorectal. Most common fusions were ETV6-NTRK3 (25), TPM3-NTRK1 (4) and TPR-NTRK1 (4).
# {'cancer_type': ['nsclc', 'sarcoma', 'colorectal', 'tumour', 'salivary', 'solid tumours', 'breast', 'thyroid'], 'biomarker': ['ntrk', 'startrk-1', 'startrk-2', None, 'ntrk1', 'ntrk2', 'etv6', 'tpr', 'ntrk3', 'tpm3']}
# =======2678=======
# In this phase 3 double-blind trial, the efficacy of capivasertib and fulvestrant combination therapy was tested in 708 patients with HR+/HER2- breast cancer. Among these 708 patients, 40.8% (n = 289) harboured AKT pathway alterations. The control group received a placebo plus fulvestrant. The median PFS in the population with AKT pathway alterations for the capivasertib-fulvestrant group was 7.3 months compared to 3.1 months in the placebo-fulvestrant group (HR - 0.50; 95% CI [0.38-0.65], p<0.001). In the capivasertib–fulvestrant group, 110 patients had PIK3CA mutations, 18 had AKT mutations, 21 had PTEN alterations, 2 had PI3KCA and AKT1 double mutations, and 4 had both PIK3CA and PTEN alterations. A breakdown of response by individual mutation was not provided.
# {'cancer_type': ['breast cancer'], 'biomarker': ['akt', 'akt1', 'pik3ca', 'pi3kca', 'pten', 'her2']}

# %%
#run BioBert NER on all contexts
context_extracted_entities = []
for ctx in tqdm(_CONTEXT):
    context_extracted_entities.append(extract_entities(ctx, model, tokenizer))
context_extracted_entities
# Out:
#   0%|          | 0/2714 [00:00<?, ?it/s]huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# 100%|██████████| 2714/2714 [02:43<00:00, 16.58it/s]
# [{'cancer_type': ['aml'], 'biomarker': ['dnmt3a']},
#  {'cancer_type': [], 'biomarker': ['perk', 'map2k1']},
#  {'cancer_type': [], 'biomarker': ['perk', 'map2k1']},
#  {'cancer_type': [], 'biomarker': ['nras']},
#  {'cancer_type': ['gist cancer'], 'biomarker': []},
#  {'cancer_type': ['cancer'], 'biomarker': ['pdgfra']},
#  {'cancer_type': [], 'biomarker': []},
#  {'cancer_type': ['aml'], 'biomarker': ['dnmt3a']},
#  {'cancer_type': [], 'biomarker': ['ifn-alpha-2a', 'jak2']},
#  {'cancer_type': [], 'biomarker': ['jak2617f', 'stat5']},
#  {'cancer_type': [], 'biomarker': ['hsp90', 'nras']},
#  {'cancer_type': ['melanoma'], 'biomarker': ['nras']},
#  {'cancer_type': ['melanoma'], 'biomarker': []},
#  {'cancer_type': [], 'biomarker': ['ranbp2', 'alk']},
#  {'cancer_type': [], 'biomarker': ['alk', 'eml4-alk', 'eml4']},
#  {'cancer_type': [], 'biomarker': ['kit']},
#  {'cancer_type': ['nsclc'], 'biomarker': ['kras', 'egfr']},
#  {'cancer_type': ['colorectal cancer'], 'biomarker': ['kras', 'nras']},
#  {'cancer_type': [], 'biomarker': ['alk']},
#  {'cancer_type': [], 'biomarker': ['alk', 'eml4']},
#  {'cancer_type': [], 'biomarker': ['alk']},
#  {'cancer_type': [], 'biomarker': ['araf', 'arf', 'mek']},
#  {'cancer_type': [], 'biomarker': ['erk', 'arf', 'araf']},
#  {'cancer_type': [], 'biomarker': ['kit']},
#  {'cancer_type': [], 'biomarker': ['pdgfra']},
#  {'cancer_type': [], 'biomarker': ['pdgfra']},
#  {'cancer_type': [], 'biomarker': ['pdgfra']},
#  {'cancer_type': [], 'biomarker': ['pdgfra']},
#  {'cancer_type': [], 'biomarker': ['pdgfra']},
#  {'cancer_type': [], 'biomarker': []},
#  {'cancer_type': ['melanoma'], 'biomarker': ['kit']},
#  {'cancer_type': ['melanoma'], 'biomarker': ['braf', 'v600m']},
#  {'cancer_type': [], 'biomarker': ['ret']},
#  {'cancer_type': [], 'biomarker': ['ret']},
#  {'cancer_type': [], 'biomarker': ['ret']},
#  {'cancer_type': ['colorectal cancer', 'tumors'],
#   'biomarker': ['pik3ca', 'kras']},
#  {'cancer_type': [], 'biomarker': ['mek', 'braf', 'ras', 'nf1']},
#  {'cancer_type': [], 'biomarker': ['kras']},
#  {'cancer_type': ['colorectal cancer'], 'biomarker': ['kras', 'braf']},
#  {'cancer_type': [], 'biomarker': ['braf']},
#  {'cancer_type': [], 'biomarker': ['braf', 'raf', 'ras', 'nf1']},
#  {'cancer_type': ['nsclc'], 'biomarker': ['v600e', 'kras']},
#  {'cancer_type': ['colorectal cancer'],
#   'biomarker': ['braf v600e', 'braf', 'mek']},
#  {'cancer_type': ['cutaneous squamous-cell carcinoma',
#    'metastatic',
#    'melanoma'],
#   'biomarker': ['v600k']},
#  {'cancer_type': [], 'biomarker': ['braf']},
#  {'cancer_type': ['melanoma'], 'biomarker': []},
#  {'cancer_type': ['tumor'], 'biomarker': ['braf', 'pi3k']},
#  {'cancer_type': ['tumor'], 'biomarker': ['braf', 'nutlin-3']},
#  {'cancer_type': ['colorectal cancer', 'tumor'],
#   'biomarker': ['braf v600e', 'braf']},
#  {'cancer_type': ['ht29 xenografts', 'tumor', 'xenograft'],
#   'biomarker': ['kras', 'pik3ca', 'braf', 'met', 'erk']},
#  {'cancer_type': ['acute promyelocytic leukemia', 'acute myeloid leukemia'],
#   'biomarker': ['cebpa']},
#  {'cancer_type': ['colorectal cancer', 'tumors'],
#   'biomarker': ['kras', 'pik3ca']},
#  {'cancer_type': ['colorectal cancer'], 'biomarker': ['nras']},
#  {'cancer_type': [], 'biomarker': ['alk']},
#  {'cancer_type': ['colorectal cancer'],
#   'biomarker': ['kras', 'braf', 'nras', 'pik3ca']},
#  {'cancer_type': [], 'biomarker': ['flt3']},
#  {'cancer_type': [], 'biomarker': ['flt3']},
#  {'cancer_type': [], 'biomarker': ['protein tyrosine kinase', 'flt3', 'ptk']},
#  {'cancer_type': ['colorectal cancer'], 'biomarker': ['kras']},
#  {'cancer_type': ['colorectal cancer'], 'biomarker': ['kras']},
#  {'cancer_type': ['xenograft'], 'biomarker': ['kras']},
#  {'cancer_type': [], 'biomarker': ['flt3', 'npm1']},
#  {'cancer_type': ['colorectal cancer', 'metastatic'],
#   'biomarker': ['kras', 'braf', 'nras', 'pik3ca']},
#  {'cancer_type': ['aml'], 'biomarker': ['wt1']},
#  {'cancer_type': ['tumor', 'xenograft'], 'biomarker': ['eml4-alk']},
#  {'cancer_type': [], 'biomarker': ['alk']},
#  {'cancer_type': [], 'biomarker': ['alk']},
#  {'cancer_type': ['xenografts', 'tumor'],
#   'biomarker': ['fgfr3', 'fgfr', 'baiap2l1']},
#  {'cancer_type': ['xenograft'], 'biomarker': ['kras']},
#  {'cancer_type': [], 'biomarker': ['flt3', 'npm1']},
#  {'cancer_type': [], 'biomarker': ['npm1']},
#  {'cancer_type': [], 'biomarker': ['npm1']},
#  {'cancer_type': [], 'biomarker': ['flt3', 'npm1']},
#  {'cancer_type': [], 'biomarker': ['flt3', 'cd123', 'cd33', 'npm1']},
#  {'cancer_type': [], 'biomarker': ['flt3', 'cd33', 'npm1']},
#  {'cancer_type': [], 'biomarker': ['npm1']},
#  {'cancer_type': ['aml'], 'biomarker': ['npm', 'npm1']},
#  {'cancer_type': ['tumor', 'lung tumors'], 'biomarker': ['krasg12d', 'tsc1']},
#  {'cancer_type': ['tumors'], 'biomarker': ['tsc2', 'tsc1']},
#  {'cancer_type': ['undifferentiated ovarian cancer', 'high grade serous'],
#   'biomarker': ['brca', 'parp', 'brca1']},
#  {'cancer_type': ['undifferentiated ovarian cancer', 'high grade serous'],
#   'biomarker': ['brca2', 'brca', 'parp']},
#  {'cancer_type': ['lung cancer'], 'biomarker': ['egfr']},
#  {'cancer_type': [], 'biomarker': ['akt1', 'pik3ca', 'akt']},
#  {'cancer_type': [], 'biomarker': ['abl', 'bcr']},
#  {'cancer_type': [], 'biomarker': ['bcr-abl']},
#  {'cancer_type': ['chronic myeloid leukemia', 'tumors'], 'biomarker': ['abl']},
#  {'cancer_type': [], 'biomarker': ['bcr-abl']},
#  {'cancer_type': ['t4n3m1', 'tumor', 'lung adenocarcinoma'],
#   'biomarker': ['alk', 'eml4-alk', 'alk variant 1', 'eml4']},
#  {'cancer_type': ['non-small cell lung cancer', 'tumor'],
#   'biomarker': ['eml4', 'e13', 'eml4-alk', 'a20', 'alk']},
#  {'cancer_type': [], 'biomarker': ['egfr']},
#  {'cancer_type': ['non-small cell lung cancer'], 'biomarker': []},
#  {'cancer_type': ['lung cancer'], 'biomarker': ['egfr', 'met']},
#  {'cancer_type': [], 'biomarker': ['erbb2']},
#  {'cancer_type': [], 'biomarker': ['esr1']},
#  {'cancer_type': [], 'biomarker': ['esr1']},
#  {'cancer_type': [], 'biomarker': ['esr1']},
#  {'cancer_type': [], 'biomarker': ['esr1']},
#  {'cancer_type': [], 'biomarker': ['esr1']},
#  {'cancer_type': ['aml'], 'biomarker': ['flt3']},
#  {'cancer_type': [], 'biomarker': ['flt3']},
#  {'cancer_type': ['gist'], 'biomarker': ['kit']},
#  {'cancer_type': ['colorectal cancer'], 'biomarker': ['kras']},
#  {'cancer_type': ['lung adenocarcinoma'], 'biomarker': ['kras', 'egfr']},
#  {'cancer_type': ['metastatic',
#    'tumors',
#    'colorectal cancer',
#    'primary',
#    'tumor'],
#   'biomarker': ['pten',
#    'kras pik3ca',
#    'pik3ca',
#    'anti-epidermal growth factor receptor']},
#  {'cancer_type': ['cml', 'philadelphia'], 'biomarker': []},
#  {'cancer_type': ['cml'], 'biomarker': ['bcr']},
#  {'cancer_type': [], 'biomarker': ['bcr-abl']},
#  {'cancer_type': ['non-small cell lung cancer'],
#   'biomarker': ['a20', 'alk', 'e13', 'eml4']},
#  {'cancer_type': ['t-cell leukemia'], 'biomarker': ['notch', 'ccnd3']},
#  {'cancer_type': ['tumor', 'xenograft', 'breast cancers'],
#   'biomarker': ['pik3ca', 'pi3k', 'cdk4 / 6']},
#  {'cancer_type': [], 'biomarker': []},
#  {'cancer_type': [], 'biomarker': []},
#  {'cancer_type': [], 'biomarker': []},
#  {'cancer_type': [], 'biomarker': []},
#  {'cancer_type': [], 'biomarker': []},
#  {'cancer_type': [], 'biomarker': []},
#  {'cancer_type': [], 'biomarker': ['ddr2']},
#  {'cancer_type': [], 'biomarker': []},
#  {'cancer_type': [], 'biomarker': []},
#  {'cancer_type': ['nsclc'], 'biomarker': ['l858r', 'egfr']},
#  {'cancer_type': [], 'biomarker': ['l858r']},
#  {'cancer_type': ['nsclc', 'tumor'], 'biomarker': ['l858r']},
#  {'cancer_type': ['nsclc'], 'biomarker': ['egfr']},
#  {'cancer_type': [], 'biomarker': []},
#  {'cancer_type': [], 'biomarker': []},
#  {'cancer_type': [], 'biomarker': ['erbb2']},
#  {'cancer_type': [], 'biomarker': []},
#  {'cancer_type': [], 'biomarker': ['erbb2']},
#  {'cancer_type': [], 'biomarker': ['erbb2']},
#  {'cancer_type': [], 'biomarker': []},
#  {'cancer_type': [], 'biomarker': ['erbb2']},
#  {'cancer_type': [], 'biomarker': []},
#  {'cancer_type': [], 'biomarker': []},
#  {'cancer_type': [], 'biomarker': []},
#  {'cancer_type': [], 'biomarker': ['luciferase', 'estrogen', 'esr1']},
#  {'cancer_type': [], 'biomarker': ['luciferase', 'estrogen', 'esr1']},
#  {'cancer_type': [], 'biomarker': ['luciferase', 'estrogen', 'esr1']},
#  {'cancer_type': [], 'biomarker': ['luciferase', 'estrogen', 'esr1']},
#  {'cancer_type': [], 'biomarker': ['luciferase', 'estrogen', 'esr1']},
#  {'cancer_type': ['intrahepatic cholangiocarcinoma'], 'biomarker': []},
#  {'cancer_type': ['intrahepatic cholangiocarcinoma', 'cancer types', 'tumor'],
#   'biomarker': []},
#  {'cancer_type': ['aml'], 'biomarker': ['flt3', 'cep701']},
#  {'cancer_type': [], 'biomarker': ['flt3']},
#  {'cancer_type': [], 'biomarker': ['flt3']},
#  {'cancer_type': ['tumor'], 'biomarker': ['gata2']},
#  {'cancer_type': ['anal melanoma'], 'biomarker': ['kit']},
#  {'cancer_type': [], 'biomarker': ['kit']},
#  {'cancer_type': [], 'biomarker': ['kit']},
#  {'cancer_type': ['lung cancer', 'tumor'], 'biomarker': ['kras']},
#  {'cancer_type': ['colorectal patients'], 'biomarker': ['kras']},
#  {'cancer_type': [], 'biomarker': ['mgmt']},
#  {'cancer_type': [], 'biomarker': ['mgmt']},
#  {'cancer_type': [], 'biomarker': ['mgmt']},
#  {'cancer_type': [], 'biomarker': ['pik3ca']},
#  {'cancer_type': [], 'biomarker': ['pik3ca']},
#  {'cancer_type': [], 'biomarker': ['pik3ca']},
#  {'cancer_type': [], 'biomarker': []},
#  {'cancer_type': [], 'biomarker': ['pten', 'pi3k', 'mtor']},
#  {'cancer_type': ['breast tumors'], 'biomarker': ['tp53']},
#  {'cancer_type': ['bladder cancer'], 'biomarker': ['nf2', 'mtor', 'tsc1']},
#  {'cancer_type': ['cml'], 'biomarker': ['bcr-abl']},
#  {'cancer_type': ['colorectal cancer', 'tumor', 'tumors'],
#   'biomarker': ['pten',
#    'kras pik3ca',
#    'pik3ca',
#    'anti-epidermal growth factor receptor']},
#  {'cancer_type': ['primary tumors',
#    'metastatic',
#    'tumors',
#    'colorectal cancer',
#    'metastatic tumor'],
#   'biomarker': ['pten',
#    'kras pik3ca',
#    'pik3ca',
#    'anti-epidermal growth factor receptor']},
#  {'cancer_type': ['breast tumors'], 'biomarker': ['tp53']},
#  {'cancer_type': [], 'biomarker': ['csf1r', 'mef2d']},
#  {'cancer_type': ['aml', 'apl'], 'biomarker': ['runx1']},
#  {'cancer_type': ['tumor'], 'biomarker': ['igf1r', 'igf2', 'insr']},
#  {'cancer_type': ['nsclc'], 'biomarker': ['l858r', 'egfr']},
#  {'cancer_type': ['xenografts'], 'biomarker': ['igf1r', 'insr']},
#  {'cancer_type': ['chronic lymphocytic leukemia'], 'biomarker': ['btk']},
#  {'cancer_type': [], 'biomarker': ['akt1', 'braf']},
#  {'cancer_type': [], 'biomarker': ['alk', 'eml4']},
#  {'cancer_type': [], 'biomarker': ['alk', 'eml4']},
#  {'cancer_type': [], 'biomarker': ['alk', 'eml4']},
#  {'cancer_type': [], 'biomarker': ['alk', 'eml4']},
#  {'cancer_type': ['cancer', 'lung adenocarcinoma'],
#   'biomarker': ['alk', 'palk', 'eml4-alk']},
#  {'cancer_type': [], 'biomarker': ['apc', 'wnt']},
#  {'cancer_type': ['tumor', 'colorectal cancers xenograft'],
#   'biomarker': ['apc']},
#  {'cancer_type': [], 'biomarker': ['androgen receptor']},
#  {'cancer_type': [], 'biomarker': ['prostate-specific antigen', 'ar']},
#  {'cancer_type': [], 'biomarker': ['atm']},
#  {'cancer_type': [], 'biomarker': ['atm']},
#  {'cancer_type': [], 'biomarker': ['dna pkcs', 'atm']},
#  {'cancer_type': ['lymphoblastoid leukemia',
#    'chronic lymphocytic leukemia',
#    'mantle cell lymphoma',
#    'blood cancers',
#    'xenograft'],
#   'biomarker': ['atm']},
#  {'cancer_type': ['esophageal adenocarcinomas', 'antitumour'],
#   'biomarker': []},
#  {'cancer_type': [], 'biomarker': ['aurk-a']},
#  {'cancer_type': ['thymic carcinoma', 'tumor'], 'biomarker': ['kit']},
#  {'cancer_type': ['breast cancer'], 'biomarker': ['pgr', 'er']},
#  {'cancer_type': ['breast cancer'], 'biomarker': ['pgr']},
#  {'cancer_type': ['colorectal cancer'], 'biomarker': ['pten']},
#  {'cancer_type': ['prostate cancer xenographs', 'tumors'],
#   'biomarker': ['pten']},
#  {'cancer_type': ['breast cancer'], 'biomarker': ['her2']},
#  {'cancer_type': ['breast cancer'], 'biomarker': ['her2']},
#  {'cancer_type': ['metastatic adenocarcinoma', 'pancreas'], 'biomarker': []},
#  {'cancer_type': ['high-grade serous ovarian cancer', 'hgs-ovca'],
#   'biomarker': ['cdk12', 'parp1 / 2', 'brca1']},
#  {'cancer_type': [], 'biomarker': ['nt5c2']},
#  {'cancer_type': [], 'biomarker': ['nt5c2']},
#  {'cancer_type': [], 'biomarker': ['nt5c2']},
#  {'cancer_type': ['t-all'], 'biomarker': ['nt5c2']},
#  {'cancer_type': ['t-all'], 'biomarker': ['nt5c2']},
#  {'cancer_type': ['t-all'], 'biomarker': ['nt5c2']},
#  {'cancer_type': ['cml'], 'biomarker': ['bcr-abl']},
#  {'cancer_type': [], 'biomarker': ['bcr-abl']},
#  {'cancer_type': [], 'biomarker': ['bcr-abl']},
#  {'cancer_type': ['tumors', 'lung cancers'], 'biomarker': ['egfr']},
#  {'cancer_type': ['bladder cancer'], 'biomarker': ['pten', 'mtor']},
#  {'cancer_type': ['breast cancer'], 'biomarker': ['pten', 'her2']},
#  {'cancer_type': ['nsclc'], 'biomarker': []},
#  {'cancer_type': ['prostate cancers'],
#   'biomarker': ['p53', 'mre11', 'pi3k', 'nbn', 'parp', 'mlh3', 'atm']},
#  {'cancer_type': ['prostate cancers'], 'biomarker': ['atm', 'parp']},
#  {'cancer_type': [], 'biomarker': ['nf2']},
#  {'cancer_type': ['prostate cancer'], 'biomarker': ['brca2']},
#  {'cancer_type': [], 'biomarker': ['pdgfra']},
#  {'cancer_type': [], 'biomarker': ['pdgfra']},
#  {'cancer_type': ['gists',
#    'gastrointestinal stromal tumors',
#    'tumor',
#    'tumors'],
#   'biomarker': ['kit', 'wt kit', 'pdgfra']},
#  {'cancer_type': ['stage iv nsclc', 'stage iv non-small cell lung carcinoma'],
#   'biomarker': ['xrcc1']},
#  {'cancer_type': [], 'biomarker': ['gstp1']},
#  {'cancer_type': ['colon cancer'], 'biomarker': ['livin', 'birc7']},
#  {'cancer_type': [], 'biomarker': ['egfr']},
#  {'cancer_type': ['epithelial ovarian cancer', 'eoc'],
#   'biomarker': ['kras', 'brca']},
#  {'cancer_type': ['gastric cancer', 'stomach cancer'], 'biomarker': ['mthfr']},
#  {'cancer_type': ['metastatic', 'colorectal carcinoma'],
#   'biomarker': ['gstp1']},
#  {'cancer_type': ['cervical carcinomas', 'cervical cancer', 'tumor'],
#   'biomarker': ['xrcc1']},
#  {'cancer_type': ['epithelial',
#    'fallopian tube frozen tumors',
#    'ovarian cancer'],
#   'biomarker': ['abcb1']},
#  {'cancer_type': ['nsclc', 'non small cell lung cancer'], 'biomarker': []},
#  {'cancer_type': ['osteosarcoma'], 'biomarker': ['ercc2']},
#  {'cancer_type': ['nsclc', 'non small cell lung cancer'],
#   'biomarker': ['ercc2']},
#  {'cancer_type': ['colorectal cancer', 'crc'], 'biomarker': ["tyms 5 ' 3tpr"]},
#  {'cancer_type': [], 'biomarker': ['mlrp1b4', 'lrp1b', 'lrp1b4']},
#  {'cancer_type': ['xenograft'], 'biomarker': ['fgfr1']},
#  {'cancer_type': [], 'biomarker': ['fgf9', 'kras', 'pik3ca', 'fgfr1', 'fgf2']},
#  {'cancer_type': ['nsclc'], 'biomarker': ['fgfr1', 'fgfr-1']},
#  {'cancer_type': [], 'biomarker': ['ros1']},
#  {'cancer_type': ['metastases'], 'biomarker': ['hgf', 'met']},
#  {'cancer_type': ['metastatic', 'hnssc'], 'biomarker': ['egfr']},
#  {'cancer_type': ['colorectal carcinoma',
#    'head and neck squamous cell carcinoma'],
#   'biomarker': ['kras', 'egfr']},
#  {'cancer_type': ['nsclc'], 'biomarker': ['egfr']},
#  {'cancer_type': ['tumors'], 'biomarker': ['cdkn2a', 'p16', 'egfr']},
#  {'cancer_type': ['hpv'], 'biomarker': ['cdkn2a', 'p16', 'egfr']},
#  {'cancer_type': ['hnscc'], 'biomarker': ['p16', 'cdkn2a', 'egfr']},
#  {'cancer_type': ['adenocarcinoma', 'lung'],
#   'biomarker': ['her2',
#    'kras',
#    'ros1',
#    'ret',
#    'kif5b',
#    'braf',
#    'egfr',
#    'met',
#    'alk']},
#  {'cancer_type': ['colorectal carcinoma'], 'biomarker': ['hras']},
#  {'cancer_type': [], 'biomarker': ['hras', 'mtor', 'mek']},
#  {'cancer_type': ['melanoma'], 'biomarker': ['pd-l1', 'pd-1 receptor']},
#  {'cancer_type': ['urothelial carcinoma'], 'biomarker': []},
#  {'cancer_type': ['breast cancer', 'tumors'],
#   'biomarker': ['ser473', 'her2', 'thr308', 'akt2', 'pakt']},
#  {'cancer_type': [], 'biomarker': ['akt']},
#  {'cancer_type': [], 'biomarker': ['pten', 'braf', 'akt']},
#  {'cancer_type': ['ovarian carcinoma', 'breast'],
#   'biomarker': ['akt1', 'akt']},
#  {'cancer_type': [], 'biomarker': ['pik3ca', 'akt', 'pi3k']},
#  {'cancer_type': [], 'biomarker': ['pten']},
#  {'cancer_type': [], 'biomarker': []},
#  {'cancer_type': [], 'biomarker': ['pten']},
#  {'cancer_type': [], 'biomarker': ['nf2']},
#  {'cancer_type': ['tumor'], 'biomarker': ['pten', 'pik3ca', 'pi3k']},
#  {'cancer_type': [], 'biomarker': ['egfr']},
#  {'cancer_type': [], 'biomarker': ['fbxw7', 'egfr']},
#  {'cancer_type': ['colorectal cancer', 'metastatic'],
#   'biomarker': ['smad4', 'egfr']},
#  {'cancer_type': [], 'biomarker': ['smad4', 'egfr']},
#  {'cancer_type': [], 'biomarker': []},
#  {'cancer_type': [], 'biomarker': ['braf', 'agk']},
#  {'cancer_type': [], 'biomarker': ['braf', 'agk']},
#  {'cancer_type': ['melanomas'], 'biomarker': ['braf', 'papss1']},
#  {'cancer_type': ['melanomas'], 'biomarker': ['braf', 'papss1', 'mapk']},
#  {'cancer_type': ['melanoma'], 'biomarker': ['braf', 'trim24', 'mek']},
#  {'cancer_type': [], 'biomarker': ['braf']},
#  {'cancer_type': ['colorectal cancer'], 'biomarker': ['her3', 'erbb3']},
#  {'cancer_type': ['crc'], 'biomarker': ['cd73']},
#  {'cancer_type': [], 'biomarker': ['idh1']},
#  {'cancer_type': [], 'biomarker': ['pi3k', 'her3', 'erbb3', 'met']},
#  {'cancer_type': ['breast cancer'], 'biomarker': ['myd88']},
#  {'cancer_type': [], 'biomarker': ['alk', 'cep7', 'met']},
#  {'cancer_type': ['lung cancers'], 'biomarker': ['cas9', 'met']},
#  {'cancer_type': [], 'biomarker': ['egfr', 'met']},
#  {'cancer_type': ['gists', 'gist'], 'biomarker': ['pdgfra']},
#  {'cancer_type': ['merkel cell carcinoma'], 'biomarker': ['pi3k']},
#  {'cancer_type': ['xenografts', 'tumor'], 'biomarker': ['egfr', 'ret']},
#  {'cancer_type': ['nci-h2110', 'tumor', 'lung adenocarcinomas'],
#   'biomarker': ['mek', 'pi3k', 'rit1']},
#  {'cancer_type': ['nsclc'], 'biomarker': ['pd-l1', 'pd-1 receptor']},
#  {'cancer_type': [], 'biomarker': ['mycn', 'fact', 'ssrp1']},
#  {'cancer_type': [], 'biomarker': ['hedgehog']},
#  {'cancer_type': ['basal cell carcinoma', 'basal cell carcinomas'],
#   'biomarker': ['smo']},
#  {'cancer_type': ['basal cell carcinomas'],
#   'biomarker': ['hedgehog', 'gli', None, 'psi', 'smo', 'apkc-ι']},
#  {'cancer_type': ['medulloblastomas', 'xenografts'],
#   'biomarker': ['shh', 'ptch1']},
#  {'cancer_type': ['medulloblastoma'], 'biomarker': ['shh']},
#  {'cancer_type': [], 'biomarker': ['stk11', 'mapk11']},
#  {'cancer_type': [], 'biomarker': ['syk', 'p-syk']},
#  {'cancer_type': [], 'biomarker': ['p16', 'hpv']},
#  {'cancer_type': ['basal cell carcinomas'], 'biomarker': ['hedgehog', 'smo']},
#  {'cancer_type': ['platinum', 'epithelial ovarian cancer', 'solid tumors'],
#   'biomarker': ['pten', 'pik3ca', 'pi3k']},
#  {'cancer_type': ['melanoma'], 'biomarker': ['braf', 'pi3k']},
#  {'cancer_type': ['hpv'], 'biomarker': ['p16', 'egfr']},
#  {'cancer_type': ['xenografts'],
#   'biomarker': ['erbb2', 'akt1 / 2', 'akti-1 / 2', 'pik3ca']},
#  {'cancer_type': [], 'biomarker': []},
#  {'cancer_type': ['xenografts', 'tumor'], 'biomarker': ['egfr']},
#  {'cancer_type': [], 'biomarker': ['alk', 'eml4']},
#  {'cancer_type': ['nsclc', 'adenocarcinoma', 'non small cell lung cancer'],
#   'biomarker': ['akt',
#    'eml4',
#    'e6',
#    'kras',
#    'e6a',
#    'stat3',
#    'egfr',
#    'a20',
#    'erk',
#    'alk']},
#  {'cancer_type': [], 'biomarker': ['alk', 'eml4']},
#  {'cancer_type': ['nsclc',
#    'adenocarcinoma',
#    'tumor',
#    'non small cell lung cancer'],
#   'biomarker': ['kras', 'alk', 'egfr', 'eml4']},
#  {'cancer_type': ['non-small cell lung cancer'], 'biomarker': ['alk', 'egfr']},
#  {'cancer_type': ['melanoma'], 'biomarker': ['erbb4']},
#  {'cancer_type': ['colorectal cancer xenografts',
#    'xenografts',
#    'tumor',
#    'tumors'],
#   'biomarker': ['axl',
#    'kras',
#    'pik3ca',
#    'tp53',
#    'ret',
#    'met',
#    'vegfr2',
#    'c-met']},
#  {'cancer_type': ['glioblastomas'], 'biomarker': ['pten', 'egfr', 'egfrviii']},
#  {'cancer_type': [], 'biomarker': ['egfr', 'egfrviii']},
#  {'cancer_type': ['glioblastomas'], 'biomarker': ['pten', 'egfr', 'egfrviii']},
#  {'cancer_type': [], 'biomarker': ['pten', 'egfr', 'egfrviii']},
#  {'cancer_type': [], 'biomarker': ['her2', 'nrg1', 'her3']},
#  {'cancer_type': [], 'biomarker': ['erbb2', 'nrg1', 'erbb3']},
#  {'cancer_type': ['ovarian cancers', 'tumor'], 'biomarker': ['nrg1', 'erbb3']},
#  {'cancer_type': ['tumor', 'nsclc tumors', 'xenografts'],
#   'biomarker': ['nrg1', 'egfr']},
#  {'cancer_type': [],
#   'biomarker': ['eml1', 'akt', 'areg', 'egfr', 'amphiregulin', 'alk']},
#  {'cancer_type': ['malignantleuralffusions'], 'biomarker': ['amphiregulin']},
#  {'cancer_type': ['tumor samples'], 'biomarker': ['egfr']},
#  {'cancer_type': ['colon carcinoma'], 'biomarker': ['egfr']},
#  {'cancer_type': ['colon carcinoma'], 'biomarker': ['egfr']},
#  {'cancer_type': ['colorectal cancer', 'tumours', 'crc'],
#   'biomarker': ['egf', 'areg', 'kras', 'ereg', 'egfr', 'tgfa']},
#  {'cancer_type': ['crc'],
#   'biomarker': ['areg', 'kras', 'ereg', 'ephrin a2 receptor', 'egfr']},
#  {'cancer_type': ['tumor', 'hnscc'], 'biomarker': ['mapk1', 'egfr']},
#  {'cancer_type': ['nsclc', 'tumor'],
#   'biomarker': ['mek', 'mapk1', 'egfr', 'met', 'erk']},
#  {'cancer_type': ['cancer', 'tumor', 'lung adenocarcinoma'],
#   'biomarker': ['kras', 'stk11', 'atm', 'cdk4']},
#  {'cancer_type': ['lesions', 'tumors'], 'biomarker': ['kras', 'cdk4']},
#  {'cancer_type': ['papillary renal cell carcinoma'], 'biomarker': ['met']},
#  {'cancer_type': ['stage iv lung adenocarcinomas'], 'biomarker': ['met']},
#  {'cancer_type': ['xenografts'], 'biomarker': ['fgfr1', 'fgfr']},
#  {'cancer_type': [], 'biomarker': ['fgfr1', 'fgfr', 'fgfr2iiic']},
#  {'cancer_type': [], 'biomarker': ['fgfr1', 'fgfr']},
#  {'cancer_type': [], 'biomarker': ['fgfr3', 'fgfr1', 'fgfr']},
#  {'cancer_type': [], 'biomarker': ['cblc']},
#  {'cancer_type': ['colorectal cancer', 'tumors'], 'biomarker': ['kras']},
#  {'cancer_type': ['head and neck cancer', 'hnscc'],
#   'biomarker': ['ptprd', 'stat3']},
#  {'cancer_type': ['prostate cancer'],
#   'biomarker': ['defa1b', 'defa1', 'defa3']},
#  {'cancer_type': [], 'biomarker': ['ercc1']},
#  {'cancer_type': ['tumor xenograft', 'colorectal cancer'],
#   'biomarker': ['jag1', 'notch1']},
#  {'cancer_type': [], 'biomarker': ['nrg1', 'hrg', 'her3']},
#  {'cancer_type': ['nsclc'], 'biomarker': ['wee1']},
#  {'cancer_type': [], 'biomarker': ['fntb']},
#  {'cancer_type': [], 'biomarker': ['braf', 'anti-egfr']},
#  {'cancer_type': ['hnscc'], 'biomarker': ['jak', 'stat3', 'ptprt']},
#  {'cancer_type': ['crc'], 'biomarker': ['vegfa']},
#  {'cancer_type': [], 'biomarker': ['dnmt1', 'kras']},
#  {'cancer_type': [], 'biomarker': ['kras']},
#  {'cancer_type': [], 'biomarker': ['pdcd4']},
#  {'cancer_type': ['glioblastoma'], 'biomarker': ['mgmt']},
#  {'cancer_type': [], 'biomarker': ['pr', 'er', 'tff1', 'tff3']},
#  {'cancer_type': ['colorectal cancer'], 'biomarker': ['dickkopf-1']},
#  {'cancer_type': [], 'biomarker': ['cd44', 'cd44s']},
#  {'cancer_type': [], 'biomarker': ['egf', 'amphiregulin', 'epiregulin']},
#  {'cancer_type': ['malignant pleural mesothelioma'], 'biomarker': ['mdm2']},
#  {'cancer_type': ['renal cell carcinoma'],
#   'biomarker': ['heme oxygenase-1', 'ho-1']},
#  {'cancer_type': [], 'biomarker': ['caspase-8', 'dr5']},
#  {'cancer_type': ['nsclc'], 'biomarker': ['tyms', 'thymidylate synthase']},
#  {'cancer_type': ['xenograft'], 'biomarker': ['pbk', 'topk']},
#  {'cancer_type': [], 'biomarker': ['cep7', 'met']},
#  {'cancer_type': [], 'biomarker': ['smarca4']},
#  {'cancer_type': ['nsclc', 'tumor'], 'biomarker': ['alk']},
#  {'cancer_type': ['nsclc', 'tumor'], 'biomarker': ['hsp90', 'alk']},
#  {'cancer_type': ['nsclc'], 'biomarker': ['l1198f', 'alk', 'eml4']},
#  {'cancer_type': ['nsclc'], 'biomarker': ['l1198f', 'alk', 'eml4']},
#  {'cancer_type': [], 'biomarker': ['brca1']},
#  {'cancer_type': ['scchn',
#    'squamous cell carcinoma , head and neck)',
#    'hnscc'],
#   'biomarker': ['areg', 'egfr', 'egfrviii']},
#  {'cancer_type': ['hnscc'], 'biomarker': ['areg', 'viii', 'egfr', 'egfrviii']},
#  {'cancer_type': ['hnscc'], 'biomarker': ['areg', 'egfr', 'egfrviii']},
#  {'cancer_type': [], 'biomarker': ['p53']},
#  {'cancer_type': [], 'biomarker': ['p21', 'tp53']},
#  {'cancer_type': ['rectal cancer'],
#   'biomarker': ['p53',
#    'p21',
#    'bax',
#    'cd133',
#    'cdkn1a',
#    'ki67',
#    'hif1α',
#    'ts',
#    'cd44',
#    'egfr',
#    'cd166',
#    'epcam',
#    'aldh1']},
#  {'cancer_type': ['rectal cancer'],
#   'biomarker': ['p53',
#    'p21',
#    'bax',
#    'cd133',
#    'ki67',
#    'hif1α',
#    'ts',
#    'cd44',
#    'alcam',
#    'egfr',
#    'cd166',
#    'epcam',
#    'aldh1']},
#  {'cancer_type': [], 'biomarker': ['kras', 'egfr']},
#  {'cancer_type': [], 'biomarker': ['stathmin']},
#  {'cancer_type': ['postmenopausal', 'breast cancers'],
#   'biomarker': ['er', 'ccnd1']},
#  {'cancer_type': [], 'biomarker': ['rsf1']},
#  {'cancer_type': [], 'biomarker': ['ccnd1']},
#  {'cancer_type': ['xenografts', 'tumor', 'xenograft', 'tumors'],
#   'biomarker': ['androgen receptor', 'ar', 'pi3k', 'er', 'mtor']},
#  {'cancer_type': [], 'biomarker': ['p27', 'cdkn1b']},
#  {'cancer_type': ['tumor xenografts'], 'biomarker': ['nrg1', 'erbb3']},
#  {'cancer_type': ['xenograft models', 'cancer types', 'tumor'],
#   'biomarker': ['nrg1', 'erbb3']},
#  {'cancer_type': ['crpc', 'castration', 'tumor'],
#   'biomarker': ['prostate-specific antigen', 'ar-v7', 'psa']},
#  {'cancer_type': ['gastric cancer'], 'biomarker': ['pten', 'her2']},
#  {'cancer_type': ['xenografts', 'tumor'],
#   'biomarker': ['erbb2', 'her2', 'her3', 'erbb3']},
#  {'cancer_type': [], 'biomarker': ['hsp90', 'ugt1a']},
#  {'cancer_type': ['xenograft'], 'biomarker': ['her2', 'her4']},
#  {'cancer_type': [], 'biomarker': ['her4']},
#  {'cancer_type': [], 'biomarker': ['akt', 'erbb4', 'pi3k', 'erbb1-3']},
#  {'cancer_type': [], 'biomarker': ['slfn11', 'topoisomerase']},
#  {'cancer_type': ['nsclc'], 'biomarker': ['aurka', 'aurora-a']},
#  {'cancer_type': ['hnssc'], 'biomarker': []},
#  {'cancer_type': [], 'biomarker': ['braf', 'rac1']},
#  {'cancer_type': ['non-small cell lung cancer', 'tumor'],
#   'biomarker': ['birc5', 'survivin', 'n-survivin']},
#  {'cancer_type': [], 'biomarker': ['tp53']},
#  {'cancer_type': ['endometrial tumors'], 'biomarker': ['mre11', 'parp']},
#  {'cancer_type': [], 'biomarker': ['parp', 'atm', 'tp53']},
#  {'cancer_type': [], 'biomarker': ['egfr', 'l858r']},
#  {'cancer_type': [], 'biomarker': ['egfr', 'l858']},
#  {'cancer_type': [], 'biomarker': ['egfr']},
#  {'cancer_type': ['lung adenocarcinoma'], 'biomarker': ['l858r', 'egfr']},
#  {'cancer_type': ['lung adenocarcinoma'], 'biomarker': ['l858r', 'egfr']},
#  {'cancer_type': ['nsclc'], 'biomarker': ['l858r', 'egfr']},
#  {'cancer_type': ['nsclc'], 'biomarker': ['l858r', 'egfr']},
#  {'cancer_type': [], 'biomarker': ['erbb2']},
#  {'cancer_type': ['breast cancer'], 'biomarker': ['erbb2', 'her2']},
#  {'cancer_type': ['colorectal cancer', 'tumor'], 'biomarker': ['top1']},
#  {'cancer_type': [],
#   'biomarker': ['p53',
#    'p21',
#    'p27',
#    'caspase 3',
#    'p-akt',
#    'hif-1a',
#    'ccnd1',
#    'bcl2',
#    'egfr',
#    'p16',
#    'cdkn2b']},
#  {'cancer_type': ['squamous cell carcinoma', 'lung'],
#   'biomarker': ['kras', 'pik3ca', 'ros1', 'egfr', 'alk', 'c-met']},
#  {'cancer_type': ['breast cancer'], 'biomarker': ['agr2']},
#  {'cancer_type': ['endometrial cancer samples'],
#   'biomarker': ['pten', 'pik3ca', 'mtor', 'kras']},
#  {'cancer_type': ['endometrial cancer samples'],
#   'biomarker': ['pten', 'pik3ca', 'mtor', 'kras']},
#  {'cancer_type': ['endometrial cancer samples', 'tumors'],
#   'biomarker': ['pten', 'kras', 'mtor', 'pik3ca']},
#  {'cancer_type': [], 'biomarker': ['erbb2', 'her2']},
#  {'cancer_type': ['crc'], 'biomarker': ['fgfr1', 'fgfr', 'pfgfr1']},
#  {'cancer_type': ['tumor', 'tumor types'], 'biomarker': ['naprt1', 'nampt']},
#  {'cancer_type': ['nsclc', 'tumor'], 'biomarker': ['egfr']},
#  {'cancer_type': ['xenografts'], 'biomarker': ['zeb1']},
#  {'cancer_type': ['xenografts'], 'biomarker': ['zeb1']},
#  {'cancer_type': [], 'biomarker': ['timp1']},
#  {'cancer_type': ['tumors'], 'biomarker': ['pp4a3', 'ptp1b', 'egfr', 'prl-3']},
#  {'cancer_type': [], 'biomarker': ['tyms']},
#  {'cancer_type': [], 'biomarker': ['igf1r', 'egfr']},
#  {'cancer_type': ['colorectal cancer'], 'biomarker': ['ephb4']},
#  {'cancer_type': [], 'biomarker': ['p53', 'tp53']},
#  {'cancer_type': ['nsclc', 'tumor specimens'], 'biomarker': ['tyms', 'dhfr']},
#  {'cancer_type': ['prostate cancer'], 'biomarker': ['tyms']},
#  {'cancer_type': ['breast cancer'], 'biomarker': ['top2a']},
#  {'cancer_type': ['ovarian', 'peritoneal carcinoma'],
#   'biomarker': ['topoisomerase 1']},
#  {'cancer_type': ['colorectal cancer', 'metastatic'],
#   'biomarker': ['kras', 'egfr']},
#  {'cancer_type': [], 'biomarker': ['topoisomerase 1', 'topoisomerase i']},
#  {'cancer_type': ['cancer histologies'],
#   'biomarker': ['acly', 'p-ampk', 'prkaa2']},
#  {'cancer_type': ['colorectal cancer'], 'biomarker': ['grp78', 'hspa5']},
#  {'cancer_type': ['colorectal cancer'], 'biomarker': ['pik3ca', 'egfr']},
#  {'cancer_type': ['pancreatic cancer'], 'biomarker': ['kras']},
#  {'cancer_type': ['xenografts'], 'biomarker': ['mtor', 'eif4ebp1']},
#  {'cancer_type': ['gists', 'antitumor'], 'biomarker': ['kit']},
#  {'cancer_type': [], 'biomarker': ['class 3 beta-tubulin']},
#  {'cancer_type': ['breast cancers'], 'biomarker': ['betaiii-tubulin']},
#  {'cancer_type': ['nsclc'], 'biomarker': ['tyms', 'garft', 'dhfr']},
#  {'cancer_type': [], 'biomarker': ['egfr']},
#  {'cancer_type': ['desmoplastic tumor',
#    'rhabdomyosarcoma',
#    'ewing sarcoma',
#    'liposarcoma',
#    'osteosarcoma',
#    'sarcomas',
#    'synovialsarcoma'],
#   'biomarker': ['igf1r', 'igf-1r']},
#  {'cancer_type': ['prostate specimens', 'castrate', 'prostate cancer'],
#   'biomarker': ['cflar', 'c-flip']},
#  {'cancer_type': ['hepatocellular carcinomas', 'xenografts', 'tumors'],
#   'biomarker': ['cd133', 'jnk', 'prom1']},
#  {'cancer_type': ['breast cancers'], 'biomarker': ['timp1', 'timp-1']},
#  {'cancer_type': ['breast cancer', 'tumor samples'], 'biomarker': ['foxp3']},
#  {'cancer_type': ['gastric tumors'], 'biomarker': ['tyms']},
#  {'cancer_type': ['gastric cancer'], 'biomarker': ['rps6', 'ps6']},
#  {'cancer_type': [], 'biomarker': ['jak 1 / 2 / 3', 'pkc', 'jak1']},
#  {'cancer_type': [], 'biomarker': ['mtor', 'eif4ebp1']},
#  {'cancer_type': [], 'biomarker': ['brca1']},
#  {'cancer_type': [], 'biomarker': ['dusp6', 'mek']},
#  {'cancer_type': [],
#   'biomarker': ['raf', 'kras', 'pik3ca', 'ras', 'braf', 'mek', 'pten']},
#  {'cancer_type': [],
#   'biomarker': ['raf', 'pik3ca', 'ras', 'braf', 'mek', 'pten']},
#  {'cancer_type': ['pancreatic adenocarcinoma', 'tumor'],
#   'biomarker': ['pten', 'kras', 'pan-akt', 'cancer antigen 19-9']},
#  {'cancer_type': ['pancreatic adenocarcinoma', 'tumor'],
#   'biomarker': ['pten', 'kras', 'pan-akt', 'cancer antigen 19-9']},
#  {'cancer_type': [], 'biomarker': ['hspb1', 'hsp27']},
#  {'cancer_type': [], 'biomarker': ['nqo1']},
#  {'cancer_type': [], 'biomarker': ['nq01', 'nqo1']},
#  {'cancer_type': ['sporadic', 'ovarian cancer'], 'biomarker': ['brca1']},
#  {'cancer_type': [], 'biomarker': ['kras', 'tlr9']},
#  {'cancer_type': [], 'biomarker': ['abcb1']},
#  {'cancer_type': ['nsclc', 'tumors'], 'biomarker': ['tyms', 'alk', 'egfr']},
#  {'cancer_type': ['gastric cancer'], 'biomarker': ['dnmt1']},
#  {'cancer_type': ['antitumor', 'xenografts'], 'biomarker': ['kras']},
#  {'cancer_type': [], 'biomarker': ['egfr', 'tyrosine kinase']},
#  {'cancer_type': ['samples', 'tumors'], 'biomarker': ['cxcr4']},
#  {'cancer_type': [], 'biomarker': ['mageh', 'mageh1']},
#  {'cancer_type': [], 'biomarker': ['abcc3', 'erbb2', 'her2']},
#  {'cancer_type': [], 'biomarker': ['abcc10']},
#  {'cancer_type': [], 'biomarker': ['asns', 'l-asparaginase']},
#  {'cancer_type': [], 'biomarker': ['egfr']},
#  {'cancer_type': [], 'biomarker': ['pten']},
#  {'cancer_type': [], 'biomarker': ['oct4b1', 'abcg2', 'pou5f1', 'p-gp']},
#  {'cancer_type': ['lung adenocarcinoma', 'lung adenocarcinomas'],
#   'biomarker': ['her2']},
#  {'cancer_type': ['xenografts', 'tumor', 'tumors'], 'biomarker': ['erbb2']},
#  {'cancer_type': ['breast cancer'], 'biomarker': ['her2']},
#  {'cancer_type': [], 'biomarker': ['erbb2', 'egfr', 'erbb3']},
#  {'cancer_type': ['tumor xenograft', 'nsclc', 'tumor', 'xenograft'],
#   'biomarker': ['egfrm', 'egfr']},
#  {'cancer_type': ['lung cancer', 'tumors'], 'biomarker': ['egfr']},
#  {'cancer_type': ['non-small cell lung cancer', 'tumor'],
#   'biomarker': ['egfr']},
#  {'cancer_type': [], 'biomarker': ['egfr']},
#  {'cancer_type': [], 'biomarker': ['egfr']},
#  {'cancer_type': [], 'biomarker': ['egfr', 'l858r']},
#  {'cancer_type': [], 'biomarker': ['egfr']},
#  {'cancer_type': ['glioblastoma multiforme', 'gbm', 'cancer'],
#   'biomarker': ['egfr']},
#  {'cancer_type': ['breast cancer', 'tumors'],
#   'biomarker': ['erbb2', 'sher2', 'her2']},
#  {'cancer_type': ['nsclc'], 'biomarker': ['egfr']},
#  {'cancer_type': ['colorectal cancer'],
#   'biomarker': ['ntrk1', 'lmna', 'tpm3', 'trka']},
#  {'cancer_type': ['glioma', 'solid tumors'], 'biomarker': ['idh1']},
#  {'cancer_type': ['nsclc'], 'biomarker': ['egfr']},
#  {'cancer_type': ['nsclc'], 'biomarker': ['egfr']},
#  {'cancer_type': ['nsclc'], 'biomarker': ['l858r', 'egfr']},
#  {'cancer_type': ['melanomas', 'tumours', 'melanoma'],
#   'biomarker': ['hla-dra', 'anti-pd1', 'mhc-ii', 'hla-dr', 'anti']},
#  {'cancer_type': [], 'biomarker': ['cxcr4', 'myd88']},
#  {'cancer_type': [], 'biomarker': ['kras', 'raf1', 'raf', 'mek']},
#  {'cancer_type': [], 'biomarker': ['kras', 'raf1', 'raf', 'mek']},
#  {'cancer_type': ['metastatic adenocarcinoma'], 'biomarker': ['kras']},
#  {'cancer_type': [], 'biomarker': ['erbb3', 'kras', 'egfr', 'mek', 'erbb2']},
#  {'cancer_type': [], 'biomarker': ['erbb3', 'kras', 'egfr', 'mek', 'erbb2']},
#  {'cancer_type': ['tumors',
#    'colorectal cancer',
#    'colorectal tumor',
#    'tumor',
#    'tumor samples'],
#   'biomarker': ['k-ras', 'kras']},
#  {'cancer_type': ['cancer', 'advanced', 'melanoma'],
#   'biomarker': ['ki67', 'ret', 'braf', 'egfr', 'met', 'mek']},
#  {'cancer_type': ['melanoma'], 'biomarker': ['braf', 'nras', 'mek']},
#  {'cancer_type': ['melanomas', 'melanoma'],
#   'biomarker': ['braf', 'nras', 'mek']},
#  {'cancer_type': ['non-small cell lung cancer', 'cancer', 'advanced', 'nsclc'],
#   'biomarker': ['kras', 'ki67', 'mek']},
#  {'cancer_type': ['colorectal cancer', 'cancer'],
#   'biomarker': ['kras', 'ki67', 'mek']},
#  {'cancer_type': [], 'biomarker': ['kras']},
#  {'cancer_type': [],
#   'biomarker': ['mitogen-activated protein kinase 1 / 2', 'braf']},
#  {'cancer_type': ['colorectal cancer'],
#   'biomarker': ['kras', 'mitogen-activated protein kinase 1 / 2', 'pik3ca']},
#  {'cancer_type': [],
#   'biomarker': ['akt', 'pik3ca', 'pi3k', 'mek', 'nras', 'mtor']},
#  {'cancer_type': [],
#   'biomarker': ['akt', 'kras', 'pi3k', 'mek', 'erk', 'mtor']},
#  {'cancer_type': ['xenografts'],
#   'biomarker': ['igf-ir', 'rtks', 'kras', 'rtki', 'meti', 'met', 'mek']},
#  {'cancer_type': [],
#   'biomarker': ['p-erk', 'mek1 / 2', 'pi3k', 'p-akt', 'braf', 'mtor']},
#  {'cancer_type': [], 'biomarker': ['erbb2']},
#  {'cancer_type': ['breast cancer', 'bc'], 'biomarker': ['her2']},
#  {'cancer_type': ['bc'], 'biomarker': ['her2']},
#  {'cancer_type': ['bc', 'her2'], 'biomarker': ['her2']},
#  {'cancer_type': ['breast cancer', 'her2 breast cancer', 'tumor'],
#   'biomarker': ['her2']},
#  {'cancer_type': ['bc'], 'biomarker': ['erbb', 'her2']},
#  {'cancer_type': ['mbc', 'metastatic bc'],
#   'biomarker': ['erbb3', 'erbb4', 'egfr', 'erbb', 'her2']},
#  {'cancer_type': ['metastatic', 'prostate cancer'],
#   'biomarker': ['mre11', 'nbn', 'parp', 'mlh3', 'atm']},
#  {'cancer_type': ['antitumor', 'tumor'],
#   'biomarker': ['egfrwt', 'akt', 'egfr', 'egfrviii']},
#  {'cancer_type': [], 'biomarker': ['ntrk1', 'cd74', 'mprip', 'trka']},
#  {'cancer_type': ['crc', 'tumor', 'tumors'],
#   'biomarker': ['ereg', 'kras', 'areg', 'ras']},
#  {'cancer_type': ['crc', 'tumor', 'tumors'],
#   'biomarker': ['ereg', 'kras', 'areg', 'ras']},
#  {'cancer_type': ['gastric cancer', 'metastatic cancer'],
#   'biomarker': ['her2']},
#  {'cancer_type': ['gastric cancer'], 'biomarker': ['ihc3', 'her2']},
#  {'cancer_type': ['low-grade endometrial stromal sarcoma'],
#   'biomarker': ['cd117']},
#  {'cancer_type': ['high-grade stromal endometrial sarcoma'],
#   'biomarker': ['c-kit']},
#  {'cancer_type': ['stage iv nsclc'], 'biomarker': ['ros1']},
#  {'cancer_type': ['kidney cancer', 'tumor', 'tumors'],
#   'biomarker': ['hif1a', 'vhl', 'mtor']},
#  {'cancer_type': [], 'biomarker': ['flt3']},
#  {'cancer_type': [], 'biomarker': ['flt3']},
#  {'cancer_type': ['acute myeloid leukemia'], 'biomarker': ['flt3-itd']},
#  {'cancer_type': ['aml'], 'biomarker': ['flt3']},
#  {'cancer_type': ['aml'], 'biomarker': ['flt3']},
#  {'cancer_type': ['nsclc'], 'biomarker': ['ihc3', 'her2', 'ihc2']},
#  {'cancer_type': ['nsclc'], 'biomarker': ['ihc3', 'ihc2', 'her2']},
#  {'cancer_type': ['nsclc', 'adenocarcinoma', 'cancer type', 'tumors'],
#   'biomarker': ['her2']},
#  {'cancer_type': ['nsclc', 'sclc', 'tumor'], 'biomarker': ['her2']},
#  {'cancer_type': [], 'biomarker': ['her2', 'ihc2']},
#  {'cancer_type': ['adenosquamous lung tumors', 'tumor'],
#   'biomarker': ['rtta', 'her2']},
#  {'cancer_type': ['nsclc tumors', 'lung cancers'], 'biomarker': ['her2']},
#  {'cancer_type': ['nsclc', 'lung cancer'],
#   'biomarker': ['calu-3', 'tdm-1', 'her2', 'calu-6']},
#  {'cancer_type': ['tumor', 'crc'], 'biomarker': ['egfr']},
#  {'cancer_type': ['tumor', 'crc'], 'biomarker': ['egfr']},
#  {'cancer_type': ['nsclc', 'cancer', 'tumor'], 'biomarker': ['ets2']},
#  {'cancer_type': ['breast cancer'], 'biomarker': ['ihc3', 'her2']},
#  {'cancer_type': ['specimens', 'mcrc', 'liver lesions', 'tumor'],
#   'biomarker': []},
#  {'cancer_type': ['colorectal cancer'], 'biomarker': ['egfr']},
#  {'cancer_type': ['colorectal cancer'], 'biomarker': ['egfr']},
#  {'cancer_type': ['colorectal cancer'], 'biomarker': ['egfr']},
#  {'cancer_type': ['colorectal cancer'], 'biomarker': ['receptor', 'egfr']},
#  {'cancer_type': ['colorectal cancer'], 'biomarker': ['receptor', 'egfr']},
#  {'cancer_type': ['breast cancer'], 'biomarker': ['her2', 'fcgr3a']},
#  {'cancer_type': ['breast cancer'], 'biomarker': ['fcgr2a', 'her2']},
#  {'cancer_type': ['scc', 'solid tumors'], 'biomarker': ['egfr']},
#  {'cancer_type': ['acute promyelocytic leukemia'],
#   'biomarker': ['pml', 'rara']},
#  {'cancer_type': ['acute promyelocytic leukemia'],
#   'biomarker': ['pml', 'rara']},
#  {'cancer_type': ['acute promyelocytic leukemia'],
#   'biomarker': ['pml', 'rara']},
#  {'cancer_type': ['acute promyelocytic leukemia'],
#   'biomarker': ['pml', 'rara']},
#  {'cancer_type': ['nsclc'], 'biomarker': ['met']},
#  {'cancer_type': ['high-grade endometrial adenocarcinoma',
#    'uspc',
#    'uterine serous papillary carcinoma',
#    'cancer',
#    'endometrial cancers'],
#   'biomarker': ['ca-125', 'ihc3', 'her2']},
#  {'cancer_type': ['gastrointestinal',
#    'uterine serous cancer',
#    'serous type',
#    'her2 cancers',
#    'cancers',
#    'endometrial cancer',
#    'breast',
#    'tumor',
#    'endometrial cancers'],
#   'biomarker': ['her2', 'ihc2']},
#  {'cancer_type': ['medulloblastoma', 'tumor'], 'biomarker': ['shh']},
#  {'cancer_type': ['tumor', 'metastatic', 'lung adenocarcinoma'],
#   'biomarker': ['cd74', 'ros1']},
#  {'cancer_type': [], 'biomarker': ['cd74-ros1', 'cd74']},
#  {'cancer_type': [], 'biomarker': ['p30', 'set', 'cebpa', 'mll', 'wrd5']},
#  {'cancer_type': [], 'biomarker': ['fgfr1', 'znf198']},
#  {'cancer_type': [], 'biomarker': ['fgfr1']},
#  {'cancer_type': [], 'biomarker': ['rhvegf', 'kdr']},
#  {'cancer_type': [], 'biomarker': ['rhvegf', 'kdr']},
#  {'cancer_type': ['tumor'], 'biomarker': ['tsc2', 'mtor']},
#  {'cancer_type': ['tumor'], 'biomarker': ['tsc2', 'mtor']},
#  {'cancer_type': ['apl'], 'biomarker': ['flt3']},
#  {'cancer_type': ['breast cancer'], 'biomarker': ['her2']},
#  {'cancer_type': [], 'biomarker': ['aldh1a2']},
#  {'cancer_type': [], 'biomarker': ['cip2a']},
#  {'cancer_type': ['lung acinar adenocarcinoma'],
#   'biomarker': ['alk', 'egfr', 'eml4']},
#  {'cancer_type': ['bc', 'invasive'], 'biomarker': ['her2']},
#  {'cancer_type': ['stage iv lung adenocarcinoma'], 'biomarker': ['her2']},
#  {'cancer_type': ['glioblastomas', 'tumor'],
#   'biomarker': ['egfrviii', 'her2 /', 'egfr', 'pten', 'neu']},
#  {'cancer_type': ['glioblastomas', 'tumor'],
#   'biomarker': ['egfrviii', 'her2 /', 'egfr', 'pten', 'neu']},
#  {'cancer_type': ['adenocarcinoma'], 'biomarker': ['kras', 'egfr']},
#  {'cancer_type': ['breast cancer', 'her2 breast cancer'],
#   'biomarker': ['erbb2', 'her2']},
#  {'cancer_type': ['breast cancer', 'her2'], 'biomarker': []},
#  {'cancer_type': ['uveal melanoma'],
#   'biomarker': ['ddx43', 'perk', 'gna11', 'ras', 'mek', 'gnaq']},
#  {'cancer_type': ['aml'], 'biomarker': ['kit', 'kras', 'nras', 'flt3']},
#  {'cancer_type': ['aml'], 'biomarker': ['flt3']},
#  {'cancer_type': [], 'biomarker': ['tbk1', 'nras', 'mek']},
#  {'cancer_type': [], 'biomarker': ['kras']},
#  {'cancer_type': ['tumours', 'xenografts', 'tumors'],
#   'biomarker': ['kras', 'braf', 'raf', 'mek']},
#  {'cancer_type': ['tumours', 'xenografts'],
#   'biomarker': ['kras', 'braf', 'mapk', 'mek']},
#  {'cancer_type': ['tumor', 'tumors'], 'biomarker': ['kras', 'mek1 / 2']},
#  {'cancer_type': ['tumor', 'tumors'], 'biomarker': ['kras']},
#  {'cancer_type': ['nsclc', 'tumors'],
#   'biomarker': ['perk', 'kras', 'lkb1', 'cre', 'trp53', 'stk11']},
#  {'cancer_type': ['nsclc', 'tumors'],
#   'biomarker': ['kras', 'perk', 'trp53', 'cre']},
#  {'cancer_type': ['nsclc', 'tumors'],
#   'biomarker': ['kras', 'perk', 'trp53', 'cre']},
#  {'cancer_type': [], 'biomarker': ['tp53wt', 'tp53']},
#  {'cancer_type': [], 'biomarker': ['tp53']},
#  {'cancer_type': ['lung adenocarcinoma'],
#   'biomarker': ['havcr2', 't-cell immunoglobulin mucin-3', 'pd-1', 'tim-3']},
#  {'cancer_type': ['lung adenocarcinoma'],
#   'biomarker': ['havcr2', 't-cell immunoglobulin mucin-3', 'pd-1', 'tim-3']},
#  {'cancer_type': ['colon cancer',
#    'nsclc xenografts',
#    'lung',
#    'tumor',
#    'crc xenografts'],
#   'biomarker': ['erbb3', 'kras', 'egfr', 'mek', 'erbb2']},
#  {'cancer_type': ['colon cancer', 'lung'],
#   'biomarker': ['erbb2i', 'erbb3', 'egfri', 'kras', 'egfr', 'mek', 'erbb2']},
#  {'cancer_type': ['head and neck squamous cell carcinoma'],
#   'biomarker': ['p16']},
#  {'cancer_type': ['breast cancer'], 'biomarker': ['bmmp2', 'mmp2']},
#  {'cancer_type': ['breast cancer'], 'biomarker': ['mmp9', 'bmmp9']},
#  {'cancer_type': ['high-grade gliomas'], 'biomarker': ['mmp2']},
#  {'cancer_type': ['her2 breast cancer'], 'biomarker': ['her2']},
#  {'cancer_type': ['breast cancer'], 'biomarker': ['her2']},
#  {'cancer_type': ['gastric cancer'], 'biomarker': ['hsph1', 'hsp110']},
#  {'cancer_type': ['stage', 'colorectal tumors'], 'biomarker': ['hsp110']},
#  {'cancer_type': ['non-small cell lung cancer',
#    'tumorothelial',
#    'renal cell cancer',
#    'hepatocellular cancer'],
#   'biomarker': ['ecscr', 'robo4']},
#  {'cancer_type': ['non-small cell lung cancer',
#    'tumorothelial',
#    'renal cell cancer',
#    'hepatocellular cancer'],
#   'biomarker': ['ecscr', 'robo4']},
#  {'cancer_type': ['tumors'], 'biomarker': ['pd-1', 'pd-l1', 'cd274']},
#  {'cancer_type': ['sarcoma', 'advanced', 'tumors'], 'biomarker': ['tp53']},
#  {'cancer_type': [], 'biomarker': ['p110α', 'gfp', 'pi3k']},
#  {'cancer_type': ['non-small cell lung cancer', 'tumour'],
#   'biomarker': ['pd-l1']},
#  {'cancer_type': [],
#   'biomarker': ['egf',
#    'mapk',
#    'kras',
#    'pi3k',
#    'egfr',
#    'epidermal growth factor']},
#  {'cancer_type': ['colon cancer patient', 'xenografts', 'tumor'],
#   'biomarker': ['her2']},
#  {'cancer_type': ['nsclc'], 'biomarker': ['alk']},
#  {'cancer_type': ['colon cancer patient', 'xenografts', 'tumor'],
#   'biomarker': ['her2']},
#  {'cancer_type': ['colon cancer patient', 'xenografts', 'tumor'],
#   'biomarker': ['her2']},
#  {'cancer_type': ['colon cancer patient', 'xenografts', 'tumor'],
#   'biomarker': ['her2']},
#  {'cancer_type': ['colon cancer patient', 'xenografts', 'tumor'],
#   'biomarker': ['her2']},
#  {'cancer_type': ['colorectal cancer'], 'biomarker': ['kras']},
#  {'cancer_type': ['colorectal cancer', 'tumours'],
#   'biomarker': ['kras', 'anti-egfr']},
#  {'cancer_type': ['colorectal cancer xenografts', 'tumors'],
#   'biomarker': ['kras', 'proteasome']},
#  {'cancer_type': ['tumor', 'tumors'], 'biomarker': ['kras', 'braf', 'cdk1']},
#  {'cancer_type': [], 'biomarker': ['c-met', 'met']},
#  {'cancer_type': ['tumor'], 'biomarker': ['metex14', 'met']},
#  {'cancer_type': ['nsclc'], 'biomarker': ['alk', 'eml4', 'met']},
#  {'cancer_type': ['nsclc', 'lung adenocarcinoma specimen'],
#   'biomarker': ['eml4', 'il3', 'eml4-', 'eml4-alk', 'alk']},
#  {'cancer_type': ['adenocarcinoma', 'nsclc tumors'],
#   'biomarker': ['alk variant 2', 'alk', 'eml4']},
#  {'cancer_type': ['lung adenocarcinoma', 'lung adenocarcinomas', 'tumors'],
#   'biomarker': ['alk', 'eml4']},
#  {'cancer_type': ['crc'],
#   'biomarker': ['kras', 'vegfr', 'apc', 'erbb2', 'vegfr2', 'kdr']},
#  {'cancer_type': ['nsclc', 'tumors'], 'biomarker': ['alk', '3a', 'eml4']},
#  {'cancer_type': ['nsclc'],
#   'biomarker': ['alk', 'eml4-alksclc', 'eml4-alk', '3a']},
#  {'cancer_type': [],
#   'biomarker': ['erk1 / 2', 'akt', 'eml4', 'alk variant 3a', 'alk']},
#  {'cancer_type': [],
#   'biomarker': ['erk1 / 2', 'akt', 'eml4', 'kras', 'egfr', 'alk', '3a']},
#  {'cancer_type': [],
#   'biomarker': ['v3a', 'v3b', 'il3', 'v1', 'v2', 'eml4-alk', 'alk', '3a']},
#  {'cancer_type': [],
#   'biomarker': ['v3a', 'eml4', 'v3b', 'v1', 'v2', 'alk', '3a']},
#  {'cancer_type': ['non-small cell lung cancer'], 'biomarker': ['alk']},
#  {'cancer_type': ['nsclc'], 'biomarker': ['alk']},
#  {'cancer_type': ['nsclc'], 'biomarker': ['alk']},
#  {'cancer_type': ['nsclc'], 'biomarker': ['alk']},
#  {'cancer_type': ['nsclc', 'tumor'], 'biomarker': ['hsp90', 'alk']},
#  {'cancer_type': ['h3122 tumors', 'tumor'],
#   'biomarker': ['hsp90', 'her2', 'egfr', 'eml4-alk']},
#  {'cancer_type': ['lung adenocarcinomas'],
#   'biomarker': ['hsp90',
#    'eml4',
#    'il3',
#    'eml4-alk variant 2',
#    'eml4-alk',
#    'alk']},
#  {'cancer_type': [], 'biomarker': ['il3', 'hsp90', 'eml4-alk']},
#  {'cancer_type': [],
#   'biomarker': ['hsp90',
#    'eml4-alk variant 1',
#    'il3',
#    'eml4-alk',
#    'alk fusion']},
#  {'cancer_type': ['nsclc', 'tumor'], 'biomarker': ['alk', 'eml4-alk']},
#  {'cancer_type': ['mcrc'],
#   'biomarker': ['kras', 'ras', 'braf', 'egfr', 'nras']},
#  {'cancer_type': ['histiocytic sarcoma',
#    'cancer',
#    'hepatocellular carcinoma',
#    'cancers',
#    'b-cell lymphoma',
#    'tumor'],
#   'biomarker': ['p47s', 'tp53', 's47']},
#  {'cancer_type': ['xenograft'], 'biomarker': ['gnaq', 'brd4', 'gna11', 'jq1']},
#  {'cancer_type': [], 'biomarker': ['gna11', 'brd4', 'jq1', 'gnaq', 'omm1']},
#  {'cancer_type': ['uveal melanoma'], 'biomarker': ['gnaq', 'gna', 'gna11']},
#  {'cancer_type': ['uveal melanoma'], 'biomarker': ['gnaq', 'gna', 'gna11']},
#  {'cancer_type': ['glioblastoma multiforme',
#    'tumors',
#    'lung',
#    'malignant tumors',
#    'tumor',
#    'melanoma'],
#   'biomarker': ['tp53', 'mgmt', 'pms2']},
#  {'cancer_type': ['colorectal cancer', 'adenocarcinoma subtype'],
#   'biomarker': ['kras', 'egfr']},
#  {'cancer_type': ['lung adenocarcinoma'], 'biomarker': ['kras']},
#  {'cancer_type': ['pancreatic cancer'], 'biomarker': ['kras']},
#  {'cancer_type': ['nsclc', 'tumor', 'advanced', 'solid tumors'],
#   'biomarker': ['kras']},
#  {'cancer_type': ['gist'], 'biomarker': ['kit']},
#  {'cancer_type': ['tumor', 'melanoma'], 'biomarker': ['kit']},
#  {'cancer_type': ['gist', 'tumor'], 'biomarker': ['kit', 'pdgfra']},
#  {'cancer_type': ['melanoma'], 'biomarker': ['kit']},
#  {'cancer_type': ['advanced', 'melanoma'], 'biomarker': ['braf', 'nras']},
#  {'cancer_type': ['melanoma'], 'biomarker': ['braf', 'nras', 'mek162']},
#  {'cancer_type': ['cutaneous', 'uveal', 'melanoma'],
#   'biomarker': ['nras', 'brafv600wt', 'nraswt']},
#  {'cancer_type': ['uveal melanoma', 'melanoma'],
#   'biomarker': ['gnaq', 'gna11']},
#  {'cancer_type': ['uveal melanoma', 'melanoma'],
#   'biomarker': ['gnaq', 'gna11']},
#  {'cancer_type': ['lung carcinoma',
#    'melanoma xenograft',
#    'melanoma',
#    'neuroblastoma'],
#   'biomarker': ['nras', 'pi3k']},
#  {'cancer_type': ['prostate cancer'], 'biomarker': ['pten', 'mtor']},
# ...
#   'biomarker': ['braf', 'mapk', 'mek']},
#  {'cancer_type': ['samples', 'melanoma sample', 'tcga'],
#   'biomarker': ['trim24', 'braf', 'papss1', 'erk1 / 2']},
#  {'cancer_type': ['er', 'tumors', 'breast cancers'],
#   'biomarker': ['sf3b complex', 'er', 'sf3b1']},
#  {'cancer_type': ['er', 'tumors', 'breast cancers'],
#   'biomarker': ['sf3b complex', 'er', 'sf3b1']},
#  {'cancer_type': [], 'biomarker': ['alk']},
#  {'cancer_type': ['melanoma'], 'biomarker': ['v600e', 'v600']},
#  {'cancer_type': ['melanoma'], 'biomarker': ['braf']},
#  {'cancer_type': ['chronic eosinophilic leukemia'], 'biomarker': ['kit']},
#  {'cancer_type': ['gastrointestinal stromal tumors'],
#   'biomarker': ['kit', 'pdgfra']},
#  {'cancer_type': ['colorectal cancer', 'tumor', 'tumors'],
#   'biomarker': ['akt',
#    'phospho',
#    's6',
#    'pi3k',
#    'braf',
#    'erk',
#    'mtor',
#    'tunel']},
#  {'cancer_type': ['tumor xenografts', 'tumor'],
#   'biomarker': ['annexin v', 'pi3k', 'mek', 'nras', 'mtor', 'pi']},
#  {'cancer_type': ['tumor', 'high-grade colorectal neuroendocrine tumors'],
#   'biomarker': ['braf', 'mek']},
#  {'cancer_type': ['breast cancer'], 'biomarker': ['her2']},
#  {'cancer_type': ['breast cancer'], 'biomarker': ['her2']},
#  {'cancer_type': ['urothelial carcinoma'], 'biomarker': ['mtor']},
#  {'cancer_type': ['breast cancer'], 'biomarker': ['her2']},
#  {'cancer_type': ['lung adenocarcinoma'],
#   'biomarker': ['mtor1 / 2', 'rictor']},
#  {'cancer_type': [], 'biomarker': ['fip1l1', 'tryptase', 'pdgfra']},
#  {'cancer_type': ['nsclc', 'tumor'],
#   'biomarker': ['cd74', 'alk', 'egfr', 'ros1']},
#  {'cancer_type': ['inflammatory myofibroblastic tumor', 'tumor'],
#   'biomarker': ['tfg', 'alk', 'ros1']},
#  {'cancer_type': [], 'biomarker': ['fip1l1', 'pdgfra']},
#  {'cancer_type': [], 'biomarker': ['fip1l1', 'bcr-abl', 'pdgfra']},
#  {'cancer_type': ['lung cancer', 'tumor', 'tumors'],
#   'biomarker': ['akt', 'pik3ca', 'phosoho-s6', 'p110alpha', 'mtor', 'p110']},
#  {'cancer_type': ['tumor xenografts', 'trastuzumab', 'tumor', 'tumors'],
#   'biomarker': ['her2', 'pi3k']},
#  {'cancer_type': ['her2 breast cancer'],
#   'biomarker': ['birc5', 'survivin', 'her2']},
#  {'cancer_type': [], 'biomarker': ['pi3k']},
#  {'cancer_type': ['cancers'],
#   'biomarker': ['pan', 'ras', 'braf', 'craf', 'mek', 'erk', 'nras']},
#  {'cancer_type': ['tumor', 'bt474 xenograft tumors'],
#   'biomarker': ['pten', 'pi3k']},
#  {'cancer_type': ['cancers'],
#   'biomarker': ['pan', 'ras', 'braf', 'craf', 'mek', 'erk', 'nras']},
#  {'cancer_type': ['cancers'],
#   'biomarker': ['pan', 'ras', 'braf', 'craf', 'mek', 'erk', 'nras']},
#  {'cancer_type': [], 'biomarker': ['erk', 'braf', 'mek']},
#  {'cancer_type': [], 'biomarker': ['erk', 'braf', 'mek']},
#  {'cancer_type': ['tumor', 'metastatic', 'metastatic lesions', 'melanoma'],
#   'biomarker': ['braf', 'mek']},
#  {'cancer_type': [], 'biomarker': ['erk', 'braf', 'mek']},
#  {'cancer_type': [], 'biomarker': ['erk', 'braf', 'mek']},
#  {'cancer_type': ['tumour', 'melanoma'], 'biomarker': ['braf']},
#  {'cancer_type': [],
#   'biomarker': ['akt', 'pik3ca', 'pi3k', 'parp', 'p110beta']},
#  {'cancer_type': [],
#   'biomarker': ['gamma', 'akt', 'alpha', 'pi3k', 'parp', 'pten', 'delta']},
#  {'cancer_type': ['melanoma', 'tumors'], 'biomarker': ['kit']},
#  {'cancer_type': [],
#   'biomarker': ['gamma', 'alpha', 'akt', 'pi3k', 'parp', 'pten', 'delta']},
#  {'cancer_type': ['melanomas', 'allografts', 'melanoma'],
#   'biomarker': ['mek', 'braf', 'nf1']},
#  {'cancer_type': ['melanomas', 'tumor', 'melanoma'],
#   'biomarker': ['mek', 'braf', 'mtor', 'nf1']},
#  {'cancer_type': ['melanoma'], 'biomarker': ['mek', 'braf', 'nf1']},
#  {'cancer_type': ['melanoma'],
#   'biomarker': ['raf', 'nf1', 'braf', 'mek', 'erk']},
#  {'cancer_type': ['melanoma'], 'biomarker': ['braf', 'nras']},
#  {'cancer_type': ['melanoma', 'advanced', 'tumor', 'cancers'],
#   'biomarker': ['nras']},
#  {'cancer_type': [], 'biomarker': ['braf', 'nras']},
#  {'cancer_type': [], 'biomarker': ['braf', 'nras']},
#  {'cancer_type': [], 'biomarker': ['braf', 'nras', 'annexin v']},
#  {'cancer_type': ['basal cell carcinoma'], 'biomarker': ['smo', 'smoothened']},
#  {'cancer_type': ['cll'], 'biomarker': ['p53']},
#  {'cancer_type': ['leukemianet'], 'biomarker': ['calr']},
#  {'cancer_type': [], 'biomarker': ['alk', 'hip1']},
#  {'cancer_type': ['tumor'], 'biomarker': ['alk', 'eml4']},
#  {'cancer_type': ['xenografts', 'tumor'],
#   'biomarker': ['gamma', 'pik3ca', 'p110 alpha', 'pten', 'delta']},
#  {'cancer_type': [], 'biomarker': ['pten', 'akt', 'egf']},
#  {'cancer_type': [], 'biomarker': ['pten']},
#  {'cancer_type': ['gastric cancer'], 'biomarker': ['pten', 'akt', 'p-akt']},
#  {'cancer_type': [], 'biomarker': ['ezh2']},
#  {'cancer_type': ['tumors'], 'biomarker': ['ccnd1']},
#  {'cancer_type': ['tumors'], 'biomarker': ['raf1']},
#  {'cancer_type': ['tumors'], 'biomarker': ['kras']},
#  {'cancer_type': [], 'biomarker': ['bcr-abl', 'pdgfrb']},
#  {'cancer_type': ['gastric cancer', 'metastatic cancer'],
#   'biomarker': ['her2']},
#  {'cancer_type': ['gastric cancer', 'tumor', 'xenograft'],
#   'biomarker': ['pten', 'akt']},
#  {'cancer_type': ['gastric cancer xenograft mouse', 'tumor'],
#   'biomarker': ['pik3ca']},
#  {'cancer_type': ['hematological tumors', 'solid'],
#   'biomarker': ['pik3ca', 'akt', 'ras']},
#  {'cancer_type': ['xenografts', 'tumor', 'hematological tumors', 'solid'],
#   'biomarker': ['pten', 'akt', 'ras']},
#  {'cancer_type': ['hcc-1954 xenografts',
#    'bt474c xenografts',
#    'hcc',
#    'tumor xenografts',
#    'tumor'],
#   'biomarker': ['pik3ca', 'her2']},
#  {'cancer_type': ['tumor xenografts', 'tumor'],
#   'biomarker': ['pik3ca', 'kpl4']},
#  {'cancer_type': ['xenografts', 'tumor'], 'biomarker': ['pik3ca']},
#  {'cancer_type': [], 'biomarker': ['braf', 'nras', 'mek']},
#  {'cancer_type': ['renal cell cancer',
#    'prostate cancer',
#    'nsclc',
#    'cancer',
#    'colorectal cancer',
#    'tumor',
#    'melanoma'],
#   'biomarker': ['pd-1', 'pd-l1']},
#  {'cancer_type': ['tumor', 'oral papillary adenocarcinoma', 'lung metastases'],
#   'biomarker': ['pten', 'mapk', 'ret']},
#  {'cancer_type': ['acute myeloid leukemia'], 'biomarker': ['pml', 'rara']},
#  {'cancer_type': ['skin tumors', 'tumor'],
#   'biomarker': ['cd28', 'ctla4 receptor', 'ctla4']},
#  {'cancer_type': ['mcrpc',
#    'castration resistant prostate cancer',
#    'mcrpc neoplasms',
#    'prostate cancer'],
#   'biomarker': ['androgen receptor',
#    'ar',
#    'spop',
#    'foxa1',
#    'zbtb16',
#    'ncor1']},
#  {'cancer_type': ['prostate adenocarcinomas', 'lncap tumors', 'tumor'],
#   'biomarker': ['androgen receptor', 'pi3k']},
#  {'cancer_type': [], 'biomarker': ['porcn', 'notch1']},
#  {'cancer_type': ['breast cancer'], 'biomarker': ['cdk6']},
#  {'cancer_type': [],
#   'biomarker': ['cdk4 / 6', 'er', 'estrogen receptor degrader']},
#  {'cancer_type': ['b-all'], 'biomarker': ['flt3']},
#  {'cancer_type': ['ovarian carcinomas', 'tumors'],
#   'biomarker': ['brca1 / 2', 'brca1']},
#  {'cancer_type': ['ovarian carcinomas', 'tumors'],
#   'biomarker': ['brca1 / 2', 'brca1']},
#  {'cancer_type': ['ovarian carcinomas', 'tumors'],
#   'biomarker': ['brca1 / 2', 'brca1']},
#  {'cancer_type': ['ovarian carcinomas', 'tumors'],
#   'biomarker': ['brca1 / 2', 'brca1']},
#  {'cancer_type': ['cutaneous melanoma', 'tumors'],
#   'biomarker': ['gnaq', 'braf']},
#  {'cancer_type': ['cutaneous melanoma', 'tumor', 'metastases', 'tumors'],
#   'biomarker': ['akt', 'braf', 'chr', 'mek', 'pten', 'erk']},
#  {'cancer_type': [], 'biomarker': ['er', 'rb', 'cdk4 / 6']},
#  {'cancer_type': ['mcl', 'mantle cell lymphoma mcl'],
#   'biomarker': ['cyclin d', 'cdk4 / 6']},
#  {'cancer_type': ['cutaneous melanoma'],
#   'biomarker': ['gnaq', 'erk', 'braf', 'perk']},
#  {'cancer_type': ['breast cancer'],
#   'biomarker': ['oestrogen receptor', 'her2', 'p16', 'ccnd1']},
#  {'cancer_type': [], 'biomarker': ['mtor']},
#  {'cancer_type': ['xenografts', 'tumor'], 'biomarker': ['mtor']},
#  {'cancer_type': ['xenografts'], 'biomarker': ['rapalink-1', 'mtor']},
#  {'cancer_type': ['xenografts'], 'biomarker': ['mtor']},
#  {'cancer_type': ['xenograft'], 'biomarker': ['rapalink-1', 'mtor']},
#  {'cancer_type': [], 'biomarker': ['pik3ca', 'pi3k', 'mtor']},
#  {'cancer_type': ['head and neck squamous cell carcinoma', 'ovarian cancer'],
#   'biomarker': ['pik3ca', 'pi3k', 'mtor']},
#  {'cancer_type': [], 'biomarker': ['braf']},
#  {'cancer_type': ['aml'], 'biomarker': ['flt3']},
#  {'cancer_type': ['aml'], 'biomarker': ['flt3']},
#  {'cancer_type': [], 'biomarker': ['flt3']},
#  {'cancer_type': [], 'biomarker': ['cyclin d1', 'ccnd1', 'cdk4 / 6']},
#  {'cancer_type': [], 'biomarker': ['her2', 'cdk4 / 6']},
#  {'cancer_type': [], 'biomarker': ['cyclin d1', 'cdk4 / 6']},
#  {'cancer_type': ['mcl', 'mantle cell lymphoma'],
#   'biomarker': ['rb', 'cyclin d1', 'cdk4 / 6']},
#  {'cancer_type': ['glioblastoma', 'gbm'], 'biomarker': ['alk', 'met']},
#  {'cancer_type': ['tumors'], 'biomarker': ['alk', 'egfr', 'met']},
#  {'cancer_type': ['biopsies', 'metastatic', 'tumor', 'melanoma'],
#   'biomarker': ['gamma',
#    'cripr',
#    'beta',
#    'pd-1',
#    'interferon alpha',
#    'jak1',
#    'cas9']},
#  {'cancer_type': ['metastatic', 'melanoma', 'tumor samples'],
#   'biomarker': ['pd-1', 'jak2']},
#  {'cancer_type': ['metastatic', 'tumor', 'melanoma'],
#   'biomarker': ['pd-1', 'mhc1']},
#  {'cancer_type': ['melanoma'],
#   'biomarker': ['kit', 'braf', 'nras', 'ppfibp2']},
#  {'cancer_type': ['subcutaneous metastasis', 'acral lentiginous melanoma'],
#   'biomarker': ['kit', 'braf', 'nras', 'kiaa1549']},
#  {'cancer_type': ['colorectal cancer'], 'biomarker': ['egfr']},
#  {'cancer_type': ['non-small-cell-lung cancer', 'tumor', 'cancers'],
#   'biomarker': ['braf']},
#  {'cancer_type': ['langerhans cell',
#    'langerhans histiocytosis',
#    'cancers',
#    'erdheim-chester disease'],
#   'biomarker': ['braf', 'v600']},
#  {'cancer_type': ['colorectal cancer', 'cancers'],
#   'biomarker': ['braf', 'v600']},
#  {'cancer_type': ['lung cancer'], 'biomarker': ['alk']},
#  {'cancer_type': ['merkel cell carcinoma'], 'biomarker': ['pd-l1', 'cd274']},
#  {'cancer_type': ['hairy-cell leukemia'], 'biomarker': ['braf']},
#  {'cancer_type': ['hairy-cell leukemia'],
#   'biomarker': ['kras', 'braf', 'runx1']},
#  {'cancer_type': ['melanomas', 'melanoma samples', 'melanoma', 'tumors'],
#   'biomarker': ['braf', 'meki', 'c-met', 'brafi']},
#  {'cancer_type': ['tumor'],
#   'biomarker': ['gna',
#    'luciferase',
#    'hgf',
#    'met',
#    'g-protein',
#    'receptor',
#    'c-met']},
#  {'cancer_type': ['ffpe tumours', 'melanoma'],
#   'biomarker': ['brim3', 'braf', 'brim2', 'met']},
#  {'cancer_type': ['aml'], 'biomarker': ['dnmt3a']},
#  {'cancer_type': ['colorectal cancer', 'colorectal cancer tumor', 'tumor'],
#   'biomarker': ['kras', 'braf', 'egfr', 'map2k1', 'met', 'nras']},
#  {'cancer_type': ['colorectal cancer'], 'biomarker': ['braf', 'egfr']},
#  {'cancer_type': ['papillary thyroid cancer'], 'biomarker': ['braf', 'vegfr']},
#  {'cancer_type': ['nsclc'], 'biomarker': ['egfr']},
#  {'cancer_type': [], 'biomarker': ['shrb', 'rb']},
#  {'cancer_type': ['angiosarcomas',
#    'dedifferentiated liposarcomas',
#    'leiomyosarcomas',
#    'gist',
#    'synovial sarcomas',
#    'pleomorphic liposarcomas',
#    'sarcomas',
#    'malignant peripheral nerve sheath tumours'],
#   'biomarker': ['hr23b', 'rad23b']},
#  {'cancer_type': ['colorectal cancer', 'tumor', 'cancers'],
#   'biomarker': ['braf', 'v600']},
#  {'cancer_type': [], 'biomarker': ['ccnd1', 'cdk4 / 6']},
#  {'cancer_type': ['xenografts'],
#   'biomarker': ['pik3ca', 'pi3k', 'p110alpha', 'cdk4 / 6']},
#  {'cancer_type': ['lung adenocarcinoma'],
#   'biomarker': ['ccdc6', 'alk', 'egfr', 'ret']},
#  {'cancer_type': ['tumor', 'melanoma'], 'biomarker': ['braf', 'map2k1']},
#  {'cancer_type': ['high-grade papillary urothelial carcinoma',
#    'cystectomy',
#    'tumor'],
#   'biomarker': ['fgfr3', 'ccnd1', 'fgf19']},
#  {'cancer_type': ['breast cancer', 'tumor', 'xenograft', 'tumors'],
#   'biomarker': ['fgf3', 'fgf', 'fgf-pathway', 'fgfr2', 'fgfr1']},
#  {'cancer_type': ['tumor', 'xenograft', 'tumors'],
#   'biomarker': ['fgf3', 'fgf', 'fgfr2', 'fgfr1', 'fgf-']},
#  {'cancer_type': ['tumor'], 'biomarker': ['fgf3', 'fgfr1', 'fgfr']},
#  {'cancer_type': [], 'biomarker': ['pik3ca', 'pi3k', 'cdk4 / 6']},
#  {'cancer_type': [], 'biomarker': ['jak1 / 2', 'vhl']},
#  {'cancer_type': [], 'biomarker': ['p-rb', 'phospho-rb', 'pi3k', 'p110alpha']},
#  {'cancer_type': [], 'biomarker': ['mtorc2', 'mtor', 'mtorc1', 'pik3ca']},
#  {'cancer_type': [], 'biomarker': ['pten', 'mtorc1 / 2', 'mtorc', 'mtorc1']},
#  {'cancer_type': [],
#   'biomarker': ['mtorc1 / 2', 'pik3r1', 'pik3ca', 'pi3k', 'pten', 'mtorc1']},
#  {'cancer_type': [], 'biomarker': ['erbb2', 'mtorc1 / 2', 'her2', 'mtorc1']},
#  {'cancer_type': [], 'biomarker': ['pten', 'mtorc1']},
#  {'cancer_type': [], 'biomarker': ['anti-', 'pd-l1', 'anti-pd1', 'ctla4']},
#  {'cancer_type': [], 'biomarker': ['pten', 'pik3ca', 'pi3k class i', 'kras']},
#  {'cancer_type': ['pancreatic cancer', 'tumor', 'peutz-jeghers'],
#   'biomarker': ['phospho-s6 ribosomal protein', 'stk11', 'mtor']},
#  {'cancer_type': [], 'biomarker': ['ps6', 'lkb1', 'stk11']},
#  {'cancer_type': ['polyp', 'polyps'], 'biomarker': ['ps6', 'lkb1', 'stk11']},
#  {'cancer_type': [], 'biomarker': ['mtor', 'lkb1', 'p4ebp1', 'stk11', 'ps6k']},
#  {'cancer_type': ['lung adenocarcinoma'],
#   'biomarker': ['ret', 'kif5b', 'akt2', 'egfr', 'alk']},
#  {'cancer_type': ['lung adenocarcinoma'],
#   'biomarker': ['kif5b', 'alk', 'egfr', 'ret']},
#  {'cancer_type': ['breast cancer', 'metastatic tumor', 'primary tumor'],
#   'biomarker': ['anti-her2', 'pik3ca', 'her2', 'pten']},
#  {'cancer_type': ['breast cancer', 'metastatic tumor', 'primary tumor'],
#   'biomarker': ['anti-her2', 'pik3ca', 'her2', 'pten']},
#  {'cancer_type': ['thyroid tumor xenograft'],
#   'biomarker': ['pik3ca', 'akt', 'pi3k', 'mtor']},
#  {'cancer_type': [], 'biomarker': ['pik3ca', 'akt', 'pi3k', 'mtor']},
#  {'cancer_type': ['xenograft'], 'biomarker': ['pten', 'akt', 'pi3k', 'mtor']},
#  {'cancer_type': ['tumor'], 'biomarker': ['fbxw7', 'mtor']},
#  {'cancer_type': [], 'biomarker': ['ccne1', 'cdk2', 'cdk4 / 6']},
#  {'cancer_type': ['xenografts', 'tumors'],
#   'biomarker': ['prb', 'e2f', 'rb1', 'cyclin e2', 'cdk4 / 6']},
#  {'cancer_type': ['cancer', 'advanced'], 'biomarker': ['fbxw7', 'mtor']},
#  {'cancer_type': ['breast cancer tumors', 'tumor', 'cancers'],
#   'biomarker': ['pten', 'fbxw7', 'mtor']},
#  {'cancer_type': ['colonic adenocarcinoma'],
#   'biomarker': ['raas', 'fos', 'cea', 'c-jun']},
#  {'cancer_type': ['colonic adenocarcinoma'],
#   'biomarker': ['raas', 'fos', 'cea', 'c-jun']},
#  {'cancer_type': ['waldenström'],
#   'biomarker': ['myd88', 'nf-kappa-b p65', 'irak 1 / 4']},
#  {'cancer_type': ['hepatocellular carcinoma'],
#   'biomarker': ['kras', 'braf', 'nras', 'ras']},
#  {'cancer_type': ['colorectal cancer'], 'biomarker': ['smad4']},
#  {'cancer_type': ['astrocytomas', 'tumor', 'tumors'], 'biomarker': ['atrx']},
#  {'cancer_type': ['tumor samples', 'high-grade ovarian serous carcinoma'],
#   'biomarker': ['aurka']},
#  {'cancer_type': ['lung adenocarcinoma'], 'biomarker': ['met']},
#  {'cancer_type': ['nsclc'], 'biomarker': ['met']},
#  {'cancer_type': ['tumor', 'esophageal squamous cell carcinoma'],
#   'biomarker': ['aurka']},
#  {'cancer_type': [], 'biomarker': ['gas6']},
#  {'cancer_type': ['xenograft tumors', 'tumor', 'tumors'],
#   'biomarker': ['stag2']},
#  {'cancer_type': ['xenograft tumors', 'tumor', 'tumors'],
#   'biomarker': ['stag3']},
#  {'cancer_type': ['low-grade serous ovarian cancer', 'tumor'],
#   'biomarker': ['mek1',
#    'map2k1',
#    'mek',
#    'erk',
#    'ribosomal protein s6 kinase']},
#  {'cancer_type': ['low-grade serous ovarian cancer'],
#   'biomarker': ['braf', 'cul1', 'mek']},
#  {'cancer_type': ['papillary thyroid cancers',
#    'tumor types',
#    'subcutaneous tumor nodules',
#    'tumors',
#    'pancreatic acinar',
#    'spitzoid melanoma',
#    'pilocytic astrocytomas',
#    'tumor'],
#   'biomarker': ['zkscan1', 'braf', 'mek']},
#  {'cancer_type': ['malignant spindle cell tumor',
#    'soft tissue sarcoma',
#    'cancer'],
#   'biomarker': ['cdkn2a', 'braf', 'sufu', 'pten', 'map3k1', 'kiaa1549']},
#  {'cancer_type': ['nsclc', 'adenocarcinoma', 'tumors'],
#   'biomarker': ['egfr', 'l858r']},
#  ...]

# %%
no_cancer_idx = []
no_biomarker_idx = []
for i, e in tqdm(enumerate(context_extracted_entities)):
    if not e['cancer_type']:
        no_cancer_idx.append(i)
    if not e['biomarker']:
        no_biomarker_idx.append(i)

print(f"{len(no_cancer_idx)*100/len(_CONTEXT):.3f}%") #no cancer entity extracted %
print(f"{len(no_biomarker_idx)*100/len(_CONTEXT):.3f}%") #no biomarker entity extracted %
# Out:
# 2714it [00:00, 1246806.25it/s]
# 32.867%
# 2.063%

# %%
#save
os.makedirs("context_retriever/entities", exist_ok=True)
with open(f"context_retriever/entities/civic_db_context_ner_entities__{_VERSION}.json", "w") as f:
    json.dump(context_extracted_entities, f, indent=4)
