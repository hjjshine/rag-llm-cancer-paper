# %%
import pandas as pd 
import numpy as np
import os, sys
from tqdm import tqdm
import warnings
warnings.filterwarnings('ignore')

# %%
while os.getcwd().split('/')[-1] != 'rag-llm-cancer-paper':
    os.chdir('..')

# %% [markdown]
# ### setup biobert

# %%
biobert_dir = "context_retriever/biobert_ner"
#download model from huggingface
from transformers import AutoTokenizer, AutoModelForTokenClassification
model = AutoModelForTokenClassification.from_pretrained("judithrosell/BioBERT_BioNLP13CG_NER_new")
tokenizer = AutoTokenizer.from_pretrained("judithrosell/BioBERT_BioNLP13CG_NER_new")
id2label = model.config.id2label

#save locally
model.save_pretrained(biobert_dir)
tokenizer.save_pretrained(biobert_dir)
# Out:
# ('context_retriever/biobert_ner/tokenizer_config.json',
#  'context_retriever/biobert_ner/special_tokens_map.json',
#  'context_retriever/biobert_ner/vocab.txt',
#  'context_retriever/biobert_ner/added_tokens.json',
#  'context_retriever/biobert_ner/tokenizer.json')

# %%
#load locally
model = AutoModelForTokenClassification.from_pretrained(biobert_dir)
tokenizer = AutoTokenizer.from_pretrained(biobert_dir)
id2label = model.config.id2label

# %% [markdown]
# ### load other libraries

# %%
# !pip install rank_bm25
import json
import pandas as pd
import random
import math
from transformers import AutoTokenizer, AutoModelForTokenClassification
from utils.entity_prediction import extract_entities, db_extract_entities
#version check is for mol almanac
# from utils.check_db_version import get_local_version
# _VERSION=get_local_version()
# print(_VERSION)

def split_ranges(max_int, num_ranges, samples=None, seed=42):
    random.seed(seed)
    step = math.ceil(max_int / num_ranges)
    ranges = [(i*step+1, min((i+1)*step, max_int)) for i in range(num_ranges)]
    
    if samples is None:
        return ranges
    
    # split samples evenly across ranges
    n_per_range = samples // num_ranges
    remainder = samples % num_ranges
    
    result = []
    for i, r in enumerate(ranges):
        count = n_per_range + (1 if i < remainder else 0)
        result.extend(random.randint(r[0], r[1]) for _ in range(count))
    
    return result

# %% [markdown]
# ### context snippets

# %%
structured_db = pd.read_csv('external-validation/non-moa-database/civic/civic-db/civic_core__2025-09.csv')
db = structured_db[['statement_id']]
statements = pd.read_csv('external-validation/non-moa-database/civic/civic-db/civic-draft.dereferenced.unique.context_db.csv')
statement_dict = dict(zip(statements['statement_id'], statements['context']))
db['evidence_statement'] = db['statement_id'].map(statement_dict)
print(db.shape)
db.head(1)
# Out:
# (1569, 2)
#    statement_id                                 evidence_statement
# 0            17  Approval level: C\nDatabase: CIVIC\nDescriptio...

# %%
# db = pd.read_csv('external-validation/non-moa-database/civic/civic-db/evidence_statements.csv')
# print(db.shape)
# db.head(1)

# %%
_VERSION = 'civic-202509'
_CONTEXT = db.evidence_statement.tolist()
test_ind = split_ranges(len(_CONTEXT), 10, 20)
for i, e in enumerate(_CONTEXT):
    if i in test_ind:
        print(f"======={i}=======")
        print(e)
        print(extract_entities(e, model, tokenizer))
# Out:
# =======7=======
# Approval level: D
# Database: CIVIC
# Description: CH5424802 (Alectinib) is effective in inhibiting the activity of the F1174L ALK mutant in a kinase activity assay and proliferation assay using neuroblastoma KELLY cells.
# Cancer type: Neuroblastoma
# Biomarkers: ALK F1174LTherapy: AlectinibApproval url: https://civicdb.org/links/evidence_items/37
# Updated date: 2023-01-09 21:46:24 UTC
# {'cancer_type': ['cancer', 'neuroblastoma'], 'biomarker': ['alk']}
# =======29=======
# Approval level: D
# Database: CIVIC
# Description: CH5424802 treatment resulted in significant tumor regression in xenograft models produced from Ba/F3 cells expressing EML4-ALK or EML4-ALK with the L1196M mutation.
# Cancer type: Lung Non-small Cell Carcinoma
# Biomarkers: EML4::ALK Fusion, ALK L1196MTherapy: AlectinibApproval url: https://civicdb.org/links/evidence_items/141
# Updated date: 2023-02-21 22:30:01 UTC
# {'cancer_type': ['cancer', 'lung non-small cell carcinoma', 'xenograft', 'tumor'], 'biomarker': ['eml4-alk', 'eml4', 'alk']}
# =======220=======
# Approval level: C
# Database: CIVIC
# Description: 1/1 patients with BRCA1 homozygous deletion had a response to olaparib in this phase 2 study.
# Cancer type: Prostate Cancer
# Biomarkers: BRCA1 Loss-of-functionTherapy: OlaparibApproval url: https://civicdb.org/links/evidence_items/845
# Updated date: 2023-01-09 21:46:28 UTC
# {'cancer_type': ['cancer', 'prostate cancer'], 'biomarker': ['brca1']}
# =======228=======
# Approval level: B
# Database: CIVIC
# Description: Patients with nuclear survivin (BIRC5) expression had significantly better responses to taxane-platinum chemotherapy than those with low tumor N-survivin expression (P < 0.001) in a retrospective analysis of 48 patients with non-small cell lung cancer.
# Cancer type: Lung Non-small Cell Carcinoma
# Biomarkers: BIRC5 NUCLEAR EXPRESSIONTherapy: Platinum Compound, Taxane CompoundApproval url: https://civicdb.org/links/evidence_items/874
# Updated date: 2023-01-09 21:46:33 UTC
# {'cancer_type': ['cancer', 'non-small cell lung cancer', 'lung non-small cell carcinoma', 'tumor'], 'biomarker': ['birc5', 'survivin', 'n-survivin']}
# =======350=======
# Approval level: C
# Database: CIVIC
# Description: The pretreatment tumor contained a somatic nonsense mutation (Q1178*) in the tumor-suppressor gene TSC2 that inactivates the gene, allowing for activation of the mTOR pathway and resulting in sensitivity to mTOR inhibition by everolimus. The patient received a sustained response to everolimus for 18 months.
# Cancer type: Thyroid Gland Carcinoma
# Biomarkers: TSC2 Q1178*Therapy: EverolimusApproval url: https://civicdb.org/links/evidence_items/1108
# Updated date: 2023-01-09 21:46:34 UTC
# {'cancer_type': ['cancer', 'thyroid gland carcinoma', 'tumor'], 'biomarker': ['tsc2', 'mtor']}
# =======372=======
# Approval level: B
# Database: CIVIC
# Description: The Phase III trial, TH3RESA (NCT01419197), was performed in patients with advanced HER2 breast cancer that was heavily pretreated. Patients were required to have prior exposure to trastuzumab and lapatinib as well as a taxane. This patient population has not seen many studies, responds poorly to late-line treatment with trastuzumab, and in this study was treated with trastuzumab emtansine (T-DM1, n=404) vs. physician's choice (usually trastuzumab plus chemotherapy, n=198). Results showed progression free survival was 6.2 months in T-DM1 treatment vs. 3.3 months under physician's choice, along with lower incidence of grade 3 or worse events with T-DM1. The authors conclude that their findings in this heavily pretreated population, along with findings in the EMILIA trial, indicate promise for antibody-drug conjugates. The NCI-MATCH trial with further study T-DM1 in the context of HER2 amplification.
# Cancer type: Her2-receptor Positive Breast Cancer
# Biomarkers: ERBB2 AmplificationTherapy: Trastuzumab EmtansineApproval url: https://civicdb.org/links/evidence_items/1159
# Updated date: 2023-01-09 21:46:31 UTC
# {'cancer_type': ['her2 breast cancer', 'breast cancer', 'cancer type'], 'biomarker': ['erbb2', 'her2', 'her2-receptor']}
# =======498=======
# Approval level: B
# Database: CIVIC
# Description: In this phase 1 trial 60 patients with advanced solid tumors (ovarian, breast, colorectal, melanoma, sarcoma, prostate) were treated with PARP inhibitor olaparib. Durable antitumor activity was only observed in BRCA1/2 mutation carriers.19 BRCA carriers had ovarian, breast, or prostate cancers; 12 of these (63%) had a clinical benefit from treatment with olaparib: radiologic or tumor-marker responses or meaningful disease stabilization (stable disease for a period of 4 months or more). Nine BRCA carriers had a response according to RECIST, with the response sustained for more than 76 weeks in one patient. No responses were seen in patients without BRCA mutation.
# Cancer type: Cancer
# Biomarkers: BRCA2 MutationTherapy: OlaparibApproval url: https://civicdb.org/links/evidence_items/1371
# Updated date: 2023-05-05 21:15:38 UTC
# {'cancer_type': ['cancer', 'prostate', 'antitumor', 'prostate cancers', 'tumor', 'breast', 'colorectal', 'sarcoma', 'solid tumors', 'ovarian', 'melanoma'], 'biomarker': ['brca2', 'brca', 'brca1', 'parp']}
# =======611=======
# Approval level: B
# Database: CIVIC
# Description: Among 46 AML patients treated with decitabine, the response rate was 75% (6/8) among DNMT3A mutated and 34% (13/38) among DNMT3A wild-type patients (P=.008)
# Cancer type: Acute Myeloid Leukemia
# Biomarkers: DNMT3A MutationTherapy: DecitabineApproval url: https://civicdb.org/links/evidence_items/1587
# Updated date: 2023-01-09 21:46:29 UTC
# {'cancer_type': ['cancer', 'aml', 'acute myeloid leukemia'], 'biomarker': ['dnmt3a']}
# =======651=======
# Approval level: C
# Database: CIVIC
# Description: Analysis of BRAF fusions in 20,573 tumors, across 12 distinct tumor types. BRAF fusions were identified in 55 (0.3%) patients and enriched in spitzoid melanoma, pilocytic astrocytomas, pancreatic acinar and papillary thyroid cancers. Clinical data were available for two patients. Among them one 46-year old woman with spitzoid melanoma that harbored a ZKSCAN1-BRAF fusion responded to treatment with the MEK inhibitor trametinib. Subcutaneous tumor nodules exhibited clinical responses within 14 days of therapy, and her dominant bulky right lung metastases showed significant response by Day 45. Subsequent robotic-assisted lobectomy was able to remove the previously unresectable tumor with clean surgical margins.
# Cancer type: Melanoma
# Biomarkers: ZKSCAN1::BRAF FusionTherapy: TrametinibApproval url: https://civicdb.org/links/evidence_items/1663
# Updated date: 2023-01-09 21:46:37 UTC
# {'cancer_type': ['cancer', 'pancreatic acinar', 'tumors', 'tumor types', 'spitzoid melanoma', 'papillary thyroid cancers', 'tumor', 'subcutaneous tumor nodules', 'pilocytic astrocytomas', 'melanoma'], 'biomarker': ['zkscan1', 'mek', 'braf']}
# =======780=======
# Approval level: D
# Database: CIVIC
# Description: This preclinical study tested the efficacy on several breast cancer cell lines of GDC-0941 (pictilisib), a selective inhibitor of all four isoforms of class I PI3-kinases at a range of IC50 values. Sensitivity and resistance was categorized as less than and more than an IC50 of 1 umol/L, respectively, with a maximum tested concentration of 20 umol/L. EFM-19 is a luminal type breast cancer cell line harboring PIK3CA H1047L, and it had an IC50 of 0.09uM, suggesting sensitivity. Authors note that luminal-like cell lines were generally more sensitive, regardless of mutation, to pictilisib than basal-like (p=.02)
# Cancer type: Breast Cancer
# Biomarkers: PIK3CA H1047LTherapy: PictilisibApproval url: https://civicdb.org/links/evidence_items/2089
# Updated date: 2023-01-09 21:46:43 UTC
# {'cancer_type': ['cancer', 'breast cancer'], 'biomarker': ['pik3ca', 'pi3-kinases']}
# =======794=======
# Approval level: D
# Database: CIVIC
# Description: In 28 out of 40 (70%) metastatic colorectal cancer tumors harboring KRAS, NRAS, PIK3CA or BRAF mutations and implanted into mice, the therapeutic combination of the MEK inhibitor AZD6244 and the PI3K/mTor inhibitor BEZ235 resulted in disease stabilization. Mean tumor growth was lower in the tumors treated with AZD6244+ BEZ235 (+77% vs. +267%, P=1E-6) compared to AZD6244 alone and (+77% vs. +222%, P=0.0014) BEZ235 alone. 32/40 mice harbored KRAS mutations including 5 G13D mutations where disease stabilization was achieved in 2/5 mice treated with AZD6244 or combination therapy and 0/5 mice treated with BEZ235 alone.
# Cancer type: Colorectal Cancer
# Biomarkers: KRAS G13DTherapy: Selumetinib, DactolisibApproval url: https://civicdb.org/links/evidence_items/2183
# Updated date: 2023-01-09 21:46:27 UTC
# {'cancer_type': ['cancer', 'tumors', 'metastatic', 'tumor', 'colorectal cancer', 'colorectal cancer tumors'], 'biomarker': ['braf', 'mtor', 'kras', 'pi3k', 'pik3ca', 'mek', 'nras']}
# =======894=======
# Approval level: C
# Database: CIVIC
# Description: A patient with an uncontrolled relapse of c-kit-positive mesenchymal tumor in descending part of the duodenum had received 400mg Imatinib daily for more than 10 years at the time of publication. He responded well to therapy (Karnofsky index 90%). KIT V559D (Exon 11) was identified in the diagnostic biopsy and indicated as a positive predictor of imatinib response with long term usage.
# Cancer type: Gastrointestinal Stromal Tumor
# Biomarkers: KIT V559DTherapy: ImatinibApproval url: https://civicdb.org/links/evidence_items/3028
# Updated date: 2023-01-09 21:46:40 UTC
# {'cancer_type': ['cancer', 'mesenchymal tumor', 'gastrointestinal stromal tumor'], 'biomarker': ['c-kit', 'kit', 'kit v559dtherapy']}
# =======950=======
# Approval level: B
# Database: CIVIC
# Description: EGFR L861 mutations have been associated with increased sensitivity to first generation EGFR tyrosine kinase inhibitors, including erlotinib and gefitinib. In a study of patients treated with erlotinib or gefitinib, a subset of patients with EGFR mutation at codons G719 or L861 (n=30) was associated with improved response rate (47.5% vs 16.5%, P<0.001) median progression free survival (5.0 vs 2.0 months, P<0.001), and overall survival (15.0 vs. 10.4 months, P =0.030), compared to patients with wild-type EGFR (n=272).
# Cancer type: Lung Non-small Cell Carcinoma
# Biomarkers: EGFR L861Therapy: Erlotinib, GefitinibApproval url: https://civicdb.org/links/evidence_items/4298
# Updated date: 2023-01-09 21:46:51 UTC
# {'cancer_type': ['cancer', 'lung non-small cell carcinoma'], 'biomarker': ['egfr']}
# =======966=======
# Approval level: D
# Database: CIVIC
# Description: In an in vitro study, a Ba/F3 cell line stably expressing the G398R mutation in the ABL1 portion of the BCR-ABL1 fusion protein was associated with sensitivity to dasatinib treatment (IC50: 1.27nM vs. IC50: 1.83nM), comparable to Ba/F3 cells expressing BCR-ABL1 fusion protein. Sensitivity was determined by assessing cell proliferation.
# Cancer type: Chronic Myeloid Leukemia
# Biomarkers: BCR::ABL1 Fusion, ABL1 G398RTherapy: DasatinibApproval url: https://civicdb.org/links/evidence_items/4561
# Updated date: 2024-03-20 23:17:53 UTC
# {'cancer_type': ['cancer', 'chronic myeloid leukemia'], 'biomarker': ['bcr', 'abl1']}
# =======1155=======
# Approval level: C
# Database: CIVIC
# Description: Case report in a HR positive, Her2/neu negative breast cancer patient harboring an FGFR1 amplification. The patient responded to treatment to Pazopanib - including a near CR of brain metastases. Duration of Treatment or median PFS was not reported at the time of publication.
# Cancer type: Breast Cancer
# Biomarkers: FGFR1 AmplificationTherapy: PazopanibApproval url: https://civicdb.org/links/evidence_items/7246
# Updated date: 2023-01-09 21:46:31 UTC
# {'cancer_type': ['cancer', 'breast cancer'], 'biomarker': ['fgfr1', 'hr', 'her2 / neu']}
# =======1159=======
# Approval level: C
# Database: CIVIC
# Description: The SSBP2-JAK2 fusion was identified in a 14 yo male with Ph-like B-ALL, a t(5;9)(q12;p1?3), and a WBC of 160,000. Following 4-drug induction therapy the patient had an MRD of 5.5%, indicating a poor response. After two additional weeks of induction, intermittent ruxolitinib was added to his regimen and a bone marrow performed 3 weeks after the addition of ruxolitinib showed 1% MRD. Following consolidation, the bone marrow showed 0.3% MRD.
# Cancer type: B-lymphoblastic Leukemia/lymphoma, BCR-ABL1–like
# Biomarkers: SSBP2::JAK2 FusionTherapy: RuxolitinibApproval url: https://civicdb.org/links/evidence_items/7257
# Updated date: 2023-01-09 21:47:01 UTC
# {'cancer_type': ['cancer', 'lymphoma', 'ph', 'b-lymphoblastic leukemia', 'b-all'], 'biomarker': ['ssbp2', 'jak2', 'bcr-abl1']}
# =======1386=======
# Approval level: C
# Database: CIVIC
# Description: A metastatic lung adenocarcinoma (bone and brain) was diagnosed in a 42-year-old woman (patient 3). The primary adenocarcinoma was found in left lower lobe (LLL). Her initial treatment with whole-brain radiotherapy and platinum-based chemotherapy resulted in a partial response. During her chemotherapy, the tumor biopsy sample was sent for NGS testing and found to harbor an EGFR rearrangement at the exon 25, resulting in the formation of a fusion gene between EGFR and PURB genes. She was treated with erlotinib, resulting in a 48% decrease in the LLL index lesion, ongoing for 20 months.
# Cancer type: Lung Adenocarcinoma
# Biomarkers: EGFR::PURB FusionTherapy: ErlotinibApproval url: https://civicdb.org/links/evidence_items/10996
# Updated date: 2025-06-26 22:10:33 UTC
# {'cancer_type': ['cancer', 'adenocarcinoma', 'tumor', 'primary', 'lung adenocarcinoma'], 'biomarker': ['egfr', 'purb']}
# =======1411=======
# Approval level: A
# Database: CIVIC
# Description: Combined meta-analysis of Study 10 (NCT01482715, phase I/II) and ARIEL2 (NCT01891344, phase II), both multi-centre, open-label, single-arm trials evaluating rucaparib in ovarian cancer with BRCA1 or BRCA2 deleterious germline or somatic mutations. Mutation status was determined by local testing or by central Foundation Medicine sequencing. Of 106 patients, OR was 53.8% (95% CI, 43.8-63.5); 8.5% and 45.3% of patients achieved complete and partial responses, respectively. Median duration of response was 9.2 months (95% CI, 6.6-11.6). Response rates by gene/mutation: BRCA1/2 germline (n=88, OR 53.4); BRCA1/2 somatic (n=18, OR 55.6); BRCA1 (n=67, OR 53.7); BRCA2 (n=39, OR 53.8).
# Cancer type: Ovarian Cancer
# Biomarkers: BRCA1 MutationTherapy: RucaparibApproval url: https://civicdb.org/links/evidence_items/11138
# Updated date: 2023-09-28 17:16:22 UTC
# {'cancer_type': ['cancer', 'ovarian cancer'], 'biomarker': ['brca2', 'ariel2', 'brca1', None]}
# =======1420=======
# Approval level: A
# Database: CIVIC
# Description: This randomized, open-label, phase 3 trial evaluated the PARP inhibitor olaparib in 387 men with metastatic castration-resistant prostate cancer (mCRPC) who had disease progression while receiving a new hormonal agent (e.g., enzalutamide or abiraterone). The study found that in men with mCRPC who had somatic or germline deleterious alterations (irrespective of zygosity) in any of the following HRR genes (BRCA1, BRCA2, ATM, BRIP1, BARD1, CDK12, CHEK1, CHEK2, FANCL, PALB2, PPP2R2A, RAD51B, RAD51C, RAD51D, and RAD54L), olaparib was associated with longer progression-free survival and better measures of response and patient-reported end points than either enzalutamide or abiraterone (PFS HR 0.49 [0.38, 0.63]). A total of 4 patients had BRIP1 mutations, 2 in each arm. Based on the results of this study, on May 19, 2020, the Food and Drug Administration approved olaparib (LYNPARZA) for adult patients with deleterious or suspected deleterious germline or somatic HRR gene-mutated mCRPC, who have progressed following prior treatment with enzalutamide or abiraterone.
# Cancer type: Castration-resistant Prostate Carcinoma
# Biomarkers: BRIP1 MutationTherapy: OlaparibApproval url: https://civicdb.org/links/evidence_items/11208
# Updated date: 2024-04-27 08:41:58 UTC
# {'cancer_type': ['castration-resistant prostate cancer', 'mcrpc', 'cancer', 'castration-resistant prostate carcinoma'], 'biomarker': ['ppp2r2a', 'chek1', 'rad51c', 'brip1', 'atm', 'fancl', 'rad54l', 'chek2', 'bard1', 'rad51b', 'parp', 'rad51d', 'cdk12', 'brca2', 'palb2', 'brca1']}
# =======1557=======
# Approval level: A
# Database: CIVIC
# Description: On December 4, 2024, the Food and Drug Administration granted accelerated approval to zenocutuzumab-zbco (Bizengri, Merus N.V.) for adults with advanced, unresectable, or metastatic non-small cell lung cancer (NSCLC) harboring a neuregulin 1 (NRG1) gene fusion with disease progression on or after prior systemic therapy, or advanced, unresectable, or metastatic pancreatic adenocarcinoma harboring a NRG1 gene fusion with disease progression on or after prior systemic therapy. This represents the first FDA approval of a systemic therapy for patients with NSCLC or pancreatic adenocarcinoma harboring an NRG1 gene fusion. Efficacy was evaluated in the eNRGy study (NCT02912949), a multicenter, open-label, multicohort trial. The trial enrolled 93 adults with advanced or metastatic NRG1 fusion-positive NSCLC. Identification of positive NRG1 gene fusion status was prospectively determined by next generation sequencing assays. The major efficacy outcome measures were confirmed overall response rate (ORR) and duration of response (DOR), determined by blinded independent central review according to RECIST v1.1. For NSCLC, ORR was 29% (95% CI: 20%, 39%) and median DOR was 12.7 months (95% CI: 7.4 - 20.4).
# Cancer type: Lung Non-small Cell Carcinoma
# Biomarkers: v::NRG1 FusionTherapy: Zenocutuzumab-zbcoApproval url: https://civicdb.org/links/evidence_items/12246
# Updated date: 2025-02-10 18:42:31 UTC
# {'cancer_type': ['cancer', 'pancreatic adenocarcinoma', 'non-small cell lung cancer', 'lung non-small cell carcinoma', 'nsclc'], 'biomarker': ['neuregulin 1', 'nrg1']}

# %%
#run BioBert NER on all contexts
context_extracted_entities = []
for ctx in tqdm(_CONTEXT):
    context_extracted_entities.append(extract_entities(ctx, model, tokenizer))
context_extracted_entities
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# 100%|██████████| 1569/1569 [01:59<00:00, 13.17it/s]
# [{'cancer_type': ['cancer', 'lung non-small cell carcinoma'],
#   'biomarker': ['araf']},
#  {'cancer_type': ['cancer', 'aml', 'acute myeloid leukemia'],
#   'biomarker': ['dnmt3a']},
#  {'cancer_type': ['cancer', 'polycythemia'], 'biomarker': ['jak2']},
#  {'cancer_type': ['cancer', 'polycythemia'],
#   'biomarker': ['jak2617f', 'jak2', 'stat5']},
#  {'cancer_type': ['malignant melanoma', 'cancer', 'melanoma'],
#   'biomarker': ['hsp90', 'nras']},
#  {'cancer_type': ['cancer', 'melanoma'], 'biomarker': ['nras']},
#  {'cancer_type': ['cancer', 'melanoma'], 'biomarker': ['nras']},
#  {'cancer_type': ['cancer', 'neuroblastoma'], 'biomarker': ['alk']},
#  {'cancer_type': ['cancer', 'neuroblastoma'], 'biomarker': ['eml4', 'alk']},
#  {'cancer_type': ['cancer'], 'biomarker': ['alk']},
#  {'cancer_type': ['cancer', 'lung non-small cell carcinoma'],
#   'biomarker': ['mek', 'araf s214ctherapy', 'arf', 'araf s214c']},
#  {'cancer_type': ['cancer', 'lung non-small cell carcinoma'],
#   'biomarker': ['araf s214ctherapy', 'arf', 'erk', 'araf s214c']},
#  {'cancer_type': ['cancer', 'melanoma'], 'biomarker': ['kit']},
#  {'cancer_type': ['cancer', 'gastrointestinal stromal tumor'],
#   'biomarker': ['pdgfra']},
#  {'cancer_type': ['cancer', 'gastrointestinal stromal tumor'],
#   'biomarker': ['pdgfra']},
#  {'cancer_type': ['cancer', 'gastrointestinal stromal tumor'],
#   'biomarker': ['pdgfra']},
#  {'cancer_type': ['cancer', 'gastrointestinal stromal tumor'],
#   'biomarker': ['pdgfra']},
#  {'cancer_type': ['cancer', 'gastrointestinal stromal tumor'],
#   'biomarker': ['pdgfra']},
#  {'cancer_type': ['cancer', 'melanoma'], 'biomarker': ['kit']},
#  {'cancer_type': ['cancer', 'shoulder lesion', 'melanoma'],
#   'biomarker': ['braf v600mtherapy', 'v600m', 'braf']},
#  {'cancer_type': ['cancer', 'medullary thyroid carcinoma'],
#   'biomarker': ['jak2', 'ret']},
#  {'cancer_type': ['cancer', 'colorectal cancer'], 'biomarker': ['braf']},
#  {'cancer_type': ['cancer',
#    'cutaneous squamous-cell carcinoma',
#    'metastatic',
#    'melanoma'],
#   'biomarker': ['v600k', 'braf']},
#  {'cancer_type': ['cancer', 'melanoma'], 'biomarker': ['braf']},
#  {'cancer_type': ['cancer', 'melanoma'], 'biomarker': ['braf']},
#  {'cancer_type': ['cancer', 'colorectal cancer', 'tumor'],
#   'biomarker': ['pi3k', 'braf']},
#  {'cancer_type': ['cancer', 'tumor', 'melanoma'],
#   'biomarker': ['nutlin-3', 'braf']},
#  {'cancer_type': ['cancer', 'colorectal cancer', 'tumor'],
#   'biomarker': ['braf v600e', 'braf']},
#  {'cancer_type': ['cancer',
#    'xenograft',
#    'ht29 xenografts',
#    'colorectal cancer',
#    'tumor'],
#   'biomarker': ['met', 'braf', 'kras', 'erk', 'pik3ca']},
#  {'cancer_type': ['cancer',
#    'lung non-small cell carcinoma',
#    'xenograft',
#    'tumor'],
#   'biomarker': ['eml4-alk', 'eml4', 'alk']},
#  {'cancer_type': ['cancer', 'neuroblastoma'], 'biomarker': ['alk']},
#  {'cancer_type': ['cancer', 'neuroblastoma'], 'biomarker': ['alk']},
#  {'cancer_type': ['cancer', 'xenografts', 'bladder carcinoma', 'tumor'],
#   'biomarker': ['fgfr3', 'fgfr', 'baiap2l1']},
#  {'cancer_type': ['cancer', 'xenograft', 'colorectal cancer'],
#   'biomarker': ['kras']},
#  {'cancer_type': ['cancer', 'acute myeloid leukemia'],
#   'biomarker': ['flt3', 'npm1']},
#  {'cancer_type': ['cancer', 'acute myeloid leukemia'], 'biomarker': ['npm1']},
#  {'cancer_type': ['cancer', 'acute myeloid leukemia'], 'biomarker': ['npm1']},
#  {'cancer_type': ['cancer', 'acute myeloid leukemia'],
#   'biomarker': ['flt3', 'npm1']},
#  {'cancer_type': ['cancer', 'acute myeloid leukemia'],
#   'biomarker': ['anti-cd33',
#    'cd123',
#    'anti-cd33approval',
#    'flt3',
#    'anti-cd123',
#    'cd33',
#    'npm1']},
#  {'cancer_type': ['cancer', 'acute myeloid leukemia'],
#   'biomarker': ['anti-cd33', 'anti-cd33approval', 'flt3', 'cd33', 'npm1']},
#  {'cancer_type': ['cancer', 'acute myeloid leukemia'], 'biomarker': ['npm1']},
#  {'cancer_type': ['cancer', 'aml', 'acute myeloid leukemia'],
#   'biomarker': ['npm', 'npm1']},
#  {'cancer_type': ['cancer',
#    'lung non-small cell carcinoma',
#    'lung tumors',
#    'tumor'],
#   'biomarker': ['tsc1', 'krasg12d']},
#  {'cancer_type': ['cancer', 'tumors', 'bladder carcinoma'],
#   'biomarker': ['tsc2', 'tsc1']},
#  {'cancer_type': ['cancer',
#    'high grade serous',
#    'undifferentiated ovarian cancer',
#    'ovarian cancer'],
#   'biomarker': ['brca', 'brca1', 'parp']},
#  {'cancer_type': ['cancer',
#    'high grade serous',
#    'undifferentiated ovarian cancer',
#    'ovarian cancer'],
#   'biomarker': ['brca2', 'brca', 'parp']},
#  {'cancer_type': ['lung cancer', 'lung non-small cell carcinoma', 'cancer'],
#   'biomarker': ['egfr']},
#  {'cancer_type': ['cancer', 'philadelphia', 'cml', 'acute myeloid leukemia'],
#   'biomarker': ['abl1', 'bcr']},
#  {'cancer_type': ['cancer', 'chronic myeloid leukemia', 'cml'],
#   'biomarker': ['abl1', 'abl', 'bcr']},
#  {'cancer_type': ['cancer', 'chronic myeloid leukemia'],
#   'biomarker': ['bcr', 'abl1', 'bcr-abl']},
#  {'cancer_type': ['cancer',
#    'non-small cell lung cancer',
#    'lung adenocarcinoma'],
#   'biomarker': ['a20', 'eml4', 'alk']},
#  {'cancer_type': ['cancer',
#    'lymphoma',
#    't-cell lymphoblastic leukemia',
#    't-cell leukemia'],
#   'biomarker': ['ccnd3', 'notch']},
#  {'cancer_type': ['breast cancers',
#    'cancer',
#    'breast cancer',
#    'xenograft',
#    'tumor'],
#   'biomarker': ['cdk4 / 6', 'cdk4', 'pi3k', 'pik3ca', 'estrogen-receptor']},
#  {'cancer_type': ['cancer'], 'biomarker': ['ddr2']},
#  {'cancer_type': ['cancer', 'lung non-small cell carcinoma'],
#   'biomarker': ['ddr2']},
#  {'cancer_type': ['cancer', 'lung non-small cell carcinoma'],
#   'biomarker': ['ddr2']},
#  {'cancer_type': ['cancer', 'lung non-small cell carcinoma'],
#   'biomarker': ['ddr2']},
#  {'cancer_type': ['cancer', 'lung non-small cell carcinoma'],
#   'biomarker': ['ddr2']},
#  {'cancer_type': ['cancer', 'lung non-small cell carcinoma'],
#   'biomarker': ['ddr2']},
#  {'cancer_type': ['cancer', 'lung non-small cell carcinoma'],
#   'biomarker': ['ddr2']},
#  {'cancer_type': ['cancer', 'lung non-small cell carcinoma'],
#   'biomarker': ['egfr']},
#  {'cancer_type': ['cancer', 'lung non-small cell carcinoma'],
#   'biomarker': ['egfr']},
#  {'cancer_type': ['nsclc', 'lung non-small cell carcinoma', 'cancer'],
#   'biomarker': ['l858r', 'egfr']},
#  {'cancer_type': ['cancer', 'lung non-small cell carcinoma'],
#   'biomarker': ['l858r', 'egfr']},
#  {'cancer_type': ['nsclc', 'lung non-small cell carcinoma', 'cancer', 'tumor'],
#   'biomarker': ['l858r', 'egfr']},
#  {'cancer_type': ['nsclc', 'lung non-small cell carcinoma', 'cancer'],
#   'biomarker': ['egfr']},
#  {'cancer_type': ['cancer', 'breast cancer'], 'biomarker': ['erbb2']},
#  {'cancer_type': ['cancer', 'breast cancer'],
#   'biomarker': ['erbb2', 'neratinibapproval']},
#  {'cancer_type': ['cancer', 'breast cancer'],
#   'biomarker': ['erbb2', 'neratinibapproval']},
#  {'cancer_type': ['cancer', 'breast cancer'],
#   'biomarker': ['erbb2', 'neratinibapproval']},
#  {'cancer_type': ['cancer', 'breast cancer'],
#   'biomarker': ['erbb2', 'neratinibapproval']},
#  {'cancer_type': ['cancer', 'breast cancer'],
#   'biomarker': ['erbb2', 'neratinibapproval']},
#  {'cancer_type': ['cancer', 'breast cancer'],
#   'biomarker': ['erbb2', 'neratinibapproval']},
#  {'cancer_type': ['cancer', 'breast cancer'], 'biomarker': ['erbb2']},
#  {'cancer_type': ['cancer', 'breast cancer'],
#   'biomarker': ['erbb2', 'neratinibapproval']},
#  {'cancer_type': ['cancer', 'breast cancer'], 'biomarker': ['erbb2']},
#  {'cancer_type': ['cancer', 'breast cancer'], 'biomarker': ['erbb2']},
#  {'cancer_type': ['cancer', 'breast cancer'],
#   'biomarker': ['esr1', 'estrogen']},
#  {'cancer_type': ['cancer', 'breast cancer'],
#   'biomarker': ['esr1', 'estrogen']},
#  {'cancer_type': ['cancer', 'breast cancer'],
#   'biomarker': ['esr1', 'estrogen']},
#  {'cancer_type': ['cancer', 'breast cancer'],
#   'biomarker': ['esr1', 'estrogen']},
#  {'cancer_type': ['cancer', 'breast cancer'],
#   'biomarker': ['esr1', 'estrogen']},
#  {'cancer_type': ['cancer',
#    'intrahepatic cholangiocarcinoma',
#    'cholangiocarcinoma'],
#   'biomarker': ['fgfr2', 'oga']},
#  {'cancer_type': ['cancer',
#    'intrahepatic cholangiocarcinoma',
#    'tumor',
#    'cancer types',
#    'cholangiocarcinoma'],
#   'biomarker': ['fgfr2', 'tacc3']},
#  {'cancer_type': ['cancer', 'aml', 'acute myeloid leukemia'],
#   'biomarker': ['cep701', 'flt3']},
#  {'cancer_type': ['cancer', 'acute myeloid leukemia'], 'biomarker': ['flt3']},
#  {'cancer_type': ['cancer', 'acute myeloid leukemia'], 'biomarker': ['flt3']},
#  {'cancer_type': ['cancer', 'tumor', 'lung adenocarcinoma'],
#   'biomarker': ['gata2']},
#  {'cancer_type': ['cancer', 'anal melanoma', 'malignant anus melanoma'],
#   'biomarker': ['kit']},
#  {'cancer_type': ['cancer', 'lung non-small cell carcinoma'],
#   'biomarker': ['kit']},
#  {'cancer_type': ['cancer', 'gastrointestinal stromal tumor'],
#   'biomarker': ['kit']},
#  {'cancer_type': ['lung cancer',
#    'lung non-small cell carcinoma',
#    'cancer',
#    'tumor'],
#   'biomarker': ['kras']},
#  {'cancer_type': ['cancer', 'colorectal cancer', 'colorectal patients'],
#   'biomarker': ['kras']},
#  {'cancer_type': ['cancer', 'glioblastoma'], 'biomarker': ['mgmt']},
#  {'cancer_type': ['cancer', 'glioblastoma'], 'biomarker': ['mgmt']},
#  {'cancer_type': ['cancer', 'glioblastoma'], 'biomarker': ['mgmt']},
#  {'cancer_type': ['cancer', 'breast cancer'], 'biomarker': ['pik3ca']},
#  {'cancer_type': ['cancer', 'breast cancer'], 'biomarker': ['pik3ca']},
#  {'cancer_type': ['cancer', 'breast cancer'], 'biomarker': ['pik3ca']},
#  {'cancer_type': ['cancer', 'acute promyelocytic leukemia'],
#   'biomarker': ['pml', 'rara']},
#  {'cancer_type': ['cancer', 'breast cancer'],
#   'biomarker': ['pi3k', 'pten', 'mtor']},
#  {'cancer_type': ['cancer', 'breast cancer', 'breast tumors'],
#   'biomarker': ['tp53']},
#  {'cancer_type': ['cancer',
#    'invasive bladder transitional cell carcinoma',
#    'bladder cancer',
#    'metastatic'],
#   'biomarker': ['nf2', 'tsc1', 'mtor']},
#  {'cancer_type': ['cancer', 'chronic myeloid leukemia', 'cml'],
#   'biomarker': ['bcr', 'abl1', 'bcr-abl']},
#  {'cancer_type': ['cancer', 'breast cancer', 'breast tumors'],
#   'biomarker': ['tp53']},
#  {'cancer_type': ['cancer', 'acute lymphoblastic leukemia'],
#   'biomarker': ['csf1r', 'mef2d']},
#  {'cancer_type': ['nsclc', 'lung non-small cell carcinoma', 'cancer'],
#   'biomarker': ['l858r', 'egfr']},
#  {'cancer_type': ['cancer', 'xenografts', 'prostate cancer'],
#   'biomarker': ['igf2', 'insr', 'igf1r']},
#  {'cancer_type': ['cancer', 'colon carcinoma'], 'biomarker': ['wnt', 'apc']},
#  {'cancer_type': ['cancer',
#    'colorectal cancers xenograft',
#    'colorectal cancer',
#    'tumor'],
#   'biomarker': ['g007-lk', 'g007-lkapproval', 'apc']},
#  {'cancer_type': ['cancer', 'glioblastoma'], 'biomarker': ['atm']},
#  {'cancer_type': ['cancer', 'melanoma'], 'biomarker': ['atm']},
#  {'cancer_type': ['cancer'], 'biomarker': ['dna pkcs', 'atm']},
#  {'cancer_type': ['cancer',
#    'hematologic cancer',
#    'xenograft',
#    'blood cancers',
#    'chronic lymphocytic leukemia',
#    'lymphoblastoid leukemia',
#    'mantle cell lymphoma'],
#   'biomarker': ['atm']},
#  {'cancer_type': ['cancer',
#    'esophageal adenocarcinomas',
#    'esophagus adenocarcinoma',
#    'antitumour'],
#   'biomarker': ['aurka']},
#  {'cancer_type': ['cancer', 'thymic carcinoma', 'tumor'],
#   'biomarker': ['kit']},
#  {'cancer_type': ['cancer',
#    'tumors',
#    'prostate cancer',
#    'prostate cancer xenographs'],
#   'biomarker': ['pten']},
#  {'cancer_type': ['cancer', 'breast cancer'],
#   'biomarker': ['erbb2', 'her2', 'her2-receptor']},
#  {'cancer_type': ['cancer', 'breast cancer'],
#   'biomarker': ['erbb2', 'her2', 'her2-receptor']},
#  {'cancer_type': ['cancer',
#    'hgs-ovca',
#    'ovarian serous carcinoma',
#    'high-grade serous ovarian cancer'],
#   'biomarker': ['parp1 / 2', 'brca1', 'cdk12']},
#  {'cancer_type': ['cancer', 'chronic myeloid leukemia'],
#   'biomarker': ['bcr', 'abl1', 'bcr-abl']},
#  {'cancer_type': ['cancer', 'chronic myeloid leukemia'],
#   'biomarker': ['bcr', 'abl1', 'bcr-abl']},
#  {'cancer_type': ['nsclc', 'lung non-small cell carcinoma', 'cancer'],
#   'biomarker': ['egfr']},
#  {'cancer_type': ['cancer', 'prostate cancers', 'prostate cancer'],
#   'biomarker': ['mre11', 'mlh3', 'atm', 'parp', 'pi3k', 'nbn', 'p53']},
#  {'cancer_type': ['cancer', 'prostate cancers', 'prostate cancer'],
#   'biomarker': ['atm', 'parp']},
#  {'cancer_type': ['cancer', 'prostate cancer'], 'biomarker': ['brca2']},
#  {'cancer_type': ['cancer', 'gastrointestinal stromal tumor'],
#   'biomarker': ['pdgfra']},
#  {'cancer_type': ['gists',
#    'tumors',
#    'tumor',
#    'metastatic',
#    'gastrointestinal stromal tumors',
#    'gastrointestinal stromal tumor',
#    'cancer type'],
#   'biomarker': ['kit', 'pdgfra']},
#  {'cancer_type': ['cancer',
#    'stage iv nsclc',
#    'lung non-small cell carcinoma',
#    'stage iv non-small cell lung carcinoma'],
#   'biomarker': ['xrcc1']},
#  {'cancer_type': ['cancer', 'ovarian carcinoma'], 'biomarker': ['gstp1']},
#  {'cancer_type': ['cancer', 'gastric cancer', 'stomach cancer'],
#   'biomarker': ['mthfr']},
#  {'cancer_type': ['cancer',
#    'colorectal cancer',
#    'metastatic',
#    'colorectal carcinoma'],
#   'biomarker': ['gstp1']},
#  {'cancer_type': ['cancer',
#    'tumor samples',
#    'stage ib',
#    'cervical cancer',
#    'cervical carcinomas'],
#   'biomarker': ['xrcc1']},
#  {'cancer_type': ['cancer',
#    'fallopian tube frozen tumors',
#    'ovarian cancer',
#    'epithelial'],
#   'biomarker': ['abcb1']},
#  {'cancer_type': ['cancer',
#    'nsclc',
#    'advanced',
#    'non small cell lung cancer',
#    'lung non-small cell carcinoma'],
#   'biomarker': ['abcb1']},
#  {'cancer_type': ['non small cell lung cancer',
#    'lung non-small cell carcinoma',
#    'nsclc',
#    'cancer'],
#   'biomarker': ['ercc2']},
#  {'cancer_type': ['lung squamous cell carcinoma', 'xenograft', 'cancer type'],
#   'biomarker': ['fgfr1']},
#  {'cancer_type': ['cancer', 'lung cancer'],
#   'biomarker': ['fgfr1', 'fgf2', 'fgf9', 'kras', 'pik3ca']},
#  {'cancer_type': ['nsclc', 'lung non-small cell carcinoma', 'cancer'],
#   'biomarker': ['fgfr1', 'fgfr-1']},
#  {'cancer_type': ['cancer', 'lung non-small cell carcinoma'],
#   'biomarker': ['ros1']},
#  {'cancer_type': ['cancer', 'gastric adenocarcinoma', 'metastases'],
#   'biomarker': ['hgf', 'met']},
#  {'cancer_type': ['cancer', 'lung non-small cell carcinoma'],
#   'biomarker': ['epidermal growth factor receptor tyrosine kinase inhibitorapproval',
#    'egfr']},
#  {'cancer_type': ['cancer', 'lung', 'adenocarcinoma', 'lung adenocarcinoma'],
#   'biomarker': ['alk',
#    'ret',
#    'met',
#    'her2',
#    'braf',
#    'kras',
#    'ros1',
#    'kif5b',
#    'egfr']},
#  {'cancer_type': ['cancer'],
#   'biomarker': ['hras', 'mek', 'mtor kinase', 'mtor']},
#  {'cancer_type': ['cancer', 'melanoma'],
#   'biomarker': ['pd-1 receptor', 'pd-l1', 'cd274']},
#  {'cancer_type': ['cancer', 'urothelial carcinoma', 'bladder carcinoma'],
#   'biomarker': ['mtor']},
#  {'cancer_type': ['cancer', 'breast cancer', 'tumors'],
#   'biomarker': ['thr308', 'ser473', 'her2', 'pakt', 'akt2']},
#  {'cancer_type': ['cancer', 'melanoma'], 'biomarker': ['akt', 'akt1']},
#  {'cancer_type': ['cancer', 'melanoma'], 'biomarker': ['pten', 'akt', 'braf']},
#  {'cancer_type': ['ovarian carcinoma', 'breast', 'breast cancer', 'cancer'],
#   'biomarker': ['akt1', 'akt']},
#  {'cancer_type': ['cancer', 'breast cancer'],
#   'biomarker': ['pi3k', 'pik3ca', 'akt']},
#  {'cancer_type': ['cancer', 'breast cancer'],
#   'biomarker': ['pten', 'pi3kbeta']},
#  {'cancer_type': ['cancer', 'melanoma'], 'biomarker': ['pi3k', 'bet', 'mtor']},
#  {'cancer_type': ['cancer', 'solid cancers'], 'biomarker': ['pten']},
#  {'cancer_type': ['cancer', 'breast cancer'], 'biomarker': ['nf2']},
#  {'cancer_type': ['cancer', 'melanoma'], 'biomarker': ['pi3k', 'bet', 'mtor']},
#  {'cancer_type': ['cancer', 'melanoma'], 'biomarker': ['agk', 'braf']},
#  {'cancer_type': ['cancer', 'melanomas', 'melanoma'],
#   'biomarker': ['papss1', 'mapk', 'braf']},
#  {'cancer_type': ['cancer', 'metastatic', 'melanoma'],
#   'biomarker': ['mek', 'trim24', 'braf']},
#  {'cancer_type': ['cancer', 'melanoma'], 'biomarker': ['braf']},
#  {'cancer_type': ['crc', 'cancer', 'colorectal cancer'],
#   'biomarker': ['nt5e', 'cd73']},
#  {'cancer_type': ['cancer', 'acute myeloid leukemia'], 'biomarker': ['idh1']},
#  {'cancer_type': ['cancer', 'lung non-small cell carcinoma'],
#   'biomarker': ['met', 'cep7', 'alk']},
#  {'cancer_type': ['cancer', 'lung cancers'], 'biomarker': ['cas9', 'met']},
#  {'cancer_type': ['cancer', 'lung non-small cell carcinoma'],
#   'biomarker': ['met',
#    'egfr',
#    'epidermal growth factor receptor tyrosine kinase']},
#  {'cancer_type': ['cancer', 'merkel cell carcinoma'],
#   'biomarker': ['pi3k', 'pik3ca']},
#  {'cancer_type': ['cancer', 'xenografts', 'breast cancer', 'tumor'],
#   'biomarker': ['egfr', 'ret']},
#  {'cancer_type': ['nci-h2110',
#    'lung adenocarcinoma',
#    'tumor',
#    'cancer type',
#    'lung adenocarcinomas',
#    'tcga'],
#   'biomarker': ['pi3k', 'rit1', 'mek']},
#  {'cancer_type': ['nsclc', 'lung non-small cell carcinoma', 'cancer'],
#   'biomarker': ['pd-1 receptor', 'pd-l1', 'cd274']},
#  {'cancer_type': ['cancer', 'neuroblastoma'],
#   'biomarker': ['mycn', 'fact', 'ssrp1']},
#  {'cancer_type': ['basal cell carcinomas', 'basal cell carcinoma', 'cancer'],
#   'biomarker': ['psi', 'smo', None, 'gli', 'apkc-ι', 'hedgehog']},
#  {'cancer_type': ['cancer',
#    'medulloblastomas',
#    'xenografts',
#    'medulloblastoma'],
#   'biomarker': ['shh', 'ptch1']},
#  {'cancer_type': ['cancer', 'medulloblastoma'],
#   'biomarker': ['shh', 'ptch1', 'aka hhantag691']},
#  {'cancer_type': ['cancer', 'prostate cancer'],
#   'biomarker': ['mapk11', 'stk11']},
#  {'cancer_type': ['cancer', 'head and neck squamous cell carcinoma'],
#   'biomarker': ['p16', 'cdkn2a']},
#  {'cancer_type': ['cancer', 'solid tumors', 'epithelial ovarian cancer'],
#   'biomarker': ['pi3k', 'pten', 'pik3ca']},
#  {'cancer_type': ['cancer', 'melanoma'], 'biomarker': ['pi3k', 'braf']},
#  {'cancer_type': ['cancer', 'xenografts', 'breast cancer'],
#   'biomarker': ['erbb2',
#    'akt1 / 2',
#    'akti-1',
#    'pik3ca',
#    'akti-1 / 2approval']},
#  {'cancer_type': ['cancer', 'breast cancer'],
#   'biomarker': ['erbb2', 'her2-receptor', 'neratinibapproval']},
#  {'cancer_type': ['cancer',
#    'xenografts',
#    'lung non-small cell carcinoma',
#    'tumor'],
#   'biomarker': ['egfr']},
#  {'cancer_type': ['cancer', 'melanoma'], 'biomarker': ['erbb4']},
#  {'cancer_type': ['cancer',
#    'xenografts',
#    'colorectal cancer xenografts',
#    'tumors',
#    'tumor',
#    'colorectal cancer'],
#   'biomarker': ['vegfr2',
#    'ret',
#    'met',
#    'axl',
#    'kras',
#    'c-met',
#    'tp53',
#    'pik3ca']},
#  {'cancer_type': ['cancer', 'glioblastoma', 'glioblastomas'],
#   'biomarker': ['epidermal growth factor receptor tyrosine kinase inhibitorapproval',
#    'pten',
#    'egfr',
#    'egfrviii']},
#  {'cancer_type': ['cancer', 'glioblastoma'],
#   'biomarker': ['egfr egfrviiitherapy', 'egfr', 'egfrviii']},
#  {'cancer_type': ['cancer', 'glioblastoma', 'glioblastomas'],
#   'biomarker': ['epidermal growth factor receptor tyrosine kinase inhibitorapproval',
#    'pten',
#    'egfr',
#    'egfrviii']},
#  {'cancer_type': ['cancer', 'glioblastoma'],
#   'biomarker': ['pten', 'egfr', 'egfrviii']},
#  {'cancer_type': ['cancer', 'head and neck squamous cell carcinoma'],
#   'biomarker': ['nrg1', 'her2', 'her3']},
#  {'cancer_type': ['cancer', 'ovarian cancer', 'tumor', 'ovarian cancers'],
#   'biomarker': ['nrg1', 'erbb3']},
#  {'cancer_type': ['cancer',
#    'xenografts',
#    'tumor',
#    'nsclc tumors',
#    'lung non-small cell carcinoma'],
#   'biomarker': ['nrg1', 'egfr']},
#  {'cancer_type': ['cancer', 'colon carcinoma', 'colorectal cancer'],
#   'biomarker': ['egfr']},
#  {'cancer_type': ['cancer', 'colon carcinoma', 'colorectal cancer'],
#   'biomarker': ['egfr']},
#  {'cancer_type': ['crc', 'cancer', 'tumours', 'colorectal cancer'],
#   'biomarker': ['tgfa', 'ereg', 'egf', 'kras', 'egfr', 'areg']},
#  {'cancer_type': ['crc', 'cancer', 'tumours', 'colorectal cancer'],
#   'biomarker': ['ereg', 'kras', 'ephrin a2 receptor', 'egfr', 'areg']},
#  {'cancer_type': ['hnscc',
#    'head and neck squamous cell carcinoma',
#    'cancer',
#    'tumor'],
#   'biomarker': ['egfr', 'mapk1']},
#  {'cancer_type': ['cancer',
#    'lung non-small cell carcinoma',
#    'tumor',
#    'lung adenocarcinoma'],
#   'biomarker': ['cdk4', 'kras', 'atm', 'stk11']},
#  {'cancer_type': ['cancer', 'lesions', 'lung non-small cell carcinoma'],
#   'biomarker': ['cdk4', 'kras']},
#  {'cancer_type': ['cancer', 'papillary renal cell carcinoma'],
#   'biomarker': ['met']},
#  {'cancer_type': ['cancer',
#    'lung adenocarcinoma',
#    'stage iv lung adenocarcinomas'],
#   'biomarker': ['met']},
#  {'cancer_type': ['cancer',
#    'xenografts',
#    'head and neck squamous cell carcinoma'],
#   'biomarker': ['fgfr1', 'fgfr']},
#  {'cancer_type': ['cancer', 'gastric adenocarcinoma'],
#   'biomarker': ['fgfr1', 'fgfr', 'fgfr2iiic']},
#  {'cancer_type': ['cancer', 'bladder carcinoma'],
#   'biomarker': ['fgfr1', 'fgfr']},
#  {'cancer_type': ['cancer', 'bladder carcinoma'],
#   'biomarker': ['fgfr1', 'fgfr3', 'tyrosine kinase', 'fgfr']},
#  {'cancer_type': ['hnscc',
#    'head and neck cancer',
#    'head and neck carcinoma',
#    'cancer'],
#   'biomarker': ['ptprd', 'stat3']},
#  {'cancer_type': ['cancer', 'prostate cancer', 'castration'],
#   'biomarker': ['defa3', 'defa1b', 'defa1']},
#  {'cancer_type': ['cancer', 'colorectal cancer', 'tumor xenograft'],
#   'biomarker': ['jag1', 'notch1']},
#  {'cancer_type': ['cancer', 'lung non-small cell carcinoma'],
#   'biomarker': ['hrg', 'nrg1', 'her3']},
#  {'cancer_type': ['nsclc', 'lung non-small cell carcinoma', 'cancer'],
#   'biomarker': ['wee1']},
#  {'cancer_type': ['hnscc', 'head and neck squamous cell carcinoma', 'cancer'],
#   'biomarker': ['stat3', 'jak', 'ptprt']},
#  {'cancer_type': ['crc', 'cancer', 'colorectal cancer'],
#   'biomarker': ['vegfa']},
#  {'cancer_type': ['cancer', 'ovarian cancer'], 'biomarker': ['kras', 'dnmt1']},
#  {'cancer_type': ['cancer', 'ovarian cancer'], 'biomarker': ['kras']},
#  {'cancer_type': ['cancer', 'lung cancer'], 'biomarker': ['pdcd4']},
#  {'cancer_type': ['cancer', 'glioblastoma'], 'biomarker': ['mgmt']},
#  {'cancer_type': ['cancer', 'breast cancer'],
#   'biomarker': ['er', 'tff1', 'pr', 'tff3']},
#  {'cancer_type': ['cancer'], 'biomarker': ['cd44 cd44s', 'cd44', 'cd44s']},
#  {'cancer_type': ['cancer', 'ewing sarcoma'],
#   'biomarker': ['dr5', 'caspase-8', 'casp8']},
#  {'cancer_type': ['cancer', 'lung adenocarcinoma'],
#   'biomarker': ['met', 'cep7']},
#  {'cancer_type': ['cancer', 'lung non-small cell carcinoma'],
#   'biomarker': ['smarca4']},
#  {'cancer_type': ['nsclc', 'lung non-small cell carcinoma', 'cancer', 'tumor'],
#   'biomarker': ['eml4', 'hsp90', 'alk']},
#  {'cancer_type': ['nsclc', 'lung non-small cell carcinoma', 'cancer'],
#   'biomarker': ['eml4', 'alk']},
#  {'cancer_type': ['cancer', 'prostate cancer'], 'biomarker': ['brca1']},
#  {'cancer_type': ['cancer', 'gastric adenocarcinoma'],
#   'biomarker': ['tp53', 'p53']},
#  {'cancer_type': ['cancer', 'breast cancer'], 'biomarker': ['p21', 'tp53']},
#  {'cancer_type': ['cancer', 'colorectal cancer'],
#   'biomarker': ['kras', 'egfr']},
#  {'cancer_type': ['cancer',
#    'xenografts',
#    'breast cancer',
#    'tumors',
#    'xenograft',
#    'tumor'],
#   'biomarker': ['ar', 'mtor', 'pi3k', 'er', 'androgen receptor']},
#  {'cancer_type': ['cancer', 'tumor xenografts'],
#   'biomarker': ['nrg1', 'erbb3']},
#  {'cancer_type': ['cancer',
#    'xenografts',
#    'pancreatic ductal adenocarcinoma',
#    'tumor'],
#   'biomarker': ['erbb2', 'her2', 'erbb3', 'her3']},
#  {'cancer_type': ['cancer', 'colorectal cancer'],
#   'biomarker': ['topoisomerase', 'slfn11']},
#  {'cancer_type': ['cancer',
#    'non-small cell lung cancer',
#    'lung non-small cell carcinoma',
#    'tumor'],
#   'biomarker': ['birc5', 'survivin', 'n-survivin']},
#  {'cancer_type': ['cancer', 'colorectal cancer'], 'biomarker': ['tp53']},
#  {'cancer_type': ['cancer', 'endometrial cancer', 'endometrial tumors'],
#   'biomarker': ['mre11', 'parp']},
#  {'cancer_type': ['cancer', 'gastric adenocarcinoma'],
#   'biomarker': ['tp53', 'atm', 'parp']},
#  {'cancer_type': ['cancer', 'lung adenocarcinoma'],
#   'biomarker': ['l858r', 'egfr']},
#  {'cancer_type': ['cancer', 'lung adenocarcinoma'],
#   'biomarker': ['l858', 'egfr']},
#  {'cancer_type': ['lung non-small cell carcinoma', 'cancer type'],
#   'biomarker': ['egfr']},
#  {'cancer_type': ['cancer', 'lung adenocarcinoma'],
#   'biomarker': ['l858r', 'egfr']},
#  {'cancer_type': ['cancer', 'lung adenocarcinoma'], 'biomarker': ['egfr']},
#  {'cancer_type': ['nsclc', 'lung non-small cell carcinoma', 'cancer'],
#   'biomarker': ['l858r', 'egfr']},
#  {'cancer_type': ['nsclc', 'lung non-small cell carcinoma', 'cancer'],
#   'biomarker': ['l858r', 'egfr']},
#  {'cancer_type': ['cancer', 'uterine corpus endometrial carcinoma'],
#   'biomarker': ['erbb2']},
#  {'cancer_type': ['cancer', 'breast cancer'],
#   'biomarker': ['erbb2', 'her2', 'her2-receptor']},
#  {'cancer_type': ['cancer', 'colorectal cancer'], 'biomarker': ['top1']},
#  {'cancer_type': ['cancer', 'head and neck squamous cell carcinoma', 'hnssc'],
#   'biomarker': ['p16',
#    'p21',
#    'cdkn2b',
#    'p-akt',
#    'ccnd1',
#    'cdkn1b',
#    'p27',
#    'caspase 3',
#    'hif-1a',
#    'bcl2',
#    'egfr',
#    'p53']},
#  {'cancer_type': ['cancer',
#    'lung squamous cell carcinoma',
#    'lung',
#    'squamous cell carcinoma'],
#   'biomarker': ['alk', 'met', 'kras', 'c-met', 'ros1', 'pik3ca', 'egfr']},
#  {'cancer_type': ['crc', 'cancer', 'colorectal cancer'],
#   'biomarker': ['pfgfr1', 'fgfr1', 'fgfr']},
#  {'cancer_type': ['cancer', 'tumor'],
#   'biomarker': ['naprt1', 'naprt', 'nampt']},
#  {'cancer_type': ['nsclc', 'lung non-small cell carcinoma', 'cancer', 'tumor'],
#   'biomarker': ['egfr']},
#  {'cancer_type': ['cancer', 'xenografts', 'mantle cell lymphoma'],
#   'biomarker': ['zeb1']},
#  {'cancer_type': ['cancer', 'tumors', 'colorectal cancer'],
#   'biomarker': ['prl-3', 'ptp4a3', 'ptp1b', 'pp4a3', 'egfr']},
#  {'cancer_type': ['cancer', 'esophageal carcinoma'],
#   'biomarker': ['tp53', 'p53']},
#  {'cancer_type': ['tumor specimens',
#    'lung non-small cell carcinoma',
#    'nsclc',
#    'cancer'],
#   'biomarker': ['dhfr', 'tyms']},
#  {'cancer_type': ['cancer', 'prostate cancer'], 'biomarker': ['tyms']},
#  {'cancer_type': ['cancer', 'breast cancer'], 'biomarker': ['top2a']},
#  {'cancer_type': ['cancer',
#    'peritoneal carcinoma',
#    'ovarian cancer',
#    'ovarian or'],
#   'biomarker': ['top1', 'topoisomerase 1']},
#  {'cancer_type': ['cancer', 'colorectal cancer', 'metastatic'],
#   'biomarker': ['kras', 'egfr']},
#  {'cancer_type': ['cancer', 'colorectal cancer'],
#   'biomarker': ['top1', 'topoisomerase 1', 'topoisomerase i']},
#  {'cancer_type': ['cancer', 'cancer histologies'],
#   'biomarker': ['acly', 'p-ampk', 'prkaa2']},
#  {'cancer_type': ['cancer', 'colorectal cancer'],
#   'biomarker': ['grp78', 'hspa5']},
#  {'cancer_type': ['cancer', 'xenografts', 'gastric adenocarcinoma'],
#   'biomarker': ['eif4ebp1', 'mtor']},
#  {'cancer_type': ['gists',
#    'cancer',
#    'gastrointestinal stromal tumor',
#    'antitumor'],
#   'biomarker': ['kit']},
#  {'cancer_type': ['breast cancers', 'breast cancer', 'cancer'],
#   'biomarker': ['betaiii-tubulin', 'tubb3']},
#  {'cancer_type': ['lung non-small cell carcinoma', 'cancer type'],
#   'biomarker': ['egfr']},
#  {'cancer_type': ['cancer',
#    'rhabdomyosarcoma',
#    'synovialsarcoma',
#    'sarcomas',
#    'sarcoma',
#    'desmoplastic tumor',
#    'osteosarcoma',
#    'liposarcoma',
#    'ewing sarcoma'],
#   'biomarker': ['igf-1r', 'igf1r']},
#  {'cancer_type': ['cancer', 'breast cancer', 'tumor samples'],
#   'biomarker': ['foxp3']},
#  {'cancer_type': ['cancer', 'gastric adenocarcinoma', 'gastric cancer'],
#   'biomarker': ['rps6', 'ps6']},
#  {'cancer_type': ['cancer', 'lung non-small cell carcinoma'],
#   'biomarker': ['jak1', 'jak 1 / 2 / 3', 'pkc']},
#  {'cancer_type': ['cancer', 'malignant mesothelioma'], 'biomarker': ['brca1']},
#  {'cancer_type': ['cancer'], 'biomarker': ['mek', 'dusp6']},
#  {'cancer_type': ['cancer'],
#   'biomarker': ['raf', 'pten', 'braf', 'kras', 'ras', 'pik3ca', 'mek']},
#  {'cancer_type': ['cancer'],
#   'biomarker': ['raf', 'pten', 'braf', 'ras', 'pik3ca', 'mek']},
#  {'cancer_type': ['cancer',
#    'pancreatic adenocarcinoma',
#    'pancreatic carcinoma',
#    'tumor'],
#   'biomarker': ['pten', 'pan-akt', 'kras', 'cancer antigen 19-9', 'akt']},
#  {'cancer_type': ['cancer',
#    'pancreatic adenocarcinoma',
#    'pancreatic carcinoma',
#    'tumor'],
#   'biomarker': ['pten', 'pan-akt', 'kras', 'cancer antigen 19-9', 'akt']},
#  {'cancer_type': ['cancer', 'pancreatic ductal adenocarcinoma'],
#   'biomarker': ['hsp27', 'hspb1']},
#  {'cancer_type': ['cancer', 'lung cancer'], 'biomarker': ['nq01', 'nqo1']},
#  {'cancer_type': ['cancer', 'sporadic', 'ovarian cancer'],
#   'biomarker': ['brca1']},
#  {'cancer_type': ['cancer', 'colorectal cancer'],
#   'biomarker': ['kras',
#    'tlr9',
#    'epidermal growth factor receptor tyrosine kinase']},
#  {'cancer_type': ['nsclc',
#    'lung non-small cell carcinoma',
#    'tumors',
#    'cancer'],
#   'biomarker': ['tyms', 'egfr', 'alk']},
#  {'cancer_type': ['antitumor', 'xenografts', 'cancer', 'colorectal cancer'],
#   'biomarker': ['kras']},
#  {'cancer_type': ['cancer', 'lung non-small cell carcinoma'],
#   'biomarker': ['epidermal growth factor receptor tyrosine kinase inhibitorapproval',
#    'tyrosine kinase',
#    'egfr']},
#  {'cancer_type': ['cancer', 'lung non-small cell carcinoma'],
#   'biomarker': ['egfr']},
#  {'cancer_type': ['cancer', 'breast cancer'], 'biomarker': ['pten']},
#  {'cancer_type': ['cancer',
#    'lung adenocarcinomas',
#    'metastatic',
#    'lung adenocarcinoma'],
#   'biomarker': ['erbb2', 'her2']},
#  {'cancer_type': ['cancer',
#    'xenografts',
#    'tumors',
#    'tumor',
#    'lung non-small cell carcinoma'],
#   'biomarker': ['erbb2']},
#  {'cancer_type': ['cancer', 'breast cancer'],
#   'biomarker': ['erbb2', 'her2', 'her2-receptor']},
#  {'cancer_type': ['cancer', 'pancreatic adenocarcinoma'],
#   'biomarker': ['kras', 'erbb2', 'egfr', 'erbb3']},
#  {'cancer_type': ['cancer',
#    'xenograft',
#    'tumor',
#    'tumor xenograft',
#    'lung non-small cell carcinoma'],
#   'biomarker': ['egfrm', 'egfr']},
#  {'cancer_type': ['cancer',
#    'non-small cell lung cancer',
#    'lung non-small cell carcinoma',
#    'tumor'],
#   'biomarker': ['egfr']},
#  {'cancer_type': ['lung non-small cell carcinoma', 'cancer type'],
#   'biomarker': ['t790m', 'egfr']},
#  {'cancer_type': ['cancer', 'lung non-small cell carcinoma'],
#   'biomarker': ['egfr']},
#  {'cancer_type': ['cancer', 'lung non-small cell carcinoma'],
#   'biomarker': ['l858r', 'egfr']},
#  {'cancer_type': ['cancer', 'lung non-small cell carcinoma'],
#   'biomarker': ['egfr']},
#  {'cancer_type': ['cancer', 'glioblastoma multiforme', 'gbm', 'glioblastoma'],
#   'biomarker': ['egfr viii', 'egfr viiitherapy']},
#  {'cancer_type': ['cancer', 'breast cancer', 'tumors'],
#   'biomarker': ['sher2', 'erbb2', 'her2']},
#  {'cancer_type': ['cancer', 'colorectal cancer'],
#   'biomarker': ['trka', 'ntrk1', 'lmna', 'tpm3']},
#  {'cancer_type': ['cancer', 'colorectal cancer'],
#   'biomarker': ['trka', 'ntrk1', 'lmna', 'tpm3']},
#  {'cancer_type': ['cancer', 'solid tumors', 'oligodendroglioma', 'glioma'],
#   'biomarker': ['idh1']},
#  {'cancer_type': ['nsclc', 'cancer', 'lung adenocarcinoma'],
#   'biomarker': ['egfr']},
#  {'cancer_type': ['nsclc', 'cancer', 'lung adenocarcinoma'],
#   'biomarker': ['egfr']},
#  {'cancer_type': ['nsclc', 'cancer', 'lung adenocarcinoma'],
#   'biomarker': ['l858r', 'egfr']},
#  {'cancer_type': ['cancer',
#    'melanomas',
#    'tumours',
#    'skin melanoma',
#    'melanoma'],
#   'biomarker': ['hla-dra', 'anti-pd1', 'hla-dr', 'pd-l1', 'mhc-ii']},
#  {'cancer_type': ['cancer',
#    'lymphoplasmacytic lymphoma',
#    "waldenström ' s macroglobulinemia"],
#   'biomarker': ['cxcr4', 'myd88']},
#  {'cancer_type': ['cancer', 'colorectal cancer'],
#   'biomarker': ['raf', 'b-raf', 'raf1', 'kras', 'raf265', 'vegfr-2', 'mek']},
#  {'cancer_type': ['cancer', 'lung non-small cell carcinoma'],
#   'biomarker': ['raf', 'b-raf', 'raf1', 'kras', 'raf265', 'vegfr-2', 'mek']},
#  {'cancer_type': ['cancer', 'colorectal cancer'],
#   'biomarker': ['erbb2', 'erbb3', 'kras', 'mek', 'egfr']},
#  {'cancer_type': ['cancer', 'lung non-small cell carcinoma'],
#   'biomarker': ['erbb2', 'erbb3', 'kras', 'mek', 'egfr']},
#  {'cancer_type': ['cancer', 'lung non-small cell carcinoma'],
#   'biomarker': ['kras']},
#  {'cancer_type': ['cancer', 'neuroblastoma'],
#   'biomarker': ['mtor', 'akt', 'pi3k', 'pik3ca', 'mek', 'nras']},
#  {'cancer_type': ['cancer', 'pancreatic adenocarcinoma'],
#   'biomarker': ['mtor', 'pi3k', 'kras', 'pi3kbeta', 'erk', 'akt', 'mek']},
#  {'cancer_type': ['cancer', 'xenografts', 'colorectal cancer'],
#   'biomarker': ['meti', 'rtki', 'met', 'igf-ir', 'rtks', 'kras', 'mek']},
#  {'cancer_type': ['cancer', 'melanoma'],
#   'biomarker': ['p-erk', 'p-akt', 'mtor', 'braf', 'pi3k', 'mek1']},
#  {'cancer_type': ['cancer', 'breast cancer'], 'biomarker': ['erbb2']},
#  {'cancer_type': ['bc', 'breast cancer', 'stage', 'cancer'],
#   'biomarker': ['erbb2', 'her2', 'her2-receptor']},
#  {'cancer_type': ['bc', 'breast cancer', 'her2', 'cancer'],
#   'biomarker': ['erbb2', 'her2', 'her2-receptor']},
#  {'cancer_type': ['cancer', 'breast cancer', 'her2 breast cancer', 'tumor'],
#   'biomarker': ['erbb2', 'her2', 'her2-receptor']},
#  {'cancer_type': ['metastatic bc', 'breast cancer', 'mbc', 'cancer'],
#   'biomarker': ['erbb2',
#    'erbb3',
#    'her2-receptor',
#    'her2',
#    'erbb',
#    'erbb4',
#    'egfr']},
#  {'cancer_type': ['cancer', 'metastatic', 'prostate cancer'],
#   'biomarker': ['mre11', 'atm', 'mlh3', 'parp', 'nbn']},
#  {'cancer_type': ['antitumor', 'brain glioma', 'cancer', 'tumor'],
#   'biomarker': ['egfrwt', 'akt', 'egfr', 'egfrviii']},
#  {'cancer_type': ['cancer', 'lung adenocarcinoma'],
#   'biomarker': ['cd74', 'ntrk1', 'trka', 'mprip']},
#  {'cancer_type': ['crc', 'tumors', 'cancer', 'colorectal cancer'],
#   'biomarker': ['kras', 'ereg', 'areg', 'ras']},
#  {'cancer_type': ['crc', 'tumors', 'cancer', 'colorectal cancer'],
#   'biomarker': ['kras', 'ereg', 'areg', 'ras']},
#  {'cancer_type': ['cancer',
#    'gastric adenocarcinoma',
#    'metastatic cancer',
#    'gastric cancer'],
#   'biomarker': ['erbb2', 'her2']},
#  {'cancer_type': ['cancer', 'gastric adenocarcinoma', 'gastric cancer'],
#   'biomarker': ['ihc3', 'erbb2', 'her2']},
#  {'cancer_type': ['cancer',
#    'low-grade endometrial stromal sarcoma',
#    'endometrial cancer'],
#   'biomarker': ['cd117', 'kit']},
#  {'cancer_type': ['cancer',
#    'high-grade stromal endometrial sarcoma',
#    'endometrial cancer'],
#   'biomarker': ['c-kit', 'kit']},
#  {'cancer_type': ['cancer', 'stage iv nsclc', 'lung non-small cell carcinoma'],
#   'biomarker': ['ros1']},
#  {'cancer_type': ['cancer',
#    'tumors',
#    'tumor',
#    'renal carcinoma',
#    'kidney cancer'],
#   'biomarker': ['hif1a', 'vhl', 'mtor']},
#  {'cancer_type': ['cancer', 'aml', 'acute myeloid leukemia'],
#   'biomarker': ['flt3']},
#  {'cancer_type': ['cancer',
#    'adenocarcinoma',
#    'tumors',
#    'lung adenocarcinoma',
#    'cancer type',
#    'nsclc'],
#   'biomarker': ['her2', 'erbb2 kinase']},
#  {'cancer_type': ['cancer',
#    'lung small cell carcinoma',
#    'tumor',
#    'sclc',
#    'nsclc'],
#   'biomarker': ['erbb2', 'her2']},
#  {'cancer_type': ['cancer', 'lung adenocarcinoma'],
#   'biomarker': ['erbb2', 'her2', 'ihc2']},
#  {'cancer_type': ['cancer',
#    'lung carcinoma',
#    'tumor',
#    'adenosquamous lung tumors'],
#   'biomarker': ['erbb2', 'her2', 'rtta']},
#  {'cancer_type': ['cancer',
#    'lung adenocarcinoma',
#    'lung cancers',
#    'nsclc tumors'],
#   'biomarker': ['erbb2', 'her2']},
#  {'cancer_type': ['cancer',
#    'nsclcer2',
#    'lung non-small cell carcinoma',
#    'lung cancer',
#    'nsclc'],
#   'biomarker': ['erbb2', 'calu-3', 'her2', 'calu-6', 'tdm-1']},
#  {'cancer_type': ['crc', 'colorectal cancer', 'tumor', 'cancer type'],
#   'biomarker': ['egfr']},
#  {'cancer_type': ['cancer', 'nsclc', 'lung non-small cell carcinoma', 'tumor'],
#   'biomarker': ['ets2']},
#  {'cancer_type': ['cancer', 'breast cancer'],
#   'biomarker': ['ihc3', 'erbb2', 'her2', 'her2-receptor']},
#  {'cancer_type': ['cancer',
#    'liver lesions',
#    'tumor',
#    'colorectal cancer',
#    'specimens',
#    'mcrc'],
#   'biomarker': ['egfr']},
#  {'cancer_type': ['cancer', 'colorectal cancer'], 'biomarker': ['egfr']},
#  {'cancer_type': ['cancer', 'colorectal cancer'], 'biomarker': ['egfr']},
#  {'cancer_type': ['cancer', 'colorectal cancer'], 'biomarker': ['egfr']},
#  {'cancer_type': ['scc',
#    'solid tumors',
#    'cancer',
#    'skin squamous cell carcinoma'],
#   'biomarker': ['egfr']},
#  {'cancer_type': ['acute promyelocytic leukemia', 'cancer'],
#   'biomarker': ['pml', 'rara']},
#  {'cancer_type': ['nsclc', 'lung non-small cell carcinoma', 'cancer'],
#   'biomarker': ['met']},
#  {'cancer_type': ['cancer',
#    'high-grade endometrial adenocarcinoma',
#    'endometrial cancers',
#    'uspc',
#    'uterine serous papillary carcinoma',
#    'endometrial serous adenocarcinoma'],
#   'biomarker': ['ihc3', 'ca-125', 'erbb2', 'her2']},
#  {'cancer_type': ['medulloblastoma', 'cancer', 'tumor'], 'biomarker': ['shh']},
#  {'cancer_type': ['cancer', 'lung non-small cell carcinoma'],
#   'biomarker': ['cd74', 'ros1']},
#  {'cancer_type': ['cancer', 'acute myeloid leukemia'],
#   'biomarker': ['cebpa', 'wrd5', 'mll', 'p30', 'set']},
#  {'cancer_type': ['cancer', 'myeloproliferative neoplasm'],
#   'biomarker': ['midostaurinapproval', 'fgfr1', 'zmym2', 'znf198']},
#  {'cancer_type': ['cancer', 'angiosarcoma'], 'biomarker': ['kdr', 'rhvegf']},
#  {'cancer_type': ['cancer', 'angiosarcoma'], 'biomarker': ['kdr', 'rhvegf']},
#  {'cancer_type': ['cancer', 'thyroid gland carcinoma', 'tumor'],
#   'biomarker': ['tsc2', 'mtor']},
#  {'cancer_type': ['cancer', 'breast cancer'],
#   'biomarker': ['erbb2', 'her2', 'her2-receptor']},
#  {'cancer_type': ['cancer', 'head and neck squamous cell carcinoma'],
#   'biomarker': ['aldh1a2']},
#  {'cancer_type': ['cancer', 'pancreatic ductal adenocarcinoma'],
#   'biomarker': ['cip2a']},
#  {'cancer_type': ['bc', 'breast cancer', 'cancer', 'invasive'],
#   'biomarker': ['erbb2', 'her2', 'her2-receptor']},
#  {'cancer_type': ['cancer',
#    'lung',
#    'stage iv lung adenocarcinoma',
#    'lung adenocarcinoma',
#    'bone lesions'],
#   'biomarker': ['erbb2', 'her2']},
#  {'cancer_type': ['cancer', 'glioblastoma', 'glioblastomas', 'tumor'],
#   'biomarker': ['egfrviii', 'pten', 'her2', 'egfr', 'neu kinase']},
#  {'cancer_type': ['cancer', 'glioblastoma', 'glioblastomas', 'tumor'],
#   'biomarker': ['egfrviii', 'pten', 'her2', 'egfr', 'neu kinase']},
#  {'cancer_type': ['cancer', 'breast cancer', 'her2 breast cancer'],
#   'biomarker': ['erbb2', 'her2', 'her2-receptor']},
#  {'cancer_type': ['cancer', 'breast cancer', 'her2'],
#   'biomarker': ['erbb2', 'her2-receptor']},
#  {'cancer_type': ['cancer', 'aml', 'acute myeloid leukemia'],
#   'biomarker': ['kit', 'kras', 'flt3', 'nras']},
#  {'cancer_type': ['cancer', 'melanoma'], 'biomarker': ['tbk1', 'mek', 'nras']},
#  {'cancer_type': ['cancer', 'xenografts', 'tumors', 'tumours'],
#   'biomarker': ['kras', 'mek', 'raf', 'braf']},
#  {'cancer_type': ['cancer', 'xenografts', 'tumours'],
#   'biomarker': ['kras', 'mek', 'mapk', 'braf']},
#  {'cancer_type': ['cancer',
#    'tumors',
#    'lung non-small cell carcinoma',
#    'tumor'],
#   'biomarker': ['kras', 'mek1 / 2']},
#  {'cancer_type': ['cancer',
#    'tumors',
#    'lung non-small cell carcinoma',
#    'tumor'],
#   'biomarker': ['kras']},
#  {'cancer_type': ['nsclc',
#    'lung non-small cell carcinoma',
#    'tumors',
#    'cancer'],
#   'biomarker': ['trp53', 'perk', 'kras', 'cre', 'tp53']},
#  {'cancer_type': ['cancer', 'lung non-small cell carcinoma'],
#   'biomarker': ['tp53']},
#  {'cancer_type': ['cancer',
#    'lung non-small cell carcinoma',
#    'lung adenocarcinoma'],
#   'biomarker': ['anti',
#    'pd1',
#    'havcr2',
#    'pd-1',
#    't-cell immunoglobulin mucin-3',
#    'tim-3']},
#  {'cancer_type': ['nsclc xenografts',
#    'cancer',
#    'lung',
#    'crc xenografts',
#    'tumor',
#    'cancer type',
#    'colon cancer'],
#   'biomarker': ['erbb2', 'erbb3', 'kras', 'mek', 'egfr']},
#  {'cancer_type': ['inflammatory breast cancer',
#    'inflammatory breast carcinoma',
#    'cancer'],
#   'biomarker': ['mmp2', 'bmmp2']},
#  {'cancer_type': ['cancer', 'high-grade gliomas', 'brain glioma'],
#   'biomarker': ['mmp2']},
#  {'cancer_type': ['her2 breast cancer', 'breast cancer', 'cancer type'],
#   'biomarker': ['erbb2', 'her2', 'her2-receptor']},
#  {'cancer_type': ['cancer', 'breast cancer'],
#   'biomarker': ['erbb2', 'her2', 'her2-receptor']},
#  {'cancer_type': ['cancer', 'gastric adenocarcinoma', 'gastric cancer'],
#   'biomarker': ['hsph1', 'hsp110']},
#  {'cancer_type': ['cancer',
#    'stage ii',
#    'colorectal cancer',
#    'colorectal tumors'],
#   'biomarker': ['hsph1 t17', 'hsp110']},
#  {'cancer_type': ['cancer', 'tumors', 'lung non-small cell carcinoma'],
#   'biomarker': ['pd-1', 'pd-l1', 'cd274']},
#  {'cancer_type': ['cancer', 'advanced', 'tumors', 'sarcoma'],
#   'biomarker': ['tp53']},
#  {'cancer_type': ['cancer',
#    'tumour',
#    'non-small cell lung cancer',
#    'lung non-small cell carcinoma'],
#   'biomarker': ['pd-l1', 'cd274']},
#  {'cancer_type': ['cancer'],
#   'biomarker': ['egf',
#    'mapk',
#    'epidermal growth factor receptor tyrosine kinase',
#    'kras',
#    'pi3k',
#    'g12c',
#    'kras g12c',
#    'egfr']},
#  {'cancer_type': ['cancer',
#    'xenografts',
#    'colon cancer patient',
#    'tumor',
#    'colon cancer'],
#   'biomarker': ['erbb2', 'her2']},
#  {'cancer_type': ['nsclc', 'lung non-small cell carcinoma', 'cancer'],
#   'biomarker': ['alk']},
#  {'cancer_type': ['cancer',
#    'xenografts',
#    'colon cancer patient',
#    'tumor',
#    'colon cancer'],
#   'biomarker': ['erbb2', 'her2']},
#  {'cancer_type': ['cancer',
#    'xenografts',
#    'colon cancer patient',
#    'tumor',
#    'colon cancer'],
#   'biomarker': ['erbb2', 'her2']},
#  {'cancer_type': ['cancer',
#    'xenografts',
#    'colon cancer patient',
#    'tumor',
#    'colon cancer'],
#   'biomarker': ['erbb2', 'her2']},
#  {'cancer_type': ['cancer',
#    'xenografts',
#    'colon cancer patient',
#    'tumor',
#    'colon cancer'],
#   'biomarker': ['erbb2', 'her2']},
#  {'cancer_type': ['cancer', 'tumors', 'tumor'],
#   'biomarker': ['cdk1', 'kras', 'braf']},
#  {'cancer_type': ['cancer', 'lung adenocarcinoma'],
#   'biomarker': ['met', 'c-met']},
#  {'cancer_type': ['cancer', 'tumor', 'lung adenocarcinoma'],
#   'biomarker': ['met', 'metex14']},
#  {'cancer_type': ['nsclc', 'lung non-small cell carcinoma', 'cancer'],
#   'biomarker': ['met', 'eml4', 'alk']},
#  {'cancer_type': ['nsclc',
#    'cancer type',
#    'lung non-small cell carcinoma',
#    'lung adenocarcinoma specimen'],
#   'biomarker': ['eml4-', 'eml4-alk', 'il3', 'alk', 'eml4']},
#  {'cancer_type': ['cancer',
#    'adenocarcinoma',
#    'lung non-small cell carcinoma',
#    'nsclc tumors'],
#   'biomarker': ['alk e20', 'alk variant 2', 'eml4', 'alk']},
#  {'cancer_type': ['tumors',
#    'lung adenocarcinoma',
#    'cancer type',
#    'lung non-small cell carcinoma',
#    'lung adenocarcinomas'],
#   'biomarker': ['eml4', 'alk']},
#  {'cancer_type': ['crc', 'colorectal adenocarcinoma', 'cancer'],
#   'biomarker': ['erbb2', 'kdr', 'vegfr2', 'kras', 'apc', 'vegfr']},
#  {'cancer_type': ['nsclc',
#    'tumors',
#    'lung non-small cell carcinoma',
#    'cancer type'],
#   'biomarker': ['3a', 'alk', 'eml4', '3b', 'e20therapy', 'alk e6']},
#  {'cancer_type': ['nsclc', 'lung non-small cell carcinoma', 'cancer'],
#   'biomarker': ['eml4-alk',
#    'alk',
#    '3a',
#    'eml4',
#    'eml4-alksclc',
#    'e20therapy',
#    'alk e6']},
#  {'cancer_type': ['cancer', 'lung non-small cell carcinoma'],
#   'biomarker': ['alk',
#    'erk1 / 2',
#    'eml4',
#    'alk variant 3a',
#    'akt',
#    'e20therapy',
#    'alk e6']},
#  {'cancer_type': ['lung non-small cell carcinoma', 'cancer type'],
#   'biomarker': ['eml4-alk',
#    'il3',
#    'alk',
#    '3a',
#    'v3a',
#    'v2',
#    'eml4',
#    'v3b',
#    'v1']},
#  {'cancer_type': ['cancer',
#    'non-small cell lung cancer',
#    'lung non-small cell carcinoma'],
#   'biomarker': ['alk']},
#  {'cancer_type': ['nsclc', 'lung non-small cell carcinoma', 'cancer'],
#   'biomarker': ['alk']},
#  {'cancer_type': ['nsclc', 'lung non-small cell carcinoma', 'cancer'],
#   'biomarker': ['alk']},
#  {'cancer_type': ['nsclc', 'lung non-small cell carcinoma', 'cancer'],
#   'biomarker': ['alk']},
#  {'cancer_type': ['nsclc', 'lung non-small cell carcinoma', 'cancer', 'tumor'],
#   'biomarker': ['hsp90', 'alk']},
#  {'cancer_type': ['cancer',
#    'h3122 tumors',
#    'lung non-small cell carcinoma',
#    'tumor'],
#   'biomarker': ['eml4-alk', 'alk', 'her2', 'eml4', 'hsp90', 'egfr']},
#  {'cancer_type': ['cancer',
#    'lung adenocarcinomas',
#    'lung non-small cell carcinoma'],
#   'biomarker': ['il3',
#    'eml4-alk',
#    'alk',
#    'eml4',
#    'eml4-alk variant 2',
#    'hsp90']},
#  {'cancer_type': ['cancer', 'lung non-small cell carcinoma'],
#   'biomarker': ['eml4-alk',
#    'il3',
#    'alk',
#    'eml4-alk variant 1',
#    'eml4',
#    'hsp90']},
#  {'cancer_type': ['nsclc', 'lung non-small cell carcinoma', 'cancer', 'tumor'],
#   'biomarker': ['eml4-alk', 'eml4', 'alk']},
#  {'cancer_type': ['cancer', 'uveal melanoma', 'xenograft'],
#   'biomarker': ['jq1', 'jq1approval', 'brd4', 'gnaq', 'gna11']},
#  {'cancer_type': ['cancer', 'uveal melanoma'],
#   'biomarker': ['mel202',
#    'jq1',
#    'jq1approval',
#    'omm1 . 3',
#    'brd4',
#    'mel270',
#    'omm1',
#    'gnaq',
#    '92 . 1',
#    'gna11']},
#  {'cancer_type': ['cancer',
#    'lung',
#    'malignant tumors',
#    'tumors',
#    'tumor',
#    'glioblastoma multiforme',
#    'cancers',
#    'glioblastoma',
#    'melanoma'],
#   'biomarker': ['tp53', 'pms2', 'mgmt']},
#  {'cancer_type': ['cancer',
#    'lung non-small cell carcinoma',
#    'tumor',
#    'solid tumors',
#    'nsclc'],
#   'biomarker': ['kras']},
#  {'cancer_type': ['cancer', 'gist', 'gastrointestinal stromal tumor'],
#   'biomarker': ['kit']},
#  {'cancer_type': ['cancer', 'tumor', 'melanoma'], 'biomarker': ['kit']},
#  {'cancer_type': ['cancer', 'gist', 'tumor', 'gastrointestinal stromal tumor'],
#   'biomarker': ['kit', 'pdgfra']},
#  {'cancer_type': ['cancer', 'melanoma'], 'biomarker': ['kit']},
#  {'cancer_type': ['cancer', 'advanced', 'skin melanoma', 'melanoma'],
#   'biomarker': ['nras', 'braf']},
#  {'cancer_type': ['cancer', 'skin melanoma', 'melanoma'],
#   'biomarker': ['braf', 'nras', 'mek162']},
#  {'cancer_type': ['cancer', 'uveal melanoma', 'melanoma'],
#   'biomarker': ['gnaq', 'gna11']},
#  {'cancer_type': ['cancer', 'uveal melanoma', 'melanoma'],
#   'biomarker': ['gnaq', 'gna11']},
#  {'cancer_type': ['cancer',
#    'melanoma xenograft',
#    'lung carcinoma',
#    'melanoma',
#    'neuroblastoma'],
#   'biomarker': ['pi3k', 'nras']},
#  {'cancer_type': ['cancer', 'prostate cancer'], 'biomarker': ['pten', 'mtor']},
#  {'cancer_type': ['cancer', 'uveal melanoma', 'ocular melanoma'],
#   'biomarker': ['mapk1 / 2', 'gnaq', 'pten']},
#  {'cancer_type': ['cancer', 'uveal melanomas', 'uveal melanoma'],
#   'biomarker': ['hdac', 'bap1']},
#  {'cancer_type': ['cancer', 'malignant mesothelioma'],
#   'biomarker': ['bap', 'hdac1', 'hdac2', 'bap1', 'hdac']},
#  {'cancer_type': ['cancer', 'endometrial cancer'],
#   'biomarker': ['fgfr2', 'mfe-280', 'fgfr', 'mfe-296']},
#  {'cancer_type': ['cancer',
#    'advanced',
#    'lung non-small cell carcinoma',
#    'nsclc',
#    'cancers'],
#   'biomarker': ['alk']},
#  {'cancer_type': ['cancer',
#    'tumors',
#    'tumor xenograft',
#    'alcl',
#    'anaplastic large cell lymphoma'],
#   'biomarker': ['met', 'npm-alk', 'npm1', 'alk']},
#  {'cancer_type': ['cancer',
#    'lesions',
#    'alcl',
#    'anaplastic large cell lymphoma'],
#   'biomarker': ['alk']},
#  {'cancer_type': ['cancer', 'alcl', 'anaplastic large cell lymphoma'],
#   'biomarker': ['npm-alk', 'npm1', 'alk']},
#  {'cancer_type': ['cancer',
#    'inflammatory myofibroblastic tumors',
#    'inflammatory myofibroblastic tumor'],
#   'biomarker': ['alk']},
#  {'cancer_type': ['cancer', 'imt', 'inflammatory myofibroblastic tumor'],
#   'biomarker': ['ranbp2', 'alk']},
#  {'cancer_type': ['cancer',
#    'lung lesion',
#    'malignant neoplasm',
#    'tumor',
#    'poorly',
#    'lung tumors',
#    'lung lesions'],
#   'biomarker': ['eml4', 'alk e6', 'alk']},
#  {'cancer_type': ['cancer',
#    'xenograft',
#    "ewing ' s sarcoma tumor samples",
#    'tumor samples',
#    'samples',
#    'ewing sarcoma'],
#   'biomarker': ['fgfr1']},
# ...
#    'pik3ca',
#    'egfr',
#    'mek1']},
#  {'cancer_type': ['ajcc iiic', 'cancer', 'skin melanoma', 'melanoma'],
#   'biomarker': ['nras']},
#  {'cancer_type': ['lung cancer', 'tumors', 'cancer'],
#   'biomarker': ['kras',
#    'egfr',
#    'epidermal growth factor receptor tyrosine kinase']},
#  {'cancer_type': ['cancer', 'multiple myeloma'],
#   'biomarker': ['lage-1', 'ctag1b', 'ny-eso-1']},
#  {'cancer_type': ['cancer', 'multiple myeloma'],
#   'biomarker': ['lage-1', 'ctag2', 'ny-eso-1']},
#  {'cancer_type': ['cancer',
#    'antitumor',
#    'non-small cell lung cancer',
#    'colorectal cancer',
#    'glioneuronal tumor',
#    'tumor',
#    'lung cancer',
#    'solid tumors',
#    'solid tumor'],
#   'biomarker': ['bcan', 'alk', None, 'sqstm1', 'lmna', 'ros1', 'ntrk1']},
#  {'cancer_type': ['cancer',
#    'tumors',
#    'antitumor',
#    'non-small cell lung cancer',
#    'colorectal cancer',
#    'lung cancer',
#    'solid tumors',
#    'mammary analogue secretory carcinoma',
#    'renal cell carcinoma',
#    'melanoma'],
#   'biomarker': ['alk', None, 'ntrk3', 'sqstm1', 'ros1', 'ntrk1']},
#  {'cancer_type': ['cancer',
#    'tumors',
#    'antitumor',
#    'non-small cell lung cancer',
#    'colorectal cancer',
#    'lung cancer',
#    'solid tumors',
#    'mammary analogue secretory carcinoma',
#    'renal cell carcinoma',
#    'lung non-small cell carcinoma',
#    'melanoma'],
#   'biomarker': ['alk', None, 'sqstm1', 'ros1', 'ntrk1']},
#  {'cancer_type': ['cancer',
#    'antitumor',
#    'non-small cell lung cancer',
#    'lung non-small cell carcinoma',
#    'solid tumors',
#    'nsclc',
#    'melanoma'],
#   'biomarker': ['cd74', 'ezr', 'ros1', 'sdc4']},
#  {'cancer_type': ['cancer',
#    'tumors',
#    'antitumor',
#    'non-small cell lung cancer',
#    'colorectal cancer',
#    'lung cancer',
#    'solid tumors',
#    'mammary analogue secretory carcinoma',
#    'renal cell carcinoma',
#    'melanoma'],
#   'biomarker': ['alk', None, 'sqstm1', 'ros1', 'ntrk1']},
#  {'cancer_type': ['cancer',
#    'tumour',
#    'gist',
#    'tumors',
#    'masc',
#    'gastrointestinal stromal tumor',
#    'soft-tissue sarcoma'],
#   'biomarker': ['ntrk1', 'trk', 'ntrk']},
#  {'cancer_type': ['cancer',
#    'lung',
#    'tumors',
#    'tumor',
#    'sarcoma',
#    'soft-tissue sarcoma'],
#   'biomarker': ['loxo-101', 'trk', 'trka', 'lmna', 'ntrk1']},
#  {'cancer_type': ['cancer',
#    'colorectal adenocarcinoma',
#    'colorectal cancer',
#    'metastatic',
#    'tumor',
#    'liver metastases'],
#   'biomarker': ['ntrk1', 'lmna']},
#  {'cancer_type': ['cancer'], 'biomarker': ['tp53', 'mdm2']},
#  {'cancer_type': ['cancer'], 'biomarker': ['tp53', 'mdm2', 'amgmds3approval']},
#  {'cancer_type': ['cancer', 'leukemia', 'scll', 'cll', 'aml', 'all', 'cml'],
#   'biomarker': ['tp53']},
#  {'cancer_type': ['cancer', 'ovarian clear cell carcinoma'],
#   'biomarker': ['arid1a']},
#  {'cancer_type': ['tumour',
#    'tumour nodules',
#    'occc',
#    'cancer type',
#    'ovarian clear cell carcinoma'],
#   'biomarker': ['ezh2', 'arid1a']},
#  {'cancer_type': ['cervix carcinoma', 'cancer type'],
#   'biomarker': ['pi3k', 'pik3ca']},
#  {'cancer_type': ['cancer', 'tumors', 'neuroblastoma'],
#   'biomarker': ['trk', 'alk', 'ros']},
#  {'cancer_type': ['cancer',
#    'melanomas',
#    'melanoma murine xenograft',
#    'tumor',
#    'metastatic',
#    'benign nevi',
#    'melanoma'],
#   'biomarker': ['ras', 'braf', 'mertk']},
#  {'cancer_type': ['cancer',
#    'tumors',
#    'non-small cell lung cancer',
#    'lung non-small cell carcinoma',
#    'metastatic',
#    'nsclc'],
#   'biomarker': ['l858r', 'egfr', 'epidermal growth factor receptor']},
#  {'cancer_type': ['cancer',
#    'tumors',
#    'non-small cell lung cancer',
#    'lung non-small cell carcinoma',
#    'metastatic',
#    'nsclc'],
#   'biomarker': ['l858r', 'epidermal growth factor receptor (', 'egfr']},
#  {'cancer_type': ['tumours',
#    'lung non-small cell carcinoma',
#    'metastatic',
#    'non-small-cell lung cancer',
#    'nsclc'],
#   'biomarker': ['l858r', 'erbb', 'egfr']},
#  {'cancer_type': ['tumours',
#    'lung non-small cell carcinoma',
#    'metastatic',
#    'non-small-cell lung cancer',
#    'nsclc'],
#   'biomarker': ['erbb', 'egfr']},
#  {'cancer_type': ['cancer', 'lung small cell carcinoma'],
#   'biomarker': ['myc', 'chek1']},
#  {'cancer_type': ['cancer', 'acute myeloid leukemia'], 'biomarker': ['flt3']},
#  {'cancer_type': ['cancer', 'acute myeloid leukemia'], 'biomarker': ['flt3']},
#  {'cancer_type': ['nsclc',
#    'lung non-small cell carcinoma',
#    'non-small cell lung cancer',
#    'cancer'],
#   'biomarker': ['egfr']},
#  {'cancer_type': ['nsclc', 'lung non-small cell carcinoma', 'cancer'],
#   'biomarker': ['braf']},
#  {'cancer_type': ['cancer', 'lung non-small cell carcinoma'],
#   'biomarker': ['fgfr1']},
#  {'cancer_type': ['cancer',
#    'mesenchymal tumor',
#    'gastrointestinal stromal tumor'],
#   'biomarker': ['c-kit', 'kit', 'kit v559dtherapy']},
#  {'cancer_type': ['cancer'], 'biomarker': ['kit']},
#  {'cancer_type': ['cancer', 'acute myeloid leukemia'], 'biomarker': ['flt3']},
#  {'cancer_type': ['cancer',
#    'tumors',
#    'breast',
#    'solid tumors',
#    'cancers',
#    'gynecologic'],
#   'biomarker': ['pi3k', 'akt1']},
#  {'cancer_type': ['cancer'], 'biomarker': ['pi3k', 'akt1', 'pik3ca', 'mtor']},
#  {'cancer_type': ['thyroid cancer',
#    'follicular thyroid carcinoma',
#    'mass',
#    'cancer'],
#   'biomarker': ['gnas', 'nras']},
#  {'cancer_type': ['cancer',
#    'uveal melanoma',
#    'metastatic melanoma',
#    'cutaneous'],
#   'biomarker': ['gnaq', 'gna11']},
#  {'cancer_type': ['cancer',
#    'non-small cell lung cancer',
#    'tumors',
#    'lung non-small cell carcinoma'],
#   'biomarker': ['kras']},
#  {'cancer_type': ['cancer', 'melanoma'], 'biomarker': ['v600k', 'braf']},
#  {'cancer_type': ['cancer', 'melanoma'],
#   'biomarker': ['braf v600etherapy', 'braf']},
#  {'cancer_type': ['cancer', 'melanoma', 'stage iv melanoma'],
#   'biomarker': ['braf']},
#  {'cancer_type': ['cancer', 'skin melanoma'], 'biomarker': ['v600e', 'braf']},
#  {'cancer_type': ['cancer',
#    'cervicomedullary low grade glioma',
#    'childhood pilocytic astrocytoma',
#    'tumor',
#    'ganglioglioma',
#    'pilocytic astrocytoma',
#    'mass',
#    'lesion'],
#   'biomarker': ['braf']},
#  {'cancer_type': ['ovarian serous carcinoma',
#    'low-grade papillary serous ovarian adenocarcinoma',
#    'cancer type'],
#   'biomarker': ['her3 antibody', 'braf']},
#  {'cancer_type': ['cancer',
#    'non-small cell lung cancer',
#    'lung adenocarcinoma subtype',
#    'lung adenocarcinoma'],
#   'biomarker': ['l858r', 'egfr']},
#  {'cancer_type': ['cancer',
#    'non-small cell lung cancer',
#    'lung adenocarcinoma subtype',
#    'lung adenocarcinoma'],
#   'biomarker': ['l858r', 'egfr']},
#  {'cancer_type': ['cancer',
#    'bronchioloalveolar carcinoma',
#    'lung non-small cell carcinoma',
#    'bac',
#    'in situ pulmonary adenocarcinoma'],
#   'biomarker': ['egfr']},
#  {'cancer_type': ['lung non-small cell carcinoma',
#    'cancer type',
#    'lung adenocarcinoma'],
#   'biomarker': ['egfr']},
#  {'cancer_type': ['cancer'], 'biomarker': ['l858r', 'egfr', 'multikinase']},
#  {'cancer_type': ['cancer',
#    'lung cancer',
#    'non-small cell lung cancer',
#    'tumors'],
#   'biomarker': ['egfr']},
#  {'cancer_type': ['cancer', 'acute myeloid leukemia'], 'biomarker': ['flt3']},
#  {'cancer_type': ['cancer', 'gastrointestinal stromal tumor'],
#   'biomarker': ['kit']},
#  {'cancer_type': ['cancer', 'tumor', 'gastrointestinal stromal tumor'],
#   'biomarker': ['kit', 'il3']},
#  {'cancer_type': ['cancer', 'gastrointestinal stromal tumor'],
#   'biomarker': ['kit', 'il3']},
#  {'cancer_type': ['cancer', 'gastrointestinal stromal tumor'],
#   'biomarker': ['kit', 'il3']},
#  {'cancer_type': ['cancer', 'gastrointestinal stromal tumor'],
#   'biomarker': ['kit', 'il3']},
#  {'cancer_type': ['cancer'], 'biomarker': ['kit']},
#  {'cancer_type': ['gists',
#    'cancer',
#    'metastatic',
#    'gastrointestinal stromal tumors',
#    'gastrointestinal stromal tumor'],
#   'biomarker': ['succinate dehydrogenase', 'kit', 'sdh', 'pdgfr']},
#  {'cancer_type': ['cancer', 'tumor', 'subungual melanoma', 'melanoma'],
#   'biomarker': ['kit']},
#  {'cancer_type': ['cancer', 'melanoma', 'stage iv melanoma'],
#   'biomarker': ['braf v600k', 'braf v600ktherapy', 'braf']},
#  {'cancer_type': ['cancer', 'skin melanoma'], 'biomarker': ['v600e', 'braf']},
#  {'cancer_type': ['cancer', 'high grade glioma'], 'biomarker': ['egfr']},
#  {'cancer_type': ['cancer', 'high grade glioma'], 'biomarker': ['egfr']},
#  {'cancer_type': ['cancer', 'high grade glioma'], 'biomarker': ['egfr']},
#  {'cancer_type': ['cancer', 'lung non-small cell carcinoma'],
#   'biomarker': ['egfr']},
#  {'cancer_type': ['cancer', 'lung non-small cell carcinoma'],
#   'biomarker': ['egfr']},
#  {'cancer_type': ['cancer', 'lung non-small cell carcinoma'],
#   'biomarker': ['egfr']},
#  {'cancer_type': ['adenocarcinoma',
#    'tumors',
#    'bronchioloalveolar carcinoma',
#    'cancer type',
#    'lung non-small cell carcinoma',
#    'bac'],
#   'biomarker': ['egfr']},
#  {'cancer_type': ['nsclc',
#    'lung non-small cell carcinoma',
#    'tumors',
#    'cancer'],
#   'biomarker': ['egfr']},
#  {'cancer_type': ['cancer',
#    'adenocarcinoma',
#    'tumors',
#    'bronchioloalveolar carcinoma',
#    'lung cancer',
#    'lung adenocarcinoma'],
#   'biomarker': ['egfr']},
#  {'cancer_type': ['cancer',
#    'stage iv',
#    'lung non-small cell carcinoma',
#    'lung adenocarcinoma'],
#   'biomarker': ['egfr']},
#  {'cancer_type': ['cancer',
#    'stage iv adenocarcinoma',
#    'lung non-small cell carcinoma'],
#   'biomarker': ['egfr']},
#  {'cancer_type': ['cancer',
#    'lung non-small cell carcinoma',
#    'lung adenocarcinoma'],
#   'biomarker': ['egfr']},
#  {'cancer_type': ['cancer',
#    'stage iv',
#    'lung non-small cell carcinoma',
#    'lung adenocarcinoma'],
#   'biomarker': ['egfr']},
#  {'cancer_type': ['cancer'], 'biomarker': ['akt', 'phospho', 'egfr', None]},
#  {'cancer_type': ['cancer', 'lung non-small cell carcinoma'],
#   'biomarker': ['egfr']},
#  {'cancer_type': ['cancer', 'malignant peritoneal mesothelioma'],
#   'biomarker': ['egfr', 'egf']},
#  {'cancer_type': ['cancer', 'lung non-small cell carcinoma'],
#   'biomarker': ['egfr']},
#  {'cancer_type': ['cancer'], 'biomarker': ['yfp', 'egfr']},
#  {'cancer_type': ['cancer', 'lung non-small cell carcinoma'],
#   'biomarker': ['akt', 'egfr', 'erk', 'bim']},
#  {'cancer_type': ['cancer', 'lung non-small cell carcinoma'],
#   'biomarker': ['egfr']},
#  {'cancer_type': ['cancer', 'lung adenocarcinoma'], 'biomarker': ['egfr']},
#  {'cancer_type': ['cancer', 'lung adenocarcinoma'],
#   'biomarker': ['akt', 'egfr', 'erk']},
#  {'cancer_type': ['cancer', 'lung small cell carcinoma'],
#   'biomarker': ['egfr', 'egfrwt']},
#  {'cancer_type': ['lung non-small cell carcinoma',
#    'tumour',
#    'nci-h3255 xenograft',
#    'cancer type'],
#   'biomarker': ['egfr', 'egfrwt']},
#  {'cancer_type': ['cancer', 'high grade glioma'], 'biomarker': ['egfr']},
#  {'cancer_type': ['cancer', 'lung non-small cell carcinoma'],
#   'biomarker': ['egfr']},
#  {'cancer_type': ['cancer', 'high grade glioma'], 'biomarker': ['egfr']},
#  {'cancer_type': ['cancer', 'malignant peritoneal mesothelioma'],
#   'biomarker': ['egfr', 'egf']},
#  {'cancer_type': ['cancer', 'chronic myeloid leukemia'],
#   'biomarker': ['abl1', 'bcr-abl1', 'bcr']},
#  {'cancer_type': ['cancer', 'chronic myeloid leukemia'],
#   'biomarker': ['bcr', 'bcr-abl', 'abl1']},
#  {'cancer_type': ['cancer', 'leukemia', 'nel', 'acute lymphoblastic leukemia'],
#   'biomarker': ['abl1', 'bcr']},
#  {'cancer_type': ['cancer', 'gastrointestinal stromal tumor'],
#   'biomarker': ['kit']},
#  {'cancer_type': ['cancer', 'lung non-small cell carcinoma'],
#   'biomarker': ['egfr']},
#  {'cancer_type': ['cancer', 'colorectal cancer'], 'biomarker': ['arid1a']},
#  {'cancer_type': ['cancer', 'melanoma'], 'biomarker': ['braf']},
#  {'cancer_type': ['cancer', 'melanoma'], 'biomarker': ['mek', 'erk', 'braf']},
#  {'cancer_type': ['cancer', 'lung non-small cell carcinoma'],
#   'biomarker': ['egfr']},
#  {'cancer_type': ['cancer', 'lung non-small cell carcinoma'],
#   'biomarker': ['akt', 'egfr', 'erk', 'bim']},
#  {'cancer_type': ['cancer', 'high grade glioma'],
#   'biomarker': ['egfr viii', 'egfr']},
#  {'cancer_type': ['cancer', 'chronic myeloid leukemia'],
#   'biomarker': ['bcr', 'bcr-abl', 'abl1']},
#  {'cancer_type': ['cancer', 'chronic myeloid leukemia', 'cml'],
#   'biomarker': ['abl1', 'bcr', 'bcr-abl']},
#  {'cancer_type': ['cancer', 'chronic myeloid leukemia'],
#   'biomarker': ['bcr', 'abl1']},
#  {'cancer_type': ['cancer', 'gastrointestinal stromal tumor'],
#   'biomarker': ['kit', 'il3']},
#  {'cancer_type': ['gastrointestinal stromal tumor (',
#    'cancer',
#    'gastrointestinal stromal tumor',
#    'gist',
#    'gistpsies'],
#   'biomarker': ['kit']},
#  {'cancer_type': ['cancer', 'gastrointestinal stromal tumor'],
#   'biomarker': ['kit', 'il3']},
#  {'cancer_type': ['gastrointestinal stromal tumor (',
#    'cancer',
#    'gastrointestinal stromal tumor',
#    'gist',
#    'gistpsies'],
#   'biomarker': ['kit']},
#  {'cancer_type': ['gastrointestinal stromal tumor', 'gist', 'cancer'],
#   'biomarker': ['kit']},
#  {'cancer_type': ['cancer', 'endometrioid ovary carcinoma'],
#   'biomarker': ['brca1']},
#  {'cancer_type': ['gastrointestinal stromal tumor', 'gist', 'cancer'],
#   'biomarker': ['kit']},
#  {'cancer_type': ['gastrointestinal stromal tumor (',
#    'gist',
#    'cancer',
#    'gastrointestinal stromal tumor'],
#   'biomarker': ['kit']},
#  {'cancer_type': ['cancer', 'malignant peritoneal mesothelioma'],
#   'biomarker': ['egfr', 'egf']},
#  {'cancer_type': ['cancer', 'malignant peritoneal mesothelioma'],
#   'biomarker': ['egfr', 'egf']},
#  {'cancer_type': ['cancer', 'malignant peritoneal mesothelioma'],
#   'biomarker': ['egfr', 'egf']},
#  {'cancer_type': ['cancer', 'malignant peritoneal mesothelioma'],
#   'biomarker': ['egfr', 'egf']},
#  {'cancer_type': ['cancer', 'malignant peritoneal mesothelioma'],
#   'biomarker': ['egfr', 'egf']},
#  {'cancer_type': ['cancer type',
#    'bronchioloalveolar carcinoma',
#    'lung adenocarcinoma',
#    'bac',
#    'in situ pulmonary adenocarcinoma'],
#   'biomarker': ['egfr']},
#  {'cancer_type': ['cancer',
#    'stage iv',
#    'lung non-small cell carcinoma',
#    'lung adenocarcinoma'],
#   'biomarker': ['egfr']},
#  {'cancer_type': ['cancer', 'chronic myeloid leukemia'],
#   'biomarker': ['bcr', 'abl1', 'bcr-abl1']},
#  {'cancer_type': ['leukemia', 'chronic myeloid leukemia', 'cancer'],
#   'biomarker': ['abl1', 'bcr']},
#  {'cancer_type': ['nsclc', 'lung non-small cell carcinoma', 'cancer type'],
#   'biomarker': ['egfr']},
#  {'cancer_type': ['lung non-small cell carcinoma',
#    'non-small cell lung cancer',
#    'tumors',
#    'cancer type'],
#   'biomarker': ['l858r', 'egfr']},
#  {'cancer_type': ['lung non-small cell carcinoma',
#    'non-small cell lung cancer',
#    'tumors',
#    'cancer type'],
#   'biomarker': ['l858r', 'egfr']},
#  {'cancer_type': ['cancer', 'lung adenocarcinoma'], 'biomarker': ['egfr']},
#  {'cancer_type': ['cancer',
#    'non-small cell lung cancer',
#    'lung adenocarcinoma'],
#   'biomarker': ['pold1']},
#  {'cancer_type': ['cancer',
#    'non-small cell lung cancer',
#    'lung non-small cell carcinoma'],
#   'biomarker': ['pold1']},
#  {'cancer_type': ['cancer', 'tumors', 'lung adenocarcinoma'],
#   'biomarker': ['met']},
#  {'cancer_type': ['lung non-small cell carcinoma', 'cancer type'],
#   'biomarker': ['abl1']},
#  {'cancer_type': ['cancer', 'lung non-small cell carcinoma'],
#   'biomarker': ['abl1']},
#  {'cancer_type': ['cancer'], 'biomarker': ['kit']},
#  {'cancer_type': ['cancer', 'ovarian clear cell carcinoma'],
#   'biomarker': ['arid1a']},
#  {'cancer_type': ['cancer',
#    'xenograft',
#    'acute myeloid leukemia',
#    'aml xenograft mouse',
#    'aml'],
#   'biomarker': ['idh1', 'idh2']},
#  {'cancer_type': ['nsclc', 'lung non-small cell carcinoma', 'cancer type'],
#   'biomarker': ['alk']},
#  {'cancer_type': ['cancer',
#    'breast cancer',
#    'pancreatic cancers',
#    'ovarian cancers',
#    'small cell lung',
#    'breast',
#    'ewings sarcoma',
#    'ovarian'],
#   'biomarker': ['brca', 'brca1']},
#  {'cancer_type': ['cancer',
#    'breast cancer',
#    'pancreatic cancers',
#    'ovarian cancers',
#    'small cell lung',
#    'breast',
#    'ewings sarcoma',
#    'ovarian'],
#   'biomarker': ['brca2', 'brca']},
#  {'cancer_type': ['cancer', 'breast cancer'],
#   'biomarker': ['erbb2', 'her2', 'her2-receptor']},
#  ...]

# %%
no_cancer_idx = []
no_biomarker_idx = []
for i, e in tqdm(enumerate(context_extracted_entities)):
    if not e['cancer_type']:
        no_cancer_idx.append(i)
    if not e['biomarker']:
        no_biomarker_idx.append(i)

print(f"{len(no_cancer_idx)*100/len(_CONTEXT):.3f}%") #no cancer entity extracted %
print(f"{len(no_biomarker_idx)*100/len(_CONTEXT):.3f}%") #no biomarker entity extracted %
# Out:
# 1569it [00:00, 1617714.60it/s]
# 0.000%
# 0.064%

# %%
#save
os.makedirs("context_retriever/entities", exist_ok=True)
with open(f"context_retriever/entities/civic_db_context_ner_entities__{_VERSION}.json", "w") as f:
    json.dump(context_extracted_entities, f, indent=4)
