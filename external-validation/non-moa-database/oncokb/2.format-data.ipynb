# %%
import pandas as pd 
import numpy as np
import os
from tqdm import tqdm
from glob import glob
import requests
import ast
from bs4 import BeautifulSoup
os.makedirs('formatted-data', exist_ok=True)

# %%
oncokb_df = pd.read_csv('processed-data/oncokb_all.csv')
oncokb_df['cancer_type_raw_text'] = oncokb_df['cancer_type_raw_text'].apply(lambda x: ast.literal_eval(x))
oncokb_df.head(1)
# Out:
#            alterations     drugs approvedIndications    level    fdaLevel  \
# 0  Oncogenic Mutations  Olaparib                 NaN  LEVEL_1  LEVEL_Fda2
#
#   levelAssociatedCancerType  levelExcludedCancerTypes     pmids abstracts  \
# 0      Prostate Cancer, NOS                       NaN  32343890       NaN
#
#                                          description gene change  \
# 0  Olaparib is a PARP inhibitor that is FDA-appro...  ATM   LOSS
#
#                                 cancer_type_raw_text
# 0  {'id': 944, 'code': '', 'color': 'Cyan', 'name...

# %%
oncokb_df[['gene', 'alterations', 'change']].drop_duplicates()
# Out:
#            gene          alterations    change
# 0           ATM  Oncogenic Mutations      LOSS
# 4           ATR  Oncogenic Mutations      LOSS
# 6         BARD1  Oncogenic Mutations      LOSS
# 8         BRCA1  Oncogenic Mutations      LOSS
# 30        BRCA2  Oncogenic Mutations  DELETION
# ..          ...                  ...       ...
# 257      PDGFRA  Oncogenic Mutations       NaN
# 278       FGFR1  Oncogenic Mutations       NaN
# 285         MET              Fusions       NaN
# 288       NTRK3              Fusions       NaN
# 289  ewsr1-fli1    EWSR1-FLI1 Fusion       NaN
#
# [67 rows x 3 columns]

# %%
oncokb_df[oncokb_df['alterations'].str.contains('Oncogenic Mutations')]
# Out:
#              alterations                     drugs approvedIndications  \
# 0    Oncogenic Mutations                  Olaparib                 NaN
# 1    Oncogenic Mutations                  Olaparib                 NaN
# 2    Oncogenic Mutations  Talazoparib,Enzalutamide                 NaN
# 3    Oncogenic Mutations  Talazoparib,Enzalutamide                 NaN
# 4    Oncogenic Mutations  Talazoparib,Enzalutamide                 NaN
# ..                   ...                       ...                 ...
# 280  Oncogenic Mutations               Erdafitinib                 NaN
# 281  Oncogenic Mutations            Lirafugratinib                 NaN
# 282  Oncogenic Mutations              Fexagratinib                 NaN
# 283  Oncogenic Mutations               Erdafitinib                 NaN
# 284  Oncogenic Mutations              Fexagratinib                 NaN
#
#        level    fdaLevel levelAssociatedCancerType  levelExcludedCancerTypes  \
# 0    LEVEL_1  LEVEL_Fda2      Prostate Cancer, NOS                       NaN
# 1    LEVEL_1  LEVEL_Fda2           Prostate Cancer                       NaN
# 2    LEVEL_1  LEVEL_Fda2      Prostate Cancer, NOS                       NaN
# 3    LEVEL_1  LEVEL_Fda2           Prostate Cancer                       NaN
# 4    LEVEL_1  LEVEL_Fda2      Prostate Cancer, NOS                       NaN
# ..       ...         ...                       ...                       ...
# 280  LEVEL_4  LEVEL_Fda3          All Solid Tumors                       NaN
# 281  LEVEL_4  LEVEL_Fda3          All Solid Tumors                       NaN
# 282  LEVEL_4  LEVEL_Fda3          All Solid Tumors                       NaN
# 283  LEVEL_4  LEVEL_Fda3          All Solid Tumors                       NaN
# 284  LEVEL_4  LEVEL_Fda3          All Solid Tumors                       NaN
#
#                  pmids                                          abstracts  \
# 0             32343890                                                NaN
# 1             32343890                                                NaN
# 2             37285865                                                NaN
# 3             37285865                                                NaN
# 4             37285865                                                NaN
# ..                 ...                                                ...
# 280  31088831,32463741                                                NaN
# 281           37270847  https://ascopubs.org/doi/abs/10.1200/JCO.2023....
# 282  31088831,32463741                                                NaN
# 283  31088831,32463741  https://ascopubs.org/doi/10.1200/JCO.2024.42.1...
# 284  31088831,32463741  https://ascopubs.org/doi/10.1200/JCO.2024.42.1...
#
#                                            description   gene change  \
# 0    Olaparib is a PARP inhibitor that is FDA-appro...    ATM   LOSS
# 1    Olaparib is a PARP inhibitor that is FDA-appro...    ATM   LOSS
# 2    Talazoparib, a small molecule PARP inhibitor, ...    ATM   LOSS
# 3    Talazoparib, a small molecule PARP inhibitor, ...    ATM   LOSS
# 4    Talazoparib, a small molecule PARP inhibitor, ...    ATR   LOSS
# ..                                                 ...    ...    ...
# 280  Fexagratinib and erdafitinib are orally availa...  FGFR2    NaN
# 281  Lirafugratinib is an orally available, small m...  FGFR2    NaN
# 282  Fexagratinib and erdafitinib are orally availa...  FGFR2    NaN
# 283  Fexagratinib and erdafitinib are orally availa...  FGFR3    NaN
# 284  Fexagratinib and erdafitinib are orally availa...  FGFR3    NaN
#
#                                   cancer_type_raw_text
# 0    {'id': 944, 'code': '', 'color': 'Cyan', 'name...
# 1    {'id': 936, 'code': '', 'color': 'Cyan', 'name...
# 2    {'id': 944, 'code': '', 'color': 'Cyan', 'name...
# 3    {'id': 936, 'code': '', 'color': 'Cyan', 'name...
# 4    {'id': 944, 'code': '', 'color': 'Cyan', 'name...
# ..                                                 ...
# 280  {'id': 984, 'code': '', 'color': '', 'name': '...
# 281  {'id': 984, 'code': '', 'color': '', 'name': '...
# 282  {'id': 984, 'code': '', 'color': '', 'name': '...
# 283  {'id': 984, 'code': '', 'color': '', 'name': '...
# 284  {'id': 984, 'code': '', 'color': '', 'name': '...
#
# [153 rows x 13 columns]

# %%
#oncotree, raw cancer, modified standardized cancer, raw biomarker, therapy
formatted_df = pd.DataFrame()
formatted_df['level'] = oncokb_df['level']
formatted_df['oncotree'] = oncokb_df['cancer_type_raw_text'].apply(lambda x: x['mainType']['name'])
formatted_df['raw_cancer'] = oncokb_df['cancer_type_raw_text'].apply(lambda x: x['name'] if x['name'] != '' else x['mainType']['name'])
formatted_df['standardized_cancer'] = formatted_df['raw_cancer'].apply(lambda x: x.split(',')[0])
def format_biomarker(x):
    if x['alterations'] == 'Fusions':
        return f"{x['gene']} Fusion"
    if x['alterations'] in ['Amplification', 'Deletion']:
        return f"{x['gene']} {x['change']}"
    if 'Oncogenic Mutations' in x['alterations']:
        if str(x['change']) != 'nan':
            return f"{x['gene']} {x['change']}"
        else:
            return x['gene']
    if ' Fusion' in x['alterations']:
        return x['alterations']
    else:
        return x['gene']
formatted_df['biomarker'] = oncokb_df.apply(lambda x: format_biomarker(x), axis=1)
formatted_df['therapy'] = oncokb_df['drugs']
formatted_df['statement'] = oncokb_df['description']
formatted_df.to_csv('formatted-data/oncokb_all.csv', index = False)
formatted_df.head()
# Out:
#      level              oncotree            raw_cancer standardized_cancer  \
# 0  LEVEL_1  Prostate Cancer, NOS  Prostate Cancer, NOS     Prostate Cancer
# 1  LEVEL_1       Prostate Cancer       Prostate Cancer     Prostate Cancer
# 2  LEVEL_1  Prostate Cancer, NOS  Prostate Cancer, NOS     Prostate Cancer
# 3  LEVEL_1       Prostate Cancer       Prostate Cancer     Prostate Cancer
# 4  LEVEL_1  Prostate Cancer, NOS  Prostate Cancer, NOS     Prostate Cancer
#
#   biomarker                   therapy  \
# 0  ATM LOSS                  Olaparib
# 1  ATM LOSS                  Olaparib
# 2  ATM LOSS  Talazoparib,Enzalutamide
# 3  ATM LOSS  Talazoparib,Enzalutamide
# 4  ATR LOSS  Talazoparib,Enzalutamide
#
#                                            statement
# 0  Olaparib is a PARP inhibitor that is FDA-appro...
# 1  Olaparib is a PARP inhibitor that is FDA-appro...
# 2  Talazoparib, a small molecule PARP inhibitor, ...
# 3  Talazoparib, a small molecule PARP inhibitor, ...
# 4  Talazoparib, a small molecule PARP inhibitor, ...
