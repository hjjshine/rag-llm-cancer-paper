# %%
import pandas as pd 
import numpy as np
import os, sys
from tqdm import tqdm
import warnings
warnings.filterwarnings('ignore')

# %%
while os.getcwd().split('/')[-1] != 'rag-llm-cancer-paper':
    os.chdir('..')

# %% [markdown]
# ### setup biobert

# %%
biobert_dir = "context_retriever/biobert_ner"
#download model from huggingface
from transformers import AutoTokenizer, AutoModelForTokenClassification
model = AutoModelForTokenClassification.from_pretrained("judithrosell/BioBERT_BioNLP13CG_NER_new")
tokenizer = AutoTokenizer.from_pretrained("judithrosell/BioBERT_BioNLP13CG_NER_new")
id2label = model.config.id2label

#save locally
model.save_pretrained(biobert_dir)
tokenizer.save_pretrained(biobert_dir)
# Out:
# ('context_retriever/biobert_ner/tokenizer_config.json',
#  'context_retriever/biobert_ner/special_tokens_map.json',
#  'context_retriever/biobert_ner/vocab.txt',
#  'context_retriever/biobert_ner/added_tokens.json',
#  'context_retriever/biobert_ner/tokenizer.json')

# %%
#load locally
model = AutoModelForTokenClassification.from_pretrained(biobert_dir)
tokenizer = AutoTokenizer.from_pretrained(biobert_dir)
id2label = model.config.id2label

# %% [markdown]
# ### load other libraries

# %%
# !pip install rank_bm25
import json
import pandas as pd
import random
import math
from transformers import AutoTokenizer, AutoModelForTokenClassification
from utils.entity_prediction import extract_entities, db_extract_entities
#version check is for mol almanac
# from utils.check_db_version import get_local_version
# _VERSION=get_local_version()
# print(_VERSION)

def split_ranges(max_int, num_ranges, samples=None, seed=42):
    random.seed(seed)
    step = math.ceil(max_int / num_ranges)
    ranges = [(i*step+1, min((i+1)*step, max_int)) for i in range(num_ranges)]
    
    if samples is None:
        return ranges
    
    # split samples evenly across ranges
    n_per_range = samples // num_ranges
    remainder = samples % num_ranges
    
    result = []
    for i, r in enumerate(ranges):
        count = n_per_range + (1 if i < remainder else 0)
        result.extend(random.randint(r[0], r[1]) for _ in range(count))
    
    return result

# %% [markdown]
# ### context snippets

# %%
structured_db = pd.read_csv('external-validation/non-moa-database/oncokb/oncokb-db/oncokb_core__2025-09.csv')
db = structured_db[['statement_id']]
statements = pd.read_csv('external-validation/non-moa-database/oncokb/oncokb-db/oncokb-draft.dereferenced.unique.context_db.csv')
statement_dict = dict(zip(statements['statement_id'], statements['context']))
db['evidence_statement'] = db['statement_id'].map(statement_dict)
print(db.shape)
db.head(1)
# Out:
# (625, 2)
#    statement_id                                 evidence_statement
# 0             0  Approval level: LEVEL_1\nDatabase: OncoKB\nDes...

# %%
# db = pd.read_csv('external-validation/non-moa-database/civic/civic-db/evidence_statements.csv')
# print(db.shape)
# db.head(1)

# %%
_VERSION = 'oncokb-202509'
_CONTEXT = db.evidence_statement.tolist()
test_ind = split_ranges(len(_CONTEXT), 10, 20)
for i, e in enumerate(_CONTEXT):
    if i in test_ind:
        print(f"======={i}=======")
        print(e)
        print(extract_entities(e, model, tokenizer))
# Out:
# =======8=======
# Approval level: LEVEL_1
# Database: OncoKB
# Description: Dabrafenib, an orally bioavailable RAF inhibitor, and trametinib, an orally bioavailable MEK1/2 inhibitor, are FDA-approved in combination for the treatment of patients with solid tumors other than colorectal harboring BRAF V600E mutation. FDA approval was based on data from 131 adult patients with solid tumors treated with dabrafenib and trametinib in the BRF117019 and NCI-MATCH trials and 36 pediatric patients treated with dabrafenib and trametinib in the CTMT212X2101 study. Of the 131 adult patients treated with dabrafenib and trametinib, the overall response rate was 41% (54/131; 95% CI = 33-50) and of the 36 pediatric patients treated with dabrafenib and trametinib (low-grade glioma, n=34; high-grade glioma, n=2), the overall response rate was 25% (95% CI = 12-24) (PMID: 32818466, 34838156, 32758030)(Abstract: Bouffet et al. Abstract# LGG-49, Neuro-Oncology 2020. https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7715318/). Approval was supported by results in COMBI-d, COMBI-v and BRF113928 studies in melanoma and lung cancer (PMID: 23020132, 25399551, 27283860). In the Phase II ROAR basket trial of dabrafenib + trametinib in patients with BRAF V600E-mutated rare cancers (biliary tract cancer, n=43), the overall response rate was 53%, the median progression-free survival was nine months (95% CI = 5.5, 9.4) and the median overall survival was 13.5 months (95% CI = 10.4, 17.6) (PMID: 37059834). Of the 43 patients with biliary tract cancer, 53% of patients (23/43) had a partial response and 37% (16/43) had stable disease (PMID: 37059834). Additionally, in subprotocol H of the NCI-MATCH basket trial of dabrafenib + trametinib in patients with BRAF V600E-mutant solid tumors (n=4 patients with intrahepatic cholangiocarcinoma), the overall response rate was 100%, with 4/4 patients achieving a partial response (PMID: 32758030).
# Cancer type: Biliary Tract
# Biomarkers: V600E
# Therapy: Dabrafenib,Trametinib
#
# {'cancer_type': ['low-grade glioma', 'solid tumors', 'colorectal', 'lung cancer', 'high-grade glioma', 'melanoma', 'biliary tract cancer'], 'biomarker': ['braf', 'raf', 'combi-', 'mek1 / 2']}
# =======41=======
# Approval level: LEVEL_1
# Database: OncoKB
# Description: Elacestrant is an oral, estrogen receptor antagonist FDA-approved for the treatment of postmenopausal adult patients with ER+/HER2-, ESR1-mutated advanced or metastatic breast cancer. In a randomized, open-label Phase III EMERALD trial of elacestrant versus standard-of-care endocrine monotherapy in 477 patients with ER+/HER2- advanced breast cancer who had received one or two lines of endocrine therapy (n=228 patients with ESR1 missense mutations in codons 310-547), the ESR1-mutated cohort had a six-month progression free-survival (PFS) of 40.8% (95% CI=30.1, 51.4) versus 19.1% (95% CI=10.5, 27.8) and a twelve-month progression-free survival of 26.8% (95% CI=16.2, 37.4) versus 8.2% (95% CI=1.3, 15.1) for the elacestrant versus standard-of-care arm, respectively (PMID: 35584336). In the updated results from the Phase III EMERALD trial based on the duration of prior CDK4/6i treatment, the ESR1-mutated cohort previously treated with CDK4/6i for ≥6.0 months (n=103 elacestrant arm; n=102 stand-of-care arm), ≥12.0 months (n=78 elacestrant arm; n=81 stand-of-care arm) or ≥18.0 months (n=55 elacestrant arm; n=56 stand-of-care arm) demonstrated a median PFS of 4.1 months, 8.6 months and 8.6 months with elacestrant versus 1.9 months (HR=0.52 [95% CI=0.36, 0.74]), 1.9 months (HR=0.41 [95% CI=0.26, 0.63]) and 2.1 months (HR=0.47 [95% CI=0.20, 0.79]) with standard-of-care treatment (Abstract: Bardia et al. Abstract# GS3-01, SABCS 2022. https://aacrjournals.org/cancerres/article/83/5_Supplement/GS3-01/717784/Abstract-GS3-01-GS3-01-EMERALD-phase-3-trial-of).
# Cancer type: Breast Cancer
# Biomarkers: E380,S463P,Y537,L536,L469V,D538
# Therapy: Elacestrant
#
# {'cancer_type': ['breast cancer'], 'biomarker': ['estrogen receptor', 'er', 'her2', 'esr1']}
# =======65=======
# Approval level: LEVEL_1
# Database: OncoKB
# Description: Tepotinib is a small molecule inhibitor of the MET tyrosine kinase that is FDA-approved for adult patients with metastatic non-small cell lung cancer (NSCLC) harboring MET exon 14 skipping alterations. FDA approval was based on results of the non-randomized, open-label Phase II VISION trial of 152 patients with advanced or metastatic NSCLC with MET exon 14 skipping alterations in which the overall response rate was 43% and the median duration of response was 10.8 months (95% CI= 6.9-NE) in treatment-naive patients and 11.1 months (95% CI= 9.5-18.5) in patients who had been previously treated (PMID: 32469185). The long-term follow-up analysis of the Phase II VISION trial with cohort A (>35 months’ follow-up; n=152) and cohort C (>18 months' follow-up; n=161) demonstrated an objective response rate of 51.4% (95% CI= 45.8%-57.1%) and a median duration of response of 18.0 months (95% CI= 12.4-46.4) across treatment lines (PMID: 37270698).
# Cancer type: Non-Small Cell Lung Cancer
# Biomarkers: Exon 14 in-frame deletions,Exon 14 Deletion,D1010,Exon 14 splice mutations
# Therapy: Tepotinib
#
# {'cancer_type': ['cancer', 'non-small cell lung cancer', 'nsclc'], 'biomarker': ['met tyrosine kinase', 'met', 'level']}
# =======111=======
# Approval level: LEVEL_2
# Database: OncoKB
# Description: Ado-trastuzumab emtansine (T-DM1) is an antibody-drug conjugate in which an ERBB2-directed monoclonal antibody is conjugated to DM1, a microtubule-inhibitory agent. The NCCN lists ado-trastuzumab emtansine as another recommended therapy for patients with NSCLC harboring ERBB2 mutations. In the lung cancer cohort of a Phase II basket trial of T-DM1 in patients with ERBB2-mutant solid tumors, 44% (95% CI=22%-69%) of eighteen patients had a partial response, with a median progression-free survival of five months (95% CI=3-9) (PMID: 29989854). Of the eight patients who had a partial response, four had been treated with prior anti-HER2 therapy, and all eight had one of the following ERBB2 mutations: A775_G776insYVMA, G778_P780dup, G776_V777insVCV, V659E or S310F (PMID: 29989854). Responses to T-DM1 have also been seen in patients with ERBB2-amplified non-small cell lung cancer (NSCLC) (PMID: 30206164). The addition of poziotinib may enhance the response of patients with NSCLC to T-DM1 (PMID: 31588020).
# Cancer type: Non-Small Cell Lung Cancer
# Biomarkers: Oncogenic Mutations
# Therapy: Ado-Trastuzumab Emtansine
#
# {'cancer_type': ['cancer type', 'non-small cell lung cancer', 'solid tumors', 'lung cancer', 'nsclc'], 'biomarker': ['erbb2']}
# =======142=======
# Approval level: LEVEL_2
# Database: OncoKB
# Description: Ripretinib is a small molecule inhibitor of KIT and PDGFRA kinases that is FDA-approved for adult patients with advanced gastrointestinal stromal tumors (GIST) who have received prior treatment with three or more kinase inhibitors. FDA approval was based on the results of the international, multi-center, randomized (2:1), double-blind, placebo-controlled trial (NCT03353753) of ripretinib in 129 patients with advanced, pretreated GIST in which the overall response rate was 9% (95% CI= 4.2, 18), the median progression-free survival was 6.3 months (95% CI= 4.6, 6.9), and the median overall survival was 15.1 months (95% CI= 12.3, 15.1) (PMID: 32511981).
# Cancer type: Gastrointestinal Stromal Tumor
# Biomarkers: Oncogenic Mutations
# Therapy: Ripretinib
#
# {'cancer_type': ['gastrointestinal stromal tumor', 'cancer', 'gastrointestinal stromal tumors', 'gist'], 'biomarker': ['pdgfra', 'kit']}
# =======144=======
# Approval level: LEVEL_2
# Database: OncoKB
# Description: Dostarlimab is a humanized monoclonal antibody that targets PD-1 and is FDA-approved for patients with advanced or recurrent solid tumors that are mismatch repair deficient (dMMR) as determined by an FDA-approved companion diagnostic, the Ventana MMR RxDx Panel. Dostarlimab is also recommended in the Colon Cancer NCCN Guidelines (v2.2024) as a treatment option for patients with dMMR and microsatellite instability-high (MSI-H) or POLE/POLD1 mutant metastatic colon cancer (mCRC). In a retrospective, multinational study of patients with metastatic colorectal cancer (CRC) treated with anti-PD-L1 inhibitors alone or in combination with anti-CTLA-4 inhibitors, patients with POLE/D1 pd tumors (n=27) had significantly improved outcomes compared to patients with dMMR/MSI-H CRC (n=610), with overall response rates (ORRs) of 89% versus 54%, progression-free survival (PFS) rates at two years of 88% versus 60%, and overall survival (OS) rates at two years of 86% versus 72%, respectively (PMID: 38777726). In a pan-cancer study of patients with MSI-stable/low tumors treated with anti-PD-1/anti-PDL-1 inhibitors, patients with functional POLE/D1 mutations (n=24) had a clinical benefit rate of 75% versus 30% for patients with POLE/D1 wildtype tumors (n=1038) (PMID: 35817971). The NCCN recommendation is based on the results of the non-randomized, open-label, multicenter, multicohort Phase I GARNET (NCT02715284) trial of dostarlimab in patients with dMMR, MSI-H and/or POLE-altered (exonuclease domain) recurrent or advanced solid tumors (N=347) who progressed following systemic therapy. In this study, the blinded independent central review (BICR) ORR was 44.1% (95% CI=38.8–49.5) and the median PFS was 7.0 months (95% CI=4.2–13.8) (PMID: 37917058). Patients with CRC (n=115) demonstrated an ORR of 43.5 (95% CI= 34.3–53.0) with fourteen complete responses (12.2%), 36 partial responses (31.3%) and a median PFS of 8.4 months (95% CI= 3.4–not reached) (PMID: 37917058). In eleven patients with POLE-altered solid tumors, the ORR was 54.5% (95% CI=23.4–83.3) and the median PFS was 19.5 months (95% CI=1.2–not reached) (PMID: 37917058). Three of six patients with mismatch repair proficient/POLE-altered tumors achieved a response, one of which achieved a complete response, and three of five patients with dMMR/POLE-altered tumors achieved a response (PMID: 37917058).
# Cancer type: Colorectal Cancer
# Biomarkers: D402N,L474P,S478N,E318K
# Therapy: Dostarlimab
#
# {'cancer_type': ['crc', 'solid tumors', 'colorectal cancer', 'metastatic', 'tumors', 'colon cancer', 'mcrc'], 'biomarker': ['pole-altered', 'anti-pd-l1', 'anti-pd-1', 'anti-ctla-4', 'pd-1', 'anti-pdl-1', 'pole', 'pole / d1']}
# =======198=======
# Approval level: LEVEL_3A
# Database: OncoKB
# Description: Adagrasib is a covalent inhibitor of KRAS G12C that is FDA-approved for patients with KRAS G12C-mutated non-small cell lung cancer. In a phase II trial (KRYSTAL-1, NCT03785249) of adagrasib in 30 patients with previously treated, inoperable, or metastatic KRAS G12C-mutant gastrointestinal cancers excluding colorectal cancer, ​​preliminary data demonstrated a 100% disease control rate in 27 evaluable patients (Abstract: Bekaii-Saab et al. Abstract# 519, ASCO GI Symposium, 2022. https://ascopubs.org/doi/abs/10.1200/JCO.2022.40.4_suppl.519). After a median of 6.3 months, four of eight patients with biliary tract cancer, one patient with gastroesophageal junction cancer, and one with small bowel cancer had partial responses, and all other evaluable patients with GI cancers developed stable disease (Abstract: Bekaii-Saab et al. Abstract# 519, ASCO GI Symposium, 2022. https://ascopubs.org/doi/abs/10.1200/JCO.2022.40.4_suppl.519). In a preclinical setting, seventeen of 26 (65%) KRAS G12C-positive cell line and patient-derived xenograft models from multiple tumor types that were treated with adagrasib resulted in tumor regression (PMID: 31658955). Furthermore, case reports of patients with KRAS G12C-positive lung and colon adenocarcinomas have also reported objective responses to adagrasib (PMID: 31658955).
# Cancer type: Tubular Adenoma of the Colon
# Biomarkers: G12C
# Therapy: Adagrasib
#
# {'cancer_type': ['tumor types', 'non-small cell lung cancer', 'small bowel cancer', 'lung', 'cancer type', 'colorectal cancer', 'tubular adenoma of', 'tumor', 'gastrointestinal cancers', 'biliary tract cancer', 'gastroesophageal junction cancer', 'gi cancers', 'colon adenocarcinomas', 'xenograft'], 'biomarker': ['kras g12c', 'g12c']}
# =======204=======
# Approval level: LEVEL_3A
# Database: OncoKB
# Description: Tepotinib, capmatinib and crizotinib are MET tyrosine kinase inhibitors (TKIs) that are FDA-approved (capmatinib and tepotinib) or NCCN-listed (crizotinib) for use in patients with non-small cell lung cancers (NSCLC) harboring MET exon 14 skipping mutations. While it is well established in vitro that mutations at MET Y1003 abrogate Cbl-mediated ubiquitination and downregulation, the same mechanism by which exon 14 skipping mutations are transforming, Y1003 mutations are not exon 14 skipping and are therefore not covered by the FDA-approval or the NCCN-listing of MET TKIs. One patient with MET Y1003S-mutant NSCLC had a partial response upon treatment with crizotinib (PMID: 27343443, 30885356, 25971938, 15123609, 25079552, 16397241, 16227611, 11741535)
# Cancer type: Non-Small Cell Lung Cancer
# Biomarkers: Y1003
# Therapy: Capmatinib
#
# {'cancer_type': ['cancer type', 'non-small cell lung cancer', 'non-small cell lung cancers', 'nsclc'], 'biomarker': ['y1003', 'met tyrosine kinase', 'met', 'cbl', 'level']}
# =======259=======
# Approval level: LEVEL_R1
# Database: OncoKB
# Description: Imatinib is a tyrosine kinase inhibitor of BCR-ABL that is NCCN-listed and FDA-approved for adult patients with relapsed or refractory Ph+ acute lymphoblastic leukemia (ALL). In a study of 297 evaluable Ph+ leukemia patients with evidence of hematologic or cytogenetic resistance to imatinib, amino acid substitutions at seven residues in the ABL kinase domain (KD) including E255K/V (n=21, 17%), Y253F/H (n=17, 13%), F359V/I (n=14, 11%), and G250E (n=13, 10%), accounted for the majority of all resistance-associated mutations (PMID: 17189410). In a retrospective study of 26 evaluable newly diagnosed elderly patients with Ph+ ALL who enrolled in the German Multicenter Study Group for Adult Acute Lymphoblastic Leukemia (GMALL) trial ADE10, BCR-ABL KD mutations were found in 21/26 patients (84%), including G250E (n = 5/21), Y253H (n = 2/21), E255K/V (n = 4/21), and F317L (n = 1/21) (PMID: 17405907). Upon sequencing the bone marrow of nine patients with Ph+ ALL who were treated with STI571 (imatinib) and developed resistance, 6/9 patients harbored the E255K mutation, which is located within the motif important for forming the pocket of the ATP-binding site in ABL (PMID: 11861307).
# Cancer type: B-Lymphoblastic Leukemia/Lymphoma
# Biomarkers: V299L,Y253H,F359C,F317I,F317C,F359I,T315A,F317V,E255K,E255V,F317L,F359V,G250E
# Therapy: Imatinib
#
# {'cancer_type': ['b-lymphoblastic leukemia', 'lymphoma', 'ph + acute lymphoblastic leukemia', 'all', 'adult acute lymphoblastic leukemia', 'cancer', 'ph'], 'biomarker': ['abl', 'bcr-abl']}
# =======300=======
# Approval level: LEVEL_R2
# Database: OncoKB
# Description: Osimertinib is an orally available, small molecule EGFR tyrosine kinase inhibitor (TKI) for EGFR T790M that is FDA-approved for adult patients with locally advanced or metastatic non-small cell lung cancer (NSCLC) whose tumors have EGFR exon 19 deletions or exon 21 L858R mutations and for adult patients with metastatic EGFR T790M mutation-positive NSCLC whose disease has progressed on or after EGFR TKI therapy, as detected by an FDA-approved test. EGFR mutational status was identified through the cobas EGFR Mutation Test. The EGFR L718Q mutation has been identified in eight patients with NSCLC following disease progression on osimertinib, with seven patients harboring either EGFR L858R and T790M or EGFR exon 19 deletion and T790M and one patient harboring only EGFR L858R (PMID: 27257132, 29506987, 33937055, 31205925, 31315676, 34926262, 31315676, 32146032). Preclinical studies with cells expressing EGFR L858R or exon 19 deletion, T790M and L718Q demonstrate resistance to osimertinib as measured by IC50 values comparable to cells expressing the control EGFR C797S (PMID: 29506987). Structural models demonstrate that EGFR L718Q is located in the ATP binding site of the kinase domain and is predicted to interfere with drug binding (PMID: 29506987).
# Cancer type: Non-Small Cell Lung Cancer
# Biomarkers: L718Q
# Therapy: Osimertinib
#
# {'cancer_type': ['cancer type', 'non-small cell lung cancer', 'tumors', 'nsclc'], 'biomarker': ['egfr', 'l718q', 'egfr tyrosine kinase']}
# =======359=======
# Approval level: LEVEL_1
# Database: OncoKB
# Description: Selpercatinib is a small molecule kinase inhibitor of the RET tyrosine kinase receptor that is FDA-approved for adult and pediatric patients two years of age and older with advanced or metastatic medullary thyroid cancer (MTC) with a RET mutation who require systemic therapy, who are radioactive iodine-refractory or who have progressed on or following prior systemic treatment. FDA approval was based on the results of the Phase I/II LIBRETTO-001 (NCT03157128) and Phase I/II LIBRETTO-121 (NCT03899792) trials of selpercatinib in adult and pediatric patients with advanced RET fusion-positive MTC. In the Phase I/II LIBRETTO-001 (NCT03157128) trial of selpercatinib in 19 patients with RET fusion-positive thyroid cancer (n=9, CCDC6-RET fusion; n=6, NCOA4-RET fusion; n=4, other RET fusion), the independently reviewed objective response rate (ORR) was 79% (95% CI=54-94), with a 5% (n=1) complete response (CR) rate, 74% (n=14) partial response (PR) rate and 21% (n=4) stable disease rate, the one-year progression-free survival (PFS) rate was 64.4% (95% CI=33.0-80.6) and the median duration of response (DOR) was 18.4 months (95% CI=7.6-NE) (PMID: 32846061). In the Phase I/II LIBRETTO-121 (NCT03899792) trial of selpercatinib in 27 pediatric and adolescent patients with RET-altered solid tumors (n=14, RET-mutant MTC; n=10, RET fusion-positive papillary thyroid cancer; n=3, other), in the overall cohort the blinded independent review committee ORR was 48% (95% CI=28-69) and the median DOR rate was not reached (95% CI=NE-NE), with 92% of responders remaining in response at twelve months (Abstract: Morgenstern, DA. et al. Abstract# 10022, ASCO 2024. https://ascopubs.org/doi/10.1200/JCO.2024.42.16_suppl.10022). Of the RET fusion-positive thyroid cancer patients, the ORR was 60% (95% CI=26-88), with a 30% CR rate and 30% PR rate, and the median DOR rate was not reached (95% CI=NE-NE), with 83% of responders remaining in response at twelve months (Abstract: Morgenstern, DA. et al. Abstract# 10022, ASCO 2024. https://ascopubs.org/doi/10.1200/JCO.2024.42.16_suppl.10022). In the long-term efficacy analysis of the Phase I/II LIBRETTO-001 (NCT03157128) trial in 324 patients with RET-mutant medullary thyroid cancer and 66 patients with RET fusion-positive thyroid cancer, patients with treatment-naïve thyroid cancer demonstrated an ORR of 95.8% (95% CI=78.9-99.9), with a 20.8% (n=5) CR rate, 75% (n=18) PR rate and 4.2% (N=1) SD rate, a median PFS that was not reached (95% CI=44.2-NE), three-year PFS rate of 87.3% (95% CI=56.-96.8) and a three-year overall survival rate of 94.4% (95% CI=66.6-99.2) (PMID: 39094065).
# Cancer type: Thyroid Cancer
# Biomarkers: Fusions
# Therapy: Selpercatinib
#
# {'cancer_type': ['mtc', 'medullary thyroid cancer', 'solid tumors', 'papillary thyroid cancer', 'thyroid cancer'], 'biomarker': ['ccdc6', 'ret', 'ncoa4', 'ret tyrosine kinase']}
# =======363=======
# Approved indication: Crizotinib is FDA approved for the treatment of patients with metastatic non-small cell lung cancer (NSCLC) whose tumors are ROS1-positive.
# Approval level: LEVEL_1
# Database: OncoKB
# Description: Crizotinib, an inhibitor of ALK, ROS1 and MET tyrosine kinases, is FDA-approved for the treatment of patients with metastatic non-small cell lung cancer (NSCLC) whose tumors are ROS1-positive. FDA approval is based on the results of a Phase I trial of crizotinib in 53 patients with advanced NSCLC positive for ROS1 rearrangements in which the objective response rate was 72% (95% CI= 58-84), including six complete responses, 32 partial responses (66%) and a median progression-free survival (PFS) of 19.3 months (95% CI= 15.2-39.1)(PMID: 25264305, 30980071). In a Phase II trial of crizotinib in 127 East Asian patients with ROS1-positive NSCLC, the overall response rate was 71.1% (95% CI= 63.0-79.3), including seventeen of 127 patients with complete responses (13.4%), 74 of 127 patients with partial responses (58.3%), and a median PFS of 15.9 months (95% CI= 12.9-24.0) (PMID: 29596029).
# Cancer type: Non-Small Cell Lung Cancer
# Biomarkers: Fusions
# Therapy: Crizotinib
#
# {'cancer_type': ['non-small cell lung cancer', 'metastatic', 'cancer', 'tumors', 'nsclc'], 'biomarker': ['ros1', 'met', 'alk']}
# =======413=======
# Approval level: LEVEL_3A
# Database: OncoKB
# Description: Seribantumab is a monoclonal antibody against the HER3 protein that targets NRG1 signaling. In the Phase II CRESTONE trial of seribantumab in NRG1 fusion-positive solid tumors, the overall response rate in patients with non-small cell lung cancer (NSCLC; n=11) was 36%, with two of eleven patients achieving a complete response, two of eleven patients achieving a partial response, and seven of eleven patients achieving stable disease (Abstract: Carrizosa et al. Abstract# 3006, ASCO 2022. https://ascopubs.org/doi/abs/10.1200/JCO.2022.40.16_suppl.3006). For the NSCLC cohort, the disease control rate was 91% (Abstract: Carrizosa et al. Abstract# 3006, ASCO 2022. https://ascopubs.org/doi/abs/10.1200/JCO.2022.40.16_suppl.3006).
# Cancer type: Non-Small Cell Lung Cancer
# Biomarkers: Fusions
# Therapy: Seribantumab
#
# {'cancer_type': ['cancer type', 'non-small cell lung cancer', 'solid tumors', 'nsclc'], 'biomarker': ['nrg1', 'her3']}
# =======436=======
# Approval level: LEVEL_1
# Database: OncoKB
# Description: Olaparib is a PARP inhibitor that is FDA-approved for patients with deleterious or suspected deleterious germline or somatic homologous recombination repair (HRR) gene-mutated metastatic castration-resistant prostate cancer (mCRPC), who have progressed following prior treatment with enzalutamide or abiraterone. FDA approval was based on the results of the Phase III PROfound trial of olaparib in adult patients with metastatic castration-resistant prostate cancer who had disease progression while receiving a new hormonal agent and who had a deleterious or suspected deleterious mutation in a homologous recombination repair (HRR) gene. Of patients with a qualifying alteration in an HRR gene, the progression-free survival in the olaparib group was 5.8 months compared to 3.5 months in the placebo group (HR=0.49; 95% CI= 0.38 to 0.63; p<0.001), with a median overall survival of 17.5 months versus 14.3 months (HR=0.67; 95% CI= 0.49 to 0.93) and an overall response rate of 22% versus 4%, respectively (PMID: 32343890). However, while the FDA approval includes those with BARD1 mutations, there is limited clinical data in patients with this biomarker (n=1)(PMID: 32343890).
# Cancer type: Prostate Cancer, NOS
# Biomarkers: Oncogenic Mutations
# Therapy: Olaparib
#
# {'cancer_type': ['metastatic castration-resistant prostate cancer', 'mcrpc', 'prostate cancer', 'cancer'], 'biomarker': ['parp', 'bard1']}
# =======447=======
# Approval level: LEVEL_1
# Database: OncoKB
# Description: Rucaparib is an orally available, small-molecule PARP inhibitor that is FDA-approved for the treatment of adult patients with a deleterious BRCA mutation (germline and/or somatic)-associated metastatic castration-resistant prostate cancer (mCRPC), as detected by an FDA-approved companion diagnostic, who have been treated with androgen receptor-directed therapy and a taxane-based chemotherapy. BRCA1 mutations for treatment with rucaparib were detected by the FoundationOne Liquid CDx. FDA approval was based on the results of the Phase II TRITON2 (NCT02952534) trial of rucaparib in 62 eligible patients with pre-treated BRCA-mutated mCRPC.
# In the Phase II TRITON2 (NCT02952534) trial, the objective response rate was 44% (95% CI=31-57), with fifteen of 27 (56%) patients with a confirmed objective response demonstrating a duration of response of ≥6 months (PMID: 32795228).
# Cancer type: Prostate Cancer
# Biomarkers: Oncogenic Mutations
# Therapy: Rucaparib
#
# {'cancer_type': ['castration-resistant prostate cancer', 'cancer', 'mcrpc', 'prostate cancer'], 'biomarker': ['brca1', 'parp', 'androgen', 'brca']}
# =======479=======
# Approval level: LEVEL_1
# Database: OncoKB
# Description: Olaparib, a small molecule PARP inhibitor, is FDA-approved for patients with deleterious or suspected deleterious germline or somatic homologous recombination repair (HRR) gene-mutated metastatic castration-resistant prostate cancer (mCRPC) who have progressed following prior treatment with enzalutamide or abiraterone. FDA approval was based on the results of the Phase III PROfound trial of olaparib in adult patients with metastatic castration-resistant prostate cancer who had disease progression while receiving a new hormonal agent and who had a deleterious or suspected deleterious mutation in a homologous recombination repair (HRR) gene. Of patients with a qualifying alteration in an HRR gene, the progression-free survival in the olaparib group was 5.8 months compared to 3.5 months in the placebo group (HR=0.49; 95% CI=0.38 to 0.63; p<0.001), with a median overall survival of 17.5 months versus 14.3 months (0.67; 95% CI=0.49 to 0.93) and an overall response rate of 22% versus 4%, respectively (PMID: 32343890). However, while the FDA approval includes those with BRIP1 mutations, there is limited clinical data in patients with this biomarker (n=3)(PMID: 32343890).
# Cancer type: Prostate Cancer, NOS
# Biomarkers: Oncogenic Mutations
# Therapy: Olaparib
#
# {'cancer_type': ['metastatic castration-resistant prostate cancer', 'mcrpc', 'prostate cancer', 'cancer'], 'biomarker': ['parp', 'brip1']}
# =======507=======
# Approval level: LEVEL_1
# Database: OncoKB
# Description: Talazoparib, a small molecule PARP inhibitor, is FDA-approved in combination with enzalutamide for the treatment of select patients with FANCA-mutant metastatic castration-resistant prostate cancer (mCRPC). FDA approval was based on the results of the Phase III TALAPRO-2 trial of talazoparib plus enzalutamide in adult patients with asymptomatic or mildly symptomatic mCRPC harboring homologous recombination repair (HRR) gene alterations receiving ongoing androgen deprivation therapy. Of patients with HRR gene mutations (n=399), the radiographic progression-free survival in the talazoparib plus enzalutamide group (n=200) was not evaluable (95% CI=21.9, NE) compared to 13.8 months (95% CI=11.0, 16.7) in the placebo plus enzalutamide group (n=199) (HR=0.45; 95% CI=0.33, 0.61), with a 2-sided p-value of <0.0001 (PMID: 37285865). Hazard ratios and p-values were not calculated for patients harboring FANCA mutations as the number of patients per treatment group was too small for evaluation (PMID: 37285865).
# Cancer type: Prostate Cancer
# Biomarkers: Oncogenic Mutations
# Therapy: Talazoparib,Enzalutamide
#
# {'cancer_type': ['castration-resistant prostate cancer', 'cancer', 'mcrpc', 'prostate cancer'], 'biomarker': ['parp', 'fanca']}
# =======532=======
# Approved indication: Everolimus is FDA-approved for the treatment of pediatric and adult patients with tuberous sclerosis complex (TSC) who have subependymal giant cell astrocytoma (SEGA) that requires therapeutic intervention but cannot be curatively resected.
# Approval level: LEVEL_1
# Database: OncoKB
# Description: Everolimus is a small molecule inhibitor of mTOR and is FDA-approved for pediatric and adult patients with tuberous sclerosis complex (TSC) who have subependymal giant cell astrocytoma (SEGA) that requires therapeutic intervention but cannot be curatively resected. FDA approval is based on the results of a Phase III clinical trial of everolimus in patients with SEGA associated with TSC in which 35% of patients receiving everolimus (27 of 78 patients) experienced a reduction of at least 50% in the total volume of all targetable SEGAs versus no patients in the placebo group (PMID: 23158522). Patients in the everolimus group responded to the drug irrespective of whether they had a TSC1 or TSC2 mutation, although a higher percentage of patients with TSC1 mutations responded (five of ten patients, 50%) compared to those with TSC2 mutations (sixteen of 55 patients, 29%) (PMID: 23158522). In the Phase II PNOC001 trial of everolimus for 65 patients with progressive/recurrent pediatric low-grade glioma, PI3K/AKT/mTOR pathway activation did not correlate with clinical outcomes as the median progression-free survival in active pathways was 11.2 months versus 11.1 months in non active pathways (P = 0.80) (PMID: 37978951).
# Cancer type: Encapsulated Glioma
# Biomarkers: Oncogenic Mutations
# Therapy: Everolimus
#
# {'cancer_type': ['glioma', 'tsc', 'subependymal giant cell astrocytoma', 'cancer', 'segas', 'tuberous sclerosis complex', 'sega'], 'biomarker': ['pi3k', 'mtor', 'tsc1', 'tsc2', 'akt']}
# =======569=======
# Approval level: LEVEL_3A
# Database: OncoKB
# Description: Cetuximab and panitumumab are orally available anti-EGFR monoclonal antibodies that are FDA-approved for patients with EGFR-expressing, RAS-wildtype colorectal cancer. In a retrospective analysis, patients with EGFR-amplified gastroesophageal adenocarcinoma (GEA) treated with EGFR inhibitors (n=60) (cetuximab [n=27; 45%], ABT-806 [n=13; 22%], panitumumab [n=10; 17%], gefitinib [n=5; 8%], erlotinib [n=3; 5%], cetuximab plus afatinib [n=1; 2%] and cetuximab plus erlotinib [n=1; 2%]) were analyzed across treatment lines, and their outcomes compared to patients with EGFR-amplified GEA treated with non-EGFR inhibitor therapies (PMID: 35349370). Patients treated with EGFR inhibitors across treatments lines (n=56) demonstrated an objective response rate of 43% (24/56) and a median progression-free survival (PFS) of 4.6 months (95% CI=3.5, 6.4) (PMID: 35349370). Among the responders (n-24), 57% (16/28) of patients received concurrent chemotherapy and 29% (8/28) of patients were treated with EGFR inhibitors alone. Patients treated with EGFR inhibitors as a first-line therapy demonstrated a median PFS of 20.6 months (95% CI=13.5, NR), whereas patients treated with non-EGFR inhibitors as a first-line therapy demonstrated a median PFS of 11.2 months (95% CI=8.7, 14.2; this data was taken from the Flatiron Health-Foundation Medicine clinicogenomic database) (PMID: 35349370). In the Phase III EXPAND trial of cetuximab plus capecitabine-cisplatin chemotherapy in patients with advanced GEA, patients with the top 3% EGFR expression based on EGFR IHC (≥220) treated with cetuximab plus capecitabine-cisplatin chemotherapy demonstrated a median PFS of 7.5 months and a median overall survival (OS) of 19.9 months whereas the placebo plus capecitabine-cisplatin chemotherapy arm demonstrated a median PFS of 4.1 months (HR=0.29 [95% CI=0.09, 0.96]) and a median OS of 8.6 months (HR=0.39 [95% CI=0.12, 1.25]) (PMID: 23594786). In the Phase III REAL3 trial of panitumumab plus epirubicin, oxaliplatin and capecitabine in patients with previously untreated advanced GEA, patients with EGFR:CNTNAP2 copy number ratio ≥5 based on EGFR FISH were treated with panitumumab plus epirubicin, oxaliplatin and capecitabine demonstrated a median PFS of 2.3 months and a median OS of 5.69 months whereas the placebo plus epirubicin, oxaliplatin and capecitabine arm demonstrated a median progression-free survival of 4.57 months (HR=2.19 [95% CI=0.8, 6.01]) and a median OS of 10.53 months (HR=1.26 [95% CI=0.46, 3.44]) (PMID: 23594787).
# Cancer type: Esophagogastric Cancer
# Biomarkers: Amplification
# Therapy: Cetuximab
#
# {'cancer_type': ['gea', 'gastroesophageal adenocarcinoma', 'colorectal cancer'], 'biomarker': ['ras', 'egfr']}
# =======573=======
# Approval level: LEVEL_3A
# Database: OncoKB
# Description: Trastuzumab deruxtecan (T-DXd) is an intravenously infused, HER2-targeted antibody and topoisomerase inhibitor conjugate that is FDA-approved for the treatment of adult patients with unresectable or metastatic HER2-positive (defined as immunohistochemistry (IHC) 3+) solid tumors who have received prior systemic treatment and have no satisfactory alternative treatment options. FDA approval was based on the results of the Phase II DESTINY-PanTumor02 (NCT04482309), DESTINY-Lung01 (NCT03505710) and DESTINY-CRC02 (NCT04744831) trials of T-DXd in patients with HER2-positive (defined by IHC 3+) solid tumors. Since the correlation between ERBB2 amplification and HER2 expression has yet to be defined in many solid tumor types and this FDA approval directly specifies HER2-positivity (IHC 3+) as the patient selection criteria, ERBB2 amplification is considered a Level 3A biomarker for this specific indication. In the Phase II DESTINY-PanTumor02 (NCT04482309) trial of T-DXd in 111 patients with HER2-expressing (IHC 3+/2+ by local or central testing) solid tumors, the overall response rate (ORR) was 51.4% (95% CI=41.7-61.0), with a 2.7% complete response (CR) rate and 48.6% partial response (PR) rate, and the median duration of response (DOR) was 19.4 months (range 1.3 months to 27.9+ months) (PMID: 37870536). In the Phase II DESTINY-Lung01 (NCT03505710) trial of T-DXd in seventeen patients with HER2-overexpressing (IHC 3+/2+) non-small cell lung cancer, the ORR was 52.9% (95% CI=27.8-77.0), with a 5.9% CR rate and 47.1% PR rate, and the median DOR was 6.9 months (range 4.0 months to 11.7+ months) (PMID: 38547891). In the Phase II DESTINY-CRC02 (NCT04744831) trial of T-DXd in 64 patients with HER2-expressing (IHC 3+, IHC 2+/in situ hybridization [ISH]+ or IHC 2+/ISH-) metastatic colorectal cancer, the ORR was 46.9% (95% CI=34.3-59.8), with a 46.9% PR rate, and the median DOR was 5.5 months (range 1.3+ months to 9.7+ months) (PMID: 37286557). In the Phase II HERB trial of T-DXd in 22 patients with HER2-positive (IHC3+ or IHC2+/ISH+) biliary tract cancer, the ORR was 36.4% (95% CI=17.2-59.3), with a 9.1% (n=2) CR rate, 27.3% (n=6) PR rate and 45.5% (n=10) SD rate (PMID: 39102634).
# Cancer type: All Solid Tumors
# Biomarkers: Amplification
# Therapy: Trastuzumab Deruxtecan
#
# {'cancer_type': ['non-small cell lung cancer', 'solid tumor', 'solid tumors'], 'biomarker': ['her2', 'erbb2']}

# %%
#run BioBert NER on all contexts
context_extracted_entities = []
for ctx in tqdm(_CONTEXT):
    context_extracted_entities.append(extract_entities(ctx, model, tokenizer))
context_extracted_entities
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# 100%|██████████| 625/625 [01:22<00:00,  7.53it/s]
# [{'cancer_type': ['cancer',
#    'lymphoma',
#    'ph + all',
#    'b-lymphoblastic leukemia'],
#   'biomarker': ['bcr', 'bcr-abl1']},
#  {'cancer_type': ['cancer',
#    'chronic myeloid leukemia',
#    'chronic myelogenous leukemia'],
#   'biomarker': ['bcr-abl1', 'bcr-abl']},
#  {'cancer_type': ['cancer',
#    'ph + cml',
#    'chronic myelogenous leukemia',
#    'cml',
#    'chronic myeloid leukemia'],
#   'biomarker': ['abl', 'bcr-abl1']},
#  {'cancer_type': ['tumors', 'breast cancer'],
#   'biomarker': ['pten', 'her2', 'er', 'akt1', 'pik3ca']},
#  {'cancer_type': ['melanoma', 'cancer'],
#   'biomarker': ['v600e', 'braf', 'raf', 'v600k']},
#  {'cancer_type': ['high-grade glioma',
#    'low-grade glioma',
#    'solid tumors',
#    'colorectal'],
#   'biomarker': ['braf', 'raf', 'mek1 / 2']},
#  {'cancer_type': ['anaplastic thyroid cancer', 'atc', 'cancer'],
#   'biomarker': ['v600e', 'braf', 'raf', 'mek1 / 2']},
#  {'cancer_type': ['low-grade glioma',
#    'solid tumors',
#    'colorectal',
#    'lung cancer',
#    'high-grade glioma',
#    'melanoma',
#    'biliary tract cancer'],
#   'biomarker': ['braf', 'raf', 'combi-', 'mek1 / 2']},
#  {'cancer_type': ['low-grade glioma',
#    'solid tumors',
#    'colorectal',
#    'lung cancer',
#    'high-grade glioma',
#    'melanoma',
#    'biliary tract cancer'],
#   'biomarker': ['braf', 'raf', 'combi-', 'mek1 / 2']},
#  {'cancer_type': ['cancer', 'low-grade glioma', 'lgg'],
#   'biomarker': ['braf', 'raf', 'mek1 / 2']},
#  {'cancer_type': ['melanoma', 'metastatic melanoma'],
#   'biomarker': ['braf', 'v600k', 'raf', 'mek1 / 2']},
#  {'cancer_type': ['non-small cell lung cancer',
#    'cancer',
#    'tumor',
#    'stage iv',
#    'nsclc'],
#   'biomarker': ['raf', 'v600e', 'mek1 / 2', 'braf', 'braf (v600e']},
#  {'cancer_type': ['crc', 'cancer', 'colorectal cancer'],
#   'biomarker': ['raf', 'v600e', 'egfr', 'braf v600e', 'mek1 / 2', 'braf']},
#  {'cancer_type': ['mcrc', 'metastatic colorectal cancer'],
#   'biomarker': ['braf', 'raf', 'egfr']},
#  {'cancer_type': ['cancer type', 'low-grade glioma', 'lgg'],
#   'biomarker': ['braf', 'v600']},
#  {'cancer_type': ['non-melanoma cancers',
#    'ecd',
#    'erdheim-chester disease',
#    'lch',
#    'cancer',
#    'melanoma',
#    'langerhans cell histiocytosis'],
#   'biomarker': ['braf', 'raf', 'v600']},
#  {'cancer_type': ['melanoma', 'cancer type'],
#   'biomarker': ['braf', 'v600', 'pd-l1', 'mek1 / 2']},
#  {'cancer_type': ['nsclc',
#    'cancer',
#    'non-small cell lung cancer',
#    'metastatic'],
#   'biomarker': ['v600e', 'braf', 'raf', 'mek1']},
#  {'cancer_type': ['melanoma', 'mel', 'metastatic melanoma', 'cancer'],
#   'biomarker': ['v600k', 'raf', 'mek', 'mek1', 'braf']},
#  {'cancer_type': ['melanoma', 'melanomas', 'cancer type'],
#   'biomarker': ['v600k', 'kinse', 'v600e', 'v600', 'braf']},
#  {'cancer_type': ['melanoma', 'cancer'],
#   'biomarker': ['braflanoma', 'v600k', 'raf', 'v600e', 'mek', 'braf']},
#  {'cancer_type': ['melanoma', 'cancer type'],
#   'biomarker': ['v600e', 'braf', 'v600k', 'mek1']},
#  {'cancer_type': ['non-small cell lung cancer', 'nsclc'],
#   'biomarker': ['trop2', 'egfr']},
#  {'cancer_type': ['cancer type', 'non-small cell lung cancer', 'nsclc'],
#   'biomarker': ['l858r', 'egfr tyrosine', 'egfr']},
#  {'cancer_type': ['non-small cell lung cancer', 'tumors', 'nsclc'],
#   'biomarker': ['egfr']},
#  {'cancer_type': ['non-small cell lung cancer', 'nsclc'],
#   'biomarker': ['met', 'egfr']},
#  {'cancer_type': ['cancer type', 'non-small cell lung cancer', 'nsclc'],
#   'biomarker': ['l858r', 'egfr tyrosine', 'egfr']},
#  {'cancer_type': ['squamous nsclc',
#    'cancer type',
#    'non-small cell lung cancer',
#    'metastatic',
#    'lung cancer',
#    'tumors',
#    'nsclc'],
#   'biomarker': ['her4', 'her2', 'egfr', 'l858r']},
#  {'cancer_type': ['cancer', 'non-small cell lung cancer', 'nsclc'],
#   'biomarker': ['l858r', 'egfr']},
#  {'cancer_type': ['non-small cell lung cancer',
#    'lung cancers',
#    'tumors',
#    'nsclc',
#    'pulmonary adenocarcinoma'],
#   'biomarker': ['l858r', 'egfr']},
#  {'cancer_type': ['non-small cell lung cancer',
#    'metastatic',
#    'tumors',
#    'tumor',
#    'nsclc'],
#   'biomarker': ['epidermal growth factor receptor (', 'egfr']},
#  {'cancer_type': ['cancer', 'non-small cell lung cancer', 'nsclc'],
#   'biomarker': ['l858r', 'epidermal growth factor receptor (', 'egfr']},
#  {'cancer_type': ['cancer type',
#    'non-small cell lung cancer',
#    'lung adenocarcinoma',
#    'nsclc'],
#   'biomarker': ['s768i', 'egfr', 'egfr tyrosine kinase']},
#  {'cancer_type': ['non-small cell lung cancer', 'xenograft', 'nsclc'],
#   'biomarker': ['met', 'egfr']},
#  {'cancer_type': ['cancer type', 'non-small cell lung cancer', 'nsclc'],
#   'biomarker': ['egfr']},
#  {'cancer_type': ['cancer type', 'non-small cell lung cancer', 'nsclc'],
#   'biomarker': ['met', 'egfr']},
#  {'cancer_type': ['non-small cell lung cancer',
#    'lung cancer',
#    'cancer',
#    'tumors',
#    'nsclc'],
#   'biomarker': ['her4', 'her2', 'egfr', 'g719']},
#  {'cancer_type': ['non-small cell lung cancer', 'nsclc'],
#   'biomarker': ['egfr', 'egfr tyrosine kinase']},
#  {'cancer_type': ['cancer',
#    'non-small cell lung cancer',
#    'lung adenocarcinoma',
#    'nsclc'],
#   'biomarker': ['egfr', 'l861q']},
#  {'cancer_type': ['non-squamous non-small cell lung cancer',
#    'tumors',
#    'nsclc'],
#   'biomarker': ['her2', 'erbb2']},
#  {'cancer_type': ['cancer', 'non-small cell lung cancer', 'nsclc'],
#   'biomarker': ['her2']},
#  {'cancer_type': ['breast cancer'],
#   'biomarker': ['estrogen receptor', 'er', 'her2', 'esr1']},
#  {'cancer_type': ['cancer', 'follicular lymphoma', 'tumors', 'fl'],
#   'biomarker': ['ezh2', 'level']},
#  {'cancer_type': ['urothelial carcinoma'],
#   'biomarker': ['tacc3', 'fgfr', 'fgfr3', 'fgfr1', 'fgfr2', 'baiap2l1']},
#  {'cancer_type': ['acute myeloid leukemia', 'aml'], 'biomarker': ['idh1']},
#  {'cancer_type': ['intrahepatic cholangiocarcinoma',
#    'cancer',
#    'cholangiocarcinoma'],
#   'biomarker': ['r132l', 'r132s', 'idh1']},
#  {'cancer_type': ['cancer', 'cholangiocarcinoma'],
#   'biomarker': ['r132l', 'r132s', 'idh1', 'r132c']},
#  {'cancer_type': ['lymphoma',
#    'clinical',
#    'cancer',
#    'mds-457',
#    'leukemia',
#    'myeloma'],
#   'biomarker': ['idh1']},
#  {'cancer_type': ['cancer type',
#    'oligodendroglioma',
#    'low-grade glioma',
#    'grade 2 astrocytoma'],
#   'biomarker': ['idh1 / 2',
#    'r132c',
#    'r132l',
#    'r132s',
#    'idh2',
#    'idh1',
#    'r132h',
#    'r132g']},
#  {'cancer_type': ['cancer type',
#    'oligodendroglioma',
#    'low-grade glioma',
#    'astrocytoma',
#    'grade 2 astrocytoma'],
#   'biomarker': ['idh1 / 2',
#    'r132c',
#    'r132l',
#    'r132s',
#    'idh2',
#    'idh1',
#    'r132h',
#    'r132g']},
#  {'cancer_type': ['acute myeloid leukemia', 'aml', 'cancer'],
#   'biomarker': ['idh1']},
#  {'cancer_type': ['acute myeloid leukemia',
#    'aml',
#    'cancer',
#    'myeloid malignancies'],
#   'biomarker': ['r172k', 'idh2', 'isocitrate dehydrogenase-2']},
#  {'cancer_type': ['cancer type',
#    'oligodendroglioma',
#    'low-grade glioma',
#    'grade 2 astrocytoma'],
#   'biomarker': ['r172k',
#    'r172w',
#    'idh1 / 2',
#    'r172m',
#    'idh2',
#    'idh1',
#    'r172g',
#    'r172s']},
#  {'cancer_type': ['cancer type',
#    'oligodendroglioma',
#    'low-grade glioma',
#    'astrocytoma',
#    'grade 2 astrocytoma'],
#   'biomarker': ['r172k',
#    'r172w',
#    'idh1 / 2',
#    'r172m',
#    'idh2',
#    'idh1',
#    'r172g',
#    'r172s']},
#  {'cancer_type': ['gists',
#    'gastrointestinal stromal tumors',
#    'cancer',
#    'gastrointestinal stromal tumor',
#    'gist',
#    'malignant'],
#   'biomarker': ['kit', 'level']},
#  {'cancer_type': ['gastrointestinal stromal tumor',
#    'cancer',
#    'gastrointestinal stromal tumors',
#    'gist'],
#   'biomarker': ['kit', 'level']},
#  {'cancer_type': ['gastrointestinal stromal tumor',
#    'cancer',
#    'gastrointestinal stromal tumors',
#    'gist'],
#   'biomarker': ['pdgfr', 'vegfr2', 'kit', '-3']},
#  {'cancer_type': ['gastrointestinal stromal tumor',
#    'cancer',
#    'gastrointestinal stromal tumors',
#    'gist'],
#   'biomarker': ['pdgfra', 'kit']},
#  {'cancer_type': [], 'biomarker': ['kit']},
#  {'cancer_type': ['lgsoc',
#    'women ’ s cancer',
#    'low-grade serous ovarian cancer'],
#   'biomarker': ['raf', 'mek', 'fak', 'kras']},
#  {'cancer_type': ['crc', 'cancer type', 'colorectal cancer'],
#   'biomarker': ['kras g12c', 'g12c', 'egfr', 'kras']},
#  {'cancer_type': ['non-small cell lung cancer', 'nsclc'],
#   'biomarker': ['kras']},
#  {'cancer_type': ['cancer type', 'non-small cell lung cancer', 'non-small'],
#   'biomarker': ['kras']},
#  {'cancer_type': ['mcrc', 'crc', 'metastatic colorectal cancer'],
#   'biomarker': ['kras g12c', 'egfr', 'kras']},
#  {'cancer_type': ['non-small cell lung cancer', 'tumors', 'nsclc'],
#   'biomarker': ['met']},
#  {'cancer_type': ['cancer', 'non-small cell lung cancer', 'nsclc'],
#   'biomarker': ['met tyrosine kinase', 'met', 'level']},
#  {'cancer_type': ['gastrointestinal stromal tumorio',
#    'gastrointestinal stromal tumor',
#    'cancer',
#    'gist'],
#   'biomarker': ['pdgfra', 'kit']},
#  {'cancer_type': ['tumors', 'breast cancer'],
#   'biomarker': ['pten', 'her2', 'er', 'akt1', 'pik3ca']},
#  {'cancer_type': ['breast cancer'],
#   'biomarker': ['pi3kα', 'hr', 'her2', 'pik3ca']},
#  {'cancer_type': ['cancer',
#    'tumor',
#    'breast cancerio',
#    'breast cancer',
#    'xenograft'],
#   'biomarker': ['estrogen receptor', 'pi3k', 'her2', 'er', 'pi3kα', 'pik3ca']},
#  {'cancer_type': ['tumors', 'breast cancer'],
#   'biomarker': ['pten', 'her2', 'er', 'akt1', 'pik3ca']},
#  {'cancer_type': ['b-lymphoblastic leukemia',
#    'lymphoma',
#    'all',
#    'cancer',
#    'acute lymphoblastic leukemia'],
#   'biomarker': ['abl', 'bcr-abl']},
#  {'cancer_type': ['cancer', 'ph', 'chronic myelogenous leukemia', 'cml'],
#   'biomarker': ['v299l', 'abl', 'bcr-abl']},
#  {'cancer_type': ['b-lymphoblastic leukemia',
#    'lymphoma',
#    'all',
#    'cancer',
#    'chronic myelogenous leukemia',
#    'acute lymphoblastic leukemia'],
#   'biomarker': ['src', 'bcr-abl']},
#  {'cancer_type': ['cancer', 'chronic myelogenous leukemia'],
#   'biomarker': ['src', 'bcr-abl']},
#  {'cancer_type': ['lymphoma',
#    'b-lymphoblastic leukemia',
#    'cancer',
#    'ph + all',
#    'philadelphia'],
#   'biomarker': ['src', 'bcr-abl']},
#  {'cancer_type': ['cancer',
#    'ph + cml',
#    'chronic myelogenous leukemia',
#    'cp cml'],
#   'biomarker': ['abl', 'src family kinases', 'bcr-abl']},
#  {'cancer_type': ['cancer', 'non-small cell lung cancer', 'tumors', 'nsclc'],
#   'biomarker': ['l1196m', 'alk']},
#  {'cancer_type': ['cancer', 'non-small cell lung cancer', 'tumors', 'nsclc'],
#   'biomarker': ['g1202r', 'l1196m', 'alk']},
#  {'cancer_type': ['pilocytic astrocytoma', 'cancer'],
#   'biomarker': ['v600e', 'braf', 'kiaa1549', 'mek1 / 2']},
#  {'cancer_type': ['ecd',
#    'cancer',
#    'tumors',
#    'hcl',
#    'melanoma',
#    'edheim-chester disease',
#    'hairy cell leukemia'],
#   'biomarker': ['kinse', 'braf', 'v600', 'v600e']},
#  {'cancer_type': ['lch',
#    'ecd',
#    'erdheim-chester disease',
#    'histiocytic neoplasms',
#    'cancer',
#    'langerhans cell histiocytosis'],
#   'biomarker': ['braf', 'raf', 'v600']},
#  {'cancer_type': ['anaplastic thyroid cancer',
#    'epithelioid glioblastoma',
#    'non-small cell lung cancer',
#    'low-grade glioma',
#    'glioblastoma multiforme',
#    'glioma subtypes',
#    'nos',
#    'anaplastic oligoastrocytoma',
#    'cancer type',
#    'anaplastic astrocytoma',
#    'high-grade glioma',
#    'melanoma',
#    'anaplastic glioma',
#    'glioblastoma',
#    'glioma'],
#   'biomarker': ['v600e', 'braf', 'raf', 'mek']},
#  {'cancer_type': ['anaplastic thyroid cancer',
#    'non-small cell lung cancer',
#    'low-grade glioma',
#    'anaplastic pleomorphic xanthoastrocytoma',
#    'glioma subtypes',
#    'pilocytic astrocytoma',
#    'melanoma',
#    'anaplastic glioma',
#    'glioblastoma',
#    'ganglioglioma',
#    'pleomorphic xanthoastrocytoma',
#    'anaplastic ganglioglioma'],
#   'biomarker': ['braf', 'raf', 'mek']},
#  {'cancer_type': ['anaplastic thyroid cancer',
#    'non-small cell lung cancer',
#    'pxa',
#    'pilocytic astrocytoma',
#    'cancer',
#    'melanoma',
#    'central nervous system cancers',
#    'pleomorphic xanthoastrocytoma',
#    'ganglioglioma'],
#   'biomarker': ['v600e', 'braf', 'raf', 'mek']},
#  {'cancer_type': ['anaplastic thyroid cancer',
#    'non-small cell lung cancer',
#    'pxa',
#    'pilocytic astrocytoma',
#    'cancer',
#    'melanoma',
#    'central nervous system cancers',
#    'pleomorphic xanthoastrocytoma',
#    'ganglioglioma',
#    'anaplastic ganglioglioma'],
#   'biomarker': ['v600e', 'braf', 'raf', 'mek']},
#  {'cancer_type': ['anaplastic thyroid cancer',
#    'non-small cell lung cancer',
#    'pxa',
#    'pilocytic astrocytoma',
#    'cancer',
#    'melanoma',
#    'central nervous system cancers',
#    'pleomorphic xanthoastrocytoma',
#    'ganglioglioma',
#    'anaplastic ganglioglioma'],
#   'biomarker': ['v600e', 'braf', 'raf', 'mek']},
#  {'cancer_type': ['lch',
#    'ecd',
#    'erdheim-chester disease',
#    'histiocytic neoplasms',
#    'cancer',
#    'langerhans cell histiocytosis'],
#   'biomarker': ['braf', 'raf', 'v600']},
#  {'cancer_type': ['cancer', 'colorectal cancer'],
#   'biomarker': ['v600e', 'egfr', 'mek1 / 2', 'raf kinase', 'braf']},
#  {'cancer_type': ['melanoma', 'cancer', 'ecd', 'erdheim-chester disease'],
#   'biomarker': ['v600k', 'v600', 'mek1 / 2', 'braf', 'mapk', 'level']},
#  {'cancer_type': ['melanoma',
#    'lch',
#    'cancer',
#    'langerhans cell histiocytosis'],
#   'biomarker': ['v600k',
#    'v600',
#    'mek1 / 2',
#    'braf',
#    'mapk',
#    'map2k1',
#    'level']},
#  {'cancer_type': ['melanoma', 'rosai-dorfman disease', 'cancer', 'metastatic'],
#   'biomarker': ['v600k', 'v600', 'mek1 / 2', 'braf', 'kras', 'level']},
#  {'cancer_type': ['melanoma', 'cancer', 'ecd', 'erdheim-chester disease'],
#   'biomarker': ['v600k', 'v600', 'mek1 / 2', 'braf', 'mapk', 'level']},
#  {'cancer_type': ['melanoma',
#    'lch',
#    'cancer',
#    'langerhans cell histiocytosis'],
#   'biomarker': ['v600k', 'v600', 'mek1 / 2', 'braf', 'mapk', 'map2k1']},
#  {'cancer_type': ['melanoma', 'rosai-dorfman disease', 'cancer', 'metastatic'],
#   'biomarker': ['v600k', 'v600', 'mek1 / 2', 'braf', 'kras', 'level']},
#  {'cancer_type': ['non-small cell lung cancer', 'nsclc'],
#   'biomarker': ['met', 'egfr']},
#  {'cancer_type': ['non-small cell lung cancer',
#    'lung adenocarcinoma',
#    'nsclc'],
#   'biomarker': ['egfr', 'egfr tyrosine kinase']},
#  {'cancer_type': ['cancer type',
#    'non-small cell lung cancer',
#    'metastatic',
#    'tumors',
#    'nsclc'],
#   'biomarker': ['epidermal growth factor receptor', 'egfr']},
#  {'cancer_type': ['non-small cell lung cancer',
#    'metastatic',
#    'tumors',
#    'lung adenocarcinoma',
#    'nsclc'],
#   'biomarker': ['l858r', 'egfr', 'egfr tyrosine kinase']},
#  {'cancer_type': ['cancer type', 'non-small cell lung cancer', 'nsclc'],
#   'biomarker': ['l858r', 's768i', 'egfr']},
#  {'cancer_type': ['non-small cell lung cancer',
#    'metastatic',
#    'cancer',
#    'tumors',
#    'nsclc'],
#   'biomarker': ['l858r',
#    'pi3k',
#    'egfr tyrosine kinase',
#    'a763',
#    'egfr',
#    'mapk',
#    'erk',
#    'akt']},
#  {'cancer_type': ['non-small cell lung cancer', 'nsclc'],
#   'biomarker': ['met', 'egfr']},
#  {'cancer_type': ['cancer type', 'non-small cell lung cancer', 'nsclc'],
#   'biomarker': ['l858r', 'egfr', 'g719']},
#  {'cancer_type': ['cancer type',
#    'non-small cell lung cancer',
#    'tumors',
#    'nsclc'],
#   'biomarker': ['g719', 'epidermal growth factor receptor', 'egfr']},
#  {'cancer_type': ['non-small cell lung cancer',
#    'lung adenocarcinoma',
#    'nsclc'],
#   'biomarker': ['egfr', 'egfr tyrosine kinase']},
#  {'cancer_type': ['non-small cell lung cancer',
#    'metastatic',
#    'tumors',
#    'lung adenocarcinoma',
#    'nsclc'],
#   'biomarker': ['egfr', 'egfr tyrosine kinase']},
#  {'cancer_type': ['cancer type', 'non-small cell lung cancer', 'nsclc'],
#   'biomarker': ['l858r', 'egfr']},
#  {'cancer_type': ['non-small cell lung cancer',
#    'lung adenocarcinoma',
#    'nsclc'],
#   'biomarker': ['egfr', 'egfr tyrosine kinase']},
#  {'cancer_type': ['cancer type',
#    'non-small cell lung cancer',
#    'metastatic',
#    'tumors',
#    'nsclc'],
#   'biomarker': ['epidermal growth factor receptor', 'egfr']},
#  {'cancer_type': ['non-small cell lung cancer',
#    'metastatic',
#    'tumors',
#    'lung adenocarcinoma',
#    'nsclc'],
#   'biomarker': ['egfr', 'egfr tyrosine kinase']},
#  {'cancer_type': ['non-small cell lung cancer', 'nsclc'],
#   'biomarker': ['met', 'egfr']},
#  {'cancer_type': ['cancer type',
#    'non-small cell lung cancer',
#    'solid tumors',
#    'lung cancer',
#    'nsclc'],
#   'biomarker': ['erbb2']},
#  {'cancer_type': ['cervical cancer',
#    'cervical',
#    'early-stage',
#    'breast cancer'],
#   'biomarker': ['her2', 'erbb2']},
#  {'cancer_type': ['cancer', 'early-stage', 'breast cancer'],
#   'biomarker': ['cdk4 / 6i', 'her targeted', 'her2', 'erbb2']},
#  {'cancer_type': ['cancer', 'breast cancer'],
#   'biomarker': ['estrogen receptor', 'hr', 'esr1', 'her2', 'er']},
#  {'cancer_type': ['urothelial carcinoma', 'bladder cancer', 'muc'],
#   'biomarker': ['tacc3', 'fgfr3', 'fgfr', 'baiap2l1']},
#  {'cancer_type': ['squamous nsclc',
#    'non-small cell lung cancer',
#    'solid tumors',
#    'urothelial carcinoma',
#    'nsclc',
#    'non-squamous nsclc'],
#   'biomarker': ['fgfr2', 'fgfr3', 'fgfr', 'fgfr1']},
#  {'cancer_type': ['cancer',
#    'bone cancer',
#    'aml',
#    'chondrosarcoma',
#    'acute myeloid leukemia'],
#   'biomarker': ['idh1']},
#  {'cancer_type': ['oligodendroglioma',
#    'astrocytoma',
#    'cholangiocarcinoma',
#    'non',
#    'cancer',
#    'central nervous system cancers',
#    'acute myeloid leukemia',
#    'glioma'],
#   'biomarker': ['idh1']},
#  {'cancer_type': ['astrocytoma',
#    'cholangiocarcinoma',
#    'non',
#    'cancer',
#    'central nervous system cancers',
#    'acute myeloid leukemia',
#    'glioma'],
#   'biomarker': ['idh1']},
#  {'cancer_type': ['metastatic',
#    'gists',
#    'gastrointestinal stromal tumors',
#    'tumors',
#    'cancer',
#    'melanoma'],
#   'biomarker': ['l576p',
#    'v559a',
#    'l576del',
#    'p577del',
#    'v560del',
#    'kit',
#    'v654a',
#    'v560g']},
#  {'cancer_type': ['cancer type',
#    'gastrointestinal stromal tumors',
#    'gastrointestinal stromal tumor',
#    'gist',
#    'solid cancer types'],
#   'biomarker': ['kit']},
#  {'cancer_type': ['melanoma', 'cancer', 'erdheim-chester disease'],
#   'biomarker': ['v600k', 'mek1 / 2', 'braf', 'kras', 'level']},
#  {'cancer_type': ['melanoma',
#    'langerhans cell',
#    'cancer',
#    'langerhans cell histiocytosis'],
#   'biomarker': ['v600k', 'mek1 / 2', 'mek1', 'braf', 'kras']},
#  {'cancer_type': ['melanoma', 'rosai-dorfman disease', 'cancer', 'metastatic'],
#   'biomarker': ['v600k', 'mek1 / 2', 'braf', 'kras', 'level']},
#  {'cancer_type': ['melanoma', 'cancer', 'erdheim-chester disease'],
#   'biomarker': ['v600k', 'mek1 / 2', 'braf', 'kras', 'level']},
#  {'cancer_type': ['melanoma',
#    'langerhans cell',
#    'cancer',
#    'langerhans cell histiocytosis'],
#   'biomarker': ['v600k', 'mek1 / 2', 'mek1', 'braf', 'kras']},
#  {'cancer_type': ['melanoma', 'rosai-dorfman disease', 'cancer', 'metastatic'],
#   'biomarker': ['v600k', 'mek1 / 2', 'braf', 'kras', 'level']},
#  {'cancer_type': ['non-small cell lung cancer',
#    'solid tumors',
#    'cancer',
#    'hepatobiliary cancer',
#    'biliary tract cancers',
#    'biliary tract cancer'],
#   'biomarker': ['kras g12c', 'g12c', 'kras']},
#  {'cancer_type': ['tumor types',
#    'non-small cell lung cancer',
#    'cancer type',
#    'colorectal cancer',
#    'pancreatic cancer nccn',
#    'tumor',
#    'pancreatic cancer',
#    'gastrointestinal cancers',
#    'pancreatic ductal adenocarcinoma',
#    'pancreatic adenocarcinoma',
#    'xenograft'],
#   'biomarker': ['kras g12c', 'g12c', 'kras']},
#  {'cancer_type': ['non-small cell lung cancer',
#    'small bowel cancer',
#    'solid tumors',
#    'colorectal cancer',
#    'cancer',
#    'small bowel cancers',
#    'small bowel adenocarcinoma'],
#   'biomarker': ['kras g12c', 'g12c', 'kras']},
#  {'cancer_type': ['non-small cell lung cancer', 'colorectal cancer'],
#   'biomarker': ['kras g12c', 'egfr', 'kras']},
#  {'cancer_type': ['cancer type',
#    'non-small cell lung cancer',
#    'solid tumors',
#    'colorectal cancer',
#    'ampullary adenocarcinoma',
#    'ampullary cancer',
#    'nsclc'],
#   'biomarker': ['kras g12c', 'g12c', 'kras']},
#  {'cancer_type': ['cancer type',
#    'non-small cell lung cancer',
#    'solid tumors',
#    'colorectal cancer',
#    'ampullary adenocarcinoma',
#    'ampullary cancer',
#    'nsclc'],
#   'biomarker': ['kras g12c', 'g12c', 'kras']},
#  {'cancer_type': ['pancreatic cancer',
#    'cancer type',
#    'pancreatic cancer nccn',
#    'pancreatic adenocarcinoma'],
#   'biomarker': ['g12c', 'kras']},
#  {'cancer_type': ['cancer type',
#    'non-small cell lung cancer',
#    'small bowel cancer',
#    'solid tumors',
#    'colorectal cancer',
#    'small bowel cancers',
#    'small bowel adenocarcinoma'],
#   'biomarker': ['kras g12c', 'g12c', 'kras']},
#  {'cancer_type': ['non-small cell lung cancer', 'colorectal cancer'],
#   'biomarker': ['kras g12c', 'egfr', 'kras']},
#  {'cancer_type': ['non-small cell lung cancer',
#    'lung cancer',
#    'metastatic',
#    'tumors',
#    'nsclc'],
#   'biomarker': ['c-met', 'ros1', 'met', 'alk']},
#  {'cancer_type': ['cancer type',
#    'gist',
#    'gastrointestinal stromal tumor',
#    'chronic myeloid leukemia',
#    'cml',
#    'acute lymphoblastic leukemia'],
#   'biomarker': ['pdgfra', 'kit', 'pdgfr', 'bcr-abl']},
#  {'cancer_type': ['gists',
#    'gastrointestinal stromal tumors',
#    'cancer',
#    'gastrointestinal stromal tumor',
#    'gist'],
#   'biomarker': ['pdgfra', 'kit']},
#  {'cancer_type': ['gastrointestinal stromal tumor',
#    'cancer type',
#    'tumor',
#    'gist'],
#   'biomarker': []},
#  {'cancer_type': ['gastrointestinal stromal tumor', 'gist'],
#   'biomarker': ['pdgfr', 'vegfr2', 'kit', '-3']},
#  {'cancer_type': ['gastrointestinal stromal tumor',
#    'cancer',
#    'gastrointestinal stromal tumors',
#    'gist'],
#   'biomarker': ['pdgfra', 'kit']},
#  {'cancer_type': ['cancer', 'breast cancer'],
#   'biomarker': ['e542k',
#    'aromatase',
#    'e545a',
#    'her2',
#    'er',
#    'c420r',
#    'pi3kα',
#    'e5',
#    'pik3ca']},
#  {'cancer_type': ['crc',
#    'solid tumors',
#    'colorectal cancer',
#    'metastatic',
#    'tumors',
#    'colon cancer',
#    'mcrc'],
#   'biomarker': ['pole-altered',
#    'anti-pd-l1',
#    'anti-pd-1',
#    'anti-ctla-4',
#    'pd-1',
#    'anti-pdl-1',
#    'pole',
#    'pole / d1']},
#  {'cancer_type': ['crc',
#    'solid tumors',
#    'colorectal cancer',
#    'metastatic',
#    'cancer',
#    'tumors',
#    'small bowel adenocarcinoma',
#    'sba'],
#   'biomarker': ['anti-pd-1',
#    'anti-ctla-4',
#    'anti',
#    'pd-1',
#    'anti-pdl-1',
#    'pole',
#    'pole / d1']},
#  {'cancer_type': ['crc',
#    'colorectal cancer',
#    'metastatic',
#    'tumors',
#    'colon cancer',
#    'mcrc'],
#   'biomarker': ['pold1',
#    'anti-pd-l1',
#    'anti-pd-1',
#    'anti-ctla-4',
#    'anti-pdl-1',
#    'pole',
#    'pole / d1']},
#  {'cancer_type': ['crc',
#    'colorectal cancer',
#    'metastatic',
#    'tumors',
#    'small bowel adenocarcinoma',
#    'mcrc',
#    'sba'],
#   'biomarker': ['pold1',
#    'anti-pd-l1',
#    'anti-pd-1',
#    'anti-ctla-4',
#    'anti-pdl-1',
#    'anti-pd1',
#    'pole',
#    'pole / d1']},
#  {'cancer_type': ['crc',
#    'colorectal cancer',
#    'metastatic',
#    'tumors',
#    'colon cancer',
#    'mcrc',
#    'metastatic colorectal cancer'],
#   'biomarker': ['anti-pd-l1',
#    'anti-pd-1',
#    'anti-ctla-4',
#    'anti-pdl-1',
#    'anti-pd1',
#    'pole',
#    'pole / d1']},
#  {'cancer_type': ['crc',
#    'colorectal cancer',
#    'metastatic',
#    'tumors',
#    'small bowel adenocarcinoma',
#    'mcrc',
#    'sba',
#    'metastatic colorectal cancer'],
#   'biomarker': ['anti-pd-l1',
#    'anti-pd-1',
#    'anti-ctla-4',
#    'anti-pd1 antibody',
#    'anti-pdl-1',
#    'pole',
#    'pole / d1']},
#  {'cancer_type': ['crc',
#    'solid tumors',
#    'metastatic carcinoma',
#    'colorectal cancer',
#    'metastatic',
#    'tumors',
#    'colon cancer'],
#   'biomarker': ['anti-pd-l1',
#    'anti-pd-1',
#    'anti-ctla-4',
#    'anti-pdl-1',
#    'pole',
#    'pole / d1']},
#  {'cancer_type': ['crc',
#    'solid tumors',
#    'metastatic carcinoma',
#    'colorectal cancer',
#    'metastatic',
#    'tumors',
#    'small bowel adenocarcinoma',
#    'tumor',
#    'sba'],
#   'biomarker': ['pold1',
#    'anti-pd-l1',
#    'anti-pd-1',
#    'anti-ctla-4',
#    'anti-pdl-1',
#    'anti-pd1',
#    'pole',
#    'pole / d1']},
#  {'cancer_type': ['crc',
#    'solid tumors',
#    'colorectal cancer',
#    'metastatic',
#    'tumors',
#    'colon cancer',
#    'mcrc'],
#   'biomarker': ['pole-altered',
#    'anti-pd-l1',
#    'anti-pd-1',
#    'anti-ctla-4',
#    'pd-1',
#    'anti-pdl-1',
#    'pole',
#    'pole / d1']},
#  {'cancer_type': ['crc',
#    'solid tumors',
#    'colorectal cancer',
#    'metastatic',
#    'cancer',
#    'tumors',
#    'small bowel adenocarcinoma',
#    'sba'],
#   'biomarker': ['anti-pd-1',
#    'anti-ctla-4',
#    'anti',
#    'pd-1',
#    'anti-pdl-1',
#    'pole',
#    'pole / d1']},
#  {'cancer_type': ['crc',
#    'colorectal cancer',
#    'metastatic',
#    'tumors',
#    'colon cancer',
#    'mcrc'],
#   'biomarker': ['pold1',
#    'anti-pd-l1',
#    'anti-pd-1',
#    'anti-ctla-4',
#    'anti-pdl-1',
#    'pole',
#    'pole / d1']},
#  {'cancer_type': ['crc',
#    'colorectal cancer',
#    'metastatic',
#    'tumors',
#    'small bowel adenocarcinoma',
#    'mcrc',
#    'sba'],
#   'biomarker': ['pold1',
#    'anti-pd-l1',
#    'anti-pd-1',
#    'anti-ctla-4',
#    'anti-pdl-1',
#    'anti-pd1',
#    'pole',
#    'pole / d1']},
#  {'cancer_type': ['crc',
#    'colorectal cancer',
#    'metastatic',
#    'tumors',
#    'tumor',
#    'colon cancer',
#    'mcrc',
#    'metastatic colorectal cancer'],
#   'biomarker': ['pold1',
#    'anti-pd-l1',
#    'anti-pd-1',
#    'anti-ctla-4',
#    'anti-pdl-1',
#    'anti-pd1',
#    'pole']},
#  {'cancer_type': ['crc',
#    'colorectal cancer',
#    'metastatic',
#    'tumors',
#    'small bowel adenocarcinoma',
#    'mcrc',
#    'sba',
#    'metastatic colorectal cancer'],
#   'biomarker': ['anti-pd-l1',
#    'anti-pd-1',
#    'anti-ctla-4',
#    'anti-pd1 antibody',
#    'anti-pdl-1',
#    'pole',
#    'pole / d1']},
#  {'cancer_type': ['crc',
#    'solid tumors',
#    'metastatic carcinoma',
#    'colorectal cancer',
#    'metastatic',
#    'tumors',
#    'colon cancer'],
#   'biomarker': ['anti-pd-l1',
#    'anti-pd-1',
#    'anti-ctla-4',
#    'anti-pdl-1',
#    'pole',
#    'pole / d1']},
#  {'cancer_type': ['crc',
#    'solid tumors',
#    'metastatic carcinoma',
#    'colorectal cancer',
#    'metastatic',
#    'tumors',
#    'small bowel adenocarcinoma',
#    'tumor',
#    'sba'],
#   'biomarker': ['pold1',
#    'anti-pd-l1',
#    'anti-pd-1',
#    'anti-ctla-4',
#    'anti-pdl-1',
#    'anti-pd1',
#    'pole',
#    'pole / d1']},
#  {'cancer_type': ['cervical cancer',
#    'cancer type',
#    'solid tumors',
#    'gynecologic cancers',
#    'cancers',
#    'metastatic tumors',
#    'ovarian cancer',
#    'breast cancerplants',
#    'breast cancer',
#    'tumor',
#    'endometrial adenocarcinoma',
#    'endometrial cancer'],
#   'biomarker': ['pras40', 'pi3k', 's6', 'mtor', 'akt1', 'akt', 'e17k']},
#  {'cancer_type': ['cervical cancer',
#    'cancer type',
#    'solid tumors',
#    'gynecologic cancers',
#    'cancers',
#    'metastatic tumors',
#    'ovarian cancer',
#    'breast cancerplants',
#    'breast cancer',
#    'tumor',
#    'endometrial adenocarcinoma',
#    'endometrial cancer'],
#   'biomarker': ['pras40', 'pi3k', 's6', 'mtor', 'akt1', 'akt', 'e17k']},
#  {'cancer_type': ['cancer',
#    'non-small cell lung cancer',
#    'tumors',
#    'neuroblastoma'],
#   'biomarker': ['f1245v', 'alk']},
#  {'cancer_type': ['non-small cell lung cancer',
#    'neuroblastoma',
#    'cancer',
#    'tumors',
#    'tumor',
#    'xenograft'],
#   'biomarker': ['alk f1174l', 'f1174l', 'alk']},
#  {'cancer_type': ['non-small cell lung cancer',
#    'neuroblastoma',
#    'cancer',
#    'tumors',
#    'tumor',
#    'xenograft'],
#   'biomarker': ['alk']},
#  {'cancer_type': ['cancer type',
#    'non-small cell lung cancer',
#    'tumor',
#    'nsclc',
#    'xenograft'],
#   'biomarker': ['g1202r', 'alk']},
#  {'cancer_type': ['cancer',
#    'non-small cell lung cancer',
#    'tumors',
#    'neuroblastoma'],
#   'biomarker': ['alk', 'r1275l']},
#  {'cancer_type': ['cancer',
#    'non-small cell lung cancer',
#    'tumors',
#    'neuroblastoma'],
#   'biomarker': ['alk f1174c', 'f1174c', 'alk']},
#  {'cancer_type': ['cancer',
#    'non-small cell lung cancer',
#    'tumors',
#    'neuroblastoma'],
#   'biomarker': ['f1245y', 'alk']},
#  {'cancer_type': ['lch',
#    'ecd',
#    'erdheim-chester disease',
#    'histiocytic neoplasms',
#    'histiocytic sarcoma',
#    'cancer',
#    'tumor',
#    'histiocytosis',
#    'langerhans cell histiocytosis'],
#   'biomarker': ['braf', 'raf', 'v600']},
#  {'cancer_type': ['lch',
#    'ecd',
#    'erdheim-chester disease',
#    'histiocytic neoplasms',
#    'histiocytic sarcoma',
#    'cancer',
#    'tumor',
#    'histiocytosis',
#    'langerhans cell histiocytosis'],
#   'biomarker': ['braf', 'raf', 'v600']},
#  {'cancer_type': ['histiocytic neoplasms',
#    'histiocytic sarcoma',
#    'cancer',
#    'melanoma',
#    'histiocytosis'],
#   'biomarker': ['v600k', 'mek1 / 2', 'braf', 'mapk', 'map2k1']},
#  {'cancer_type': ['histiocytic neoplasms',
#    'histiocytic sarcoma',
#    'cancer',
#    'melanoma',
#    'histiocytosis'],
#   'biomarker': ['v600k', 'mek1 / 2', 'braf', 'mapk', 'map2k1']},
#  {'cancer_type': ['melanoma', 'cancer type', 'metastatic melanoma'],
#   'biomarker': ['raf',
#    'mek',
#    'k601',
#    'braf v600e',
#    'mek1',
#    'braf k601',
#    'braf k601e']},
#  {'cancer_type': ['melanoma', 'metastatic melanoma', 'cancer', 'tumor'],
#   'biomarker': ['raf', 'mek', 'mek1', 'braf', 'l597']},
#  {'cancer_type': ['non-small cell lung cancer', 'tumor', 'nsclc'],
#   'biomarker': ['her3', 'topoisomerase i', 'egfr', 'egfr tyrosine kinase']},
#  {'cancer_type': ['non-small cell lung cancer', 'nsclc'],
#   'biomarker': ['met', 'egfr']},
#  {'cancer_type': ['non-small cell lung cancers', 'nsclc'],
#   'biomarker': ['her4', 'her2', 'egfr']},
#  {'cancer_type': ['cancer type',
#    'non-small cell lung cancer',
#    'tumor',
#    'nsclc',
#    'xenograft',
#    'non-small cell lung cancers'],
#   'biomarker': ['egfr', 'egfr tyrosine kinase']},
#  {'cancer_type': ['non-small cell lung cancer',
#    'metastatic',
#    'cancer',
#    'tumors',
#    'nsclc'],
#   'biomarker': ['egfr', 'l718q']},
#  {'cancer_type': ['non-small cell lung cancer', 'nsclc'],
#   'biomarker': ['met', 'egfr']},
#  {'cancer_type': ['cancer type',
#    'non-small cell lung cancer',
#    'metastatic',
#    'tumors',
#    'stage iv lung adenocarcinoma',
#    'tumor',
#    'nsclc',
#    'pulmonary lesion'],
#   'biomarker': ['her4', 'her2', 'egfr']},
#  {'cancer_type': ['cancer type',
#    'non-small cell lung cancer',
#    'metastatic',
#    'tumors',
#    'nsclc'],
#   'biomarker': ['egfr', 'egfr tyrosine kinase']},
#  {'cancer_type': ['cancer type',
#    'non-small cell lung cancer',
#    'metastatic',
#    'cancer',
#    'tumors',
#    'nsclc'],
#   'biomarker': ['egfr', 'l718v']},
#  {'cancer_type': ['non-small cell lung cancer', 'nsclc'],
#   'biomarker': ['met', 'egfr']},
#  {'cancer_type': ['cancer', 'tumors', 'tumor', 'breast cancer', 'xenograft'],
#   'biomarker': ['estrogen receptor', 'her2', 'egfr', 'er', 'erbb2']},
#  {'cancer_type': ['cancer type',
#    'non-small cell lung cancer',
#    'tumor',
#    'breast cancer',
#    'xenograft'],
#   'biomarker': ['her2', 'egfr', 'erbb2']},
#  {'cancer_type': ['non-small cell lung cancer', 'nsclc'],
#   'biomarker': ['her2', 'erbb2']},
#  {'cancer_type': ['non-small cell lung cancer', 'nsclc'],
#   'biomarker': ['her2', 'egfr', 'erbb2']},
#  {'cancer_type': ['non – small cell lung cancer xenograft',
#    'non-small cell lung cancer',
#    'antitumor',
#    'cancer',
#    'breast',
#    'breast cancer',
#    'tumor',
#    'xenograft',
#    'non-small cell lung cancer bio'],
#   'biomarker': ['egfr', 'her2', 'erk', 'akt', 'her3', 'erbb2']},
#  {'cancer_type': ['cancer', 'hormone', 'breast cancer'],
#   'biomarker': ['estrogen receptor', 'aromatase', 'esr1', 'her2', 'er']},
#  {'cancer_type': ['non',
#    'cancer',
#    'aml',
#    'tumor',
#    'acute myeloid leukemia',
#    'glioma'],
#   'biomarker': ['level', 'idh1']},
#  {'cancer_type': ['histiocytic neoplasms',
#    'histiocytic sarcoma',
#    'cancer',
#    'melanoma',
#    'histiocytosis'],
#   'biomarker': ['v600k', 'mek', 'mek1 / 2', 'braf', 'kras', 'mapk', 'map2k1']},
#  {'cancer_type': ['non-small cell lung cancer', 'nsclc'],
#   'biomarker': ['ras', 'kras']},
#  {'cancer_type': ['pancreatic adenocarcinoma', 'pdac'],
#   'biomarker': ['kras', 'ras', 'ras (on']},
#  {'cancer_type': ['histiocytic neoplasms',
#    'histiocytic sarcoma',
#    'cancer',
#    'melanoma',
#    'histiocytosis'],
#   'biomarker': ['v600k', 'mek', 'mek1 / 2', 'braf', 'kras', 'mapk', 'map2k1']},
#  {'cancer_type': ['cancer type',
#    'non-small cell lung cancer',
#    'antitumor',
#    'nsclc mouse',
#    'cancerres',
#    'tumor',
#    'nsclc',
#    'xenograft'],
#   'biomarker': ['g12d', 'kras']},
#  {'cancer_type': ['cancer type',
#    'antitumor',
#    'pdac mouse xenograft',
#    'pdac',
#    'cancerres',
#    'tumor',
#    'pancreatic ductal adenocarcinoma',
#    'pancreatic adenocarcinoma'],
#   'biomarker': ['g12d', 'kras']},
#  {'cancer_type': ['tumor types',
#    'non-small cell lung cancer',
#    'small bowel cancer',
#    'lung',
#    'cancer type',
#    'colorectal cancer',
#    'tubular adenoma of',
#    'tumor',
#    'gastrointestinal cancers',
#    'biliary tract cancer',
#    'gastroesophageal junction cancer',
#    'gi cancers',
#    'colon adenocarcinomas',
#    'xenograft'],
#   'biomarker': ['kras g12c', 'g12c']},
#  {'cancer_type': ['tumor types',
#    'non-small cell lung cancer',
#    'small bowel cancer',
#    'lung',
#    'cancer type',
#    'colorectal cancer',
#    'tumor',
#    'gastrointestinal cancers',
#    'biliary tract cancer',
#    'gastroesophageal junction cancer',
#    'gi cancers',
#    'esophagogastric cancer',
#    'colon adenocarcinomas',
#    'xenograft'],
#   'biomarker': ['kras g12c', 'g12c']},
#  {'cancer_type': ['tumor types',
#    'non-small cell lung cancer',
#    'small bowel cancer',
#    'lung',
#    'cancer type',
#    'colorectal cancer',
#    'tumor',
#    'gastrointestinal cancers',
#    'biliary tract cancer',
#    'gastroesophageal junction cancer',
#    'gi cancers',
#    'anal cancer',
#    'colon adenocarcinomas',
#    'xenograft'],
#   'biomarker': ['kras g12c', 'g12c']},
#  {'cancer_type': ['tumor types',
#    'non-small cell lung cancer',
#    'small bowel cancer',
#    'lung',
#    'cancer type',
#    'colorectal cancer',
#    'tumor',
#    'gastrointestinal neuroendocrine tumors',
#    'gastrointestinal cancers',
#    'biliary tract cancer',
#    'gastroesophageal junction cancer',
#    'gi cancers',
#    'colon adenocarcinomas',
#    'xenograft'],
#   'biomarker': ['kras g12c', 'g12c']},
#  {'cancer_type': ['cancer',
#    'non-small cell lung cancer',
#    'solid tumors',
#    'nsclc'],
#   'biomarker': ['met tyrosine kinase', 'met']},
#  {'cancer_type': ['cancer type',
#    'non-small cell lung cancer',
#    'non-small cell lung cancers',
#    'nsclc'],
#   'biomarker': ['y1003', 'met tyrosine kinase', 'met', 'cbl', 'level']},
#  {'cancer_type': ['cancer type',
#    'non-small cell lung cancer',
#    'non-small cell lung cancers',
#    'nsclc'],
#   'biomarker': ['y1003', 'met tyrosine kinase', 'met', 'cbl', 'level']},
#  {'cancer_type': ['cancer type',
#    'non-small cell lung cancer',
#    'non-small cell lung cancers',
#    'nsclc'],
#   'biomarker': ['y1003', 'met tyrosine kinase', 'met', 'cbl', 'level']},
#  {'cancer_type': ['non-small cell lung cancer',
#    'solid tumors',
#    'cancer',
#    'lung adenocarcinoma',
#    'nsclc'],
#   'biomarker': ['met tyrosine kinase', 'met', 'f1200i', 'met f1200i']},
#  {'cancer_type': ['cancer', 'renal cell carcinoma', 'rcc'],
#   'biomarker': ['tsc2', 'mtor', 'mammalian target of rapamycin', 'tsc1']},
#  {'cancer_type': ['pancreatic neuroendocrine carcinomas',
#    'kidney cancer',
#    'subependymal giant cell astrocytomas',
#    'tuberous sclerosis',
#    'cancer',
#    'urothelial cancers',
#    'urothelial carcinoma',
#    'bladder cancer',
#    'breast cancers'],
#   'biomarker': ['mtor', 'mammalian target of rapamycin']},
#  {'cancer_type': ['cancer type',
#    'renal cell carcinoma',
#    'rcc',
#    'advanced',
#    'specimens'],
#   'biomarker': ['mtor', 'mammalian target of rapamycin', 'tsc1']},
#  {'cancer_type': ['xenograft mouse',
#    'cancer type',
#    'solid tumors',
#    'colorectal cancer',
#    'breast cancer',
#    'tumor',
#    'sarcoma'],
#   'biomarker': ['g595r', 'ntrk tyrosine kinase', 'ntrk1', 'lmna', 'tpm3']},
#  {'cancer_type': ['xenograft mouse',
#    'cancer type',
#    'solid tumors',
#    'metastatic',
#    'pancreatic origin',
#    'mixed acinar neuroendocrine carcinoma',
#    'tumor',
#    'infantile fibrosarcoma',
#    'mammary analog secretory carcinomas'],
#   'biomarker': ['g623r', 'etv6', 'ntrk3', 'ntrk tyrosine kinase']},
#  {'cancer_type': ['cancer type',
#    'non-small cell lung cancer',
#    'tumor',
#    'nsclc',
#    'xenograft'],
#   'biomarker': ['ros1', 'ntrk']},
#  {'cancer_type': ['cancer type', 'non-small cell lung cancer', 'nsclc'],
#   'biomarker': ['ros1', 'l2086f']},
#  {'cancer_type': ['ovarian',
#    'solid tumors',
#    'small cell lung cancer',
#    'ovarian cancer',
#    'breast',
#    'breast cancer',
#    'prostate',
#    'small-cell lung',
#    'endometrial cancer'],
#   'biomarker': ['p53', 'kras', 'tp53']},
#  {'cancer_type': ['anaplastic thyroid cancer',
#    'small bowel cancer',
#    'solid tumors',
#    'ovarian cancer',
#    'tumors',
#    'papillary thyroid cancer',
#    'solid',
#    'cns tumors'],
#   'biomarker': ['v600', 'braf', 'mapk', 'mapki', 'cyp3a4']},
#  {'cancer_type': ['anaplastic thyroid cancer',
#    'small bowel cancer',
#    'solid tumors',
#    'ovarian cancer',
#    'tumors',
#    'papillary thyroid cancer',
#    'solid',
#    'cns tumors'],
#   'biomarker': ['v600', 'braf', 'mapk', 'mapki', 'cyp3a4']},
#  {'cancer_type': ['cancer type', 'solid tumors'],
#   'biomarker': ['braf', 'mapk', 'cyp3a4']},
#  {'cancer_type': ['non-small cell lung cancer',
#    'metastatic',
#    'cancer',
#    'tumors',
#    'stage iv lung adenocarcinoma',
#    'nsclc'],
#   'biomarker': ['her4', 'her2', 'egfr']},
#  {'cancer_type': ['cancer', 'glioma'], 'biomarker': ['egfr', 'erbb2']},
#  {'cancer_type': ['non-small cell lung cancer',
#    'metastatic',
#    'cancer',
#    'tumors',
#    'nsclc'],
#   'biomarker': ['her4', 'her2', 'egfr']},
#  {'cancer_type': ['cancer type', 'non-small cell lung cancer'],
#   'biomarker': ['egfr']},
#  {'cancer_type': ['solid tumors',
#    'cholangiocarcinoma',
#    'breast cancer',
#    'biliary tract cancer',
#    'gallbladder cancer',
#    'ampullary cancer'],
#   'biomarker': ['her2', 'erbb2']},
#  {'cancer_type': ['solid tumors',
#    'cholangiocarcinoma',
#    'breast cancer',
#    'biliary tract cancer',
#    'gallbladder cancer',
#    'ampullary cancer'],
#   'biomarker': ['her2', 'erbb2']},
#  {'cancer_type': ['solid tumors',
#    'cancer',
#    'hepatobiliary cancer',
#    'breast cancer',
#    'biliary tract cancer'],
#   'biomarker': ['her2', 'erbb2']},
#  {'cancer_type': ['cancer',
#    'solid tumors',
#    'biliary tract cancer',
#    'breast cancer'],
#   'biomarker': ['her2', 'erbb2']},
#  {'cancer_type': ['hepatobiliary cancer',
#    'biliary tract cancers',
#    'biliary tract cancer',
#    'cancer'],
#   'biomarker': ['her2', 'erbb2']},
#  {'cancer_type': ['biliary tract cancers', 'biliary tract cancer', 'cancer'],
#   'biomarker': ['her2', 'erbb2']},
#  {'cancer_type': ['cervical',
#    'solid tumors',
#    'cancers',
#    'endometrial',
#    'tumors',
#    'breast',
#    'lymphomas',
#    'myelomas',
#    'urothelial',
#    'malignancies'],
#   'biomarker': ['fgfr', 'fgfr1-4', 'fgfr3', 'fgfr1', 'fgfr2']},
#  {'cancer_type': ['cervical',
#    'solid tumors',
#    'cancers',
#    'endometrial',
#    'tumors',
#    'breast',
#    'lymphomas',
#    'myelomas',
#    'urothelial',
#    'malignancies'],
#   'biomarker': ['fgfr', 'fgfr1-4', 'fgfr3', 'fgfr1', 'fgfr2']},
#  {'cancer_type': ['cancer',
#    'gastrointestinal stromal tumors',
#    'gastrointestinal stromal tumor',
#    'heme malignancies',
#    'gist'],
#   'biomarker': ['kit', 'abl1']},
#  {'cancer_type': ['cancer',
#    'gastrointestinal stromal tumors',
#    'gastrointestinal stromal tumor',
#    'gist',
#    'soft tissue sarcoma'],
#   'biomarker': ['kit']},
#  {'cancer_type': ['non-small cell lung cancer',
#    'colorectal cancer',
#    'tumors',
#    'tumor',
#    'pancreatic ductal adenocarcinoma',
#    'xenograft'],
#   'biomarker': ['ras', 'kras', 'erk']},
#  {'cancer_type': ['cancer type',
#    'solid tumors',
#    'metastatic',
#    'tumors',
#    'stage',
#    'melanoma'],
#   'biomarker': ['v600k', 'raf', 'mek', 'mek1 / 2', 'braf', 'kras']},
#  {'cancer_type': ['cancer type',
#    'solid tumors',
#    'metastatic',
#    'tumors',
#    'melanoma'],
#   'biomarker': ['v600k', 'raf', 'mek', 'mek1 / 2', 'braf', 'kras']},
#  {'cancer_type': ['cancer type',
#    'solid tumors',
#    'metastatic',
#    'tumors',
#    'melanoma'],
#   'biomarker': ['v600k', 'raf', 'mek', 'mek1 / 2', 'braf', 'kras']},
#  {'cancer_type': ['antitumor',
#    'cancer type',
#    'pancreatic ductal adenocarcinoma mouse xenograft',
#    'solid tumors'],
#   'biomarker': ['mapk', 'g12d', 'kras g12d', 'kras']},
#  {'cancer_type': ['cancer type',
#    'solid tumors',
#    'antitumor',
#    'cancerres',
#    'non-small cell lung cancer mouse xenograft',
#    'tumor',
#    'pancreatic ductal adenocarcinoma'],
#   'biomarker': ['g12d', 'kras g12d', 'kras', 'erk']},
#  {'cancer_type': ['cancer type',
#    'non-small cell lung cancer',
#    'solid tumors',
#    'nsclc'],
#   'biomarker': ['met tyrosine kinase', 'met']},
#  {'cancer_type': ['cancer type',
#    'non-small cell lung cancer',
#    'solid tumors',
#    'nsclc'],
#   'biomarker': ['met tyrosine kinase', 'met']},
#  {'cancer_type': ['cancer type',
#    'non-small cell lung cancer',
#    'solid tumors',
#    'nsclc'],
#   'biomarker': ['met tyrosine kinase', 'met']},
#  {'cancer_type': ['cancer type',
#    'renal cell carcinoma',
#    'solid tumors',
#    'rcc',
#    'xenograft'],
#   'biomarker': ['mtor',
#    'pten',
#    'tsc1',
#    'tsc2',
#    'mammalian target of rapamycin']},
#  {'cancer_type': ['cancer type',
#    'renal cell carcinoma',
#    'solid tumors',
#    'rcc',
#    'xenograft'],
#   'biomarker': ['mtor',
#    'pten',
#    'tsc1',
#    'tsc2',
#    'mammalian target of rapamycin']},
#  {'cancer_type': ['cancer type', 'xenograft models', 'solid tumors', 'tumor'],
#   'biomarker': ['ntrk1', 'g595r', 'ntrk', 'ntrk tyrosine kinase']},
#  {'cancer_type': ['cancer type', 'xenograft', 'solid tumors', 'tumor'],
#   'biomarker': ['g623r', 'ntrk3', 'ntrk', 'ntrk tyrosine kinase']},
#  {'cancer_type': ['solid tumors',
#    'cancer',
#    'cancerres',
#    'her2',
#    'tumor',
#    'breast cancer',
#    'anti',
#    'xenograft'],
#   'biomarker': ['pi3kα', 'pik3ca']},
#  {'cancer_type': ['tumor', 'xenograft', 'her2', 'breast cancer'],
#   'biomarker': ['estrogen receptor',
#    'hr',
#    'e453k',
#    'her2',
#    'pi3kα',
#    'hormone receptor',
#    'pik3ca']},
#  {'cancer_type': ['ph + cml'],
#   'biomarker': ['bcr-abl1', 'abl1', 'bcr-abl kinase', 'bcr-abl']},
#  {'cancer_type': ['cancer', 'ph + cml', 'chronic myelogenous leukemia'],
#   'biomarker': ['t315i', 'bcr-abl']},
#  {'cancer_type': ['ph + cml'],
#   'biomarker': ['bcr-abl1', 'abl1', 'bcr-abl kinase', 'bcr-abl']},
#  {'cancer_type': ['cancer', 'ph + cml', 'chronic myelogenous leukemia'],
#   'biomarker': ['t315i', 'bcr-abl']},
#  {'cancer_type': ['ph + cml'],
#   'biomarker': ['bcr-abl1', 'abl1', 'bcr-abl kinase', 'bcr-abl']},
#  {'cancer_type': ['cancer', 'ph + cml', 'chronic myelogenous leukemia'],
#   'biomarker': ['t315i', 'bcr-abl']},
#  {'cancer_type': ['ph + cml'],
#   'biomarker': ['bcr-abl1', 'abl1', 'bcr-abl kinase', 'bcr-abl']},
#  {'cancer_type': ['cancer', 'ph + cml', 'chronic myelogenous leukemia'],
#   'biomarker': ['bcr-abl']},
#  {'cancer_type': ['lymphoma',
#    'b-lymphoblastic leukemia',
#    'cancer',
#    'chronic myelogenous leukemia',
#    'ph'],
#   'biomarker': ['src', 'abl', 'level _ r1', 'f317l', 'bcr-abl', 'v299l']},
#  {'cancer_type': ['cancer', 'ph + cml', 'chronic myelogenous leukemia'],
#   'biomarker': ['abl', 'src', 'f317l', 'v299l']},
#  {'cancer_type': ['b-lymphoblastic leukemia',
#    'lymphoma',
#    'cancer',
#    'ph + all',
#    'ph',
#    'philadelphia chromosome'],
#   'biomarker': ['src', None, 'bcr-abl', 'level', 'v299l']},
#  {'cancer_type': ['cancer',
#    'ph + cml',
#    'chronic myelogenous leukemia',
#    'ph + all',
#    'chronic phase cml',
#    'ph'],
#   'biomarker': ['v299l', 'src', 'f317l', 'bcr-abl']},
#  {'cancer_type': ['b-lymphoblastic leukemia',
#    'lymphoma',
#    'ph + acute lymphoblastic leukemia',
#    'all',
#    'adult acute lymphoblastic leukemia',
#    'cancer',
#    'ph'],
#   'biomarker': ['abl', 'bcr-abl']},
#  {'cancer_type': ['chronic myeloid leukemia', 'ph', 'ph + cml'],
#   'biomarker': ['bcr-abl']},
#  {'cancer_type': ['all', 'philadelphia chromosome', 'cml', 'cp ph + cml'],
#   'biomarker': ['level', 'bcr-abl']},
#  {'cancer_type': ['cml'], 'biomarker': ['bcr-abl kinase', 'bcr-abl']},
#  {'cancer_type': ['cancer type',
#    'cll',
#    'chronic lymphocytic leukemia',
#    'sll',
#    'small lymphocytic lymphoma',
#    'chronic lymphocytic leukemia /'],
#   'biomarker': ['perk', 'level', 'btk']},
#  {'cancer_type': ['cancer type', 'non-small cell lung cancer', 'lung cancers'],
#   'biomarker': ['t790m', 'egfr', 'level', 'egfr tyrosine kinase']},
#  {'cancer_type': ['cancer type', 'non-small cell lung cancer', 'lung cancers'],
#   'biomarker': ['t790m', 'egfr', 'level', 'egfr tyrosine kinase']},
#  {'cancer_type': ['cancer type', 'non-small cell lung cancer', 'lung cancers'],
#   'biomarker': ['t790m', 'egfr', 'level', 'egfr tyrosine kinase']},
#  {'cancer_type': ['mcrc',
#    'cancer',
#    'colorectal cancer',
#    'metastatic colorectal cancer'],
#   'biomarker': ['level _ r1', 'egfr', 'kras', 'ras']},
#  {'cancer_type': ['mcrc',
#    'cancer',
#    'colorectal cancer',
#    'metastatic colorectal cancer'],
#   'biomarker': ['level _ r1', 'egfr', 'kras', 'ras']},
#  {'cancer_type': ['cancer', 'tumors', 'colorectal cancer'],
#   'biomarker': ['her2', 'braf', 'level _ r1', 'kras', 'ras']},
#  {'cancer_type': ['cancer type', 'tumor', 'solid tumors', 'solid cancer'],
#   'biomarker': ['ntrk1', 'level _ r1', 'ntrk', None]},
#  {'cancer_type': ['cancer', 'solid tumors'],
#   'biomarker': ['g623r',
#    'ntrk',
#    None,
#    'ntrk1 / 2',
#    'level _ r1',
#    'etv6',
#    'ntrk3']},
#  {'cancer_type': ['cancer', 'solid tumors', 'tumor'],
#   'biomarker': ['ntrk1', 'ntrk', None, 'ntrk3', 'level']},
#  {'cancer_type': ['cancer', 'solid tumors', 'tumor'],
#   'biomarker': ['trk', 'ntrk1', 'ntrk', None, 'ntrk3', 'level']},
#  {'cancer_type': ['cancer type',
#    'gists',
#    'gastrointestinal stromal tumors',
#    'gastrointestinal stromal tumor',
#    'gist'],
#   'biomarker': ['pdgfra', 'level _ r1', 'kit']},
#  {'cancer_type': ['cancer type',
#    'non-small cell lung cancer',
#    'lung cancer',
#    'lung cancers'],
#   'biomarker': ['egfr', 'met', 'alk', 'kras', 'eml4', 'ros1', 'level']},
#  {'cancer_type': ['cancer type',
#    'non-small cell lung cancer',
#    'lung cancer',
#    'lung cancers'],
#   'biomarker': ['egfr', 'met', 'alk', 'kras', 'eml4', 'ros1', 'l1196m']},
#  {'cancer_type': ['cancer type',
#    'non-small cell lung cancer',
#    'lung cancers',
#    'tumor',
#    'nsclc',
#    'xenograft'],
#   'biomarker': ['eml4-alk', 'met', 'alk', 'eml4', 'ros1', 'level']},
#  {'cancer_type': ['cancer', 'non-small cell lung cancer', 'nsclc'],
#   'biomarker': ['level', 'alk']},
#  {'cancer_type': ['cancer', 'non-small cell lung cancer', 'nsclc'],
#   'biomarker': ['g1202r', 'alk tyrosine kinase', 'level', 'alk']},
#  {'cancer_type': ['non-small cell lung cancer',
#    'cancer',
#    'tumors',
#    'lung adenocarcinoma',
#    'nsclc'],
#   'biomarker': ['ros1', 'kit', 'g1202r', 'alk']},
#  {'cancer_type': ['cancer type',
#    'non-small cell lung cancer',
#    'tumors',
#    'nsclc'],
#   'biomarker': ['g1202r', 'alk']},
#  {'cancer_type': ['cancer type',
#    'non-small cell lung cancer',
#    'lung adenocarcinoma',
#    'nsclc'],
#   'biomarker': ['g1202r', 'alk']},
#  {'cancer_type': ['cll',
#    'cancer',
#    'chronic lymphocytic leukemia',
#    'sll',
#    'small lymphocytic lymphoma'],
#   'biomarker': ['btk']},
#  {'cancer_type': ['cancer type',
#    'cll',
#    'chronic lymphocytic leukemia',
#    'sll',
#    'small lymphocytic lymphoma'],
#   'biomarker': ['btk']},
#  {'cancer_type': ['cll',
#    'cancer',
#    'chronic lymphocytic leukemia',
#    'sll',
#    'small lymphocytic lymphoma'],
#   'biomarker': ['c481f', 'level', 'btk']},
#  {'cancer_type': ['cancer type',
#    'cll',
#    'chronic lymphocytic leukemia',
#    'sll',
#    'small lymphocytic lymphoma',
#    'waldenström macroglobulinemia'],
#   'biomarker': ['c481r', 'c481y', 'btk']},
#  {'cancer_type': ['cancer type',
#    'cll',
#    'chronic lymphocytic leukemia',
#    'sll',
# ...
#    'mcrpc',
#    'prostate cancer',
#    'cancer'],
#   'biomarker': ['parp', 'rad51d']},
#  {'cancer_type': ['metastatic castration-resistant prostate cancer',
#    'mcrpc',
#    'prostate cancer',
#    'cancer'],
#   'biomarker': ['parp', 'rad51d']},
#  {'cancer_type': ['cancer', 'advanced', 'epithelioid sarcoma'],
#   'biomarker': ['smarcb1', 'ezh2']},
#  {'cancer_type': ['glioma',
#    'tsc',
#    'subependymal giant cell astrocytoma',
#    'cancer',
#    'segas',
#    'tuberous sclerosis complex',
#    'sega'],
#   'biomarker': ['pi3k', 'mtor', 'tsc1', 'tsc2', 'akt']},
#  {'cancer_type': ['pancreatic adenocarcinoma', 'pancreatic cancer'],
#   'biomarker': ['palb2', 'parp', 'kras', 'brca1 / 2']},
#  {'cancer_type': ['pancreatic adenocarcinoma', 'pancreatic cancer'],
#   'biomarker': ['palb2', 'parp', 'kras', 'brca1 / 2']},
#  {'cancer_type': ['uterine cancers',
#    'cancer',
#    'ovarian cancer',
#    'breast',
#    'uterine cancer',
#    'uterine sarcoma',
#    'uterine leiomyosarcoma'],
#   'biomarker': ['brca2', 'parp', 'pten', 'tp53']},
#  {'cancer_type': ['platinum',
#    'ovarian cancer',
#    'pancreatic cancer',
#    'pancreatic adenocarcinoma',
#    'xenograft'],
#   'biomarker': ['brca1', 'palb2', 'brca2', 'parp', 'kras', 'brca1 / 2']},
#  {'cancer_type': ['platinum',
#    'ovarian cancer',
#    'pancreatic cancer',
#    'pancreatic adenocarcinoma',
#    'xenograft'],
#   'biomarker': ['brca1', 'palb2', 'brca2', 'parp', 'kras', 'brca1 / 2']},
#  {'cancer_type': ['uterine cancers',
#    'cancer',
#    'ovarian cancer',
#    'breast',
#    'uterine cancer',
#    'uterine sarcoma',
#    'uterine leiomyosarcoma'],
#   'biomarker': ['brca2', 'parp', 'pten', 'tp53']},
#  {'cancer_type': ['uterine cancers',
#    'cancer',
#    'ovarian cancer',
#    'breast',
#    'uterine cancer',
#    'uterine sarcoma',
#    'uterine leiomyosarcoma'],
#   'biomarker': ['brca2', 'parp', 'pten', 'tp53']},
#  {'cancer_type': ['head and neck cancer',
#    'cancer type',
#    'carcinoma',
#    'pleomorphic adenoma',
#    'salivary gland cancer',
#    'breast cancer',
#    'salivary duct carcinoma'],
#   'biomarker': ['her2']},
#  {'cancer_type': ['cancer',
#    'breast cancer',
#    'uterine papillary serous carcinoma',
#    'uterine serous carcinoma',
#    'uterine cancer'],
#   'biomarker': ['erbb2', 'her2 receptor']},
#  {'cancer_type': ['colorectal cancer',
#    'cancer',
#    'advanced tumors',
#    'tumors',
#    'her2'],
#   'biomarker': ['braf', 'ras', 'her2', 'kras']},
#  {'cancer_type': ['hepatobiliary cancer',
#    'biliary tract cancers',
#    'biliary tract cancer',
#    'cancer'],
#   'biomarker': ['her2']},
#  {'cancer_type': ['biliary tract cancers', 'biliary tract cancer', 'cancer'],
#   'biomarker': ['her2']},
#  {'cancer_type': ['cancer type',
#    'colorectal cancer',
#    'hepatobiliary cancer',
#    'biliary tract cancers',
#    'biliary tract cancer'],
#   'biomarker': ['ras', 'her2']},
#  {'cancer_type': ['biliary tract cancers',
#    'cancer type',
#    'biliary tract cancer',
#    'colorectal cancer'],
#   'biomarker': ['ras', 'her2']},
#  {'cancer_type': ['cancer', 'tumors', 'colorectal cancer'],
#   'biomarker': ['egfr',
#    'her2',
#    'braf',
#    'kras',
#    'her2 receptor',
#    'ras',
#    'erbb2']},
#  {'cancer_type': ['head and neck cancer',
#    'cancer type',
#    'carcinoma',
#    'pleomorphic adenoma',
#    'salivary gland cancer',
#    'breast cancer',
#    'salivary duct carcinoma'],
#   'biomarker': ['her2']},
#  {'cancer_type': ['head and neck cancer',
#    'solid tumors',
#    'cancer',
#    'tumors',
#    'salivary gland cancer',
#    'breast cancer'],
#   'biomarker': ['cep17', 'her2', 'microtubule', 'erbb2']},
#  {'cancer_type': ['cancer type',
#    'gastric cancer',
#    'colorectal cancer',
#    'breast'],
#   'biomarker': ['her2', 'erbb2']},
#  {'cancer_type': ['head and neck cancer',
#    'salivary gland cancer',
#    'cancer',
#    'breast cancer'],
#   'biomarker': ['her2']},
#  {'cancer_type': ['head and neck cancer',
#    'cancer type',
#    'salivary gland cancer',
#    'breast cancer'],
#   'biomarker': ['anti-her2', 'ihc 3', 'her2', 'anti', 'cep17']},
#  {'cancer_type': ['cancer', 'follicular lymphoma', 'tumors', 'fl'],
#   'biomarker': ['ezh2', 'level']},
#  {'cancer_type': ['non-small cell lung cancer',
#    'lung cancer',
#    'metastatic',
#    'tumors',
#    'nsclc'],
#   'biomarker': ['c-met', 'ros1', 'met', 'alk']},
#  {'cancer_type': ['non-small cell lung cancer',
#    'metastatic',
#    'cancer',
#    'tumors',
#    'nsclc'],
#   'biomarker': ['met', 'level']},
#  {'cancer_type': ['cancer', 'non-small cell lung cancer', 'nsclc'],
#   'biomarker': ['met tyrosine kinase', 'met', 'level']},
#  {'cancer_type': ['pancreatic adenocarcinoma',
#    'cancer type',
#    'pancreatic cancer'],
#   'biomarker': ['palb2', 'parp', 'kras', 'brca1 / 2']},
#  {'cancer_type': ['pancreatic adenocarcinoma',
#    'cancer type',
#    'acinar cell carcinoma of',
#    'pancreatic cancer'],
#   'biomarker': ['palb2', 'parp', 'kras', 'brca1 / 2']},
#  {'cancer_type': ['pancreatic adenocarcinoma', 'paad'],
#   'biomarker': ['brca1', 'parp', 'brca']},
#  {'cancer_type': ['pancreatic adenocarcinoma', 'paad'],
#   'biomarker': ['brca1', 'parp', 'brca']},
#  {'cancer_type': ['solid tumors', 'tumor', 'breast cancer'],
#   'biomarker': ['brca1', 'her2', 'atm', 'parp', 'brca']},
#  {'cancer_type': ['breast cancer'],
#   'biomarker': ['brca1', 'her2', 'parp', 'brca1 / 2', 'brca']},
#  {'cancer_type': ['pancreatic adenocarcinoma', 'paad'],
#   'biomarker': ['brca1', 'parp', 'brca']},
#  {'cancer_type': ['pancreatic adenocarcinoma', 'paad'],
#   'biomarker': ['brca1', 'parp', 'brca']},
#  {'cancer_type': ['solid tumors', 'tumor', 'breast cancer'],
#   'biomarker': ['brca1', 'her2', 'atm', 'parp', 'brca']},
#  {'cancer_type': ['breast cancer'],
#   'biomarker': ['brca1', 'her2', 'parp', 'brca1 / 2', 'brca']},
#  {'cancer_type': ['ovarian',
#    'lung',
#    'gynecologic cancers',
#    'colorectal',
#    'tumors',
#    'endometrial',
#    'breast',
#    'tumor',
#    'xenograft'],
#   'biomarker': ['atr', 'pkmyt1', 'ppp2r1a', 'fbxw7', 'ccne1']},
#  {'cancer_type': ['ovarian',
#    'lung',
#    'gynecologic cancers',
#    'colorectal',
#    'tumors',
#    'endometrial',
#    'breast',
#    'tumor',
#    'xenograft'],
#   'biomarker': ['atr', 'pkmyt1', 'ppp2r1a', 'fbxw7', 'ccne1']},
#  {'cancer_type': ['gea',
#    'gastroesophageal adenocarcinoma',
#    'colorectal cancer'],
#   'biomarker': ['ras', 'egfr']},
#  {'cancer_type': ['gea',
#    'gastroesophageal adenocarcinoma',
#    'colorectal cancer'],
#   'biomarker': ['ras', 'egfr']},
#  {'cancer_type': ['gea',
#    'gastroesophageal adenocarcinoma',
#    'colorectal cancer'],
#   'biomarker': ['ras', 'egfr']},
#  {'cancer_type': ['gea',
#    'gastroesophageal adenocarcinoma',
#    'colorectal cancer'],
#   'biomarker': ['ras', 'egfr']},
#  {'cancer_type': ['non-small cell lung cancer', 'solid tumor', 'solid tumors'],
#   'biomarker': ['her2', 'erbb2']},
#  {'cancer_type': ['cancer type',
#    'hepatobiliary cancer',
#    'biliary tract cancer',
#    'btc',
#    'solid tumor types'],
#   'biomarker': ['4b5', 'her-2', 'her2', 'neu', 'erbb2']},
#  {'cancer_type': ['cancer', 'solid tumor', 'btc', 'biliary tract cancer'],
#   'biomarker': ['4b5', 'her-2', 'her2', 'neu', 'erbb2']},
#  {'cancer_type': ['cancer',
#    'tumors',
#    'muscle-invasive urothelial bladder carcinoma',
#    'bladder cancer',
#    'xenograft',
#    'muscle-invasive bladder cancer'],
#   'biomarker': ['ercc2', 'ercc1']},
#  {'cancer_type': ['ovarian',
#    'lung',
#    'gynecologic cancers',
#    'colorectal',
#    'tumors',
#    'endometrial',
#    'breast',
#    'tumor',
#    'xenograft'],
#   'biomarker': ['atr', 'pkmyt1', 'ppp2r1a', 'fbxw7', 'ccne1']},
#  {'cancer_type': ['ovarian',
#    'lung',
#    'gynecologic cancers',
#    'colorectal',
#    'tumors',
#    'endometrial',
#    'breast',
#    'tumor',
#    'xenograft'],
#   'biomarker': ['atr', 'pkmyt1', 'ppp2r1a', 'fbxw7', 'ccne1']},
#  {'cancer_type': ['ampullary carcinoma',
#    'cholangiocarcinoma',
#    'cancer',
#    'hepatobiliary cancer',
#    'cc',
#    'biliary tract cancer',
#    'gallbladder carcinoma',
#    'intrahepatic cc'],
#   'biomarker': ['p53', 'mdm2', 'pd-1']},
#  {'cancer_type': ['ampullary carcinoma',
#    'cholangiocarcinoma',
#    'cancer',
#    'cc',
#    'biliary tract cancer',
#    'gallbladder carcinoma',
#    'intrahepatic cc'],
#   'biomarker': ['p53', 'mdm2', 'pd-1']},
#  {'cancer_type': ['intimal sarcoma', 'cancer type', 'sarcoma'],
#   'biomarker': ['p53', 'mdm2', 'tp53']},
#  {'cancer_type': ['cancer', 'ddlps', 'solid tumors'],
#   'biomarker': ['p53', 'mdm2', 'tp53']},
#  {'cancer_type': ['cancer',
#    'well-differentiated liposarcoma',
#    'solid tumors',
#    'wdlps'],
#   'biomarker': ['p53', 'mdm2', 'tp53']},
#  {'cancer_type': ['ampullary carcinoma',
#    'cholangiocarcinoma',
#    'cancer',
#    'hepatobiliary cancer',
#    'cc',
#    'biliary tract cancer',
#    'gallbladder carcinoma',
#    'intrahepatic cc'],
#   'biomarker': ['p53', 'mdm2', 'pd-1']},
#  {'cancer_type': ['ampullary carcinoma',
#    'cholangiocarcinoma',
#    'cancer',
#    'cc',
#    'biliary tract cancer',
#    'gallbladder carcinoma',
#    'intrahepatic cc'],
#   'biomarker': ['p53', 'mdm2', 'pd-1']},
#  {'cancer_type': ['cancer type',
#    'non-small cell lung cancer',
#    'nonsquamous',
#    'nsclc'],
#   'biomarker': ['met receptor', 'egfr', 'level']},
#  {'cancer_type': ['neuroendocrine tumor',
#    'non-small cell lung cancer',
#    'renal cell carcinoma',
#    'solid tumors',
#    'pdac',
#    'cholangiocarcinoma',
#    'meso',
#    'sarcoma',
#    'gastrointestinal stromal tumor',
#    'salivary',
#    'pancreatic ductal adenocarcinoma',
#    'cca',
#    'nsclc',
#    'mtap',
#    'ovarian sertoli-leydig',
#    'mesothelioma',
#    'pulmonary pleomorphic carcinoma'],
#   'biomarker': ['prmt5', 'mtap']},
#  {'cancer_type': ['malignant mesothelioma',
#    'non-small cell lung cancer',
#    'gallbladder adenocarcinoma',
#    'solid tumors',
#    'malignant peripheral nerve sheath tumor',
#    'cancer type',
#    'malignant melanoma',
#    'tumor',
#    'xenograft',
#    'tumorpsies'],
#   'biomarker': ['prmt5', 'mtap', 'mta complex']},
#  {'cancer_type': ['acute leukemia', 'cancer', 'acute myeloid leukemia'],
#   'biomarker': ['npm1', 'meis1', 'kmt2a', 'mll', 'menin', 'hox']},
#  {'cancer_type': ['ovarian',
#    'lung',
#    'gynecologic cancers',
#    'colorectal',
#    'cancer',
#    'ovarian cancer',
#    'tumors',
#    'endometrial',
#    'breast',
#    'tumor'],
#   'biomarker': ['atr', 'pkmyt1', 'ppp2r1a', 'fbxw7', 'c46f541b', 'ccne1']},
#  {'cancer_type': ['ovarian',
#    'lung',
#    'gynecologic cancers',
#    'colorectal',
#    'cancer',
#    'tumors',
#    'endometrial',
#    'breast',
#    'tumor',
#    'endometrial cancer'],
#   'biomarker': ['atr', 'pkmyt1', 'ppp2r1a', 'fbxw7', 'c46f541b', 'ccne1']},
#  {'cancer_type': ['cancer type',
#    'non-small cell lung cancer',
#    'nsclc xenograft',
#    'cancerres',
#    'tumor',
#    'nsclc',
#    'esophageal adenocarcinoma'],
#   'biomarker': ['smarca4', 'smarca2']},
#  {'cancer_type': ['cancer type',
#    'non-small cell lung cancer',
#    'nsclc xenograft',
#    'cancerres',
#    'tumor',
#    'nsclc',
#    'esophageal adenocarcinoma'],
#   'biomarker': ['smarca4', 'smarca2']},
#  {'cancer_type': ['cancer', 'perivascular epithelioid cell tumor', 'pecomas'],
#   'biomarker': ['mtor', None, 'tsc1', 'tsc2', 'level']},
#  {'cancer_type': ['cancer', 'pecomas', 'uterine perivascularpithelioid tumor'],
#   'biomarker': ['mtor', None, 'tsc1', 'tsc2', 'level']},
#  {'cancer_type': ['cancer type',
#    'ovarian',
#    'solid tumors',
#    'colorectal',
#    'ovarian cancer',
#    'tumors',
#    'tumor',
#    'xenograft',
#    'bile duct cancer'],
#   'biomarker': ['atr',
#    'ca-125',
#    'pkmyt1',
#    'ppp2r1a',
#    'fbxw7',
#    'ccne1',
#    'cyclin e1']},
#  {'cancer_type': ['ovarian',
#    'lung',
#    'solid tumors',
#    'colorectal',
#    'endometrial',
#    'tumors',
#    'breast',
#    'tumor',
#    'advanced',
#    'xenograft',
#    'bile duct cancer'],
#   'biomarker': ['atr', 'pkmyt1', 'ppp2r1a', 'fbxw7', 'ccne1']},
#  {'cancer_type': ['solid tumors',
#    'cancer',
#    'tumors',
#    'cancerres',
#    'xenograft tumor',
#    'tumor'],
#   'biomarker': ['cyclin e1', 'cdk2']},
#  {'cancer_type': ['cancer',
#    'breast cancer',
#    'dedifferentiated liposarcoma',
#    'tumor'],
#   'biomarker': ['rb',
#    'cdk4',
#    'mdm2',
#    'cyclin-dependent kinases 4',
#    'estrogen']},
#  {'cancer_type': ['cancer', 'breast cancer', 'tumor'],
#   'biomarker': ['rb',
#    'cdk4',
#    'mdm2',
#    'cyclin-dependent kinases 4',
#    'estrogen']},
#  {'cancer_type': ['cancer',
#    'breast cancer',
#    'dedifferentiated liposarcoma',
#    'tumor'],
#   'biomarker': ['rb',
#    'cdk4',
#    'mdm2',
#    'cyclin-dependent kinases 4',
#    'estrogen']},
#  {'cancer_type': ['cancer', 'breast cancer', 'tumor'],
#   'biomarker': ['rb',
#    'cdk4',
#    'mdm2',
#    'cyclin-dependent kinases 4',
#    'estrogen']},
#  {'cancer_type': ['cancer', 'solid tumors', 'uterine leiomyosarcoma'],
#   'biomarker': ['cdk6', 'cdk4 / 6', 'cdkn2a', 'cdk4']},
#  {'cancer_type': ['cancer', 'solid tumors', 'uterine leiomyosarcoma'],
#   'biomarker': ['cdk6', 'cdk4 / 6', 'cdkn2a', 'cdk4']},
#  {'cancer_type': ['cancer', 'solid tumors', 'uterine leiomyosarcoma'],
#   'biomarker': ['cdk6', 'cdk4 / 6', 'cdkn2a', 'cdk4']},
#  {'cancer_type': ['cancer', 'glioma'], 'biomarker': ['egfr', 'erbb2']},
#  {'cancer_type': ['ovarian',
#    'lung',
#    'solid tumors',
#    'colorectal',
#    'colorectal cancer',
#    'tumors',
#    'endometrial',
#    'breast',
#    'tumor',
#    'breast cancer',
#    'xenograft'],
#   'biomarker': ['atr', 'pkmyt1', 'ppp2r1a', 'fbxw7', 'ccne1']},
#  {'cancer_type': ['cancer type', 'solid tumors'],
#   'biomarker': ['fgfr2', 'fgfri']},
#  {'cancer_type': ['cancer', 'tumors', 'bladder cancer'],
#   'biomarker': ['kdm6a', 'ezh2']},
#  {'cancer_type': ['solid tumors',
#    'intrahepatic cholangiocarcinoma',
#    'cancer',
#    'well-differentiated liposarcoma',
#    'tumors',
#    'pancreatic cancer'],
#   'biomarker': ['p53', 'mdm2', 'tp53']},
#  {'cancer_type': ['solid tumors',
#    'cancer',
#    'retesarcoma',
#    'liposarcoma',
#    'wd'],
#   'biomarker': ['p53', 'mdm2']},
#  {'cancer_type': ['cancer type',
#    'solid tumors',
#    'retesarcoma',
#    'liposarcoma',
#    'wd'],
#   'biomarker': ['p53', 'mdm2']},
#  {'cancer_type': ['solid tumors',
#    'astrocytoma',
#    'nf1',
#    'cancer',
#    'tumor',
#    'neurofibromatosis',
#    'neurofibromatosis type i'],
#   'biomarker': ['mek2', 'nf1', 'mek', 'mek1', 'mapk']},
#  {'cancer_type': ['solid tumors',
#    'astrocytoma',
#    'nf1',
#    'cancer',
#    'tumor',
#    'neurofibromatosis',
#    'neurofibromatosis type i'],
#   'biomarker': ['mek2', 'nf1', 'mek', 'mek1', 'mapk']},
#  {'cancer_type': ['cervical cancer',
#    'ovarian',
#    'lung',
#    'solid tumors',
#    'colorectal',
#    'cancer',
#    'endometrial',
#    'tumors',
#    'breast',
#    'tumor',
#    'advanced'],
#   'biomarker': ['atr', 'pkmyt1', 'ppp2r1a', 'fbxw7', 'ccne1']},
#  {'cancer_type': ['castration',
#    'cancer type',
#    'solid tumors',
#    'colorectal cancer',
#    'prostate cancer'],
#   'biomarker': ['pten', 'mtorc1 / 2', 'pi3kβ']},
#  {'cancer_type': ['castration',
#    'cancer type',
#    'solid tumors',
#    'colorectal cancer',
#    'prostate cancer'],
#   'biomarker': ['pten', 'mtorc1 / 2', 'pi3kβ']},
#  {'cancer_type': ['solid tumors',
#    'malignant rhabdoid tumors',
#    'cancer',
#    'synovial sarcomas',
#    'tumors',
#    'liquid tumors',
#    'b-cell non-hodgkin lymphoma',
#    'xenograft'],
#   'biomarker': ['ssx', 'smarcb1', 'ezh2', 'ss18-']},
#  {'cancer_type': ['cancer', 'non-small cell lung cancer', 'tumor', 'nsclc'],
#   'biomarker': ['pd-1', 'axl', 'stk11']},
#  {'cancer_type': ['myelodysplastic syndromes',
#    'cmml',
#    'chronic myelomonocytic leukemia'],
#   'biomarker': ['atr',
#    'u2af1',
#    'srsf2',
#    'sf3b1',
#    'zrsr2',
#    'spliceosome complex']},
#  {'cancer_type': ['myelodysplastic syndromes',
#    'cmml',
#    'chronic myelomonocytic leukemia'],
#   'biomarker': ['atr',
#    'u2af1',
#    'srsf2',
#    'sf3b1',
#    'zrsr2',
#    'spliceosome complex']},
#  {'cancer_type': ['cancer', 'non-small cell lung cancer', 'lung cancer'],
#   'biomarker': ['erbb3',
#    'pi3k',
#    'egfr tyrosine kinase',
#    'egfr',
#    'met',
#    'level']},
#  {'cancer_type': ['cancer', 'non-small cell lung cancer', 'lung cancer'],
#   'biomarker': ['erbb3',
#    'pi3k',
#    'egfr tyrosine kinase',
#    'egfr',
#    'met',
#    'level']},
#  {'cancer_type': ['cancer', 'non-small cell lung cancer', 'lung cancer'],
#   'biomarker': ['erbb3',
#    'pi3k',
#    'egfr tyrosine kinase',
#    'egfr',
#    'met',
#    'level']}]

# %%
no_cancer_idx = []
no_biomarker_idx = []
for i, e in tqdm(enumerate(context_extracted_entities)):
    if not e['cancer_type']:
        no_cancer_idx.append(i)
    if not e['biomarker']:
        no_biomarker_idx.append(i)

print(f"{len(no_cancer_idx)*100/len(_CONTEXT):.3f}%") #no cancer entity extracted %
print(f"{len(no_biomarker_idx)*100/len(_CONTEXT):.3f}%") #no biomarker entity extracted %
# Out:
# 625it [00:00, 2508555.02it/s]
# 0.160%
# 0.320%

# %%
#save
os.makedirs("context_retriever/entities", exist_ok=True)
with open(f"context_retriever/entities/oncokb_db_context_ner_entities__{_VERSION}.json", "w") as f:
    json.dump(context_extracted_entities, f, indent=4)
