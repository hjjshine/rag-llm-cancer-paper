# %%
import pandas as pd 
import numpy as np
import os
from tqdm import tqdm
from glob import glob
import requests
import ast
from bs4 import BeautifulSoup
os.makedirs('formatted-data', exist_ok=True)

# %%
oncokb_df = pd.read_csv('processed-data/oncokb_all.csv')
oncokb_df['cancer_type_raw_text'] = oncokb_df['cancer_type_raw_text'].apply(lambda x: ast.literal_eval(x))
oncokb_df.head(1)
# Out:
#   alterations      drugs approvedIndications    level    fdaLevel  \
# 0       T315I  Ponatinib                 NaN  LEVEL_1  LEVEL_Fda2
#
#            levelAssociatedCancerType levelExcludedCancerTypes  \
# 0  B-Lymphoblastic Leukemia/Lymphoma                       []
#
#                         pmids abstracts  \
# 0  24180494,23190221,29567798       NaN
#
#                                          description  gene change  \
# 0  Ponatinib is a small molecule kinase inhibitor...  ABL1  t315i
#
#                                 cancer_type_raw_text
# 0  {'id': 95, 'code': 'BLL', 'color': 'LimeGreen'...

# %%
oncokb_df[['gene', 'alterations', 'change']].drop_duplicates()
# Out:
#         gene          alterations change
# 0       ABL1                T315I  t315i
# 3       AKT1                 E17K   e17k
# 4       BRAF                V600E  v600e
# 10      BRAF          V600E,V600K  v600e
# 14      BRAF                 V600  v600e
# ..       ...                  ...    ...
# 608    FGFR2        Amplification    NaN
# 609    KDM6A  Oncogenic Mutations    NaN
# 618  SMARCB1  Oncogenic Mutations    NaN
# 619    STK11  Oncogenic Mutations    NaN
# 620    ZRSR2  Oncogenic Mutations    NaN
#
# [181 rows x 3 columns]

# %%
oncokb_df[oncokb_df['alterations'].str.contains('Oncogenic Mutations')]
# Out:
#              alterations                      drugs approvedIndications  \
# 22   Oncogenic Mutations     Datopotamab Deruxtecan                 NaN
# 40   Oncogenic Mutations     Trastuzumab Deruxtecan                 NaN
# 54   Oncogenic Mutations                   Imatinib                 NaN
# 55   Oncogenic Mutations                  Sunitinib                 NaN
# 56   Oncogenic Mutations                Regorafenib                 NaN
# ..                   ...                        ...                 ...
# 617  Oncogenic Mutations                    AZD8186                 NaN
# 618  Oncogenic Mutations               Tazemetostat                 NaN
# 619  Oncogenic Mutations  Bemcentinib,Pembrolizumab                 NaN
# 620  Oncogenic Mutations               Ceralasertib                 NaN
# 621  Oncogenic Mutations               Ceralasertib                 NaN
#
#        level    fdaLevel        levelAssociatedCancerType  \
# 22   LEVEL_1  LEVEL_Fda2       Non-Small Cell Lung Cancer
# 40   LEVEL_1  LEVEL_Fda3       Non-Small Cell Lung Cancer
# 54   LEVEL_1  LEVEL_Fda2   Gastrointestinal Stromal Tumor
# 55   LEVEL_1  LEVEL_Fda2   Gastrointestinal Stromal Tumor
# 56   LEVEL_1  LEVEL_Fda2   Gastrointestinal Stromal Tumor
# ..       ...         ...                              ...
# 617  LEVEL_4  LEVEL_Fda3                 All Solid Tumors
# 618  LEVEL_4  LEVEL_Fda3                All Liquid Tumors
# 619  LEVEL_4  LEVEL_Fda3       Non-Small Cell Lung Cancer
# 620  LEVEL_4  LEVEL_Fda3  Chronic Myelomonocytic Leukemia
# 621  LEVEL_4  LEVEL_Fda3        Myelodysplastic Syndromes
#
#     levelExcludedCancerTypes                                pmids  \
# 22                        []                    39761483,39250535
# 40                        []                             34534430
# 54                        []  28196207,18955451,18235122,12181401
# 55                        []                             17046465
# 56                        []                             23177515
# ..                       ...                                  ...
# 617                      NaN                    28645941,34281912
# 618                      NaN  29650362,23620515,20951942,27391784
# 619                      NaN                                  NaN
# 620                      NaN                                  NaN
# 621                      NaN                                  NaN
#
#                                              abstracts  \
# 22                                                 NaN
# 40                                                 NaN
# 54                                                 NaN
# 55                                                 NaN
# 56                                                 NaN
# ..                                                 ...
# 617  http://ascopubs.org/doi/abs/10.1200/JCO.2017.3...
# 618  http://www.abstractsonline.com/pp8/#!/4557/pre...
# 619  https://jitc.bmj.com/content/9/Suppl_2/A632.al...
# 620  https://journals.lww.com/hemasphere/fulltext/2...
# 621  https://journals.lww.com/hemasphere/fulltext/2...
#
#                                            description     gene   change  \
# 22   Datopotamab deruxtecan (Dato-DXd) is an intrav...     EGFR    c797g
# 40   Trastuzumab Deruxtecan is a HER2-directed anti...    ERBB2    l768s
# 54   Imatinib is a small molecule inhibitor of KIT ...      KIT  p577del
# 55   Sunitinib is a small molecule inhibitor of KIT...      KIT  p577del
# 56   Regorafenib is a small molecule inhibitor of K...      KIT  p577del
# ..                                                 ...      ...      ...
# 617  GSK2636771 and AZD8186 are ATP-competitive sma...     PTEN      NaN
# 618  Tazemetostat is a small molecule inhibitor of ...  SMARCB1      NaN
# 619  Bemcentinib is an inhibitor of the AXL recepto...    STK11      NaN
# 620  Ceralasertib is an orally available, small mol...    ZRSR2      NaN
# 621  Ceralasertib is an orally available, small mol...    ZRSR2      NaN
#
#                                   cancer_type_raw_text
# 22   {'id': 876, 'code': '', 'color': 'Gainsboro', ...
# 40   {'id': 876, 'code': '', 'color': 'Gainsboro', ...
# 54   {'id': 642, 'code': 'GIST', 'color': 'LightYel...
# 55   {'id': 642, 'code': 'GIST', 'color': 'LightYel...
# 56   {'id': 642, 'code': 'GIST', 'color': 'LightYel...
# ..                                                 ...
# 617  {'id': 984, 'code': '', 'color': '', 'name': '...
# 618  {'id': 983, 'code': '', 'color': '', 'name': '...
# 619  {'id': 876, 'code': '', 'color': 'Gainsboro', ...
# 620  {'id': 224, 'code': 'CMML', 'color': 'LightSal...
# 621  {'id': 355, 'code': 'MDS', 'color': 'LightSalm...
#
# [214 rows x 13 columns]

# %%
#oncotree, raw cancer, modified standardized cancer, raw biomarker, therapy
formatted_df = pd.DataFrame()
formatted_df['level'] = oncokb_df['level']
formatted_df['oncotree'] = oncokb_df['cancer_type_raw_text'].apply(lambda x: x['mainType']['name'])
formatted_df['raw_cancer'] = oncokb_df['cancer_type_raw_text'].apply(lambda x: x['name'] if x['name'] != '' else x['mainType']['name'])
formatted_df['standardized_cancer'] = formatted_df['raw_cancer'].apply(lambda x: x.split(',')[0])
def format_biomarker(x):
    if x['alterations'] == 'Fusions':
        return f"{x['gene']} Fusion"
    if x['alterations'] in ['Amplification', 'Deletion']:
        return f"{x['gene']} {x['change']}"
    if 'Oncogenic Mutations' in x['alterations']:
        if str(x['change']) != 'nan':
            return f"{x['gene']} {x['change']}"
        else:
            return x['gene']
    if ' Fusion' in x['alterations']:
        return x['alterations']
    else:
        return x['gene'] + ' ' + x['alterations']
formatted_df['biomarker'] = oncokb_df.apply(lambda x: format_biomarker(x), axis=1)
formatted_df['therapy'] = oncokb_df['drugs']
formatted_df['statement'] = oncokb_df['description']
formatted_df.to_csv('formatted-data/oncokb_all.csv', index = False)
print(formatted_df.shape)
formatted_df.head()
# Out:
# (625, 7)
#      level                           oncotree  \
# 0  LEVEL_1  B-Lymphoblastic Leukemia/Lymphoma
# 1  LEVEL_1       Myeloproliferative Neoplasms
# 2  LEVEL_1       Myeloproliferative Neoplasms
# 3  LEVEL_1                      Breast Cancer
# 4  LEVEL_1                           Melanoma
#
#                           raw_cancer                standardized_cancer  \
# 0  B-Lymphoblastic Leukemia/Lymphoma  B-Lymphoblastic Leukemia/Lymphoma
# 1       Chronic Myelogenous Leukemia       Chronic Myelogenous Leukemia
# 2       Chronic Myelogenous Leukemia       Chronic Myelogenous Leukemia
# 3                      Breast Cancer                      Breast Cancer
# 4                           Melanoma                           Melanoma
#
#     biomarker                   therapy  \
# 0  ABL1 T315I                 Ponatinib
# 1  ABL1 T315I                 Ponatinib
# 2  ABL1 T315I                 Asciminib
# 3   AKT1 E17K  Capivasertib,Fulvestrant
# 4  BRAF V600E                Dabrafenib
#
#                                            statement
# 0  Ponatinib is a small molecule kinase inhibitor...
# 1  Ponatinib is a small molecule kinase inhibitor...
# 2  Asciminib is a STAMP (Specifically Targeting t...
# 3  Capivasertib is an orally available, ATP-compe...
# 4  Dabrafenib is an orally bioavailable RAF inhib...
